# %%
here::i_am("snakemake/01_create_arrow.R")
source(here::here("settings.R"))

# I/O
io$output.directory <- file.path(io$basedir,"ArchR_test6")
dir.create(file.path(io$output.directory), showWarnings = FALSE)

setwd(io$output.directory)
# Out:
# here() starts at /rds/project/rds-SDzz0CATGms/users/bt392/04_Rabbit_ATAC_final
#
# Setting default number of Parallel threads to 1.

# %%
args = list()
args$sample = 'BGRGP1'
args$min_fragments = 100
args$min_tss_score = 2

# %%
#genomeAnnotation = readRDS(file.path(io$basedir, 'genomeAnnotation.rds'))
geneAnnotation = readRDS(file.path(io$basedir, 'geneAnnotation_new.rds'))

library(BSgenome.Ocuniculus.NCBI.oryCun2)
genomeAnnotation = createGenomeAnnotation(
  genome = BSgenome.Ocuniculus.NCBI.oryCun2,
  chromSizes = NULL,
  blacklist = NULL,
  filter = FALSE,
  filterChr = c("chrM")
)
genomeAnnotation$chromSizes = genomeAnnotation$chromSizes[100:500]
geneAnnotation$genes = geneAnnotation$genes[as.vector(seqnames(geneAnnotation$genes)) %in% genomeAnnotation$chromSizes@seqnames@values]
geneAnnotation$exons = geneAnnotation$exons[as.vector(seqnames(geneAnnotation$exons)) %in% genomeAnnotation$chromSizes@seqnames@values]
geneAnnotation$TSS = geneAnnotation$TSS[as.vector(seqnames(geneAnnotation$TSS)) %in% genomeAnnotation$chromSizes@seqnames@values]
# Out:
# Getting genome..
#
# Getting chromSizes..
#
# Getting blacklist..
#
# Blacklist not downloaded! Continuing without, be careful for downstream biases..

# %%
# trim 2kb ends of geneAnnotation, otherwise gives error: 

exclude = GRanges(
    seqnames = Rle(rep(genomeAnnotation$chromSizes@seqnames@values,2)),
    ranges = IRanges(start = c(genomeAnnotation$chromSizes@ranges@start, 
                               genomeAnnotation$chromSizes@ranges@width-2000), 
                     end = c(genomeAnnotation$chromSizes@ranges@start + 2000, 
                             genomeAnnotation$chromSizes@ranges@width)))

exclude_ranges = as.data.frame(findOverlaps(exclude, geneAnnotation$TSS))
if(nrow(exclude_ranges)){
geneAnnotation$TSS = geneAnnotation$TSS[-exclude_ranges$subjectHits]
}

exclude_ranges = as.data.frame(findOverlaps(exclude, geneAnnotation$genes))
if(nrow(exclude_ranges)){
geneAnnotation$genes = geneAnnotation$genes[-exclude_ranges$subjectHits]
}
exclude_ranges = as.data.frame(findOverlaps(exclude, geneAnnotation$exons))
if(nrow(exclude_ranges)){
geneAnnotation$exons = geneAnnotation$exons[-exclude_ranges$subjectHits]
}

# %%
fragment_file_path = paste0(io$basedir, '/data/', args$sample, '_fragments.tsv.gz')

#Create Arrow File
ArrowFiles <- createArrowFiles(
  inputFiles = fragment_file_path,
  sampleNames = paste0('rabbit_', args$sample),
    
  minTSS = args$min_tss_score, #Dont set this too high because you can always increase later
  minFrags = args$min_fragments , 
    
  addTileMat = TRUE,
  addGeneScoreMat = TRUE,
    
  geneAnnotation = geneAnnotation,
  genomeAnnotation = genomeAnnotation, 
    force= TRUE
)
# Out:
# ArchR logging to : ArchRLogs/ArchR-createArrows-485763658781-Date-2022-01-28_Time-16-29-16.log
# If there is an issue, please report to github with logFile!
#
# Cleaning Temporary Files
#
# 2022-01-28 16:29:21 : Batch Execution w/ safelapply!, 0 mins elapsed.
#
# (rabbit_BGRGP1 : 1 of 1) Checking if completed file exists!
#
# 2022-01-28 16:29:21 : (rabbit_BGRGP1 : 1 of 1) Arrow Exists! Overriding since force = TRUE!, 0 mins elapsed.
#
# (rabbit_BGRGP1 : 1 of 1) Determining Arrow Method to use!
#
# 2022-01-28 16:29:21 : (rabbit_BGRGP1 : 1 of 1) Reading In Fragments from inputFiles (readMethod = tabix), 0.001 mins elapsed.
#
# 2022-01-28 16:29:21 : (rabbit_BGRGP1 : 1 of 1) Tabix Bed To Temporary File, 0.001 mins elapsed.
#
# Warning message in sprintf("%s Reading TabixFile %s Percent", prefix, round(100 * :
# “one argument not used by format '%s Reading TabixFile %s Percent'”
# 2022-01-28 16:29:32 : (rabbit_BGRGP1 : 1 of 1) Reading TabixFile 0 Percent, 0.181 mins elapsed.
#
# Warning message in sprintf("%s Reading TabixFile %s Percent", prefix, round(100 * :
# “one argument not used by format '%s Reading TabixFile %s Percent'”
# 2022-01-28 16:29:41 : (rabbit_BGRGP1 : 1 of 1) Reading TabixFile 1 Percent, 0.334 mins elapsed.
#
# Warning message in sprintf("%s Reading TabixFile %s Percent", prefix, round(100 * :
# “one argument not used by format '%s Reading TabixFile %s Percent'”
# 2022-01-28 16:29:50 : (rabbit_BGRGP1 : 1 of 1) Reading TabixFile 1 Percent, 0.485 mins elapsed.
#
# Warning message in sprintf("%s Reading TabixFile %s Percent", prefix, round(100 * :
# “one argument not used by format '%s Reading TabixFile %s Percent'”
# 2022-01-28 16:29:59 : (rabbit_BGRGP1 : 1 of 1) Reading TabixFile 2 Percent, 0.627 mins elapsed.
#
# Warning message in sprintf("%s Reading TabixFile %s Percent", prefix, round(100 * :
# “one argument not used by format '%s Reading TabixFile %s Percent'”
# 2022-01-28 16:30:07 : (rabbit_BGRGP1 : 1 of 1) Reading TabixFile 2 Percent, 0.769 mins elapsed.
#
# Warning message in sprintf("%s Reading TabixFile %s Percent", prefix, round(100 * :
# “one argument not used by format '%s Reading TabixFile %s Percent'”
# 2022-01-28 16:30:17 : (rabbit_BGRGP1 : 1 of 1) Reading TabixFile 3 Percent, 0.927 mins elapsed.
#
# Warning message in sprintf("%s Reading TabixFile %s Percent", prefix, round(100 * :
# “one argument not used by format '%s Reading TabixFile %s Percent'”
# 2022-01-28 16:30:26 : (rabbit_BGRGP1 : 1 of 1) Reading TabixFile 3 Percent, 1.082 mins elapsed.
#
# Warning message in sprintf("%s Reading TabixFile %s Percent", prefix, round(100 * :
# “one argument not used by format '%s Reading TabixFile %s Percent'”
# 2022-01-28 16:30:35 : (rabbit_BGRGP1 : 1 of 1) Reading TabixFile 4 Percent, 1.238 mins elapsed.
#
# Warning message in sprintf("%s Reading TabixFile %s Percent", prefix, round(100 * :
# “one argument not used by format '%s Reading TabixFile %s Percent'”
# 2022-01-28 16:30:44 : (rabbit_BGRGP1 : 1 of 1) Reading TabixFile 4 Percent, 1.383 mins elapsed.
#
# Warning message in sprintf("%s Reading TabixFile %s Percent", prefix, round(100 * :
# “one argument not used by format '%s Reading TabixFile %s Percent'”
# 2022-01-28 16:30:53 : (rabbit_BGRGP1 : 1 of 1) Reading TabixFile 5 Percent, 1.535 mins elapsed.
#
# Warning message in sprintf("%s Reading TabixFile %s Percent", prefix, round(100 * :
# “one argument not used by format '%s Reading TabixFile %s Percent'”
# 2022-01-28 16:31:02 : (rabbit_BGRGP1 : 1 of 1) Reading TabixFile 5 Percent, 1.691 mins elapsed.
#
# Warning message in sprintf("%s Reading TabixFile %s Percent", prefix, round(100 * :
# “one argument not used by format '%s Reading TabixFile %s Percent'”
# 2022-01-28 16:31:12 : (rabbit_BGRGP1 : 1 of 1) Reading TabixFile 6 Percent, 1.85 mins elapsed.
#
# Warning message in sprintf("%s Reading TabixFile %s Percent", prefix, round(100 * :
# “one argument not used by format '%s Reading TabixFile %s Percent'”
# 2022-01-28 16:31:21 : (rabbit_BGRGP1 : 1 of 1) Reading TabixFile 6 Percent, 2.004 mins elapsed.
#
# Warning message in sprintf("%s Reading TabixFile %s Percent", prefix, round(100 * :
# “one argument not used by format '%s Reading TabixFile %s Percent'”
# 2022-01-28 16:31:31 : (rabbit_BGRGP1 : 1 of 1) Reading TabixFile 7 Percent, 2.168 mins elapsed.
#
# Warning message in sprintf("%s Reading TabixFile %s Percent", prefix, round(100 * :
# “one argument not used by format '%s Reading TabixFile %s Percent'”
# 2022-01-28 16:31:40 : (rabbit_BGRGP1 : 1 of 1) Reading TabixFile 7 Percent, 2.313 mins elapsed.
#
# Warning message in sprintf("%s Reading TabixFile %s Percent", prefix, round(100 * :
# “one argument not used by format '%s Reading TabixFile %s Percent'”
# 2022-01-28 16:31:48 : (rabbit_BGRGP1 : 1 of 1) Reading TabixFile 8 Percent, 2.454 mins elapsed.
#
# Warning message in sprintf("%s Reading TabixFile %s Percent", prefix, round(100 * :
# “one argument not used by format '%s Reading TabixFile %s Percent'”
# 2022-01-28 16:31:57 : (rabbit_BGRGP1 : 1 of 1) Reading TabixFile 8 Percent, 2.593 mins elapsed.
#
# Warning message in sprintf("%s Reading TabixFile %s Percent", prefix, round(100 * :
# “one argument not used by format '%s Reading TabixFile %s Percent'”
# 2022-01-28 16:32:05 : (rabbit_BGRGP1 : 1 of 1) Reading TabixFile 9 Percent, 2.739 mins elapsed.
#
# Warning message in sprintf("%s Reading TabixFile %s Percent", prefix, round(100 * :
# “one argument not used by format '%s Reading TabixFile %s Percent'”
# 2022-01-28 16:32:14 : (rabbit_BGRGP1 : 1 of 1) Reading TabixFile 9 Percent, 2.88 mins elapsed.
#
# Warning message in sprintf("%s Reading TabixFile %s Percent", prefix, round(100 * :
# “one argument not used by format '%s Reading TabixFile %s Percent'”
# 2022-01-28 16:32:22 : (rabbit_BGRGP1 : 1 of 1) Reading TabixFile 10 Percent, 3.017 mins elapsed.
#
# Warning message in sprintf("%s Reading TabixFile %s Percent", prefix, round(100 * :
# “one argument not used by format '%s Reading TabixFile %s Percent'”
# 2022-01-28 16:32:31 : (rabbit_BGRGP1 : 1 of 1) Reading TabixFile 10 Percent, 3.169 mins elapsed.
#
# Warning message in sprintf("%s Reading TabixFile %s Percent", prefix, round(100 * :
# “one argument not used by format '%s Reading TabixFile %s Percent'”
# 2022-01-28 16:32:39 : (rabbit_BGRGP1 : 1 of 1) Reading TabixFile 11 Percent, 3.307 mins elapsed.
#
# Warning message in sprintf("%s Reading TabixFile %s Percent", prefix, round(100 * :
# “one argument not used by format '%s Reading TabixFile %s Percent'”
# 2022-01-28 16:32:48 : (rabbit_BGRGP1 : 1 of 1) Reading TabixFile 11 Percent, 3.45 mins elapsed.
#
# Warning message in sprintf("%s Reading TabixFile %s Percent", prefix, round(100 * :
# “one argument not used by format '%s Reading TabixFile %s Percent'”
# 2022-01-28 16:32:57 : (rabbit_BGRGP1 : 1 of 1) Reading TabixFile 12 Percent, 3.605 mins elapsed.
#
# Warning message in sprintf("%s Reading TabixFile %s Percent", prefix, round(100 * :
# “one argument not used by format '%s Reading TabixFile %s Percent'”
# 2022-01-28 16:33:06 : (rabbit_BGRGP1 : 1 of 1) Reading TabixFile 12 Percent, 3.751 mins elapsed.
#
# Warning message in sprintf("%s Reading TabixFile %s Percent", prefix, round(100 * :
# “one argument not used by format '%s Reading TabixFile %s Percent'”
# 2022-01-28 16:33:15 : (rabbit_BGRGP1 : 1 of 1) Reading TabixFile 13 Percent, 3.893 mins elapsed.
#
# Warning message in sprintf("%s Reading TabixFile %s Percent", prefix, round(100 * :
# “one argument not used by format '%s Reading TabixFile %s Percent'”
# 2022-01-28 16:33:24 : (rabbit_BGRGP1 : 1 of 1) Reading TabixFile 13 Percent, 4.047 mins elapsed.
#
# Warning message in sprintf("%s Reading TabixFile %s Percent", prefix, round(100 * :
# “one argument not used by format '%s Reading TabixFile %s Percent'”
# 2022-01-28 16:33:32 : (rabbit_BGRGP1 : 1 of 1) Reading TabixFile 14 Percent, 4.187 mins elapsed.
#
# Warning message in sprintf("%s Reading TabixFile %s Percent", prefix, round(100 * :
# “one argument not used by format '%s Reading TabixFile %s Percent'”
# 2022-01-28 16:33:41 : (rabbit_BGRGP1 : 1 of 1) Reading TabixFile 14 Percent, 4.334 mins elapsed.
#
# Warning message in sprintf("%s Reading TabixFile %s Percent", prefix, round(100 * :
# “one argument not used by format '%s Reading TabixFile %s Percent'”
# 2022-01-28 16:33:50 : (rabbit_BGRGP1 : 1 of 1) Reading TabixFile 15 Percent, 4.489 mins elapsed.
#
# Warning message in sprintf("%s Reading TabixFile %s Percent", prefix, round(100 * :
# “one argument not used by format '%s Reading TabixFile %s Percent'”
# 2022-01-28 16:33:59 : (rabbit_BGRGP1 : 1 of 1) Reading TabixFile 15 Percent, 4.639 mins elapsed.
#
# Warning message in sprintf("%s Reading TabixFile %s Percent", prefix, round(100 * :
# “one argument not used by format '%s Reading TabixFile %s Percent'”
# 2022-01-28 16:34:05 : (rabbit_BGRGP1 : 1 of 1) Reading TabixFile 16 Percent, 4.728 mins elapsed.
#
# Warning message in sprintf("%s Reading TabixFile %s Percent", prefix, round(100 * :
# “one argument not used by format '%s Reading TabixFile %s Percent'”
# 2022-01-28 16:34:12 : (rabbit_BGRGP1 : 1 of 1) Reading TabixFile 16 Percent, 4.853 mins elapsed.
#
# Warning message in sprintf("%s Reading TabixFile %s Percent", prefix, round(100 * :
# “one argument not used by format '%s Reading TabixFile %s Percent'”
# 2022-01-28 16:34:21 : (rabbit_BGRGP1 : 1 of 1) Reading TabixFile 17 Percent, 4.999 mins elapsed.
#
# Warning message in sprintf("%s Reading TabixFile %s Percent", prefix, round(100 * :
# “one argument not used by format '%s Reading TabixFile %s Percent'”
# 2022-01-28 16:34:30 : (rabbit_BGRGP1 : 1 of 1) Reading TabixFile 17 Percent, 5.144 mins elapsed.
#
# Warning message in sprintf("%s Reading TabixFile %s Percent", prefix, round(100 * :
# “one argument not used by format '%s Reading TabixFile %s Percent'”
# 2022-01-28 16:34:39 : (rabbit_BGRGP1 : 1 of 1) Reading TabixFile 18 Percent, 5.292 mins elapsed.
#
# Warning message in sprintf("%s Reading TabixFile %s Percent", prefix, round(100 * :
# “one argument not used by format '%s Reading TabixFile %s Percent'”
# 2022-01-28 16:34:47 : (rabbit_BGRGP1 : 1 of 1) Reading TabixFile 18 Percent, 5.431 mins elapsed.
#
# Warning message in sprintf("%s Reading TabixFile %s Percent", prefix, round(100 * :
# “one argument not used by format '%s Reading TabixFile %s Percent'”
# 2022-01-28 16:34:55 : (rabbit_BGRGP1 : 1 of 1) Reading TabixFile 19 Percent, 5.572 mins elapsed.
#
# Warning message in sprintf("%s Reading TabixFile %s Percent", prefix, round(100 * :
# “one argument not used by format '%s Reading TabixFile %s Percent'”
# 2022-01-28 16:35:04 : (rabbit_BGRGP1 : 1 of 1) Reading TabixFile 19 Percent, 5.713 mins elapsed.
#
# Warning message in sprintf("%s Reading TabixFile %s Percent", prefix, round(100 * :
# “one argument not used by format '%s Reading TabixFile %s Percent'”
# 2022-01-28 16:35:12 : (rabbit_BGRGP1 : 1 of 1) Reading TabixFile 20 Percent, 5.85 mins elapsed.
#
# Warning message in sprintf("%s Reading TabixFile %s Percent", prefix, round(100 * :
# “one argument not used by format '%s Reading TabixFile %s Percent'”
# 2022-01-28 16:35:20 : (rabbit_BGRGP1 : 1 of 1) Reading TabixFile 20 Percent, 5.981 mins elapsed.
#
# Warning message in sprintf("%s Reading TabixFile %s Percent", prefix, round(100 * :
# “one argument not used by format '%s Reading TabixFile %s Percent'”
# 2022-01-28 16:35:28 : (rabbit_BGRGP1 : 1 of 1) Reading TabixFile 21 Percent, 6.116 mins elapsed.
#
# Warning message in sprintf("%s Reading TabixFile %s Percent", prefix, round(100 * :
# “one argument not used by format '%s Reading TabixFile %s Percent'”
# 2022-01-28 16:35:32 : (rabbit_BGRGP1 : 1 of 1) Reading TabixFile 21 Percent, 6.189 mins elapsed.
#
# Warning message in sprintf("%s Reading TabixFile %s Percent", prefix, round(100 * :
# “one argument not used by format '%s Reading TabixFile %s Percent'”
# 2022-01-28 16:35:37 : (rabbit_BGRGP1 : 1 of 1) Reading TabixFile 22 Percent, 6.269 mins elapsed.
#
# Warning message in sprintf("%s Reading TabixFile %s Percent", prefix, round(100 * :
# “one argument not used by format '%s Reading TabixFile %s Percent'”
# 2022-01-28 16:35:44 : (rabbit_BGRGP1 : 1 of 1) Reading TabixFile 22 Percent, 6.391 mins elapsed.
#
# Warning message in sprintf("%s Reading TabixFile %s Percent", prefix, round(100 * :
# “one argument not used by format '%s Reading TabixFile %s Percent'”
# 2022-01-28 16:35:53 : (rabbit_BGRGP1 : 1 of 1) Reading TabixFile 23 Percent, 6.533 mins elapsed.
#
# Warning message in sprintf("%s Reading TabixFile %s Percent", prefix, round(100 * :
# “one argument not used by format '%s Reading TabixFile %s Percent'”
# 2022-01-28 16:36:01 : (rabbit_BGRGP1 : 1 of 1) Reading TabixFile 23 Percent, 6.667 mins elapsed.
#
# Warning message in sprintf("%s Reading TabixFile %s Percent", prefix, round(100 * :
# “one argument not used by format '%s Reading TabixFile %s Percent'”
# 2022-01-28 16:36:09 : (rabbit_BGRGP1 : 1 of 1) Reading TabixFile 24 Percent, 6.801 mins elapsed.
#
# Warning message in sprintf("%s Reading TabixFile %s Percent", prefix, round(100 * :
# “one argument not used by format '%s Reading TabixFile %s Percent'”
# 2022-01-28 16:36:17 : (rabbit_BGRGP1 : 1 of 1) Reading TabixFile 24 Percent, 6.939 mins elapsed.
#
# Warning message in sprintf("%s Reading TabixFile %s Percent", prefix, round(100 * :
# “one argument not used by format '%s Reading TabixFile %s Percent'”
# 2022-01-28 16:36:25 : (rabbit_BGRGP1 : 1 of 1) Reading TabixFile 25 Percent, 7.074 mins elapsed.
#
# Warning message in sprintf("%s Reading TabixFile %s Percent", prefix, round(100 * :
# “one argument not used by format '%s Reading TabixFile %s Percent'”
# 2022-01-28 16:36:33 : (rabbit_BGRGP1 : 1 of 1) Reading TabixFile 25 Percent, 7.203 mins elapsed.
#
# Warning message in sprintf("%s Reading TabixFile %s Percent", prefix, round(100 * :
# “one argument not used by format '%s Reading TabixFile %s Percent'”
# 2022-01-28 16:36:41 : (rabbit_BGRGP1 : 1 of 1) Reading TabixFile 26 Percent, 7.337 mins elapsed.
#
# Warning message in sprintf("%s Reading TabixFile %s Percent", prefix, round(100 * :
# “one argument not used by format '%s Reading TabixFile %s Percent'”
# 2022-01-28 16:36:49 : (rabbit_BGRGP1 : 1 of 1) Reading TabixFile 26 Percent, 7.469 mins elapsed.
#
# Warning message in sprintf("%s Reading TabixFile %s Percent", prefix, round(100 * :
# “one argument not used by format '%s Reading TabixFile %s Percent'”
# 2022-01-28 16:36:57 : (rabbit_BGRGP1 : 1 of 1) Reading TabixFile 27 Percent, 7.602 mins elapsed.
#
# Warning message in sprintf("%s Reading TabixFile %s Percent", prefix, round(100 * :
# “one argument not used by format '%s Reading TabixFile %s Percent'”
# 2022-01-28 16:37:05 : (rabbit_BGRGP1 : 1 of 1) Reading TabixFile 27 Percent, 7.734 mins elapsed.
#
# Warning message in sprintf("%s Reading TabixFile %s Percent", prefix, round(100 * :
# “one argument not used by format '%s Reading TabixFile %s Percent'”
# 2022-01-28 16:37:13 : (rabbit_BGRGP1 : 1 of 1) Reading TabixFile 28 Percent, 7.859 mins elapsed.
#
# Warning message in sprintf("%s Reading TabixFile %s Percent", prefix, round(100 * :
# “one argument not used by format '%s Reading TabixFile %s Percent'”
# 2022-01-28 16:37:20 : (rabbit_BGRGP1 : 1 of 1) Reading TabixFile 28 Percent, 7.985 mins elapsed.
#
# Warning message in sprintf("%s Reading TabixFile %s Percent", prefix, round(100 * :
# “one argument not used by format '%s Reading TabixFile %s Percent'”
# 2022-01-28 16:37:28 : (rabbit_BGRGP1 : 1 of 1) Reading TabixFile 29 Percent, 8.117 mins elapsed.
#
# Warning message in sprintf("%s Reading TabixFile %s Percent", prefix, round(100 * :
# “one argument not used by format '%s Reading TabixFile %s Percent'”
# 2022-01-28 16:37:36 : (rabbit_BGRGP1 : 1 of 1) Reading TabixFile 29 Percent, 8.247 mins elapsed.
#
# Warning message in sprintf("%s Reading TabixFile %s Percent", prefix, round(100 * :
# “one argument not used by format '%s Reading TabixFile %s Percent'”
# 2022-01-28 16:37:40 : (rabbit_BGRGP1 : 1 of 1) Reading TabixFile 30 Percent, 8.318 mins elapsed.
#
# Warning message in sprintf("%s Reading TabixFile %s Percent", prefix, round(100 * :
# “one argument not used by format '%s Reading TabixFile %s Percent'”
# 2022-01-28 16:37:45 : (rabbit_BGRGP1 : 1 of 1) Reading TabixFile 30 Percent, 8.393 mins elapsed.
#
# Warning message in sprintf("%s Reading TabixFile %s Percent", prefix, round(100 * :
# “one argument not used by format '%s Reading TabixFile %s Percent'”
# 2022-01-28 16:37:53 : (rabbit_BGRGP1 : 1 of 1) Reading TabixFile 31 Percent, 8.526 mins elapsed.
#
# Warning message in sprintf("%s Reading TabixFile %s Percent", prefix, round(100 * :
# “one argument not used by format '%s Reading TabixFile %s Percent'”
# 2022-01-28 16:38:00 : (rabbit_BGRGP1 : 1 of 1) Reading TabixFile 31 Percent, 8.653 mins elapsed.
#
# Warning message in sprintf("%s Reading TabixFile %s Percent", prefix, round(100 * :
# “one argument not used by format '%s Reading TabixFile %s Percent'”
# 2022-01-28 16:38:08 : (rabbit_BGRGP1 : 1 of 1) Reading TabixFile 32 Percent, 8.782 mins elapsed.
#
# Warning message in sprintf("%s Reading TabixFile %s Percent", prefix, round(100 * :
# “one argument not used by format '%s Reading TabixFile %s Percent'”
# 2022-01-28 16:38:16 : (rabbit_BGRGP1 : 1 of 1) Reading TabixFile 32 Percent, 8.918 mins elapsed.
#
# Warning message in sprintf("%s Reading TabixFile %s Percent", prefix, round(100 * :
# “one argument not used by format '%s Reading TabixFile %s Percent'”
# 2022-01-28 16:38:24 : (rabbit_BGRGP1 : 1 of 1) Reading TabixFile 33 Percent, 9.051 mins elapsed.
#
# Warning message in sprintf("%s Reading TabixFile %s Percent", prefix, round(100 * :
# “one argument not used by format '%s Reading TabixFile %s Percent'”
# 2022-01-28 16:38:32 : (rabbit_BGRGP1 : 1 of 1) Reading TabixFile 33 Percent, 9.186 mins elapsed.
#
# Warning message in sprintf("%s Reading TabixFile %s Percent", prefix, round(100 * :
# “one argument not used by format '%s Reading TabixFile %s Percent'”
# 2022-01-28 16:38:40 : (rabbit_BGRGP1 : 1 of 1) Reading TabixFile 34 Percent, 9.32 mins elapsed.
#
# Warning message in sprintf("%s Reading TabixFile %s Percent", prefix, round(100 * :
# “one argument not used by format '%s Reading TabixFile %s Percent'”
# 2022-01-28 16:38:48 : (rabbit_BGRGP1 : 1 of 1) Reading TabixFile 34 Percent, 9.456 mins elapsed.
#
# Warning message in sprintf("%s Reading TabixFile %s Percent", prefix, round(100 * :
# “one argument not used by format '%s Reading TabixFile %s Percent'”
# 2022-01-28 16:38:57 : (rabbit_BGRGP1 : 1 of 1) Reading TabixFile 35 Percent, 9.599 mins elapsed.
#
# Warning message in sprintf("%s Reading TabixFile %s Percent", prefix, round(100 * :
# “one argument not used by format '%s Reading TabixFile %s Percent'”
# 2022-01-28 16:39:06 : (rabbit_BGRGP1 : 1 of 1) Reading TabixFile 35 Percent, 9.751 mins elapsed.
#
# Warning message in sprintf("%s Reading TabixFile %s Percent", prefix, round(100 * :
# “one argument not used by format '%s Reading TabixFile %s Percent'”
# 2022-01-28 16:39:15 : (rabbit_BGRGP1 : 1 of 1) Reading TabixFile 36 Percent, 9.895 mins elapsed.
#
# Warning message in sprintf("%s Reading TabixFile %s Percent", prefix, round(100 * :
# “one argument not used by format '%s Reading TabixFile %s Percent'”
# 2022-01-28 16:39:23 : (rabbit_BGRGP1 : 1 of 1) Reading TabixFile 36 Percent, 10.033 mins elapsed.
#
# Warning message in sprintf("%s Reading TabixFile %s Percent", prefix, round(100 * :
# “one argument not used by format '%s Reading TabixFile %s Percent'”
# 2022-01-28 16:39:31 : (rabbit_BGRGP1 : 1 of 1) Reading TabixFile 37 Percent, 10.17 mins elapsed.
#
# Warning message in sprintf("%s Reading TabixFile %s Percent", prefix, round(100 * :
# “one argument not used by format '%s Reading TabixFile %s Percent'”
# 2022-01-28 16:39:39 : (rabbit_BGRGP1 : 1 of 1) Reading TabixFile 37 Percent, 10.304 mins elapsed.
#
# Warning message in sprintf("%s Reading TabixFile %s Percent", prefix, round(100 * :
# “one argument not used by format '%s Reading TabixFile %s Percent'”
# 2022-01-28 16:39:47 : (rabbit_BGRGP1 : 1 of 1) Reading TabixFile 38 Percent, 10.433 mins elapsed.
#
# Warning message in sprintf("%s Reading TabixFile %s Percent", prefix, round(100 * :
# “one argument not used by format '%s Reading TabixFile %s Percent'”
# 2022-01-28 16:39:52 : (rabbit_BGRGP1 : 1 of 1) Reading TabixFile 38 Percent, 10.522 mins elapsed.
#
# Warning message in sprintf("%s Reading TabixFile %s Percent", prefix, round(100 * :
# “one argument not used by format '%s Reading TabixFile %s Percent'”
# 2022-01-28 16:40:00 : (rabbit_BGRGP1 : 1 of 1) Reading TabixFile 39 Percent, 10.644 mins elapsed.
#
# Warning message in sprintf("%s Reading TabixFile %s Percent", prefix, round(100 * :
# “one argument not used by format '%s Reading TabixFile %s Percent'”
# 2022-01-28 16:40:04 : (rabbit_BGRGP1 : 1 of 1) Reading TabixFile 39 Percent, 10.718 mins elapsed.
#
# Warning message in sprintf("%s Reading TabixFile %s Percent", prefix, round(100 * :
# “one argument not used by format '%s Reading TabixFile %s Percent'”
# 2022-01-28 16:40:12 : (rabbit_BGRGP1 : 1 of 1) Reading TabixFile 40 Percent, 10.853 mins elapsed.
#
# Warning message in sprintf("%s Reading TabixFile %s Percent", prefix, round(100 * :
# “one argument not used by format '%s Reading TabixFile %s Percent'”
# 2022-01-28 16:40:17 : (rabbit_BGRGP1 : 1 of 1) Reading TabixFile 40 Percent, 10.927 mins elapsed.
#
# Warning message in sprintf("%s Reading TabixFile %s Percent", prefix, round(100 * :
# “one argument not used by format '%s Reading TabixFile %s Percent'”
# 2022-01-28 16:40:24 : (rabbit_BGRGP1 : 1 of 1) Reading TabixFile 41 Percent, 11.056 mins elapsed.
#
# Warning message in sprintf("%s Reading TabixFile %s Percent", prefix, round(100 * :
# “one argument not used by format '%s Reading TabixFile %s Percent'”
# 2022-01-28 16:40:33 : (rabbit_BGRGP1 : 1 of 1) Reading TabixFile 41 Percent, 11.203 mins elapsed.
#
# Warning message in sprintf("%s Reading TabixFile %s Percent", prefix, round(100 * :
# “one argument not used by format '%s Reading TabixFile %s Percent'”
# 2022-01-28 16:40:39 : (rabbit_BGRGP1 : 1 of 1) Reading TabixFile 42 Percent, 11.3 mins elapsed.
#
# Warning message in sprintf("%s Reading TabixFile %s Percent", prefix, round(100 * :
# “one argument not used by format '%s Reading TabixFile %s Percent'”
# 2022-01-28 16:40:48 : (rabbit_BGRGP1 : 1 of 1) Reading TabixFile 42 Percent, 11.444 mins elapsed.
#
# Warning message in sprintf("%s Reading TabixFile %s Percent", prefix, round(100 * :
# “one argument not used by format '%s Reading TabixFile %s Percent'”
# 2022-01-28 16:40:56 : (rabbit_BGRGP1 : 1 of 1) Reading TabixFile 43 Percent, 11.583 mins elapsed.
#
# Warning message in sprintf("%s Reading TabixFile %s Percent", prefix, round(100 * :
# “one argument not used by format '%s Reading TabixFile %s Percent'”
# 2022-01-28 16:41:04 : (rabbit_BGRGP1 : 1 of 1) Reading TabixFile 43 Percent, 11.722 mins elapsed.
#
# Warning message in sprintf("%s Reading TabixFile %s Percent", prefix, round(100 * :
# “one argument not used by format '%s Reading TabixFile %s Percent'”
# 2022-01-28 16:41:13 : (rabbit_BGRGP1 : 1 of 1) Reading TabixFile 44 Percent, 11.862 mins elapsed.
#
# Warning message in sprintf("%s Reading TabixFile %s Percent", prefix, round(100 * :
# “one argument not used by format '%s Reading TabixFile %s Percent'”
# 2022-01-28 16:41:21 : (rabbit_BGRGP1 : 1 of 1) Reading TabixFile 44 Percent, 11.996 mins elapsed.
#
# Warning message in sprintf("%s Reading TabixFile %s Percent", prefix, round(100 * :
# “one argument not used by format '%s Reading TabixFile %s Percent'”
# 2022-01-28 16:41:32 : (rabbit_BGRGP1 : 1 of 1) Reading TabixFile 45 Percent, 12.177 mins elapsed.
#
# Warning message in sprintf("%s Reading TabixFile %s Percent", prefix, round(100 * :
# “one argument not used by format '%s Reading TabixFile %s Percent'”
# 2022-01-28 16:41:43 : (rabbit_BGRGP1 : 1 of 1) Reading TabixFile 45 Percent, 12.363 mins elapsed.
#
# Warning message in sprintf("%s Reading TabixFile %s Percent", prefix, round(100 * :
# “one argument not used by format '%s Reading TabixFile %s Percent'”
# 2022-01-28 16:41:51 : (rabbit_BGRGP1 : 1 of 1) Reading TabixFile 46 Percent, 12.5 mins elapsed.
#
# Warning message in sprintf("%s Reading TabixFile %s Percent", prefix, round(100 * :
# “one argument not used by format '%s Reading TabixFile %s Percent'”
# 2022-01-28 16:41:56 : (rabbit_BGRGP1 : 1 of 1) Reading TabixFile 46 Percent, 12.583 mins elapsed.
#
# Warning message in sprintf("%s Reading TabixFile %s Percent", prefix, round(100 * :
# “one argument not used by format '%s Reading TabixFile %s Percent'”
# 2022-01-28 16:42:04 : (rabbit_BGRGP1 : 1 of 1) Reading TabixFile 47 Percent, 12.712 mins elapsed.
#
# Warning message in sprintf("%s Reading TabixFile %s Percent", prefix, round(100 * :
# “one argument not used by format '%s Reading TabixFile %s Percent'”
# 2022-01-28 16:42:12 : (rabbit_BGRGP1 : 1 of 1) Reading TabixFile 47 Percent, 12.849 mins elapsed.
#
# Warning message in sprintf("%s Reading TabixFile %s Percent", prefix, round(100 * :
# “one argument not used by format '%s Reading TabixFile %s Percent'”
# 2022-01-28 16:42:20 : (rabbit_BGRGP1 : 1 of 1) Reading TabixFile 48 Percent, 12.989 mins elapsed.
#
# Warning message in sprintf("%s Reading TabixFile %s Percent", prefix, round(100 * :
# “one argument not used by format '%s Reading TabixFile %s Percent'”
# 2022-01-28 16:42:29 : (rabbit_BGRGP1 : 1 of 1) Reading TabixFile 48 Percent, 13.125 mins elapsed.
#
# Warning message in sprintf("%s Reading TabixFile %s Percent", prefix, round(100 * :
# “one argument not used by format '%s Reading TabixFile %s Percent'”
# 2022-01-28 16:42:36 : (rabbit_BGRGP1 : 1 of 1) Reading TabixFile 49 Percent, 13.256 mins elapsed.
#
# Warning message in sprintf("%s Reading TabixFile %s Percent", prefix, round(100 * :
# “one argument not used by format '%s Reading TabixFile %s Percent'”
# 2022-01-28 16:42:45 : (rabbit_BGRGP1 : 1 of 1) Reading TabixFile 49 Percent, 13.395 mins elapsed.
#
# Warning message in sprintf("%s Reading TabixFile %s Percent", prefix, round(100 * :
# “one argument not used by format '%s Reading TabixFile %s Percent'”
# 2022-01-28 16:42:50 : (rabbit_BGRGP1 : 1 of 1) Reading TabixFile 50 Percent, 13.48 mins elapsed.
#
# Warning message in sprintf("%s Reading TabixFile %s Percent", prefix, round(100 * :
# “one argument not used by format '%s Reading TabixFile %s Percent'”
# 2022-01-28 16:42:54 : (rabbit_BGRGP1 : 1 of 1) Reading TabixFile 50 Percent, 13.549 mins elapsed.
#
# Warning message in sprintf("%s Reading TabixFile %s Percent", prefix, round(100 * :
# “one argument not used by format '%s Reading TabixFile %s Percent'”
# 2022-01-28 16:43:01 : (rabbit_BGRGP1 : 1 of 1) Reading TabixFile 51 Percent, 13.666 mins elapsed.
#
# Warning message in sprintf("%s Reading TabixFile %s Percent", prefix, round(100 * :
# “one argument not used by format '%s Reading TabixFile %s Percent'”
# 2022-01-28 16:43:09 : (rabbit_BGRGP1 : 1 of 1) Reading TabixFile 51 Percent, 13.797 mins elapsed.
#
# Warning message in sprintf("%s Reading TabixFile %s Percent", prefix, round(100 * :
# “one argument not used by format '%s Reading TabixFile %s Percent'”
# 2022-01-28 16:43:17 : (rabbit_BGRGP1 : 1 of 1) Reading TabixFile 52 Percent, 13.927 mins elapsed.
#
# Warning message in sprintf("%s Reading TabixFile %s Percent", prefix, round(100 * :
# “one argument not used by format '%s Reading TabixFile %s Percent'”
# 2022-01-28 16:43:25 : (rabbit_BGRGP1 : 1 of 1) Reading TabixFile 52 Percent, 14.06 mins elapsed.
#
# Warning message in sprintf("%s Reading TabixFile %s Percent", prefix, round(100 * :
# “one argument not used by format '%s Reading TabixFile %s Percent'”
# 2022-01-28 16:43:33 : (rabbit_BGRGP1 : 1 of 1) Reading TabixFile 53 Percent, 14.192 mins elapsed.
#
# Warning message in sprintf("%s Reading TabixFile %s Percent", prefix, round(100 * :
# “one argument not used by format '%s Reading TabixFile %s Percent'”
# 2022-01-28 16:43:37 : (rabbit_BGRGP1 : 1 of 1) Reading TabixFile 53 Percent, 14.269 mins elapsed.
#
# Warning message in sprintf("%s Reading TabixFile %s Percent", prefix, round(100 * :
# “one argument not used by format '%s Reading TabixFile %s Percent'”
# 2022-01-28 16:43:42 : (rabbit_BGRGP1 : 1 of 1) Reading TabixFile 54 Percent, 14.356 mins elapsed.
#
# Warning message in sprintf("%s Reading TabixFile %s Percent", prefix, round(100 * :
# “one argument not used by format '%s Reading TabixFile %s Percent'”
# 2022-01-28 16:43:51 : (rabbit_BGRGP1 : 1 of 1) Reading TabixFile 54 Percent, 14.497 mins elapsed.
#
# Warning message in sprintf("%s Reading TabixFile %s Percent", prefix, round(100 * :
# “one argument not used by format '%s Reading TabixFile %s Percent'”
# 2022-01-28 16:43:59 : (rabbit_BGRGP1 : 1 of 1) Reading TabixFile 55 Percent, 14.64 mins elapsed.
#
# Warning message in sprintf("%s Reading TabixFile %s Percent", prefix, round(100 * :
# “one argument not used by format '%s Reading TabixFile %s Percent'”
# 2022-01-28 16:44:07 : (rabbit_BGRGP1 : 1 of 1) Reading TabixFile 55 Percent, 14.771 mins elapsed.
#
# Warning message in sprintf("%s Reading TabixFile %s Percent", prefix, round(100 * :
# “one argument not used by format '%s Reading TabixFile %s Percent'”
# 2022-01-28 16:44:15 : (rabbit_BGRGP1 : 1 of 1) Reading TabixFile 56 Percent, 14.906 mins elapsed.
#
# Warning message in sprintf("%s Reading TabixFile %s Percent", prefix, round(100 * :
# “one argument not used by format '%s Reading TabixFile %s Percent'”
# 2022-01-28 16:44:23 : (rabbit_BGRGP1 : 1 of 1) Reading TabixFile 56 Percent, 15.036 mins elapsed.
#
# Warning message in sprintf("%s Reading TabixFile %s Percent", prefix, round(100 * :
# “one argument not used by format '%s Reading TabixFile %s Percent'”
# 2022-01-28 16:44:28 : (rabbit_BGRGP1 : 1 of 1) Reading TabixFile 57 Percent, 15.109 mins elapsed.
#
# Warning message in sprintf("%s Reading TabixFile %s Percent", prefix, round(100 * :
# “one argument not used by format '%s Reading TabixFile %s Percent'”
# 2022-01-28 16:44:38 : (rabbit_BGRGP1 : 1 of 1) Reading TabixFile 57 Percent, 15.286 mins elapsed.
#
# Warning message in sprintf("%s Reading TabixFile %s Percent", prefix, round(100 * :
# “one argument not used by format '%s Reading TabixFile %s Percent'”
# 2022-01-28 16:44:43 : (rabbit_BGRGP1 : 1 of 1) Reading TabixFile 58 Percent, 15.365 mins elapsed.
#
# Warning message in sprintf("%s Reading TabixFile %s Percent", prefix, round(100 * :
# “one argument not used by format '%s Reading TabixFile %s Percent'”
# 2022-01-28 16:44:52 : (rabbit_BGRGP1 : 1 of 1) Reading TabixFile 58 Percent, 15.515 mins elapsed.
#
# Warning message in sprintf("%s Reading TabixFile %s Percent", prefix, round(100 * :
# “one argument not used by format '%s Reading TabixFile %s Percent'”
# 2022-01-28 16:45:00 : (rabbit_BGRGP1 : 1 of 1) Reading TabixFile 59 Percent, 15.644 mins elapsed.
#
# Warning message in sprintf("%s Reading TabixFile %s Percent", prefix, round(100 * :
# “one argument not used by format '%s Reading TabixFile %s Percent'”
# 2022-01-28 16:45:08 : (rabbit_BGRGP1 : 1 of 1) Reading TabixFile 59 Percent, 15.785 mins elapsed.
#
# Warning message in sprintf("%s Reading TabixFile %s Percent", prefix, round(100 * :
# “one argument not used by format '%s Reading TabixFile %s Percent'”
# 2022-01-28 16:45:16 : (rabbit_BGRGP1 : 1 of 1) Reading TabixFile 60 Percent, 15.911 mins elapsed.
#
# Warning message in sprintf("%s Reading TabixFile %s Percent", prefix, round(100 * :
# “one argument not used by format '%s Reading TabixFile %s Percent'”
# 2022-01-28 16:45:21 : (rabbit_BGRGP1 : 1 of 1) Reading TabixFile 60 Percent, 16.008 mins elapsed.
#
# Warning message in sprintf("%s Reading TabixFile %s Percent", prefix, round(100 * :
# “one argument not used by format '%s Reading TabixFile %s Percent'”
# 2022-01-28 16:45:32 : (rabbit_BGRGP1 : 1 of 1) Reading TabixFile 61 Percent, 16.177 mins elapsed.
#
# Warning message in sprintf("%s Reading TabixFile %s Percent", prefix, round(100 * :
# “one argument not used by format '%s Reading TabixFile %s Percent'”
# 2022-01-28 16:45:41 : (rabbit_BGRGP1 : 1 of 1) Reading TabixFile 61 Percent, 16.333 mins elapsed.
#
# Warning message in sprintf("%s Reading TabixFile %s Percent", prefix, round(100 * :
# “one argument not used by format '%s Reading TabixFile %s Percent'”
# 2022-01-28 16:45:48 : (rabbit_BGRGP1 : 1 of 1) Reading TabixFile 62 Percent, 16.457 mins elapsed.
#
# Warning message in sprintf("%s Reading TabixFile %s Percent", prefix, round(100 * :
# “one argument not used by format '%s Reading TabixFile %s Percent'”
# 2022-01-28 16:45:57 : (rabbit_BGRGP1 : 1 of 1) Reading TabixFile 62 Percent, 16.601 mins elapsed.
#
# Warning message in sprintf("%s Reading TabixFile %s Percent", prefix, round(100 * :
# “one argument not used by format '%s Reading TabixFile %s Percent'”
# 2022-01-28 16:46:01 : (rabbit_BGRGP1 : 1 of 1) Reading TabixFile 63 Percent, 16.67 mins elapsed.
#
# Warning message in sprintf("%s Reading TabixFile %s Percent", prefix, round(100 * :
# “one argument not used by format '%s Reading TabixFile %s Percent'”
# 2022-01-28 16:46:09 : (rabbit_BGRGP1 : 1 of 1) Reading TabixFile 63 Percent, 16.803 mins elapsed.
#
# Warning message in sprintf("%s Reading TabixFile %s Percent", prefix, round(100 * :
# “one argument not used by format '%s Reading TabixFile %s Percent'”
# 2022-01-28 16:46:18 : (rabbit_BGRGP1 : 1 of 1) Reading TabixFile 64 Percent, 16.951 mins elapsed.
#
# Warning message in sprintf("%s Reading TabixFile %s Percent", prefix, round(100 * :
# “one argument not used by format '%s Reading TabixFile %s Percent'”
# 2022-01-28 16:46:28 : (rabbit_BGRGP1 : 1 of 1) Reading TabixFile 64 Percent, 17.122 mins elapsed.
#
# Warning message in sprintf("%s Reading TabixFile %s Percent", prefix, round(100 * :
# “one argument not used by format '%s Reading TabixFile %s Percent'”
# 2022-01-28 16:46:34 : (rabbit_BGRGP1 : 1 of 1) Reading TabixFile 65 Percent, 17.209 mins elapsed.
#
# Warning message in sprintf("%s Reading TabixFile %s Percent", prefix, round(100 * :
# “one argument not used by format '%s Reading TabixFile %s Percent'”
# 2022-01-28 16:46:34 : (rabbit_BGRGP1 : 1 of 1) Reading TabixFile 65 Percent, 17.22 mins elapsed.
#
# Warning message in sprintf("%s Reading TabixFile %s Percent", prefix, round(100 * :
# “one argument not used by format '%s Reading TabixFile %s Percent'”
# 2022-01-28 16:46:37 : (rabbit_BGRGP1 : 1 of 1) Reading TabixFile 66 Percent, 17.265 mins elapsed.
#
# Warning message in sprintf("%s Reading TabixFile %s Percent", prefix, round(100 * :
# “one argument not used by format '%s Reading TabixFile %s Percent'”
# 2022-01-28 16:46:46 : (rabbit_BGRGP1 : 1 of 1) Reading TabixFile 66 Percent, 17.424 mins elapsed.
#
# Warning message in sprintf("%s Reading TabixFile %s Percent", prefix, round(100 * :
# “one argument not used by format '%s Reading TabixFile %s Percent'”
# 2022-01-28 16:46:48 : (rabbit_BGRGP1 : 1 of 1) Reading TabixFile 67 Percent, 17.447 mins elapsed.
#
# Warning message in sprintf("%s Reading TabixFile %s Percent", prefix, round(100 * :
# “one argument not used by format '%s Reading TabixFile %s Percent'”
# 2022-01-28 16:46:54 : (rabbit_BGRGP1 : 1 of 1) Reading TabixFile 67 Percent, 17.558 mins elapsed.
#
# Warning message in sprintf("%s Reading TabixFile %s Percent", prefix, round(100 * :
# “one argument not used by format '%s Reading TabixFile %s Percent'”
# 2022-01-28 16:47:04 : (rabbit_BGRGP1 : 1 of 1) Reading TabixFile 68 Percent, 17.721 mins elapsed.
#
# Warning message in sprintf("%s Reading TabixFile %s Percent", prefix, round(100 * :
# “one argument not used by format '%s Reading TabixFile %s Percent'”
# 2022-01-28 16:47:13 : (rabbit_BGRGP1 : 1 of 1) Reading TabixFile 68 Percent, 17.871 mins elapsed.
#
# Warning message in sprintf("%s Reading TabixFile %s Percent", prefix, round(100 * :
# “one argument not used by format '%s Reading TabixFile %s Percent'”
# 2022-01-28 16:47:18 : (rabbit_BGRGP1 : 1 of 1) Reading TabixFile 69 Percent, 17.946 mins elapsed.
#
# Warning message in sprintf("%s Reading TabixFile %s Percent", prefix, round(100 * :
# “one argument not used by format '%s Reading TabixFile %s Percent'”
# 2022-01-28 16:47:26 : (rabbit_BGRGP1 : 1 of 1) Reading TabixFile 69 Percent, 18.078 mins elapsed.
#
# Warning message in sprintf("%s Reading TabixFile %s Percent", prefix, round(100 * :
# “one argument not used by format '%s Reading TabixFile %s Percent'”
# 2022-01-28 16:47:34 : (rabbit_BGRGP1 : 1 of 1) Reading TabixFile 70 Percent, 18.214 mins elapsed.
#
# Warning message in sprintf("%s Reading TabixFile %s Percent", prefix, round(100 * :
# “one argument not used by format '%s Reading TabixFile %s Percent'”
# 2022-01-28 16:47:38 : (rabbit_BGRGP1 : 1 of 1) Reading TabixFile 70 Percent, 18.286 mins elapsed.
#
# Warning message in sprintf("%s Reading TabixFile %s Percent", prefix, round(100 * :
# “one argument not used by format '%s Reading TabixFile %s Percent'”
# 2022-01-28 16:47:46 : (rabbit_BGRGP1 : 1 of 1) Reading TabixFile 71 Percent, 18.409 mins elapsed.
#
# Warning message in sprintf("%s Reading TabixFile %s Percent", prefix, round(100 * :
# “one argument not used by format '%s Reading TabixFile %s Percent'”
# 2022-01-28 16:47:53 : (rabbit_BGRGP1 : 1 of 1) Reading TabixFile 71 Percent, 18.529 mins elapsed.
#
# Warning message in sprintf("%s Reading TabixFile %s Percent", prefix, round(100 * :
# “one argument not used by format '%s Reading TabixFile %s Percent'”
# 2022-01-28 16:47:59 : (rabbit_BGRGP1 : 1 of 1) Reading TabixFile 72 Percent, 18.641 mins elapsed.
#
# Warning message in sprintf("%s Reading TabixFile %s Percent", prefix, round(100 * :
# “one argument not used by format '%s Reading TabixFile %s Percent'”
# 2022-01-28 16:48:07 : (rabbit_BGRGP1 : 1 of 1) Reading TabixFile 72 Percent, 18.768 mins elapsed.
#
# Warning message in sprintf("%s Reading TabixFile %s Percent", prefix, round(100 * :
# “one argument not used by format '%s Reading TabixFile %s Percent'”
# 2022-01-28 16:48:15 : (rabbit_BGRGP1 : 1 of 1) Reading TabixFile 73 Percent, 18.902 mins elapsed.
#
# Warning message in sprintf("%s Reading TabixFile %s Percent", prefix, round(100 * :
# “one argument not used by format '%s Reading TabixFile %s Percent'”
# 2022-01-28 16:48:20 : (rabbit_BGRGP1 : 1 of 1) Reading TabixFile 73 Percent, 18.983 mins elapsed.
#
# Warning message in sprintf("%s Reading TabixFile %s Percent", prefix, round(100 * :
# “one argument not used by format '%s Reading TabixFile %s Percent'”
# 2022-01-28 16:48:27 : (rabbit_BGRGP1 : 1 of 1) Reading TabixFile 74 Percent, 19.095 mins elapsed.
#
# Warning message in sprintf("%s Reading TabixFile %s Percent", prefix, round(100 * :
# “one argument not used by format '%s Reading TabixFile %s Percent'”
# 2022-01-28 16:48:35 : (rabbit_BGRGP1 : 1 of 1) Reading TabixFile 74 Percent, 19.239 mins elapsed.
#
# Warning message in sprintf("%s Reading TabixFile %s Percent", prefix, round(100 * :
# “one argument not used by format '%s Reading TabixFile %s Percent'”
# 2022-01-28 16:48:44 : (rabbit_BGRGP1 : 1 of 1) Reading TabixFile 75 Percent, 19.375 mins elapsed.
#
# Warning message in sprintf("%s Reading TabixFile %s Percent", prefix, round(100 * :
# “one argument not used by format '%s Reading TabixFile %s Percent'”
# 2022-01-28 16:48:48 : (rabbit_BGRGP1 : 1 of 1) Reading TabixFile 75 Percent, 19.458 mins elapsed.
#
# Warning message in sprintf("%s Reading TabixFile %s Percent", prefix, round(100 * :
# “one argument not used by format '%s Reading TabixFile %s Percent'”
# 2022-01-28 16:48:55 : (rabbit_BGRGP1 : 1 of 1) Reading TabixFile 76 Percent, 19.573 mins elapsed.
#
# Warning message in sprintf("%s Reading TabixFile %s Percent", prefix, round(100 * :
# “one argument not used by format '%s Reading TabixFile %s Percent'”
# 2022-01-28 16:49:00 : (rabbit_BGRGP1 : 1 of 1) Reading TabixFile 76 Percent, 19.642 mins elapsed.
#
# Warning message in sprintf("%s Reading TabixFile %s Percent", prefix, round(100 * :
# “one argument not used by format '%s Reading TabixFile %s Percent'”
# 2022-01-28 16:49:01 : (rabbit_BGRGP1 : 1 of 1) Reading TabixFile 77 Percent, 19.664 mins elapsed.
#
# Warning message in sprintf("%s Reading TabixFile %s Percent", prefix, round(100 * :
# “one argument not used by format '%s Reading TabixFile %s Percent'”
# 2022-01-28 16:49:07 : (rabbit_BGRGP1 : 1 of 1) Reading TabixFile 77 Percent, 19.76 mins elapsed.
#
# Warning message in sprintf("%s Reading TabixFile %s Percent", prefix, round(100 * :
# “one argument not used by format '%s Reading TabixFile %s Percent'”
# 2022-01-28 16:49:17 : (rabbit_BGRGP1 : 1 of 1) Reading TabixFile 78 Percent, 19.928 mins elapsed.
#
# Warning message in sprintf("%s Reading TabixFile %s Percent", prefix, round(100 * :
# “one argument not used by format '%s Reading TabixFile %s Percent'”
# 2022-01-28 16:49:26 : (rabbit_BGRGP1 : 1 of 1) Reading TabixFile 78 Percent, 20.091 mins elapsed.
#
# Warning message in sprintf("%s Reading TabixFile %s Percent", prefix, round(100 * :
# “one argument not used by format '%s Reading TabixFile %s Percent'”
# 2022-01-28 16:49:37 : (rabbit_BGRGP1 : 1 of 1) Reading TabixFile 79 Percent, 20.273 mins elapsed.
#
# Warning message in sprintf("%s Reading TabixFile %s Percent", prefix, round(100 * :
# “one argument not used by format '%s Reading TabixFile %s Percent'”
# 2022-01-28 16:49:47 : (rabbit_BGRGP1 : 1 of 1) Reading TabixFile 79 Percent, 20.429 mins elapsed.
#
# Warning message in sprintf("%s Reading TabixFile %s Percent", prefix, round(100 * :
# “one argument not used by format '%s Reading TabixFile %s Percent'”
# 2022-01-28 16:49:48 : (rabbit_BGRGP1 : 1 of 1) Reading TabixFile 80 Percent, 20.454 mins elapsed.
#
# Warning message in sprintf("%s Reading TabixFile %s Percent", prefix, round(100 * :
# “one argument not used by format '%s Reading TabixFile %s Percent'”
# 2022-01-28 16:49:53 : (rabbit_BGRGP1 : 1 of 1) Reading TabixFile 80 Percent, 20.527 mins elapsed.
#
# Warning message in sprintf("%s Reading TabixFile %s Percent", prefix, round(100 * :
# “one argument not used by format '%s Reading TabixFile %s Percent'”
# 2022-01-28 16:50:03 : (rabbit_BGRGP1 : 1 of 1) Reading TabixFile 81 Percent, 20.694 mins elapsed.
#
# Warning message in sprintf("%s Reading TabixFile %s Percent", prefix, round(100 * :
# “one argument not used by format '%s Reading TabixFile %s Percent'”
# 2022-01-28 16:50:09 : (rabbit_BGRGP1 : 1 of 1) Reading TabixFile 81 Percent, 20.791 mins elapsed.
#
# Warning message in sprintf("%s Reading TabixFile %s Percent", prefix, round(100 * :
# “one argument not used by format '%s Reading TabixFile %s Percent'”
# 2022-01-28 16:50:15 : (rabbit_BGRGP1 : 1 of 1) Reading TabixFile 82 Percent, 20.905 mins elapsed.
#
# Warning message in sprintf("%s Reading TabixFile %s Percent", prefix, round(100 * :
# “one argument not used by format '%s Reading TabixFile %s Percent'”
# 2022-01-28 16:50:20 : (rabbit_BGRGP1 : 1 of 1) Reading TabixFile 82 Percent, 20.984 mins elapsed.
#
# Warning message in sprintf("%s Reading TabixFile %s Percent", prefix, round(100 * :
# “one argument not used by format '%s Reading TabixFile %s Percent'”
# 2022-01-28 16:50:27 : (rabbit_BGRGP1 : 1 of 1) Reading TabixFile 83 Percent, 21.094 mins elapsed.
#
# Warning message in sprintf("%s Reading TabixFile %s Percent", prefix, round(100 * :
# “one argument not used by format '%s Reading TabixFile %s Percent'”
# 2022-01-28 16:50:34 : (rabbit_BGRGP1 : 1 of 1) Reading TabixFile 83 Percent, 21.213 mins elapsed.
#
# Warning message in sprintf("%s Reading TabixFile %s Percent", prefix, round(100 * :
# “one argument not used by format '%s Reading TabixFile %s Percent'”
# 2022-01-28 16:50:42 : (rabbit_BGRGP1 : 1 of 1) Reading TabixFile 84 Percent, 21.344 mins elapsed.
#
# Warning message in sprintf("%s Reading TabixFile %s Percent", prefix, round(100 * :
# “one argument not used by format '%s Reading TabixFile %s Percent'”
# 2022-01-28 16:50:47 : (rabbit_BGRGP1 : 1 of 1) Reading TabixFile 84 Percent, 21.431 mins elapsed.
#
# Warning message in sprintf("%s Reading TabixFile %s Percent", prefix, round(100 * :
# “one argument not used by format '%s Reading TabixFile %s Percent'”
# 2022-01-28 16:50:51 : (rabbit_BGRGP1 : 1 of 1) Reading TabixFile 85 Percent, 21.493 mins elapsed.
#
# Warning message in sprintf("%s Reading TabixFile %s Percent", prefix, round(100 * :
# “one argument not used by format '%s Reading TabixFile %s Percent'”
# 2022-01-28 16:50:52 : (rabbit_BGRGP1 : 1 of 1) Reading TabixFile 85 Percent, 21.519 mins elapsed.
#
# Warning message in sprintf("%s Reading TabixFile %s Percent", prefix, round(100 * :
# “one argument not used by format '%s Reading TabixFile %s Percent'”
# 2022-01-28 16:50:59 : (rabbit_BGRGP1 : 1 of 1) Reading TabixFile 86 Percent, 21.628 mins elapsed.
#
# Warning message in sprintf("%s Reading TabixFile %s Percent", prefix, round(100 * :
# “one argument not used by format '%s Reading TabixFile %s Percent'”
# 2022-01-28 16:51:07 : (rabbit_BGRGP1 : 1 of 1) Reading TabixFile 86 Percent, 21.758 mins elapsed.
#
# Warning message in sprintf("%s Reading TabixFile %s Percent", prefix, round(100 * :
# “one argument not used by format '%s Reading TabixFile %s Percent'”
# 2022-01-28 16:51:11 : (rabbit_BGRGP1 : 1 of 1) Reading TabixFile 87 Percent, 21.831 mins elapsed.
#
# Warning message in sprintf("%s Reading TabixFile %s Percent", prefix, round(100 * :
# “one argument not used by format '%s Reading TabixFile %s Percent'”
# 2022-01-28 16:51:16 : (rabbit_BGRGP1 : 1 of 1) Reading TabixFile 87 Percent, 21.915 mins elapsed.
#
# Warning message in sprintf("%s Reading TabixFile %s Percent", prefix, round(100 * :
# “one argument not used by format '%s Reading TabixFile %s Percent'”
# 2022-01-28 16:51:22 : (rabbit_BGRGP1 : 1 of 1) Reading TabixFile 88 Percent, 22.022 mins elapsed.
#
# Warning message in sprintf("%s Reading TabixFile %s Percent", prefix, round(100 * :
# “one argument not used by format '%s Reading TabixFile %s Percent'”
# 2022-01-28 16:51:29 : (rabbit_BGRGP1 : 1 of 1) Reading TabixFile 88 Percent, 22.141 mins elapsed.
#
# Warning message in sprintf("%s Reading TabixFile %s Percent", prefix, round(100 * :
# “one argument not used by format '%s Reading TabixFile %s Percent'”
# 2022-01-28 16:51:35 : (rabbit_BGRGP1 : 1 of 1) Reading TabixFile 89 Percent, 22.225 mins elapsed.
#
# Warning message in sprintf("%s Reading TabixFile %s Percent", prefix, round(100 * :
# “one argument not used by format '%s Reading TabixFile %s Percent'”
# 2022-01-28 16:51:39 : (rabbit_BGRGP1 : 1 of 1) Reading TabixFile 89 Percent, 22.296 mins elapsed.
#
# Warning message in sprintf("%s Reading TabixFile %s Percent", prefix, round(100 * :
# “one argument not used by format '%s Reading TabixFile %s Percent'”
# 2022-01-28 16:51:42 : (rabbit_BGRGP1 : 1 of 1) Reading TabixFile 90 Percent, 22.355 mins elapsed.
#
# Warning message in sprintf("%s Reading TabixFile %s Percent", prefix, round(100 * :
# “one argument not used by format '%s Reading TabixFile %s Percent'”
# 2022-01-28 16:51:50 : (rabbit_BGRGP1 : 1 of 1) Reading TabixFile 90 Percent, 22.485 mins elapsed.
#
# Warning message in sprintf("%s Reading TabixFile %s Percent", prefix, round(100 * :
# “one argument not used by format '%s Reading TabixFile %s Percent'”
# 2022-01-28 16:51:58 : (rabbit_BGRGP1 : 1 of 1) Reading TabixFile 91 Percent, 22.613 mins elapsed.
#
# Warning message in sprintf("%s Reading TabixFile %s Percent", prefix, round(100 * :
# “one argument not used by format '%s Reading TabixFile %s Percent'”
# 2022-01-28 16:52:05 : (rabbit_BGRGP1 : 1 of 1) Reading TabixFile 91 Percent, 22.741 mins elapsed.
#
# Warning message in sprintf("%s Reading TabixFile %s Percent", prefix, round(100 * :
# “one argument not used by format '%s Reading TabixFile %s Percent'”
# 2022-01-28 16:52:13 : (rabbit_BGRGP1 : 1 of 1) Reading TabixFile 92 Percent, 22.866 mins elapsed.
#
# Warning message in sprintf("%s Reading TabixFile %s Percent", prefix, round(100 * :
# “one argument not used by format '%s Reading TabixFile %s Percent'”
# 2022-01-28 16:52:21 : (rabbit_BGRGP1 : 1 of 1) Reading TabixFile 92 Percent, 22.992 mins elapsed.
#
# Warning message in sprintf("%s Reading TabixFile %s Percent", prefix, round(100 * :
# “one argument not used by format '%s Reading TabixFile %s Percent'”
# 2022-01-28 16:52:25 : (rabbit_BGRGP1 : 1 of 1) Reading TabixFile 93 Percent, 23.074 mins elapsed.
#
# Warning message in sprintf("%s Reading TabixFile %s Percent", prefix, round(100 * :
# “one argument not used by format '%s Reading TabixFile %s Percent'”
# 2022-01-28 16:52:32 : (rabbit_BGRGP1 : 1 of 1) Reading TabixFile 93 Percent, 23.188 mins elapsed.
#
# Warning message in sprintf("%s Reading TabixFile %s Percent", prefix, round(100 * :
# “one argument not used by format '%s Reading TabixFile %s Percent'”
# 2022-01-28 16:52:40 : (rabbit_BGRGP1 : 1 of 1) Reading TabixFile 94 Percent, 23.317 mins elapsed.
#
# Warning message in sprintf("%s Reading TabixFile %s Percent", prefix, round(100 * :
# “one argument not used by format '%s Reading TabixFile %s Percent'”
# 2022-01-28 16:52:44 : (rabbit_BGRGP1 : 1 of 1) Reading TabixFile 94 Percent, 23.385 mins elapsed.
#
# Warning message in sprintf("%s Reading TabixFile %s Percent", prefix, round(100 * :
# “one argument not used by format '%s Reading TabixFile %s Percent'”
# 2022-01-28 16:52:52 : (rabbit_BGRGP1 : 1 of 1) Reading TabixFile 95 Percent, 23.512 mins elapsed.
#
# Warning message in sprintf("%s Reading TabixFile %s Percent", prefix, round(100 * :
# “one argument not used by format '%s Reading TabixFile %s Percent'”
# 2022-01-28 16:53:00 : (rabbit_BGRGP1 : 1 of 1) Reading TabixFile 95 Percent, 23.646 mins elapsed.
#
# Warning message in sprintf("%s Reading TabixFile %s Percent", prefix, round(100 * :
# “one argument not used by format '%s Reading TabixFile %s Percent'”
# 2022-01-28 16:53:05 : (rabbit_BGRGP1 : 1 of 1) Reading TabixFile 96 Percent, 23.727 mins elapsed.
#
# Warning message in sprintf("%s Reading TabixFile %s Percent", prefix, round(100 * :
# “one argument not used by format '%s Reading TabixFile %s Percent'”
# 2022-01-28 16:53:11 : (rabbit_BGRGP1 : 1 of 1) Reading TabixFile 96 Percent, 23.841 mins elapsed.
#
# Warning message in sprintf("%s Reading TabixFile %s Percent", prefix, round(100 * :
# “one argument not used by format '%s Reading TabixFile %s Percent'”
# 2022-01-28 16:53:19 : (rabbit_BGRGP1 : 1 of 1) Reading TabixFile 97 Percent, 23.967 mins elapsed.
#
# Warning message in sprintf("%s Reading TabixFile %s Percent", prefix, round(100 * :
# “one argument not used by format '%s Reading TabixFile %s Percent'”
# 2022-01-28 16:53:27 : (rabbit_BGRGP1 : 1 of 1) Reading TabixFile 97 Percent, 24.091 mins elapsed.
#
# Warning message in sprintf("%s Reading TabixFile %s Percent", prefix, round(100 * :
# “one argument not used by format '%s Reading TabixFile %s Percent'”
# 2022-01-28 16:53:31 : (rabbit_BGRGP1 : 1 of 1) Reading TabixFile 98 Percent, 24.162 mins elapsed.
#
# Warning message in sprintf("%s Reading TabixFile %s Percent", prefix, round(100 * :
# “one argument not used by format '%s Reading TabixFile %s Percent'”
# 2022-01-28 16:53:35 : (rabbit_BGRGP1 : 1 of 1) Reading TabixFile 98 Percent, 24.241 mins elapsed.
#
# Warning message in sprintf("%s Reading TabixFile %s Percent", prefix, round(100 * :
# “one argument not used by format '%s Reading TabixFile %s Percent'”
# 2022-01-28 16:53:43 : (rabbit_BGRGP1 : 1 of 1) Reading TabixFile 99 Percent, 24.361 mins elapsed.
#
# Warning message in sprintf("%s Reading TabixFile %s Percent", prefix, round(100 * :
# “one argument not used by format '%s Reading TabixFile %s Percent'”
# 2022-01-28 16:53:50 : (rabbit_BGRGP1 : 1 of 1) Reading TabixFile 99 Percent, 24.49 mins elapsed.
#
# Warning message in sprintf("%s Reading TabixFile %s Percent", prefix, round(100 * :
# “one argument not used by format '%s Reading TabixFile %s Percent'”
# 2022-01-28 16:53:58 : (rabbit_BGRGP1 : 1 of 1) Reading TabixFile 100 Percent, 24.617 mins elapsed.
#
# 2022-01-28 16:54:03 : (rabbit_BGRGP1 : 1 of 1) Successful creation of Temporary File, 24.694 mins elapsed.
#
# 2022-01-28 16:54:03 : (rabbit_BGRGP1 : 1 of 1) Creating ArrowFile From Temporary File, 24.694 mins elapsed.
#
# (rabbit_BGRGP1 : 1 of 1) detected 0 Fragments for chrUn0141
#
# (rabbit_BGRGP1 : 1 of 1) detected 0 Fragments for chrUn0162
#
# (rabbit_BGRGP1 : 1 of 1) detected 0 Fragments for chrUn0165
#
# (rabbit_BGRGP1 : 1 of 1) detected 0 Fragments for chrUn0196
#
# (rabbit_BGRGP1 : 1 of 1) detected 0 Fragments for chrUn0198
#
# (rabbit_BGRGP1 : 1 of 1) detected 0 Fragments for chrUn0231
#
# (rabbit_BGRGP1 : 1 of 1) detected 0 Fragments for chrUn0234
#
# (rabbit_BGRGP1 : 1 of 1) detected 0 Fragments for chrUn0238
#
# (rabbit_BGRGP1 : 1 of 1) detected 0 Fragments for chrUn0245
#
# (rabbit_BGRGP1 : 1 of 1) detected 0 Fragments for chrUn0263
#
# (rabbit_BGRGP1 : 1 of 1) detected 0 Fragments for chrUn0277
#
# (rabbit_BGRGP1 : 1 of 1) detected 0 Fragments for chrUn0279
#
# (rabbit_BGRGP1 : 1 of 1) detected 0 Fragments for chrUn0290
#
# (rabbit_BGRGP1 : 1 of 1) detected 0 Fragments for chrUn0293
#
# (rabbit_BGRGP1 : 1 of 1) detected 0 Fragments for chrUn0304
#
# (rabbit_BGRGP1 : 1 of 1) detected 0 Fragments for chrUn0308
#
# (rabbit_BGRGP1 : 1 of 1) detected 0 Fragments for chrUn0319
#
# (rabbit_BGRGP1 : 1 of 1) detected 0 Fragments for chrUn0328
#
# (rabbit_BGRGP1 : 1 of 1) detected 0 Fragments for chrUn0337
#
# (rabbit_BGRGP1 : 1 of 1) detected 0 Fragments for chrUn0338
#
# (rabbit_BGRGP1 : 1 of 1) detected 0 Fragments for chrUn0339
#
# (rabbit_BGRGP1 : 1 of 1) detected 0 Fragments for chrUn0340
#
# (rabbit_BGRGP1 : 1 of 1) detected 0 Fragments for chrUn0344
#
# (rabbit_BGRGP1 : 1 of 1) detected 0 Fragments for chrUn0345
#
# (rabbit_BGRGP1 : 1 of 1) detected 0 Fragments for chrUn0352
#
# (rabbit_BGRGP1 : 1 of 1) detected 0 Fragments for chrUn0358
#
# (rabbit_BGRGP1 : 1 of 1) detected 0 Fragments for chrUn0371
#
# (rabbit_BGRGP1 : 1 of 1) detected 0 Fragments for chrUn0379
#
# (rabbit_BGRGP1 : 1 of 1) detected 0 Fragments for chrUn0382
#
# (rabbit_BGRGP1 : 1 of 1) detected 0 Fragments for chrUn0384
#
# (rabbit_BGRGP1 : 1 of 1) detected 0 Fragments for chrUn0385
#
# (rabbit_BGRGP1 : 1 of 1) detected 0 Fragments for chrUn0387

# %%
# Calculate doublet scores

ArrowFile = paste0(io$output.directory, '/rabbit_', args$sample, '.arrow')

doubScores <- addDoubletScores(
  input = ArrowFiles,
  k = 15, #Refers to how many cells near a "pseudo-doublet" to count.
  knnMethod = "UMAP", #Refers to the embedding to use for nearest neighbor search.
  LSIMethod = 1
)

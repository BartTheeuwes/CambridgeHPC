# %%
here::i_am("01_create_arrow.R")
source(here::here("settings.R"))
source(here::here("load_archr.R"))
# Out:
# here() starts at /rds/project/rds-SDzz0CATGms/users/bt392/04_Rabbit_ATAC_final/rerun/code
#
# Setting default number of Parallel threads to 1.
#
# Setting addArchRVerbose = FALSE
#
# Successfully loaded ArchRProject!
#
#
#                                                    / |
#                                                  /    \
#             .                                  /      |.
#             \\\                              /        |.
#               \\\                          /           `|.
#                 \\\                      /              |.
#                   \                    /                |\
#                   \\#####\           /                  ||
#                 ==###########>      /                   ||
#                  \\##==......\    /                     ||
#             ______ =       =|__ /__                     ||      \\\
#         ,--' ,----`-,__ ___/'  --,-`-===================##========>
#        \               '        ##_______ _____ ,--,__,=##,__   ///
#         ,    __==    ___,-,__,--'#'  ==='      `-'    | ##,-/
#         -,____,---'       \\####\\________________,--\\_##,/
#            ___      .______        ______  __    __  .______
#           /   \     |   _  \      /      ||  |  |  | |   _  \
#          /  ^  \    |  |_)  |    |  ,----'|  |__|  | |  |_)  |
#         /  /_\  \   |      /     |  |     |   __   | |      /
#        /  _____  \  |  |\  \\___ |  `----.|  |  |  | |  |\  \\___.
#       /__/     \__\ | _| `._____| \______||__|  |__| | _| `._____|

# %%
# #### Prepare for mapping ######
# # Add metadata stage column where GD9_ExE = GD9
# ArchRProject@cellColData$cell = rownames(ArchRProject@cellColData)
# cells = rownames(ArchRProject@cellColData)
# stages = data.frame('sample' = c('rabbit_BGRGP1', 'rabbit_BGRGP2', 'rabbit_BGRGP3', 'rabbit_BGRGP4', 'rabbit_BGRGP5', 'rabbit_BGRGP6', 'rabbit_BGRGP7', 'rabbit_BGRGP8'),
#                     'stage_mapping' = c('GD7', 'GD8', 'GD8', 'GD9', 'GD9', 'GD9', 'GD9', 'GD9' ))
# ArchRProject@cellColData = merge(ArchRProject@cellColData, stages, by='sample')

# ArchRProject@cellColData = ArchRProject@cellColData[order(ArchRProject@cellColData$cell, cells),]
# rownames(ArchRProject@cellColData) = ArchRProject@cellColData$cell

# %%
Mapping_matrix('TileMatrix', dims=35, features=55000)
# Out:
# [1] "GD7"
# Dropping ImputeWeights Since You Are Subsetting Cells! ImputeWeights is a cell-x-cell Matrix!
#
# Checking Inputs...
#
# Computing nearest neighbor graph
#
# Computing SNN
# Modularity Optimizer version 1.3.0 by Ludo Waltman and Nees Jan van Eck
#
# Number of nodes: 9954
# Number of edges: 409084
#
# Running Louvain algorithm...
# Maximum modularity in 10 random starts: 0.8000
# Number of communities: 19
# Elapsed time: 1 seconds
# Getting ImputeWeights
#
# Length of unique values greater than palette, interpolating..
#
# Overriding previous entry for predictedGroup_celltype_TileMatrix
# [1] "GD8"
# Dropping ImputeWeights Since You Are Subsetting Cells! ImputeWeights is a cell-x-cell Matrix!
#
# Checking Inputs...
#
# Computing nearest neighbor graph
#
# Computing SNN
# Modularity Optimizer version 1.3.0 by Ludo Waltman and Nees Jan van Eck
#
# Number of nodes: 8965
# Number of edges: 430862
#
# Running Louvain algorithm...
# Maximum modularity in 10 random starts: 0.8581
# Number of communities: 21
# Elapsed time: 0 seconds
# Getting ImputeWeights
#
# Length of unique values greater than palette, interpolating..
#
# Overriding previous entry for predictedGroup_celltype_TileMatrix
# [1] "GD9_ExE"
# Dropping ImputeWeights Since You Are Subsetting Cells! ImputeWeights is a cell-x-cell Matrix!
#
# Checking Inputs...
#
# Computing nearest neighbor graph
#
# Computing SNN
# Modularity Optimizer version 1.3.0 by Ludo Waltman and Nees Jan van Eck
#
# Number of nodes: 1709
# Number of edges: 76568
#
# Running Louvain algorithm...
# Maximum modularity in 10 random starts: 0.7382
# Number of communities: 13
# Elapsed time: 0 seconds
# Getting ImputeWeights
#
# Length of unique values greater than palette, interpolating..
#
# Overriding previous entry for predictedGroup_celltype_TileMatrix
# [1] "GD9"
# Dropping ImputeWeights Since You Are Subsetting Cells! ImputeWeights is a cell-x-cell Matrix!
#
# Checking Inputs...
#
# Computing nearest neighbor graph
#
# Computing SNN
# Modularity Optimizer version 1.3.0 by Ludo Waltman and Nees Jan van Eck
#
# Number of nodes: 16529
# Number of edges: 712141
#
# Running Louvain algorithm...
# Maximum modularity in 10 random starts: 0.8384
# Number of communities: 24
# Elapsed time: 2 seconds
# 1 singletons identified. 23 final clusters.
#
# Getting ImputeWeights
#
# Getting ImputeWeights
#
# Length of unique values greater than palette, interpolating..
#
# Length of unique values greater than palette, interpolating..
#
# Overriding previous entry for predictedGroup_celltype_TileMatrix
#
# Saving ArchRProject...
#
# Loading ArchRProject...
#
# Successfully loaded ArchRProject!
#
#
#                                                    / |
#                                                  /    \
#             .                                  /      |.
#             \\\                              /        |.
#               \\\                          /           `|.
#                 \\\                      /              |.
#                   \                    /                |\
#                   \\#####\           /                  ||
#                 ==###########>      /                   ||
#                  \\##==......\    /                     ||
#             ______ =       =|__ /__                     ||      \\\
#         ,--' ,----`-,__ ___/'  --,-`-===================##========>
#        \               '        ##_______ _____ ,--,__,=##,__   ///
#         ,    __==    ___,-,__,--'#'  ==='      `-'    | ##,-/
#         -,____,---'       \\####\\________________,--\\_##,/
#            ___      .______        ______  __    __  .______
#           /   \     |   _  \      /      ||  |  |  | |   _  \
#          /  ^  \    |  |_)  |    |  ,----'|  |__|  | |  |_)  |
#         /  /_\  \   |      /     |  |     |   __   | |      /
#        /  _____  \  |  |\  \\___ |  `----.|  |  |  | |  |\  \\___.
#       /__/     \__\ | _| `._____| \______||__|  |__| | _| `._____|
#
#
#
#            ___      .______        ______  __    __  .______
#           /   \     |   _  \      /      ||  |  |  | |   _  \
#          /  ^  \    |  |_)  |    |  ,----'|  |__|  | |  |_)  |
#         /  /_\  \   |      /     |  |     |   __   | |      /
#        /  _____  \  |  |\  \\___ |  `----.|  |  |  | |  |\  \\___.
#       /__/     \__\ | _| `._____| \______||__|  |__| | _| `._____|
# class: ArchRProject
# outputDirectory: /rds/project/rds-SDzz0CATGms/users/bt392/04_Rabbit_ATAC_final/rerun/ArchR/Project
# samples(8): rabbit_BGRGP1 rabbit_BGRGP2 ... rabbit_BGRGP7 rabbit_BGRGP8
# sampleColData names(1): ArrowFiles
# cellColData names(37): sample Sample ... stage_clusters cell
# numberOfCells(1): 37157
# medianTSS(1): 3.605
# medianFrags(1): 34347

# %%
table(ArchRProject@cellColData$predictedGroup_celltype_TileMatrix)
# Out:
#                      Allantois             Anterior Hypoblast
#                           4263                           1032
#              Anterior Mesoderm              Brain/Neural Tube
#                            460                           7054
#                 Cardiomyocytes                        Chorion
#                             63                             26
#                            CYT        Early Amniotic Ectoderm
#                           1376                            247
#             Early Erythrocytes                    Endothelium
#                             74                           1065
#                       Epiblast                   EXE mesoderm
#                           4839                            685
#                    Floor Plate Haematoendothelial progenitors
#                              2                            630
#                      Hypoblast         Late Amniotic Ectoderm
#                           2843                            131
#              Late Erythrocytes                 Megakaryocytes
#                            991                            237
#                   Neural Crest                            NMP
#                             13                           3142
#                      Notochord                       Placodes
#                             30                            637
#             Posterior Mesoderm               Primitive Streak
#                            755                           1035
#                            SCT               Somitic Mesoderm
#                            588                           2449
#                    Trophoblast           Visceral YS Endoderm
#                            875                            999
#                 YS Mesothelium
#                            616

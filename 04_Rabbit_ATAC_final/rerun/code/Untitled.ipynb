# %%
here::i_am("01_create_arrow.R")
source(here::here("settings.R"))
# Out:
# here() starts at /rds/project/rds-SDzz0CATGms/users/bt392/04_Rabbit_ATAC_final/rerun/code
#
# Setting default number of Parallel threads to 1.

# %%
# I/O
io$output.directory <- file.path(io$basedir,"ArchR")
setwd(io$output.directory)

# %%
ArrowFiles = file.path(io$output.directory, list.files(io$output.directory, pattern ='arrow'))

# %%
ArrowFiles
# Out:
# [1] "/rds/project/rds-SDzz0CATGms/users/bt392/04_Rabbit_ATAC_final/rerun/ArchR/rabbit_BGRGP1.arrow"
# [2] "/rds/project/rds-SDzz0CATGms/users/bt392/04_Rabbit_ATAC_final/rerun/ArchR/rabbit_BGRGP2.arrow"
# [3] "/rds/project/rds-SDzz0CATGms/users/bt392/04_Rabbit_ATAC_final/rerun/ArchR/rabbit_BGRGP3.arrow"
# [4] "/rds/project/rds-SDzz0CATGms/users/bt392/04_Rabbit_ATAC_final/rerun/ArchR/rabbit_BGRGP4.arrow"
# [5] "/rds/project/rds-SDzz0CATGms/users/bt392/04_Rabbit_ATAC_final/rerun/ArchR/rabbit_BGRGP5.arrow"
# [6] "/rds/project/rds-SDzz0CATGms/users/bt392/04_Rabbit_ATAC_final/rerun/ArchR/rabbit_BGRGP6.arrow"
# [7] "/rds/project/rds-SDzz0CATGms/users/bt392/04_Rabbit_ATAC_final/rerun/ArchR/rabbit_BGRGP7.arrow"
# [8] "/rds/project/rds-SDzz0CATGms/users/bt392/04_Rabbit_ATAC_final/rerun/ArchR/rabbit_BGRGP8.arrow"

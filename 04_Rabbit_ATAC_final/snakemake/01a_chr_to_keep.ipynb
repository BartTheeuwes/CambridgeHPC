# %%
here::i_am("snakemake/01_create_arrow.R")
library(data.table)
# Out:
# here() starts at /rds/project/rds-SDzz0CATGms/users/bt392/04_Rabbit_ATAC_final

# %%
in_path = '/rds/project/rds-SDzz0CATGms/users/bt392/04_Rabbit_ATAC_final/data/'
samples = paste0('BGRGP', 1:8)

# %%
chrs_all_samples = lapply(paste0(in_path, samples, '_chrs.txt'), fread)

# %%
chrs_keep = Reduce(intersect, chrs_all_samples)

# %%
unique(rbindlist(chrs_all_samples))
# Out:
#      #
# 1    chr1
# 2    chr10
# 3    chr11
# 4    chr12
# 5    chr13
# 6    chr14
# 7    chr15
# 8    chr16
# 9    chr17
# 10   chr18
# 11   chr19
# 12   chr2
# 13   chr20
# 14   chr21
# 15   chr3
# 16   chr4
# 17   chr5
# 18   chr6
# 19   chr7
# 20   chr8
# 21   chr9
# 22   chrX
# 23   chrUn0001
# 24   chrUn0002
# 25   chrUn0003
# 26   chrUn0004
# 27   chrUn0005
# 28   chrUn0006
# 29   chrUn0007
# 30   chrUn0008
# ⋮    ⋮
# 996  chrUn2600
# 997  chrUn2659
# 998  chrUn2673
# 999  chrUn2704
# 1000 chrUn2710
# 1001 chrUn2720
# 1002 chrUn2737
# 1003 chrUn2746
# 1004 chrUn2748
# 1005 chrUn2758
# 1006 chrUn2784
# 1007 chrUn2828
# 1008 chrUn2855
# 1009 chrUn2873
# 1010 chrUn2885
# 1011 chrUn2893
# 1012 chrUn2918
# 1013 chrUn2923
# 1014 chrUn2942
# 1015 chrUn2944
# 1016 chrUn2955
# 1017 chrUn2995
# 1018 chrUn3042
# 1019 chrUn3098
# 1020 chrUn3107
# 1021 chrUn3122
# 1022 chrUn3124
# 1023 chrUn3163
# 1024 chrUn3205
# 1025 chrUn3209

# %%
nrow(chrs_keep)
# Out:
# [1] 1025

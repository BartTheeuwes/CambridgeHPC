# %%
here::i_am("snakemake/01_create_arrow.R")
source(here::here("settings.R"))
source(here::here("load_archr.R"))
addArchRThreads(1)
# Out:
# here() starts at /rds/project/rds-SDzz0CATGms/users/bt392/04_Rabbit_ATAC_final
#
# Setting default number of Parallel threads to 1.
#
# Setting addArchRVerbose = FALSE
#
# Successfully loaded ArchRProject!
#
#
#                                                    / |
#                                                  /    \
#             .                                  /      |.
#             \\\                              /        |.
#               \\\                          /           `|.
#                 \\\                      /              |.
#                   \                    /                |\
#                   \\#####\           /                  ||
#                 ==###########>      /                   ||
#                  \\##==......\    /                     ||
#             ______ =       =|__ /__                     ||      \\\
#         ,--' ,----`-,__ ___/'  --,-`-===================##========>
#        \               '        ##_______ _____ ,--,__,=##,__   ///
#         ,    __==    ___,-,__,--'#'  ==='      `-'    | ##,-/
#         -,____,---'       \\####\\________________,--\\_##,/
#            ___      .______        ______  __    __  .______
#           /   \     |   _  \      /      ||  |  |  | |   _  \
#          /  ^  \    |  |_)  |    |  ,----'|  |__|  | |  |_)  |
#         /  /_\  \   |      /     |  |     |   __   | |      /
#        /  _____  \  |  |\  \\___ |  `----.|  |  |  | |  |\  \\___.
#       /__/     \__\ | _| `._____| \______||__|  |__| | _| `._____|
#
#
# Setting default number of Parallel threads to 1.

# %%
# #### Prepare for mapping ######
# # Add metadata stage column where GD9_ExE = GD9
# ArchRProject@cellColData$cell = rownames(ArchRProject@cellColData)
# cells = rownames(ArchRProject@cellColData)
# stages = data.frame('sample' = c('rabbit_BGRGP1', 'rabbit_BGRGP2', 'rabbit_BGRGP3', 'rabbit_BGRGP4', 'rabbit_BGRGP5', 'rabbit_BGRGP6', 'rabbit_BGRGP7', 'rabbit_BGRGP8'),
#                     'stage_mapping' = c('GD7', 'GD8', 'GD8', 'GD9', 'GD9', 'GD9', 'GD9', 'GD9' ))
# ArchRProject@cellColData = merge(ArchRProject@cellColData, stages, by='sample')

# ArchRProject@cellColData = ArchRProject@cellColData[order(ArchRProject@cellColData$cell, cells),]
# rownames(ArchRProject@cellColData) = ArchRProject@cellColData$cell

# %%
Mapping_matrix('TileMatrix', 45, 55000)
# Out:
# [1] "GD7"
# Checking Inputs...
#
# Computing nearest neighbor graph
#
# Computing SNN
# Modularity Optimizer version 1.3.0 by Ludo Waltman and Nees Jan van Eck
#
# Number of nodes: 7562
# Number of edges: 387363
#
# Running Louvain algorithm...
# Maximum modularity in 10 random starts: 0.7342
# Number of communities: 16
# Elapsed time: 0 seconds
# Getting ImputeWeights
#
# Length of unique values greater than palette, interpolating..
#
# Overriding previous entry for predictedCell_Un_TileMatrix
#
# Overriding previous entry for predictedGroup_celltype_TileMatrix
#
# Overriding previous entry for predictedScore_celltype_TileMatrix
# [1] "GD8"
# Checking Inputs...
#
# Computing nearest neighbor graph
#
# Computing SNN
# Modularity Optimizer version 1.3.0 by Ludo Waltman and Nees Jan van Eck
#
# Number of nodes: 6730
# Number of edges: 405698
#
# Running Louvain algorithm...
# Maximum modularity in 10 random starts: 0.8167
# Number of communities: 19
# Elapsed time: 0 seconds
# Getting ImputeWeights
#
# Length of unique values greater than palette, interpolating..
#
# Overriding previous entry for predictedCell_Un_TileMatrix
#
# Overriding previous entry for predictedGroup_celltype_TileMatrix
#
# Overriding previous entry for predictedScore_celltype_TileMatrix
# [1] "GD9_ExE"
# Checking Inputs...
#
# Computing nearest neighbor graph
#
# Computing SNN
# Modularity Optimizer version 1.3.0 by Ludo Waltman and Nees Jan van Eck
#
# Number of nodes: 1133
# Number of edges: 48544
#
# Running Louvain algorithm...
# Maximum modularity in 10 random starts: 0.7139
# Number of communities: 10
# Elapsed time: 0 seconds
# Getting ImputeWeights
#
# Length of unique values greater than palette, interpolating..
#
# Overriding previous entry for predictedCell_Un_TileMatrix
#
# Overriding previous entry for predictedGroup_celltype_TileMatrix
#
# Overriding previous entry for predictedScore_celltype_TileMatrix
# [1] "GD9"
# Checking Inputs...
#
# Computing nearest neighbor graph
#
# Computing SNN
# Modularity Optimizer version 1.3.0 by Ludo Waltman and Nees Jan van Eck
#
# Number of nodes: 13014
# Number of edges: 655676
#
# Running Louvain algorithm...
# Maximum modularity in 10 random starts: 0.8327
# Number of communities: 22
# Elapsed time: 1 seconds
# Getting ImputeWeights
#
# Length of unique values greater than palette, interpolating..
#
# Overriding previous entry for predictedCell_Un_TileMatrix
#
# Overriding previous entry for predictedGroup_celltype_TileMatrix
#
# Overriding previous entry for predictedScore_celltype_TileMatrix
#
# Saving ArchRProject...
#
# Loading ArchRProject...
#
# Successfully loaded ArchRProject!
#
#
#                                                    / |
#                                                  /    \
#             .                                  /      |.
#             \\\                              /        |.
#               \\\                          /           `|.
#                 \\\                      /              |.
#                   \                    /                |\
#                   \\#####\           /                  ||
#                 ==###########>      /                   ||
#                  \\##==......\    /                     ||
#             ______ =       =|__ /__                     ||      \\\
#         ,--' ,----`-,__ ___/'  --,-`-===================##========>
#        \               '        ##_______ _____ ,--,__,=##,__   ///
#         ,    __==    ___,-,__,--'#'  ==='      `-'    | ##,-/
#         -,____,---'       \\####\\________________,--\\_##,/
#            ___      .______        ______  __    __  .______
#           /   \     |   _  \      /      ||  |  |  | |   _  \
#          /  ^  \    |  |_)  |    |  ,----'|  |__|  | |  |_)  |
#         /  /_\  \   |      /     |  |     |   __   | |      /
#        /  _____  \  |  |\  \\___ |  `----.|  |  |  | |  |\  \\___.
#       /__/     \__\ | _| `._____| \______||__|  |__| | _| `._____|
#
#
#
#            ___      .______        ______  __    __  .______
#           /   \     |   _  \      /      ||  |  |  | |   _  \
#          /  ^  \    |  |_)  |    |  ,----'|  |__|  | |  |_)  |
#         /  /_\  \   |      /     |  |     |   __   | |      /
#        /  _____  \  |  |\  \\___ |  `----.|  |  |  | |  |\  \\___.
#       /__/     \__\ | _| `._____| \______||__|  |__| | _| `._____|
# class: ArchRProject
# outputDirectory: /rds/project/rds-SDzz0CATGms/users/bt392/04_Rabbit_ATAC_final/ArchR/Project
# samples(8): rabbit_BGRGP1 rabbit_BGRGP2 ... rabbit_BGRGP7 rabbit_BGRGP8
# sampleColData names(1): ArrowFiles
# cellColData names(28): sample Sample ... stage_clusters cell
# numberOfCells(1): 28439
# medianTSS(1): 3.467
# medianFrags(1): 40984

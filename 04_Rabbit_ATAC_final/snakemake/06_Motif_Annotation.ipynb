# %%
here::i_am("snakemake/01_create_arrow.R")
source(here::here("settings.R"))
source(here::here("load_archr.R"))
# Out:
# here() starts at /rds/project/rds-SDzz0CATGms/users/bt392/04_Rabbit_ATAC_final
#
# Setting default number of Parallel threads to 1.
#
# Successfully loaded ArchRProject!
#
#
#                                                    / |
#                                                  /    \
#             .                                  /      |.
#             \\\                              /        |.
#               \\\                          /           `|.
#                 \\\                      /              |.
#                   \                    /                |\
#                   \\#####\           /                  ||
#                 ==###########>      /                   ||
#                  \\##==......\    /                     ||
#             ______ =       =|__ /__                     ||      \\\
#         ,--' ,----`-,__ ___/'  --,-`-===================##========>
#        \               '        ##_______ _____ ,--,__,=##,__   ///
#         ,    __==    ___,-,__,--'#'  ==='      `-'    | ##,-/
#         -,____,---'       \\####\\________________,--\\_##,/
#            ___      .______        ______  __    __  .______
#           /   \     |   _  \      /      ||  |  |  | |   _  \
#          /  ^  \    |  |_)  |    |  ,----'|  |__|  | |  |_)  |
#         /  /_\  \   |      /     |  |     |   __   | |      /
#        /  _____  \  |  |\  \\___ |  `----.|  |  |  | |  |\  \\___.
#       /__/     \__\ | _| `._____| \______||__|  |__| | _| `._____|

# %% [markdown]
# ### Motif enrichment

# %%
# Motif enrichment
ArchRProject <- addMotifAnnotations(ArchRProj = ArchRProject, motifSet = "cisbp", name = "Motif", species='Homo sapiens', force=TRUE)
# Out:
# ArchR logging to : ArchRLogs/ArchR-addMotifAnnotations-1538c775917cd-Date-2022-01-11_Time-12-24-39.log
# If there is an issue, please report to github with logFile!
#
# 2022-01-11 12:24:54 : Gettting Motif Set, Species : Homo sapiens, 0.003 mins elapsed.
#
# Using version 2 motifs!
#
# 2022-01-11 12:25:01 : Finding Motif Positions with motifmatchr!, 0.123 mins elapsed.
#
# 2022-01-11 12:27:32 : Creating Motif Overlap Matrix, 2.65 mins elapsed.
#
# 2022-01-11 12:27:35 : Finished Getting Motif Info!, 2.687 mins elapsed.
#
# ArchR logging successful to : ArchRLogs/ArchR-addMotifAnnotations-1538c775917cd-Date-2022-01-11_Time-12-24-39.log

# %%
ArchRProject <- addBgdPeaks(ArchRProject, method='chromVAR') # method ArchR bc of error ?
# Out:
# Identifying Background Peaks!
#
# Saving ArchRProject...
#
# Loading ArchRProject...
#
# Successfully loaded ArchRProject!
#
#
#                                                    / |
#                                                  /    \
#             .                                  /      |.
#             \\\                              /        |.
#               \\\                          /           `|.
#                 \\\                      /              |.
#                   \                    /                |\
#                   \\#####\           /                  ||
#                 ==###########>      /                   ||
#                  \\##==......\    /                     ||
#             ______ =       =|__ /__                     ||      \\\
#         ,--' ,----`-,__ ___/'  --,-`-===================##========>
#        \               '        ##_______ _____ ,--,__,=##,__   ///
#         ,    __==    ___,-,__,--'#'  ==='      `-'    | ##,-/
#         -,____,---'       \\####\\________________,--\\_##,/
#            ___      .______        ______  __    __  .______
#           /   \     |   _  \      /      ||  |  |  | |   _  \
#          /  ^  \    |  |_)  |    |  ,----'|  |__|  | |  |_)  |
#         /  /_\  \   |      /     |  |     |   __   | |      /
#        /  _____  \  |  |\  \\___ |  `----.|  |  |  | |  |\  \\___.
#       /__/     \__\ | _| `._____| \______||__|  |__| | _| `._____|
#
#
#
#            ___      .______        ______  __    __  .______
#           /   \     |   _  \      /      ||  |  |  | |   _  \
#          /  ^  \    |  |_)  |    |  ,----'|  |__|  | |  |_)  |
#         /  /_\  \   |      /     |  |     |   __   | |      /
#        /  _____  \  |  |\  \\___ |  `----.|  |  |  | |  |\  \\___.
#       /__/     \__\ | _| `._____| \______||__|  |__| | _| `._____|
# class: ArchRProject
# outputDirectory: /rds/project/rds-SDzz0CATGms/users/bt392/04_Rabbit_ATAC_final/ArchR/Project
# samples(8): rabbit_BGRGP1 rabbit_BGRGP2 ... rabbit_BGRGP7 rabbit_BGRGP8
# sampleColData names(1): ArrowFiles
# cellColData names(31): sample Sample ... cell Clusters_PeakMatrix
# numberOfCells(1): 50525
# medianTSS(1): 3.353
# medianFrags(1): 34982

# %%
addArchRThreads(12)
# Out:
# Setting default number of Parallel threads to 12.

# %%
ArchRProject <- addDeviationsMatrix(
  ArchRProj = ArchRProject, 
  peakAnnotation = "Motif",
  force = TRUE
)
saveArchRProject(ArchRProj = ArchRProject)
# Out:
# Using Previous Background Peaks!
#
# ArchR logging to : ArchRLogs/ArchR-addDeviationsMatrix-1538cc922fcb-Date-2022-01-11_Time-12-51-18.log
# If there is an issue, please report to github with logFile!
# NULL
# 2022-01-11 12:51:22 : Batch Execution w/ safelapply!, 0 mins elapsed.
#
# ###########
# 2022-01-11 13:34:38 : Completed Computing Deviations!, 43.341 mins elapsed.
# ###########
#
# ArchR logging successful to : ArchRLogs/ArchR-addDeviationsMatrix-1538cc922fcb-Date-2022-01-11_Time-12-51-18.log
#
# Saving ArchRProject...
#
# Loading ArchRProject...
#
# Successfully loaded ArchRProject!
#
#
#                                                    / |
#                                                  /    \
#             .                                  /      |.
#             \\\                              /        |.
#               \\\                          /           `|.
#                 \\\                      /              |.
#                   \                    /                |\
#                   \\#####\           /                  ||
#                 ==###########>      /                   ||
#                  \\##==......\    /                     ||
#             ______ =       =|__ /__                     ||      \\\
#         ,--' ,----`-,__ ___/'  --,-`-===================##========>
#        \               '        ##_______ _____ ,--,__,=##,__   ///
#         ,    __==    ___,-,__,--'#'  ==='      `-'    | ##,-/
#         -,____,---'       \\####\\________________,--\\_##,/
#            ___      .______        ______  __    __  .______
#           /   \     |   _  \      /      ||  |  |  | |   _  \
#          /  ^  \    |  |_)  |    |  ,----'|  |__|  | |  |_)  |
#         /  /_\  \   |      /     |  |     |   __   | |      /
#        /  _____  \  |  |\  \\___ |  `----.|  |  |  | |  |\  \\___.
#       /__/     \__\ | _| `._____| \______||__|  |__| | _| `._____|
#
#
#
#            ___      .______        ______  __    __  .______
#           /   \     |   _  \      /      ||  |  |  | |   _  \
#          /  ^  \    |  |_)  |    |  ,----'|  |__|  | |  |_)  |
#         /  /_\  \   |      /     |  |     |   __   | |      /
#        /  _____  \  |  |\  \\___ |  `----.|  |  |  | |  |\  \\___.
#       /__/     \__\ | _| `._____| \______||__|  |__| | _| `._____|
# class: ArchRProject
# outputDirectory: /rds/project/rds-SDzz0CATGms/users/bt392/04_Rabbit_ATAC_final/ArchR/Project
# samples(8): rabbit_BGRGP1 rabbit_BGRGP2 ... rabbit_BGRGP7 rabbit_BGRGP8
# sampleColData names(1): ArrowFiles
# cellColData names(31): sample Sample ... cell Clusters_PeakMatrix
# numberOfCells(1): 50525
# medianTSS(1): 3.353
# medianFrags(1): 34982

# %%
saveArchRProject(ArchRProj = ArchRProject)
# Out:
# Saving ArchRProject...
#
# Loading ArchRProject...
#
# Successfully loaded ArchRProject!
#
#
#                                                    / |
#                                                  /    \
#             .                                  /      |.
#             \\\                              /        |.
#               \\\                          /           `|.
#                 \\\                      /              |.
#                   \                    /                |\
#                   \\#####\           /                  ||
#                 ==###########>      /                   ||
#                  \\##==......\    /                     ||
#             ______ =       =|__ /__                     ||      \\\
#         ,--' ,----`-,__ ___/'  --,-`-===================##========>
#        \               '        ##_______ _____ ,--,__,=##,__   ///
#         ,    __==    ___,-,__,--'#'  ==='      `-'    | ##,-/
#         -,____,---'       \\####\\________________,--\\_##,/
#            ___      .______        ______  __    __  .______
#           /   \     |   _  \      /      ||  |  |  | |   _  \
#          /  ^  \    |  |_)  |    |  ,----'|  |__|  | |  |_)  |
#         /  /_\  \   |      /     |  |     |   __   | |      /
#        /  _____  \  |  |\  \\___ |  `----.|  |  |  | |  |\  \\___.
#       /__/     \__\ | _| `._____| \______||__|  |__| | _| `._____|
#
#
#
#            ___      .______        ______  __    __  .______
#           /   \     |   _  \      /      ||  |  |  | |   _  \
#          /  ^  \    |  |_)  |    |  ,----'|  |__|  | |  |_)  |
#         /  /_\  \   |      /     |  |     |   __   | |      /
#        /  _____  \  |  |\  \\___ |  `----.|  |  |  | |  |\  \\___.
#       /__/     \__\ | _| `._____| \______||__|  |__| | _| `._____|
# class: ArchRProject
# outputDirectory: /rds/project/rds-SDzz0CATGms/users/bt392/04_Rabbit_ATAC_final/ArchR/Project
# samples(8): rabbit_BGRGP1 rabbit_BGRGP2 ... rabbit_BGRGP7 rabbit_BGRGP8
# sampleColData names(1): ArrowFiles
# cellColData names(31): sample Sample ... cell Clusters_PeakMatrix
# numberOfCells(1): 50525
# medianTSS(1): 3.353
# medianFrags(1): 34982

# %% [markdown]
# ### Identification of Positive TF-Regulators

# %%
library(ggrepel)

# %%
seGroupMotif <- getGroupSE(ArchRProj = ArchRProject, useMatrix = "MotifMatrix", groupBy = "Clusters_PeakMatrix")
seZ <- seGroupMotif[rowData(seGroupMotif)$seqnames=="z",]
# Out:
# ArchR logging to : ArchRLogs/ArchR-getGroupSE-3e4c223f1c4a-Date-2022-01-11_Time-20-37-22.log
# If there is an issue, please report to github with logFile!
#
# Getting Group Matrix
#
# 2022-01-11 20:37:23 : Constructing Group Matrix 1 of 2, 0.006 mins elapsed.
#
# 2022-01-11 20:37:40 : Finished Group Matrix 1 of 2, 0.285 mins elapsed.
#
# 2022-01-11 20:37:40 : Constructing Group Matrix 2 of 2, 0.285 mins elapsed.
#
# 2022-01-11 20:37:54 : Finished Group Matrix 2 of 2, 0.514 mins elapsed.
#
# 2022-01-11 20:37:54 : Successfully Created Group Matrix, 0.514 mins elapsed.
#
# Normalizing by number of Cells
#
# ArchR logging successful to : ArchRLogs/ArchR-getGroupSE-3e4c223f1c4a-Date-2022-01-11_Time-20-37-22.log

# %%
rowData(seZ)$maxDelta <- lapply(seq_len(ncol(seZ)), function(x){
  rowMaxs(assay(seZ) - assay(seZ)[,x])
}) %>% Reduce("cbind", .) %>% rowMaxs

# %%
# GeneScoreMatrix
corGSM_MM <- correlateMatrices(
    ArchRProj = ArchRProject,
    useMatrix1 = "GeneScoreMatrix",
    useMatrix2 = "MotifMatrix",
    reducedDims = "PeakMatrix"
)

corGSM_MM$maxDelta <- rowData(seZ)[match(corGSM_MM$MotifMatrix_name, rowData(seZ)$name), "maxDelta"]

corGSM_MM <- corGSM_MM[order(abs(corGSM_MM$cor), decreasing = TRUE), ]
corGSM_MM <- corGSM_MM[which(!duplicated(gsub("\\-.*","",corGSM_MM[,"MotifMatrix_name"]))), ]
corGSM_MM$TFRegulator <- "NO"
corGSM_MM$TFRegulator[which(corGSM_MM$cor > 0.5 & corGSM_MM$padj < 0.01 & corGSM_MM$maxDelta > quantile(corGSM_MM$maxDelta, 0.75))] <- "YES"
sort(corGSM_MM[corGSM_MM$TFRegulator=="YES",1])
# Out:
# ArchR logging to : ArchRLogs/ArchR-correlateMatrices-3e4c2602de4ea-Date-2022-01-11_Time-20-37-55.log
# If there is an issue, please report to github with logFile!
#
# When accessing features from a matrix of class Sparse.Assays.Matrix it requires 1 seqname!
# Continuing with first seqname 'z'!
# If confused, try getFeatures(ArchRProj, 'MotifMatrix') to list out available seqnames for input!
#
# 2022-01-11 20:37:57 : Testing 434 Mappings!, 0.032 mins elapsed.
#
# 2022-01-11 20:37:57 : Computing KNN, 0.033 mins elapsed.
#
# 2022-01-11 20:37:58 : Identifying Non-Overlapping KNN pairs, 0.044 mins elapsed.
#
# 2022-01-11 20:38:00 : Identified 500 Groupings!, 0.078 mins elapsed.
#
# 2022-01-11 20:38:02 : Getting Group Matrix 1, 0.116 mins elapsed.
#
# 2022-01-11 20:39:38 : Getting Group Matrix 2, 1.718 mins elapsed.
#
# Some entries in groupMat2 are less than 0, continuing without Log2 Normalization.
# Most likely this assay is a deviations matrix.
#
# Getting Correlations...
#
# 2022-01-11 20:39:47 :
#
# Computing Correlation (250 of 434)
#
# ArchR logging successful to : ArchRLogs/ArchR-correlateMatrices-3e4c2602de4ea-Date-2022-01-11_Time-20-37-55.log
#  [1] "CDX1"   "CDX4"   "CEBPA"  "FOS"    "FOSL2"  "FOXA2"  "GATA3"  "HAND1"
#  [9] "HNF1B"  "HOXB9"  "LHX1"   "LHX9"   "MITF"   "POU3F3" "POU3F4" "PRRX1"
# [17] "RFX3"   "RFX4"   "SHOX2"  "SOX13"  "SOX5"   "TEAD1"  "TEAD4"  "TFAP2A"
# [25] "TP63"

# %%
p <- ggplot(data.frame(corGSM_MM), aes(cor, maxDelta, color = TFRegulator, label=GeneScoreMatrix_name)) +
  geom_point() + 
  theme_ArchR() +
  geom_vline(xintercept = 0, lty = "dashed") + 
  scale_color_manual(values = c("NO"="darkgrey", "YES"="firebrick3")) +
  xlab("Correlation To Gene Score") +
  ylab("Max TF Motif Delta") +
  scale_y_continuous(
    expand = c(0,0), 
    limits = c(0, max(corGSM_MM$maxDelta)*1.05))  +
  geom_label_repel(data=data.frame(corGSM_MM)[data.frame(corGSM_MM)$TFRegulator=='YES',], hjust=0, vjust=0)

p
# Out:
# Warning message:
# “ggrepel: 17 unlabeled data points (too many overlaps). Consider increasing max.overlaps”
# plot without title

# %%
# GeneIntegrationMatrix
corGIM_MM <- correlateMatrices(
    ArchRProj = ArchRProject,
    useMatrix1 = "GeneIntegrationMatrix_TileMatrix",
    useMatrix2 = "MotifMatrix",
    reducedDims = "PeakMatrix"
)

corGIM_MM$maxDelta <- rowData(seZ)[match(corGIM_MM$MotifMatrix_name, rowData(seZ)$name), "maxDelta"]

corGIM_MM <- corGIM_MM[order(abs(corGIM_MM$cor), decreasing = TRUE), ]
corGIM_MM <- corGIM_MM[which(!duplicated(gsub("\\-.*","",corGIM_MM[,"MotifMatrix_name"]))), ]
corGIM_MM$TFRegulator <- "NO"
corGIM_MM$TFRegulator[which(corGIM_MM$cor > 0.5 & corGIM_MM$padj < 0.01 & corGIM_MM$maxDelta > quantile(corGIM_MM$maxDelta, 0.75))] <- "YES"
sort(corGIM_MM[corGIM_MM$TFRegulator=="YES",1])
# Out:
# ArchR logging to : ArchRLogs/ArchR-correlateMatrices-3e4c2123a005f-Date-2022-01-11_Time-20-39-48.log
# If there is an issue, please report to github with logFile!
#
# When accessing features from a matrix of class Sparse.Assays.Matrix it requires 1 seqname!
# Continuing with first seqname 'z'!
# If confused, try getFeatures(ArchRProj, 'MotifMatrix') to list out available seqnames for input!
#
# 2022-01-11 20:39:50 : Testing 434 Mappings!, 0.031 mins elapsed.
#
# 2022-01-11 20:39:50 : Computing KNN, 0.032 mins elapsed.
#
# 2022-01-11 20:39:51 : Identifying Non-Overlapping KNN pairs, 0.042 mins elapsed.
#
# 2022-01-11 20:39:53 : Identified 500 Groupings!, 0.076 mins elapsed.
#
# 2022-01-11 20:39:55 : Getting Group Matrix 1, 0.113 mins elapsed.
#
# 2022-01-11 20:41:08 : Getting Group Matrix 2, 1.33 mins elapsed.
#
# Some entries in groupMat2 are less than 0, continuing without Log2 Normalization.
# Most likely this assay is a deviations matrix.
#
# Getting Correlations...
#
# 2022-01-11 20:41:18 :
#
# Computing Correlation (250 of 434)
#
# ArchR logging successful to : ArchRLogs/ArchR-correlateMatrices-3e4c2123a005f-Date-2022-01-11_Time-20-39-48.log
#  [1] "ARID2"  "CDX4"   "CEBPA"  "FOXA2"  "GATA3"  "HAND1"  "HNF1B"  "HNF4G"
#  [9] "HOXA13" "HOXB8"  "HOXB9"  "HOXD13" "MITF"   "NFYA"   "POU2F1" "POU3F4"
# [17] "RFX3"   "RFX4"   "RFX7"   "SOX5"   "SOX9"   "TEAD4"  "TFAP2A" "TP63"

# %%
p <- ggplot(data.frame(corGIM_MM), aes(cor, maxDelta, color = TFRegulator,, label=GeneIntegrationMatrix_TileMatrix_name)) +
  geom_point() + 
  theme_ArchR() +
  geom_vline(xintercept = 0, lty = "dashed") + 
  scale_color_manual(values = c("NO"="darkgrey", "YES"="firebrick3")) +
  xlab("Correlation To Gene Expression") +
  ylab("Max TF Motif Delta") +
  scale_y_continuous(
    expand = c(0,0), 
    limits = c(0, max(corGIM_MM$maxDelta)*1.05)) +
  geom_label_repel(data=data.frame(corGIM_MM)[data.frame(corGIM_MM)$TFRegulator=='YES',], hjust=0, vjust=0)

p
# Out:
# Warning message:
# “Removed 16 rows containing missing values (geom_point).”
# Warning message:
# “ggrepel: 12 unlabeled data points (too many overlaps). Consider increasing max.overlaps”
# plot without title

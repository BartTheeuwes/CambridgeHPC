# %%
getwd()
# Out:
# [1] "/rds/project/rds-SDzz0CATGms/users/bt392/09_Eomes_invitro_blood/ChIP/pbx1"

# %%
cmd = sprintf('/rds/project/rds-SDzz0CATGms/users/bt392/software/homer/bin/findMotifsGenome.pl %s/GSM692743_PBX1_MCF7_red_m16_10_5.bed_peaks.bed mm10 %s/HOMER_s200/ -size 200 -S 25 -len 6,8,10 -p 24',
                getwd(), 
                getwd())
system(cmd)

# %%
sprintf('%s/GSM692743_PBX1_MCF7_red_m16_10_5.bed_peaks.bed', getwd())
# Out:
# [1] "/rds/project/rds-SDzz0CATGms/users/bt392/09_Eomes_invitro_blood/ChIP/pbx1/GSM692743_PBX1_MCF7_red_m16_10_5.bed_peaks.bed"

# %%
# Motif search using Homer
cmd = sprintf('/rds/project/rds-SDzz0CATGms/users/bt392/software/homer/bin/findMotifsGenome.pl %s/ZFP462_BioChIp_summits.bed mm10 %s/HOMER_50/ -size 50 -S 25 -len 6,8,10 -p 24', 
                   getwd(),
                     getwd())
system(cmd)

# %%
# Motif search using Homer
cmd = sprintf('/rds/project/rds-SDzz0CATGms/users/bt392/software/homer/bin/findMotifsGenome.pl %s/ZFP462_BioChIp_summits.bed mm10 %s/HOMER_200/ -size 200 -S 25 -len 6,8,10 -p 24', 
                   getwd(),
                     getwd())
system(cmd)

# %% [markdown]
# # Motif enrichment on top 5000 peaks

# %%
library(data.table)
library(dplyr)

# %%
bed = fread(sprintf('%s/ZFP462_BioChIp_summits.bed', getwd()))
fwrite(bed[order(-V5)][,c(1,2,3)] %>% head(5000), sprintf('%s/ZFP462_BioChIp_summits_top5000.bed', getwd()), sep='\t', col.names=F)

# %%
# Motif search using Homer
cmd = sprintf('/rds/project/rds-SDzz0CATGms/users/bt392/software/homer/bin/findMotifsGenome.pl %s/ZFP462_BioChIp_summits_top5000.bed mm10 %s/HOMER_top5000_50/ -size 50 -S 25 -len 6,8,10 -p 24', 
                   getwd(),
                     getwd())
system(cmd)

# %%
# Motif search using Homer
cmd = sprintf('/rds/project/rds-SDzz0CATGms/users/bt392/software/homer/bin/findMotifsGenome.pl %s/ZFP462_BioChIp_summits_top5000.bed mm10 %s/HOMER_top5000_200/ -size 200 -S 25 -len 6,8,10 -p 24', 
                   getwd(),
                     getwd())
system(cmd)

# %% [markdown]
# # Motif enrichment on top 1500 peaks

# %%
library(data.table)
library(dplyr)
# Out:
# Attaching package: ‘dplyr’
#
#
# The following objects are masked from ‘package:data.table’:
#
#     between, first, last
#
#
# The following objects are masked from ‘package:stats’:
#
#     filter, lag
#
#
# The following objects are masked from ‘package:base’:
#
#     intersect, setdiff, setequal, union

# %%
bed = fread(sprintf('%s/ZFP462_BioChIp_summits.bed', getwd()))
fwrite(bed[order(-V5)][,c(1,2,3)] %>% head(1500), sprintf('%s/ZFP462_BioChIp_summits_top1500.bed', getwd()), sep='\t', col.names=F)

# %%
# Motif search using Homer
cmd = sprintf('/rds/project/rds-SDzz0CATGms/users/bt392/software/homer/bin/findMotifsGenome.pl %s/ZFP462_BioChIp_summits_top1500.bed mm10 %s/HOMER_top1500_75/ -size 75 -S 10 -len 8,10,12 -p 24', 
                   getwd(),
                     getwd())
system(cmd)

# %%
# Motif search using Homer
cmd = sprintf('/rds/project/rds-SDzz0CATGms/users/bt392/software/homer/bin/findMotifsGenome.pl %s/ZFP462_BioChIp_summits_top1500.bed mm10 %s/HOMER_top1500_200/ -size 150 -S 10 -len 8,10,12 -p 24', 
                   getwd(),
                     getwd())
system(cmd)

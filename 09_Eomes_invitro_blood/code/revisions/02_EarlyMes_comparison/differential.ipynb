# %% [markdown]
# # Comparison between Early Mesoderm populations

# %%
here::i_am("revisions/02_EarlyMes_comparison/differential.ipynb")

source(here::here("settings.R"))
source(here::here("utils.R"))

suppressPackageStartupMessages(library(scran))
suppressPackageStartupMessages(library(scater))
suppressPackageStartupMessages(library(Seurat))
suppressPackageStartupMessages(library(dplyr))
suppressPackageStartupMessages(library(edgeR))
suppressPackageStartupMessages(library(ArchR))


BPPARAM <- BiocParallel::bpparam()
BPPARAM$workers = 16

# Multi core using future - built in to seurat
plan("multicore", workers = 16)
options(future.globals.maxSize = 50 * 1024 ^ 3) # for 50 Gb RAM
# Out:
# here() starts at /rds/project/rds-SDzz0CATGms/users/bt392/09_Eomes_invitro_blood/code
#
# Warning message:
# “package ‘rtracklayer’ was built under R version 4.2.3”
#
#                                                    / |
#                                                  /    \
#             .                                  /      |.
#             \\\                              /        |.
#               \\\                          /           `|.
#                 \\\                      /              |.
#                   \                    /                |\
#                   \\#####\           /                  ||
#                 ==###########>      /                   ||
#                  \\##==......\    /                     ||
#             ______ =       =|__ /__                     ||      \\\
#         ,--' ,----`-,__ ___/'  --,-`-===================##========>
#        \               '        ##_______ _____ ,--,__,=##,__   ///
#         ,    __==    ___,-,__,--'#'  ==='      `-'    | ##,-/
#         -,____,---'       \\####\\________________,--\\_##,/
#            ___      .______        ______  __    __  .______
#           /   \     |   _  \      /      ||  |  |  | |   _  \
#          /  ^  \    |  |_)  |    |  ,----'|  |__|  | |  |_)  |
#         /  /_\  \   |      /     |  |     |   __   | |      /
#        /  _____  \  |  |\  \\___ |  `----.|  |  |  | |  |\  \\___.
#       /__/     \__\ | _| `._____| \______||__|  |__| | _| `._____|
#
#
# Warning message:
# “package ‘rhdf5’ was built under R version 4.2.3”

# %%
args = list()

# Metadata
args$metadata = file.path(io$basedir, 'results/rna_atac/clustering/metadata_celltype_annotated_v2.txt.gz')

# RNA_sce
args$rna_sce = file.path(io$basedir, 'processed/rna/SingleCellExperiment.rds')

args$logFC_thr = 0.25
args$FDR_thr = 0.05

# outdir
args$outdir = file.path(io$basedir, 'results/revisions/02_EarlyMes_comparison/')
dir.create(args$outdir, recursive=TRUE, showWarnings =FALSE)

# %%
# Load meta
meta = fread(args$metadata)[genotype == 'WT']

# %% [markdown]
# #### Load Data

# %%
# load sce
rna.sce <- load_SingleCellExperiment(args$rna_sce, normalise = TRUE, cells = meta$cell)
colData(rna.sce) = meta %>% as.data.frame() %>% tibble::column_to_rownames('cell') %>% DataFrame()

# Convert to Seurat
seurat = as.Seurat(rna.sce)

# %%
unique(seurat$genotype)
# Out:
# [1] "WT"

# %%
# Define functions
find_DEGs_seurat = function(fr_cells, bg_cells, logFC_thr = args$logFC_thr, FDR_thr = args$FDR_thr, test = 'wilcox', sample_cells = NULL){
    tmp = seurat[, c(bg_cells, fr_cells)]
    tmp$group = ifelse(colnames(tmp) %in% fr_cells, 'fr', 'bg')
    
    if(!is.null(sample_cells)){
     tmp1 = tmp[,bg_cells]
     tmp1 = tmp1[,sample(colnames(tmp1), sample_cells)]

     tmp2 = tmp[,fr_cells]
     tmp2 = tmp2[,sample(colnames(tmp2), sample_cells)]
    
     tmp = merge(tmp1, tmp2)
    }
    
    Idents(tmp) = tmp$group
    
    markers_tmp = FindMarkers(tmp, ident.1 = "fr", ident.2 = "bg",
      logfc.threshold = logFC_thr, test.use = test)
    
    if(nrow(markers_tmp)>0){
        tmp = as.data.table(markers_tmp, keep.rownames=T) %>%
            setnames('rn', 'gene') %>% 
            .[,sig:=ifelse(p_val_adj <= FDR_thr, TRUE, FALSE)]
        return(tmp)
    }
}  

# volcano plot
volcano_plot_seurat = function(dt, ntop=5, logFC_thr = args$logFC_thr, FDR_thr = args$FDR_thr, title=NULL){
    tmp = dt[,sign:=ifelse(p_val_adj < FDR_thr & abs(avg_log2FC) > logFC_thr, ifelse(avg_log2FC>0, 'pos', 'neg'), 'nonsig')] %>%
        .[order(p_val_adj)] #(-abs(avg_log2FC))]
    labels = tmp[, head(.SD, ntop),  by=sign][sign!='nonsig']
    
    negative_hits <- tmp[sign == 'neg',gene]
    positive_hits <- tmp[sign == 'pos',gene]
    all <- nrow(tmp[!is.na(sign)])
    
    ylim = max(-log10(tmp$p_val_adj))
    xlim = max(abs(tmp$avg_log2FC))
    
    p = ggplot(tmp, aes(avg_log2FC, -log10(p_val_adj), col=sign)) + 
        geom_point() +  
        scale_colour_manual(values=c('pos' = 'red', 'neg' = 'blue', 'nonsig' = 'black')) + 
        geom_vline(xintercept=c(-logFC_thr, logFC_thr),  linetype = "longdash") +
        geom_vline(xintercept=0, color='orange', linetype = "longdash") +
        geom_hline(yintercept=-log10(FDR_thr),  linetype = "longdash") + 
        ggrepel::geom_text_repel(data=labels, aes(label=gene), 
                                 color='black',
                                 size=5,
                                 box.padding = 0.5, 
                                 max.overlaps = Inf,
                                 bg.color='white', 
                                 bg.r = 0.1) + 
        # ylim(c(0, ylim*1.2)) + 
        annotate("text", x=0, y=ylim*1.1, size=6, label=sprintf("(%d)", all)) +
        annotate("text", x=-xlim*0.9, y=ylim*1.15, size=6, label=sprintf("%d (-)",length(negative_hits))) +
        annotate("text", x=xlim*0.9, y=ylim*1.15, size=6, label=sprintf("%d (+)",length(positive_hits))) +
        xlim(c(-max(abs(tmp$avg_log2FC)), max(abs(tmp$avg_log2FC)))) + 
        ggtitle(title) + 
        theme_bw() + 
        theme(text = element_text(size=15, color='black'),
             axis.text = element_text(size=15, color='black'),
             legend.position = 'none',
             plot.title = element_text(hjust=0.5))

    
    return(p)
}

# %%
fr_cells = meta[celltype_v2 == 'Early_Mes_EOd' & genotype == 'WT', cell]
bg_cells = meta[celltype_v2 == 'Early_Mes_EOi' & genotype == 'WT', cell]

# %%
DEG = find_DEGs_seurat(fr_cells, bg_cells, logFC_thr = 0, sample_cells = NULL)

# %%
volcano_plot_seurat(DEG, logFC_thr = 0.25)
# Out:
# plot without title

# %%
fwrite(DEG, file.path(args$outdir, 'DEGs_seurat.csv'), sep = ',')

# %%
volcano_plot = function(dt, ntop=5, logFC_thr = args$logFC_thr, FDR_thr = args$FDR_thr, xlim=5, ylim=40, title=NULL){
    tmp = dt[,sign:=ifelse(padj_fdr < FDR_thr & abs(logFC) > logFC_thr, ifelse(logFC>0, 'pos', 'neg'), 'nonsig')] %>%
        #.[order(-abs(logFC))] %>% 
        .[order(padj_fdr)] %>% 
        .[,logFC_plot:=ifelse(logFC<=-xlim, -xlim, ifelse(logFC>=xlim, xlim, logFC))] %>%
        .[,log10_padj_fdr:=ifelse(-log10(padj_fdr)>=ylim, ylim, -log10(padj_fdr))]
    
    labels = tmp[, head(.SD, ntop),  by=sign][sign!='nonsig']
    
    negative_hits <- tmp[sign == 'neg',gene]
    positive_hits <- tmp[sign == 'pos',gene]
    all <- nrow(tmp[!is.na(sign)])
    
    p = ggplot(tmp, aes(logFC_plot, log10_padj_fdr, col=sign, size = sign)) + 
        geom_point() + 
        scale_colour_manual(values=c('pos' = 'red', 'neg' = 'blue', 'nonsig' = 'black')) + 
        scale_size_manual(values=c('pos' = 1, 'neg' = 1, 'nonsig' = 0.2)) + 
        geom_vline(xintercept=c(-logFC_thr, logFC_thr),  linetype = "longdash") +
        geom_segment(aes(x=0, xend=0, y=0, yend=ylim*1.05), color="orange", linewidth=0.5) +
        geom_hline(yintercept=-log10(FDR_thr),  linetype = "longdash") + 
        ggrepel::geom_text_repel(data=labels, aes(label=gene), 
                                 color='black',
                                 size=5,
                                 box.padding = 0.5, 
                                 max.overlaps = Inf,
                                 bg.color='white', 
                                 bg.r = 0.1) + 
        scale_x_continuous(limits=c(-xlim*1.05,xlim*1.05), expand = c(0,0)) +
        scale_y_continuous(limits=c(0,ylim*1.2), expand = c(0,0)) +
        annotate("text", x=0, y=ylim*1.1, size=6, label=sprintf("(%d)", all)) +
        annotate("text", x=-xlim*0.9, y=ylim*1.15, size=6, label=sprintf("%d (-)",length(negative_hits))) +
        annotate("text", x=xlim*0.9, y=ylim*1.15, size=6, label=sprintf("%d (+)",length(positive_hits))) +
        #xlim(c(-max(abs(tmp$logFC)), max(abs(tmp$logFC)))) + 
        ggtitle(title) + 
        theme_bw() + 
        theme(text = element_text(size=15, color='black'),
             axis.text = element_text(size=15, color='black'),
             legend.position = 'none',
              plot.title = element_text(hjust=0.5))
    
    return(p)
}

# %%
cell_metadata.dt = meta[genotype == 'WT']
cell_metadata.dt = cell_metadata.dt[,group:=paste0(celltype_v2, '.', genotype)]

args$min_cells = 25
args$fraction_cells_per_replicate = 0.4
args$nrep = 5
args$min_CDR = 0.30

# Define groups
opts$groups <- c(args$groupA,args$groupB)

# %%
##################################
## Create pseudobulk replicates ##
##################################

cell2replicate.dt <- lapply(unique(cell_metadata.dt$group), function(i){
  tmp <- cell_metadata.dt[group==i]
  if ((args$fraction_cells_per_replicate*nrow(tmp))<=args$min_cells) {
    return(NULL) # ncells_per_replicate <- args$min_cells
  } else {
    ncells_per_replicate <- round(args$fraction_cells_per_replicate*nrow(tmp))

    seq(1,args$nrep) %>% map(function(j) {
    tmp[sample.int(nrow(tmp),ncells_per_replicate, replace=F)] %>% 
      .[,replicate:=sprintf("%s_rep%s",i,j)] %>%
      .[,c("cell","group","replicate")] %>% 
      return
    }) %>% rbindlist %>% return
  }
}) %>% rbindlist

stats.dt <- cell2replicate.dt[,.(ncells=.N),c("group","replicate")]
print(stats.dt)
# Out:
#                      group                   replicate ncells
#  1:    Primitive_Streak.WT    Primitive_Streak.WT_rep1   2244
#  2:    Primitive_Streak.WT    Primitive_Streak.WT_rep2   2244
#  3:    Primitive_Streak.WT    Primitive_Streak.WT_rep3   2244
#  4:    Primitive_Streak.WT    Primitive_Streak.WT_rep4   2244
#  5:    Primitive_Streak.WT    Primitive_Streak.WT_rep5   2244
#  6:       Early_Mes_EOi.WT       Early_Mes_EOi.WT_rep1    701
#  7:       Early_Mes_EOi.WT       Early_Mes_EOi.WT_rep2    701
#  8:       Early_Mes_EOi.WT       Early_Mes_EOi.WT_rep3    701
#  9:       Early_Mes_EOi.WT       Early_Mes_EOi.WT_rep4    701
# 10:       Early_Mes_EOi.WT       Early_Mes_EOi.WT_rep5    701
# 11:       Early_Mes_EOd.WT       Early_Mes_EOd.WT_rep1   2195
# 12:       Early_Mes_EOd.WT       Early_Mes_EOd.WT_rep2   2195
# 13:       Early_Mes_EOd.WT       Early_Mes_EOd.WT_rep3   2195
# 14:       Early_Mes_EOd.WT       Early_Mes_EOd.WT_rep4   2195
# 15:       Early_Mes_EOd.WT       Early_Mes_EOd.WT_rep5   2195
# 16:                 PGC.WT                 PGC.WT_rep1    140
# 17:                 PGC.WT                 PGC.WT_rep2    140
# 18:                 PGC.WT                 PGC.WT_rep3    140
# 19:                 PGC.WT                 PGC.WT_rep4    140
# 20:                 PGC.WT                 PGC.WT_rep5    140
# 21:       Posterior_Mes.WT       Posterior_Mes.WT_rep1    226
# 22:       Posterior_Mes.WT       Posterior_Mes.WT_rep2    226
# 23:       Posterior_Mes.WT       Posterior_Mes.WT_rep3    226
# 24:       Posterior_Mes.WT       Posterior_Mes.WT_rep4    226
# 25:       Posterior_Mes.WT       Posterior_Mes.WT_rep5    226
# 26:        HE_Precursor.WT        HE_Precursor.WT_rep1    516
# 27:        HE_Precursor.WT        HE_Precursor.WT_rep2    516
# 28:        HE_Precursor.WT        HE_Precursor.WT_rep3    516
# 29:        HE_Precursor.WT        HE_Precursor.WT_rep4    516
# 30:        HE_Precursor.WT        HE_Precursor.WT_rep5    516
# 31:                  HE.WT                  HE.WT_rep1    694
# 32:                  HE.WT                  HE.WT_rep2    694
# 33:                  HE.WT                  HE.WT_rep3    694
# 34:                  HE.WT                  HE.WT_rep4    694
# 35:                  HE.WT                  HE.WT_rep5    694
# 36:          Mesenchyme.WT          Mesenchyme.WT_rep1    670
# 37:          Mesenchyme.WT          Mesenchyme.WT_rep2    670
# 38:          Mesenchyme.WT          Mesenchyme.WT_rep3    670
# 39:          Mesenchyme.WT          Mesenchyme.WT_rep4    670
# 40:          Mesenchyme.WT          Mesenchyme.WT_rep5    670
# 41: Allantois_Precursor.WT Allantois_Precursor.WT_rep1    160
# 42: Allantois_Precursor.WT Allantois_Precursor.WT_rep2    160
# 43: Allantois_Precursor.WT Allantois_Precursor.WT_rep3    160
# 44: Allantois_Precursor.WT Allantois_Precursor.WT_rep4    160
# 45: Allantois_Precursor.WT Allantois_Precursor.WT_rep5    160
# 46:    Blood_Progenitor.WT    Blood_Progenitor.WT_rep1     98
# 47:    Blood_Progenitor.WT    Blood_Progenitor.WT_rep2     98
# 48:    Blood_Progenitor.WT    Blood_Progenitor.WT_rep3     98
# 49:    Blood_Progenitor.WT    Blood_Progenitor.WT_rep4     98
# 50:    Blood_Progenitor.WT    Blood_Progenitor.WT_rep5     98
# 51:         Endothelium.WT         Endothelium.WT_rep1     82
# 52:         Endothelium.WT         Endothelium.WT_rep2     82
# 53:         Endothelium.WT         Endothelium.WT_rep3     82
# 54:         Endothelium.WT         Endothelium.WT_rep4     82
# 55:         Endothelium.WT         Endothelium.WT_rep5     82
# 56:           Allantois.WT           Allantois.WT_rep1    172
# 57:           Allantois.WT           Allantois.WT_rep2    172
# 58:           Allantois.WT           Allantois.WT_rep3    172
# 59:           Allantois.WT           Allantois.WT_rep4    172
# 60:           Allantois.WT           Allantois.WT_rep5    172
#                      group                   replicate ncells

# %%
##################################
## Create pseudobulk replicates ##
##################################

cell2replicate.dt <- lapply(unique(cell_metadata.dt$group), function(i){
  # Select group
  tmp <- cell_metadata.dt[group==i]
  # continue only if enough cells
  if ((args$fraction_cells_per_replicate*nrow(tmp))>=args$min_cells) {
      # determine nr cells per replicate
      ncells_per_replicate <- round(args$fraction_cells_per_replicate*nrow(tmp))
      # randomly sample cells
      seq(1,args$nrep) %>% map(function(j) {
        tmp[sample.int(nrow(tmp),ncells_per_replicate, replace=F)] %>% 
          .[,replicate:=sprintf("%s_rep%s",i,j)] %>%
          .[,c("cell","group","replicate")] %>% 
          return
  }) %>% rbindlist %>% return
}}) %>% rbindlist

stats.dt <- cell2replicate.dt[,.(ncells=.N),c("group","replicate")]
print(stats.dt)
# Out:
#                      group                   replicate ncells
#  1:    Primitive_Streak.WT    Primitive_Streak.WT_rep1   2244
#  2:    Primitive_Streak.WT    Primitive_Streak.WT_rep2   2244
#  3:    Primitive_Streak.WT    Primitive_Streak.WT_rep3   2244
#  4:    Primitive_Streak.WT    Primitive_Streak.WT_rep4   2244
#  5:    Primitive_Streak.WT    Primitive_Streak.WT_rep5   2244
#  6:       Early_Mes_EOi.WT       Early_Mes_EOi.WT_rep1    701
#  7:       Early_Mes_EOi.WT       Early_Mes_EOi.WT_rep2    701
#  8:       Early_Mes_EOi.WT       Early_Mes_EOi.WT_rep3    701
#  9:       Early_Mes_EOi.WT       Early_Mes_EOi.WT_rep4    701
# 10:       Early_Mes_EOi.WT       Early_Mes_EOi.WT_rep5    701
# 11:       Early_Mes_EOd.WT       Early_Mes_EOd.WT_rep1   2195
# 12:       Early_Mes_EOd.WT       Early_Mes_EOd.WT_rep2   2195
# 13:       Early_Mes_EOd.WT       Early_Mes_EOd.WT_rep3   2195
# 14:       Early_Mes_EOd.WT       Early_Mes_EOd.WT_rep4   2195
# 15:       Early_Mes_EOd.WT       Early_Mes_EOd.WT_rep5   2195
# 16:                 PGC.WT                 PGC.WT_rep1    140
# 17:                 PGC.WT                 PGC.WT_rep2    140
# 18:                 PGC.WT                 PGC.WT_rep3    140
# 19:                 PGC.WT                 PGC.WT_rep4    140
# 20:                 PGC.WT                 PGC.WT_rep5    140
# 21:       Posterior_Mes.WT       Posterior_Mes.WT_rep1    226
# 22:       Posterior_Mes.WT       Posterior_Mes.WT_rep2    226
# 23:       Posterior_Mes.WT       Posterior_Mes.WT_rep3    226
# 24:       Posterior_Mes.WT       Posterior_Mes.WT_rep4    226
# 25:       Posterior_Mes.WT       Posterior_Mes.WT_rep5    226
# 26:        HE_Precursor.WT        HE_Precursor.WT_rep1    516
# 27:        HE_Precursor.WT        HE_Precursor.WT_rep2    516
# 28:        HE_Precursor.WT        HE_Precursor.WT_rep3    516
# 29:        HE_Precursor.WT        HE_Precursor.WT_rep4    516
# 30:        HE_Precursor.WT        HE_Precursor.WT_rep5    516
# 31:                  HE.WT                  HE.WT_rep1    694
# 32:                  HE.WT                  HE.WT_rep2    694
# 33:                  HE.WT                  HE.WT_rep3    694
# 34:                  HE.WT                  HE.WT_rep4    694
# 35:                  HE.WT                  HE.WT_rep5    694
# 36:          Mesenchyme.WT          Mesenchyme.WT_rep1    670
# 37:          Mesenchyme.WT          Mesenchyme.WT_rep2    670
# 38:          Mesenchyme.WT          Mesenchyme.WT_rep3    670
# 39:          Mesenchyme.WT          Mesenchyme.WT_rep4    670
# 40:          Mesenchyme.WT          Mesenchyme.WT_rep5    670
# 41: Allantois_Precursor.WT Allantois_Precursor.WT_rep1    160
# 42: Allantois_Precursor.WT Allantois_Precursor.WT_rep2    160
# 43: Allantois_Precursor.WT Allantois_Precursor.WT_rep3    160
# 44: Allantois_Precursor.WT Allantois_Precursor.WT_rep4    160
# 45: Allantois_Precursor.WT Allantois_Precursor.WT_rep5    160
# 46:    Blood_Progenitor.WT    Blood_Progenitor.WT_rep1     98
# 47:    Blood_Progenitor.WT    Blood_Progenitor.WT_rep2     98
# 48:    Blood_Progenitor.WT    Blood_Progenitor.WT_rep3     98
# 49:    Blood_Progenitor.WT    Blood_Progenitor.WT_rep4     98
# 50:    Blood_Progenitor.WT    Blood_Progenitor.WT_rep5     98
# 51:         Endothelium.WT         Endothelium.WT_rep1     82
# 52:         Endothelium.WT         Endothelium.WT_rep2     82
# 53:         Endothelium.WT         Endothelium.WT_rep3     82
# 54:         Endothelium.WT         Endothelium.WT_rep4     82
# 55:         Endothelium.WT         Endothelium.WT_rep5     82
# 56:           Allantois.WT           Allantois.WT_rep1    172
# 57:           Allantois.WT           Allantois.WT_rep2    172
# 58:           Allantois.WT           Allantois.WT_rep3    172
# 59:           Allantois.WT           Allantois.WT_rep4    172
# 60:           Allantois.WT           Allantois.WT_rep5    172
#                      group                   replicate ncells

# %%
head(cell2replicate.dt)
# Out:
#   cell                                     group
# 1 1A_Eo_DEG_G9_day3#CGCAAATTCCCATAAA-1     Primitive_Streak.WT
# 2 1B_Eo_DEG_G9_day3#GGATTTATCTTGGACG-1     Primitive_Streak.WT
# 3 1A_Eo_DEG_G9_day3#CGTGTTACATTGCAGC-1     Primitive_Streak.WT
# 4 2_Eo_DEG_G9_day3_5_VC#GTTTACCGTGTTTGTC-1 Primitive_Streak.WT
# 5 1A_Eo_DEG_G9_day3#ACCCAACCAACTCGCG-1     Primitive_Streak.WT
# 6 1B_Eo_DEG_G9_day3#GTTGTGAGTTAAGCCA-1     Primitive_Streak.WT
#   replicate
# 1 Primitive_Streak.WT_rep1
# 2 Primitive_Streak.WT_rep1
# 3 Primitive_Streak.WT_rep1
# 4 Primitive_Streak.WT_rep1
# 5 Primitive_Streak.WT_rep1
# 6 Primitive_Streak.WT_rep1

# %%
sce = rna.sce[, cell2replicate.dt$cell] 
sce$group_by = cell2replicate.dt$replicate

# %%
################
## Pseudobulk ##
################
BPPARAM$workers = 24 # for some reason crashed when not using this
sce_full = scuttle::aggregateAcrossCells(sce, id=sce$group_by, BPPARAM = BPPARAM)

assayNames(sce_full) <- "counts"
sce_full = as(sce_full, 'SingleCellExperiment')
rm(sce)

###################
## Normalisation ##
###################
# log cpm
logcounts(sce_full) <- log2(1e6*(sweep(counts(sce_full),2,colSums(counts(sce_full)),"/"))+1)

# %%
sce_full
rna.sce
# Out:
# class: SingleCellExperiment
# dim: 32285 60
# metadata(0):
# assays(2): counts logcounts
# rownames(32285): Xkr4 Gm1992 ... AC234645.1 AC149090.1
# rowData names(0):
# colnames(60): Allantois_Precursor.WT_rep1 Allantois_Precursor.WT_rep2
#   ... Primitive_Streak.WT_rep4 Primitive_Streak.WT_rep5
# colData names(30): barcode sample ... ids ncells
# reducedDimNames(0):
# mainExpName: RNA
# altExpNames(0):
# class: SingleCellExperiment
# dim: 32285 19740
# metadata(0):
# assays(2): counts logcounts
# rownames(32285): Xkr4 Gm1992 ... AC234645.1 AC149090.1
# rowData names(0):
# colnames(19740): 1A_Eo_DEG_G9_day3#AAACAGCCAGCAAGAT-1
#   1A_Eo_DEG_G9_day3#AAACAGCCAGCACCAT-1 ...
#   rv_eo_deg_day4_control#TTTGTGGCATCCCTCA-1
#   rv_eo_deg_day4_control#TTTGTGTTCCTGAATA-1
# colData names(27): barcode sample ... celltype_v1 celltype_v2
# reducedDimNames(0):
# mainExpName: RNA
# altExpNames(0):

# %%
###################
## Normalisation ##
###################

# log cpm
logcounts(sce_full) <- log2(1e6*(sweep(counts(sce_full),2,colSums(counts(sce_full)),"/"))+1)

# %%
sce_full$celltype_v2 <- colnames(sce_full) %>% strsplit("\\.") %>% map_chr(1)
sce_full$genotype <- colnames(sce_full) %>% strsplit("\\.") %>% map_chr(2) %>% strsplit('_rep') %>% map_chr(1)
sce_full$celltype_genotype = paste0(sce_full$celltype_v2, '_', sce_full$genotype)

# %%
# ct =  'Early_Mes_EOd'
# min.expr = 0.5
# min.cdr = 0.2

find_DEGs = function(celltype1, celltype2, min.expr = 0.3, min.cdr = 0.15){
      message(paste0(celltype1, ' vs ', celltype2))
      sce <- sce_full[,sce_full$celltype_v2 %in% c(celltype1, celltype2)]
      sce$group = factor(ifelse(sce$celltype_v2 == celltype2, 'fg', 'bg'), levels = c('fg', 'bg'))
      singlecell_sce <- rna.sce[,rna.sce$celltype_v2 %in% c(celltype1, celltype2)]

        #######################################
        ## Calculate Cellular Detection Rate ##
        #######################################
        expr.dt <- data.table(
          gene = rownames(rna.sce),
          mean_groupA = rowMeans(logcounts(rna.sce[,sce$celltype_v2 == celltype1])) %>% round(2),
          mean_groupB = rowMeans(logcounts(rna.sce[,sce$celltype_v2 == celltype2])) %>% round(2),
          cdr_groupA = rowMeans(counts(singlecell_sce[,singlecell_sce$celltype_v2 == celltype1])>0) %>% round(2),
          cdr_groupB = rowMeans(counts(singlecell_sce[,singlecell_sce$celltype_v2 == celltype2])>0) %>% round(2)
        )

        #######################
        ## Feature selection ##
        #######################
        # Filter features
        features.to.use <- expr.dt[mean_groupA>=min.expr | mean_groupB>=min.expr,][cdr_groupA>=min.cdr | cdr_groupB>=min.cdr,gene]
        message(paste0('Nr of Genes: ', length(features.to.use)))
        ################################################
        ## Differential expression testing with edgeR ##
        ################################################

        # Convert SCE to DGEList
        sce_edger <- scran::convertTo(sce[features.to.use,], type="edgeR")
        
        # Calculate Normalisation Factors
        sce_edger <- calcNormFactors(sce_edger)
        
        # Define design matrix (with intercept)
        design <- model.matrix(~sce$group)

        # Estimate dispersions
        sce_edger  <- estimateDisp(sce_edger,design)

        # Fit GLM
        fit <- glmQLFit(sce_edger,design)

        # Likelihood ratio test
        lrt <- glmQLFTest(fit)

        # Construct output data.frame
        out <- topTags(lrt, n=nrow(lrt))$table %>% as.data.table(keep.rownames=T) %>%
          setnames(c("gene","logFC","logCPM","LR","p.value","padj_fdr")) %>%
          .[,c("logCPM","LR","p.value"):=NULL] %>%
          .[,c("padj_fdr","logFC"):=list(signif(padj_fdr,digits=3), round(logFC,3))] %>%
          merge(expr.dt, by="gene", all.y=TRUE) %>%
          setorder(padj_fdr, na.last=T) %>%
          .[!is.na(logFC)]
    
        return(out)
}

# %%
DEGs = find_DEGs('Early_Mes_EOd', 'Early_Mes_EOi')
# Out:
# Early_Mes_EOd vs Early_Mes_EOi
#
# Nr of Genes: 6455

# %%
volcano_plot(DEGs, xlim = 2, ylim = 50, logFC_thr = 0.5)
# Out:
# Warning message:
# “Using `size` aesthetic for lines was deprecated in ggplot2 3.4.0.
# ℹ Please use `linewidth` instead.”
# plot without title

# %%
fwrite(DEGs, file.path(args$outdir, 'DEGs_edgeR.csv'), sep = ',')

# %%
head(DEGs[gene == 'Eomes'])
# Out:
#   gene  logFC padj_fdr mean_groupA mean_groupB cdr_groupA cdr_groupB sign
# 1 Eomes 0.93  3.07e-30 1.2         1.19        0.84       0.65       pos

# %%
options(repr.plot.width = 5, repr.plot.height = 6)
volcano_plot(DEGs, xlim = 3, ylim = 40, logFC_thr = 0.5, ntop = 15)
# Out:
# plot without title

# %%
# Gene Ontology
GO_plot = function(plot){
    ggplot(plot, 
           aes(enrichment, Term, color = -log10(FDR), fill = -log10(FDR), size = DE)) +  #, 
        geom_bar(stat = 'identity', aes(fill = -log10(FDR)), color = NA,  width = 0.05) +
        geom_point() + 
        geom_text(aes(x = max(plot$enrichment)/100, label = Term), vjust = -0.5, hjust = 0, color = 'black', size = 5 * 0.35) + 
        guides(fill = guide_colourbar(
             barwidth = 0.5, barheight = 2.5,
            frame.colour = "black", 
            ticks.colour = "black"
        )) + 
        scale_size(range = c(0, 1)) + 
        scale_fill_gradientn(colors = c('white', 'blue', 'red'), limits = c(0, max(-log10(plot$FDR))), name = '-log10(FDR)') + 
        scale_color_gradientn(colors = c('white', 'blue', 'red'), limits = c(0, max(-log10(plot$FDR))), name = '-log10(FDR)') + 
        scale_x_continuous(limits = c(0, max(plot$enrichment)), expand = c(0,0,0,3)) + 
        scale_y_discrete(expand = c(0,0.3,0,1.5)) + 
        theme_bw() + 
        theme(axis.text = element_text(size = 5, color = 'black'),
                axis.text.y = element_blank(), 
                axis.ticks.y = element_blank(),
                axis.title.x = element_text(size = 7),
                axis.title.y = element_blank(),
                panel.border = element_rect(color='black', linewidth=0.5, fill = NA),
                panel.background = element_rect(fill = 'white'),
                panel.grid.major = element_blank(), panel.grid.minor = element_blank(),
             #   plot.margin = margin(0, 0, 0, 0),  # Adjust the margin around the plot
                # legend.margin = margin(0, 0, 0, 0),  # Adjust the margin inside the legend box
                # legend.box.margin = margin(0, 0, 0, 0),  # Adjust the margin outside the legend box
                legend.key.size  = unit(1, "mm"),
                legend.key = element_blank(),
                legend.position = 'right')
}

genes = DEGs[sign == 'pos', gene]
tmp = do_GO(genes, background = rownames(rna.sce))
p1 = GO_plot(tmp[[1]] %>% copy() %>%
           .[FDR < 0.05] %>% .[Ont == 'BP'] %>% .[N > 20 & N < 1000 & DE > 3 & enrichment > 3] %>% .[order(-enrichment)] %>% 
           # .[FDR < 0.05] %>% .[Ont == 'BP'] %>% .[N > 50 & N < 1000 & DE > 3 & enrichment > 5] %>% .[order(FDR)] %>% 
            .[,Term := factor(Term, levels = rev(Term))] %>% 
            .[, enrichment := ifelse(enrichment > 100, 100, enrichment)] %>% 
            head(7)
)

genes = DEGs[sign == 'neg', gene]
tmp = do_GO(genes, background = rownames(rna.sce))
p2 = GO_plot(tmp[[1]] %>% copy() %>%
           .[FDR < 0.05] %>% .[Ont == 'BP'] %>% .[N > 20 & N < 1000 & DE > 3 & enrichment > 3] %>% .[order(-enrichment)] %>% 
           # .[FDR < 0.05] %>% .[Ont == 'BP'] %>% .[N > 50 & N < 1000 & DE > 3 & enrichment > 5] %>% .[order(FDR)] %>% 
            .[,Term := factor(Term, levels = rev(Term))] %>% 
            .[, enrichment := ifelse(enrichment > 100, 100, enrichment)] %>% 
            head(7)
)
# Out:
# 'select()' returned 1:many mapping between keys and columns
#
# 'select()' returned 1:many mapping between keys and columns

# %%
options(repr.plot.width = 20, repr.plot.height = 4)
ggarrange(p1, p2, align = 'hv')
# Out:
# plot without title

# %%
genes = DEGs[sign == 'pos', gene]
tmp = do_GO(genes, background = rownames(rna.sce))
tmp[[1]] %>% copy() %>%
           .[FDR < 0.05] %>% .[Ont == 'BP'] %>% .[N > 20 & N < 1000 & DE > 10 & enrichment > 3] %>% .[order(-enrichment)]
# Out:
# 'select()' returned 1:many mapping between keys and columns
#    GOALL
# 1  GO:0010811
# 2  GO:0007369
# 3  GO:0010810
# 4  GO:0048754
# 5  GO:0035265
# 6  GO:0007160
# 7  GO:0098742
# 8  GO:0061138
# 9  GO:0001763
# 10 GO:0048762
# 11 GO:0007411
# 12 GO:0097485
# 13 GO:0045165
# 14 GO:0048738
# 15 GO:0031589
# 16 GO:0060485
# 17 GO:0090092
# 18 GO:0090287
# 19 GO:0045765
# 20 GO:0014706
# 21 GO:1901342
# 22 GO:0030198
# 23 GO:0043062
# 24 GO:0045229
# 25 GO:0050769
# 26 GO:0070372
# 27 GO:0090130
# 28 GO:0060562
# 29 GO:0022604
# 30 GO:0003002
# 31 GO:0010631
# 32 GO:0090132
# 33 GO:0048562
# 34 GO:0070371
# 35 GO:0010720
# 36 GO:0072001
# 37 GO:0051962
#    Term
# 1  positive regulation of cell-substrate adhesion
# 2  gastrulation
# 3  regulation of cell-substrate adhesion
# 4  branching morphogenesis of an epithelial tube
# 5  organ growth
# 6  cell-matrix adhesion
# 7  cell-cell adhesion via plasma-membrane adhesion molecules
# 8  morphogenesis of a branching epithelium
# 9  morphogenesis of a branching structure
# 10 mesenchymal cell differentiation
# 11 axon guidance
# 12 neuron projection guidance
# 13 cell fate commitment
# 14 cardiac muscle tissue development
# 15 cell-substrate adhesion
# 16 mesenchyme development
# 17 regulation of transmembrane receptor protein serine/threonine kinase signaling pathway
# 18 regulation of cellular response to growth factor stimulus
# 19 regulation of angiogenesis
# 20 striated muscle tissue development
# 21 regulation of vasculature development
# 22 extracellular matrix organization
# 23 extracellular structure organization
# 24 external encapsulating structure organization
# 25 positive regulation of neurogenesis
# 26 regulation of ERK1 and ERK2 cascade
# 27 tissue migration
# 28 epithelial tube morphogenesis
# 29 regulation of cell morphogenesis
# 30 regionalization
# 31 epithelial cell migration
# 32 epithelium migration
# 33 embryonic organ morphogenesis
# 34 ERK1 and ERK2 cascade
# 35 positive regulation of cell development
# 36 renal system development
# 37 positive regulation of nervous system development
#    Ont N   DE P.DE         FDR          enrichment
# 1  BP  137 15 1.293291e-16 6.163880e-14 25.801854
# 2  BP  182 12 6.627819e-11 1.365988e-08 11.696051
# 3  BP  223 18 2.567920e-17 1.468658e-14 11.685938
# 4  BP  191 11 1.687409e-09 2.523062e-07  9.734793
# 5  BP  212 12 5.008371e-10 8.746297e-08  8.620061
# 6  BP  231 13 7.785393e-11 1.576163e-08  7.865389
# 7  BP  216 11 6.425936e-09 8.121886e-07  7.611776
# 8  BP  229 11 1.123284e-08 1.338405e-06  6.772087
# 9  BP  249 13 1.772417e-10 3.378964e-08  6.769326
# 10 BP  243 12 1.892288e-09 2.739865e-07  6.560992
# 11 BP  248 12 3.541192e-09 4.765403e-07  6.299102
# 12 BP  249 12 3.697935e-09 4.890038e-07  6.248609
# 13 BP  293 15 1.100948e-11 2.708214e-09  5.641009
# 14 BP  265 12 5.884210e-09 7.478504e-07  5.516839
# 15 BP  368 23 2.211519e-19 1.945881e-16  5.483186
# 16 BP  302 15 1.460603e-11 3.444765e-09  5.309800
# 17 BP  267 11 6.793459e-08 7.096528e-06  4.981624
# 18 BP  312 15 2.759389e-11 6.069861e-09  4.974883
# 19 BP  296 13 2.371907e-09 3.349513e-07  4.790278
# 20 BP  285 12 1.300190e-08 1.533219e-06  4.769714
# 21 BP  300 13 2.770473e-09 3.814210e-07  4.663389
# 22 BP  319 13 4.045991e-09 5.319548e-07  4.124419
# 23 BP  320 13 4.199086e-09 5.458096e-07  4.098682
# 24 BP  321 13 4.357410e-09 5.631890e-07  4.073184
# 25 BP  297 11 2.071339e-07 1.982679e-05  4.026063
# 26 BP  319 12 4.537570e-08 4.966794e-06  3.807156
# 27 BP  325 12 5.536339e-08 5.989405e-06  3.667882
# 28 BP  394 17 5.646540e-12 1.435288e-09  3.535552
# 29 BP  334 12 6.727612e-08 7.059981e-06  3.472875
# 30 BP  387 16 4.477803e-11 9.573709e-09  3.449045
# 31 BP  321 11 4.264094e-07 3.795707e-05  3.446541
# 32 BP  323 11 4.527899e-07 3.984028e-05  3.403991
# 33 BP  327 11 4.950660e-07 4.306321e-05  3.321222
# 34 BP  342 12 9.819813e-08 1.002892e-05  3.312301
# 35 BP  376 14 3.667991e-09 4.878641e-07  3.197077
# 36 BP  339 11 7.632040e-07 6.372197e-05  3.090253
# 37 BP  358 12 1.589719e-07 1.560858e-05  3.022846
#    genes
# 1  Braf, Cdh13, Fbln1, Fbln2, Fn1, Has2, Foxf1, Itga5, Kdr, Nrp1, Pcsk5, Prkce, Ptprj, Tdgf1, Prex1
# 2  Eomes, Fn1, Fzd7, Gata4, Gata6, Foxf1, Hmga2, Itga5, Smad1, Tdgf1, Tenm4, Crb2
# 3  Kank1, Braf, Cdh13, Fbln1, Fbln2, Fn1, Fzd7, Has2, Foxf1, Itga5, Kdr, Nrp1, Pcsk5, Prkce, Ptprj, Tdgf1, Prex1, Dlc1
# 4  Col4a1, Fgf10, Foxf1, Hmga2, Kdr, Ncoa3, Nrp1, Pdgfra, Tbx3, Hs3st3b1, Tbx20
# 5  Cacna1c, Fgf10, Gata4, Gata6, Kdr, Smad1, Ncam1, Pdgfra, Tcf7l2, Tenm4, Cacna2d2, Tbx20
# 6  Adamts9, Itga9, Cdh13, Col13a1, Fn1, Itga5, Itgb5, Kdr, Nrp1, Pcsk5, Ptprj, Tdgf1, Dlc1
# 7  Cdh11, Cdh13, Cdh4, Itga5, Robo1, Prtg, Tenm4, Crb2, Nrcam, Clstn2, Pcdh18
# 8  Col4a1, Fgf10, Foxf1, Hmga2, Kdr, Ncoa3, Nrp1, Pdgfra, Tbx3, Hs3st3b1, Tbx20
# 9  Col13a1, Col4a1, Fgf10, Foxf1, Hmga2, Kdr, Ncoa3, Nrp1, Pdgfra, Tbx3, Tdgf1, Hs3st3b1, Tbx20
# 10 Cyp26a1, Eomes, Fgf10, Fn1, Has2, Hmga2, Nrp1, Tbx3, Tcf7l2, Zic2, Crb2, Tbx20
# 11 Cdh4, Gas1, Ncam1, Nrp1, Plxna2, Robo1, Zic2, Ece1, Prtg, Nrcam, Kalrn, Bcl11b
# 12 Cdh4, Gas1, Ncam1, Nrp1, Plxna2, Robo1, Zic2, Ece1, Prtg, Nrcam, Kalrn, Bcl11b
# 13 Braf, Runx1, Eomes, Fgf10, Fzd7, Gas1, Gata4, Gata6, Kdr, Smad1, Tbx3, Tcf7l2, Tenm4, Tbx20, Bcl11b
# 14 Adamts9, Fgf3, Fzd7, Gata4, Gata6, Smad1, Ncam1, Pdgfra, Tbx3, Tdgf1, Tenm4, Tbx20
# 15 Adamts9, Itga9, Kank1, Braf, Cdh13, Col13a1, Fbln1, Fbln2, Fn1, Fzd7, Has2, Foxf1, Itga5, Itgb5, Kdr, Parvb, Nrp1, Pcsk5, Prkce, Ptprj, Tdgf1, Prex1, Dlc1
# 16 Cyp26a1, Eomes, Fgf10, Fn1, Gata4, Has2, Foxf1, Hmga2, Nrp1, Robo1, Tbx3, Tcf7l2, Zic2, Crb2, Tbx20
# 17 Fbn2, Fgf10, Gata4, Gata6, Kdr, Tcf7l2, Zeb1, Tdgf1, Zic2, Crb2, Tbx20
# 18 Cd59a, Fbn2, Fgf10, Gata4, Gata6, Kdr, Nrp1, Robo1, Tcf7l2, Zeb1, Tdgf1, Vegfc, Crb2, Adamts3, Tbx20
# 19 Adamts9, Tafa5, Runx1, Cd59a, Col4a2, Gata4, Gata6, Hmga2, Itga5, Kdr, Smad1, Nrp1, Vegfc
# 20 Adamts9, Fgf3, Fzd7, Gata4, Gata6, Smad1, Ncam1, Pdgfra, Tbx3, Tdgf1, Tenm4, Tbx20
# 21 Adamts9, Tafa5, Runx1, Cd59a, Col4a2, Gata4, Gata6, Hmga2, Itga5, Kdr, Smad1, Nrp1, Vegfc
# 22 Adamts9, Aplp2, Col13a1, Col4a1, Col4a2, Fbln1, Fbln2, Fn1, Has2, Foxf1, Pdgfra, Pmp22, Adamts3
# 23 Adamts9, Aplp2, Col13a1, Col4a1, Col4a2, Fbln1, Fbln2, Fn1, Has2, Foxf1, Pdgfra, Pmp22, Adamts3
# 24 Adamts9, Aplp2, Col13a1, Col4a1, Col4a2, Fbln1, Fbln2, Fn1, Has2, Foxf1, Pdgfra, Pmp22, Adamts3
# 25 Braf, Cdh4, Fn1, Kdr, Nin, Nrp1, Plxna2, Robo1, Vegfc, Tenm4, Kalrn
# 26 Braf, Ackr3, Fbln1, Fgf10, Fn1, Gata4, Kdr, Nrp1, Pdgfra, Ece1, Mfhas1, Rps6ka6
# 27 Adamts9, Kank1, Cdh13, Fgf10, Has2, Foxf1, Kdr, Nrp1, Prkce, Robo1, Vegfc, Amotl1
# 28 Col4a1, Fgf10, Fgf3, Gata4, Foxf1, Hmga2, Kdr, Ncoa3, Nrp1, Pdgfra, Robo1, Tbx3, Zic2, Kif26b, Dlc1, Hs3st3b1, Tbx20
# 29 Kank1, Braf, Fbln1, Fn1, Has2, Kdr, Parvb, Nrp1, Plxna2, Prex1, Dlc1, Kalrn
# 30 Cyp26a1, Eomes, Fgf10, Fgf3, Gas1, Gata4, Foxf1, Nrp1, Pcsk5, Plxna2, Robo1, Tbx3, Tdgf1, Zic2, Crb2, Tbx20
# 31 Adamts9, Kank1, Cdh13, Fgf10, Has2, Kdr, Nrp1, Prkce, Robo1, Vegfc, Amotl1
# 32 Adamts9, Kank1, Cdh13, Fgf10, Has2, Kdr, Nrp1, Prkce, Robo1, Vegfc, Amotl1
# 33 Fgf10, Fgf3, Gas1, Gata4, Foxf1, Pdgfra, Tbx3, Tcf7l2, Zeb1, Crb2, Tbx20
# 34 Braf, Ackr3, Fbln1, Fgf10, Fn1, Gata4, Kdr, Nrp1, Pdgfra, Ece1, Mfhas1, Rps6ka6
# 35 Braf, Runx1, Cdh4, Fn1, Has2, Kdr, Nin, Nrp1, Plxna2, Robo1, Vegfc, Tenm4, Prex1, Kalrn
# 36 Col4a1, Vcan, Fgf10, Foxf1, Smad1, Nrp1, Pcsk5, Pdgfra, Robo1, Kif26b, Hs3st3b1
# 37 Braf, Cdh4, Fn1, Kdr, Nin, Nrp1, Plxna2, Robo1, Vegfc, Tenm4, Kalrn, Clstn2

# %%
genes = DEGs[sign == 'neg', gene]
tmp = do_GO(genes, background = rownames(rna.sce))
tmp[[1]] %>% copy() %>%
           .[FDR < 0.05] %>% .[Ont == 'BP'] %>% .[N > 20 & N < 1000 & DE > 10 & enrichment > 3] %>% .[order(-enrichment)]
# Out:
# 'select()' returned 1:many mapping between keys and columns
#    GOALL      Term                                                      Ont N
# 1  GO:0016331 morphogenesis of embryonic epithelium                     BP  184
# 2  GO:0048839 inner ear development                                     BP  215
# 3  GO:0098742 cell-cell adhesion via plasma-membrane adhesion molecules BP  216
# 4  GO:0043583 ear development                                           BP  248
# 5  GO:0061138 morphogenesis of a branching epithelium                   BP  229
# 6  GO:0002064 epithelial cell development                               BP  234
# 7  GO:0001763 morphogenesis of a branching structure                    BP  249
# 8  GO:0003007 heart morphogenesis                                       BP  272
# 9  GO:2000146 negative regulation of cell motility                      BP  321
# 10 GO:0030336 negative regulation of cell migration                     BP  308
# 11 GO:0040013 negative regulation of locomotion                         BP  356
# 12 GO:0001822 kidney development                                        BP  325
# 13 GO:0072001 renal system development                                  BP  339
# 14 GO:0045927 positive regulation of growth                             BP  307
# 15 GO:0001655 urogenital system development                             BP  382
# 16 GO:0060562 epithelial tube morphogenesis                             BP  394
#    DE P.DE         FDR          enrichment
# 1  11 3.762351e-08 7.616930e-06 10.489573
# 2  12 2.047547e-08 4.419032e-06  8.381179
# 3  12 1.671656e-08 3.712863e-06  8.303755
# 4  13 1.052465e-08 2.577514e-06  6.824028
# 5  11 2.776586e-07 4.602895e-05  6.772087
# 6  11 5.431998e-07 8.284521e-05  6.485773
# 7  12 7.602173e-08 1.437313e-05  6.248609
# 8  12 3.025640e-07 4.944112e-05  5.236538
# 9  16 3.517188e-10 1.166126e-07  5.013150
# 10 14 1.495673e-08 3.421651e-06  4.764610
# 11 16 1.545413e-09 4.713921e-07  4.075874
# 12 13 2.565146e-07 4.346878e-05  3.973538
# 13 14 5.832483e-08 1.150256e-05  3.933050
# 14 11 8.054064e-06 8.490913e-04  3.768051
# 15 15 3.611261e-08 7.376323e-06  3.318680
# 16 15 4.408278e-08 8.769407e-06  3.119605
#    genes
# 1  Prickle1, Celsr1, Fgf8, Lama5, Nodal, Spint1, Spint2, T, Tgfb2, Grsf1, Shroom3
# 2  Abr, Cdh1, Celsr1, Fgf8, Gabrb3, H2-K1, Lrig1, Esrp1, Tgfb2, Frem2, Fat4, Ahi1
# 3  Alcam, Cdh1, Cdh6, Celsr1, Dscam, Epcam, Nrxn1, Tgfb2, Fat4, Magi2, Hmcn1, Palld
# 4  Abr, Shroom2, Cdh1, Celsr1, Fgf8, Gabrb3, H2-K1, Lrig1, Esrp1, Tgfb2, Frem2, Fat4, Ahi1
# 5  Cdh1, Celsr1, Fgf8, Lama5, Pml, Slit2, Spint1, Spint2, Esrp1, Fat4, Rspo3
# 6  Cdh1, Col18a1, Id1, F11r, Spint2, Tjp2, Ezr, Shroom3, Zdhhc21, Ccdc88c, Palld
# 7  Cdh1, Celsr1, Fgf8, Lama5, Ctnnd2, Pml, Slit2, Spint1, Spint2, Esrp1, Fat4, Rspo3
# 8  Fgf8, Id2, Nodal, Pdcd4, Slit2, Slit3, T, Tgfb2, Tpm1, Zfpm2, Fat4, Ahi1
# 9  Abr, Cdh1, Igfbp3, Nodal, Ptprk, Slit2, Spint2, Tpm1, Frmd5, Mcc, Magi2, Ldlrad4, Trp53inp1, Ifitm3, Bst2, Limch1
# 10 Abr, Cdh1, Igfbp3, Nodal, Ptprk, Slit2, Tpm1, Mcc, Magi2, Ldlrad4, Trp53inp1, Ifitm3, Bst2, Limch1
# 11 Abr, Cdh1, Igfbp3, Nodal, Ptprk, Slit2, Spint2, Tpm1, Frmd5, Mcc, Magi2, Ldlrad4, Trp53inp1, Ifitm3, Bst2, Limch1
# 12 Adamts6, Fgf8, Id2, Lama5, Epcam, Prom1, Slit2, Tgfb2, Fras1, Frem2, Fat4, Ahi1, Pdgfd
# 13 Adamts6, Mecom, Fgf8, Id2, Lama5, Epcam, Prom1, Slit2, Tgfb2, Fras1, Frem2, Fat4, Ahi1, Pdgfd
# 14 Agrn, Rims2, Dscam, Fgf8, Ghr, Itsn2, Tgfb2, Ezr, Zfpm2, Ahi1, Nedd4l
# 15 Adamts6, Cyp7b1, Mecom, Fgf8, Id2, Lama5, Epcam, Prom1, Slit2, Tgfb2, Fras1, Frem2, Fat4, Ahi1, Pdgfd
# 16 Prickle1, Celsr1, Fgf8, Lama5, Nodal, Pml, Slit2, Spint1, Spint2, Esrp1, T, Tgfb2, Shroom3, Fat4, Ahi1

# %% [markdown]
# ## ATAC analysis

# %%
suppressPackageStartupMessages(library(ArchR))
addArchRThreads(32)
# Out:
# Setting default number of Parallel threads to 32.

# %%
ArchRProject <- loadArchRProject(io$archR.directory)[meta$cell]
# Out:
# Successfully loaded ArchRProject!
#
#
#                                                    / |
#                                                  /    \
#             .                                  /      |.
#             \\\                              /        |.
#               \\\                          /           `|.
#                 \\\                      /              |.
#                   \                    /                |\
#                   \\#####\           /                  ||
#                 ==###########>      /                   ||
#                  \\##==......\    /                     ||
#             ______ =       =|__ /__                     ||      \\\
#         ,--' ,----`-,__ ___/'  --,-`-===================##========>
#        \               '        ##_______ _____ ,--,__,=##,__   ///
#         ,    __==    ___,-,__,--'#'  ==='      `-'    | ##,-/
#         -,____,---'       \\####\\________________,--\\_##,/
#            ___      .______        ______  __    __  .______
#           /   \     |   _  \      /      ||  |  |  | |   _  \
#          /  ^  \    |  |_)  |    |  ,----'|  |__|  | |  |_)  |
#         /  /_\  \   |      /     |  |     |   __   | |      /
#        /  _____  \  |  |\  \\___ |  `----.|  |  |  | |  |\  \\___.
#       /__/     \__\ | _| `._____| \______||__|  |__| | _| `._____|

# %%
# Create new SCE to prepare for pseudobulking
atac.sce = getMatrixFromProject(
                  ArchRProj = ArchRProject,
                  useMatrix = "PeakMatrix")
atac.sce$celltype_v2 = meta[match(colnames(atac.sce), cell), celltype_v2] # add cell type
assayNames(atac.sce) <- "counts"

# prepare replicates
sce = atac.sce[,cell2replicate.dt$cell] 
sce$group_by <- cell2replicate.dt$replicate
# Out:
# ArchR logging to : ArchRLogs/ArchR-getMatrixFromProject-21070790c09d5-Date-2024-12-03_Time-14-48-08.log
# If there is an issue, please report to github with logFile!
#
# 2024-12-03 14:48:58 : Organizing colData, 0.829 mins elapsed.
#
# 2024-12-03 14:48:58 : Organizing rowData, 0.834 mins elapsed.
#
# 2024-12-03 14:48:58 : Organizing rowRanges, 0.834 mins elapsed.
#
# 2024-12-03 14:48:58 : Organizing Assays (1 of 1), 0.834 mins elapsed.
#
# 2024-12-03 14:49:18 : Constructing SummarizedExperiment, 1.176 mins elapsed.
#
# 2024-12-03 14:49:41 : Finished Matrix Creation, 1.546 mins elapsed.

# %%
################
## Pseudobulk ##
################
BPPARAM$workers = 24 # for some reason crashed when not using this
sce_full = scuttle::aggregateAcrossCells(sce, id=sce$group_by, BPPARAM = BPPARAM)

assayNames(sce_full) <- "counts"
sce_full = as(sce_full, 'SingleCellExperiment')
rm(sce)

###################
## Normalisation ##
###################
# log cpm
logcounts(sce_full) <- log2(1e6*(sweep(counts(sce_full),2,colSums(counts(sce_full)),"/"))+1)

# %%
# prepare single-cell ATAC for CDR
atac.sce = as(atac.sce, 'SingleCellExperiment')
atac.sce = atac.sce[,cell_metadata.dt$cell]
summary(colnames(atac.sce) == cell_metadata.dt$cell)

# Get peakset
peakSet = as.data.table(ArchRProject@peakSet) %>% 
    .[, feature:=paste0(seqnames, ':', start, '-', end)] %>%
    .[,idx:=1:nrow(.)] %>%
    .[,c('feature', 'idx')]
features = peakSet$feature

# fix other things
assayNames(atac.sce) <- "counts"
rownames(atac.sce) = features
rownames(sce_full) = features
# Out:
#    Mode    TRUE
# logical   19740

# %%
atac.sce
sce_full
# Out:
# class: SingleCellExperiment
# dim: 234908 19740
# metadata(0):
# assays(1): counts
# rownames(234908): chr1:3003470-3004070 chr1:3035598-3036198 ...
#   chrX:169925416-169926016 chrX:169937236-169937836
# rowData names(1): idx
# colnames(19740): 1A_Eo_DEG_G9_day3#AAACAGCCAGCAAGAT-1
#   1A_Eo_DEG_G9_day3#AAACAGCCAGCACCAT-1 ...
#   rv_eo_deg_day4_control#TTTGTGGCATCCCTCA-1
#   rv_eo_deg_day4_control#TTTGTGTTCCTGAATA-1
# colData names(40): BlacklistRatio nDiFrags ... replicate celltype_v2
# reducedDimNames(0):
# mainExpName: NULL
# altExpNames(0):
# class: SingleCellExperiment
# dim: 234908 60
# metadata(0):
# assays(2): counts logcounts
# rownames(234908): chr1:3003470-3004070 chr1:3035598-3036198 ...
#   chrX:169925416-169926016 chrX:169937236-169937836
# rowData names(1): idx
# colnames(60): Allantois_Precursor.WT_rep1 Allantois_Precursor.WT_rep2
#   ... Primitive_Streak.WT_rep4 Primitive_Streak.WT_rep5
# colData names(43): BlacklistRatio nDiFrags ... ids ncells
# reducedDimNames(0):
# mainExpName: NULL
# altExpNames(0):

# %%
# ct =  'Early_Mes_EOd'
# min.expr = 0.5
# min.cdr = 0.2

find_DARs = function(celltype1, celltype2, min.expr = 0.3, min.cdr = 0.15){
      message(paste0(celltype1, ' vs ', celltype2))
      sce <- sce_full[,sce_full$celltype_v2 %in% c(celltype1, celltype2)]
      sce$group = factor(ifelse(sce$celltype_v2 == celltype2, 'fg', 'bg'), levels = c('fg', 'bg'))
      singlecell_sce <- atac.sce[,atac.sce$celltype_v2 %in% c(celltype1, celltype2)]

        #######################################
        ## Calculate Cellular Detection Rate ##
        #######################################
        expr.dt <- data.table(
          gene = rownames(atac.sce),
          mean_groupA = rowMeans(logcounts(sce[,sce$celltype_v2 == celltype1])) %>% round(2),
          mean_groupB = rowMeans(logcounts(sce[,sce$celltype_v2 == celltype2])) %>% round(2),
          cdr_groupA = rowMeans(counts(singlecell_sce[,singlecell_sce$celltype_v2 == celltype1])>0) %>% round(2),
          cdr_groupB = rowMeans(counts(singlecell_sce[,singlecell_sce$celltype_v2 == celltype2])>0) %>% round(2)
        )

        #######################
        ## Feature selection ##
        #######################
        # Filter features
        features.to.use <- expr.dt[mean_groupA>=min.expr | mean_groupB>=min.expr,][cdr_groupA>=min.cdr | cdr_groupB>=min.cdr,gene]
        message(paste0('Nr of peaks: ', length(features.to.use)))
        ################################################
        ## Differential expression testing with edgeR ##
        ################################################

        # Convert SCE to DGEList
        sce_edger <- scran::convertTo(sce[features.to.use,], type="edgeR")
        
        # Calculate Normalisation Factors
        sce_edger <- calcNormFactors(sce_edger)
        
        # Define design matrix (with intercept)
        design <- model.matrix(~sce$group)

        # Estimate dispersions
        sce_edger  <- estimateDisp(sce_edger,design)

        # Fit GLM
        fit <- glmQLFit(sce_edger,design)

        # Likelihood ratio test
        lrt <- glmQLFTest(fit)

        # Construct output data.frame
        out <- topTags(lrt, n=nrow(lrt))$table %>% as.data.table(keep.rownames=T) %>%
          .[,idx:=NULL] %>% 
          setnames(c("gene","logFC","logCPM","LR","p.value","padj_fdr")) %>%
          .[,c("logCPM","LR","p.value"):=NULL] %>%
          .[,c("padj_fdr","logFC"):=list(signif(padj_fdr,digits=3), round(logFC,3))] %>%
          merge(expr.dt, by="gene", all.y=TRUE) %>%
          setorder(padj_fdr, na.last=T) %>%
          .[!is.na(logFC)]
    
        return(out)
}

# %%
DARs = find_DARs('Early_Mes_EOd', 'Early_Mes_EOi')
# Out:
# Early_Mes_EOd vs Early_Mes_EOi
#
# Nr of peaks: 32740
#
# Warning message in .local(x, row.names, optional, ...):
# “Arguments in '...' ignored”

# %%
fwrite(DARs, file.path(args$outdir, 'DARs_edgeR.csv'), sep = ',')

# %%
options(repr.plot.width = 5, repr.plot.height = 5)
volcano_plot(DARs, xlim = 2.2, ylim = 150, logFC_thr = 0.5, ntop = 0)
# Out:
# plot without title

# %%
# matches <- getMatches(ArchRProject, 'Motif_cisbp')
# rownames(matches) = rownames(atac.sce)

io$multiome = '/rds/project/rds-SDzz0CATGms/users/bt392/09_Eomes_invitro_blood/results/multiome_atlas/'
silico_chip = readRDS(file.path(io$multiome, 'vitro_peaks_silicoChIP_cisbp.rds'))
assay(silico_chip, 'matches') = assay(silico_chip, 'VirtualChipScores') > 0.2 # keep only motifs with in silico score > 0.2
assay(silico_chip, 'motifScores') = NULL
assay(silico_chip, 'motifMatches') = NULL
assay(silico_chip, 'motifCounts') = NULL
assay(silico_chip, 'VirtualChipScores') = NULL
matches = silico_chip

# Need to re-run in silico ChIP on new peak set...
# Definitely do this in the future...
# for now:
# matches = motifmatcher.se

# %%
head(DARs)
# Out:
#   gene                     logFC padj_fdr  mean_groupA mean_groupB cdr_groupA
# 1 chr7:46454349-46454949   2.017 9.86e-160 4.36        2.56        0.30
# 2 chr1:128551897-128552497 1.684 4.20e-159 4.60        3.05        0.34
# 3 chr18:82897845-82898445  1.686 9.25e-155 4.54        3.00        0.34
# 4 chr18:80624992-80625592  1.180 7.88e-151 5.05        3.94        0.45
# 5 chr7:142330308-142330908 1.131 5.63e-150 5.09        4.03        0.45
# 6 chr7:82890994-82891594   1.904 3.53e-146 4.26        2.56        0.28
#   cdr_groupB sign
# 1 0.08       pos
# 2 0.11       pos
# 3 0.10       pos
# 4 0.20       pos
# 5 0.19       pos
# 6 0.08       pos

# %%
options(repr.plot.width = 10, repr.plot.height = 3)

tmp2 = as.data.table(ArchR:::.computeEnrichment(matches, DARs[sign == 'pos', gene], seq_len(nrow(matches)))) %>%
        .[,feature := str_split(feature, '_') %>% map_chr(1)] %>% 
        .[mlog10Padj > -log10(0.05)]

to.plot = tmp2[order(-mlog10Padj)] %>% .[,I := .I]
ggplot(head(to.plot, 50), aes(I, mlog10Padj, color = Enrichment)) + 
    geom_point() + 
    ggrepel::geom_text_repel(data = head(to.plot,10), aes(label = feature), color = 'black') + 
    theme_bw()

tmp2 = as.data.table(ArchR:::.computeEnrichment(matches, DARs[sign == 'neg', gene], seq_len(nrow(matches)))) %>%
        .[,feature := str_split(feature, '_') %>% map_chr(1)] %>% 
        .[mlog10Padj > -log10(0.05)]

to.plot = tmp2[order(-mlog10Padj)] %>% .[,I := .I]
ggplot(head(to.plot, 50), aes(I, mlog10Padj, color = Enrichment)) + 
    geom_point() + 
    ggrepel::geom_text_repel(data = head(to.plot,10), aes(label = feature), color = 'black') + 
    theme_bw()
# Out:
# plot without title
# plot without title

# %%
tmp2 = as.data.table(ArchR:::.computeEnrichment(matches, DARs[sign == 'pos', gene], seq_len(nrow(matches)))) %>%
        .[,feature := str_split(feature, '_') %>% map_chr(1)] %>% 
        .[mlog10Padj > -log10(0.05)]

to.plot = tmp2[order(-mlog10Padj)] %>% .[,I := .I]

fwrite(to.plot, file.path(args$outdir, 'DARs_edgeR_motif_pos.csv'), sep = ',')

tmp2 = as.data.table(ArchR:::.computeEnrichment(matches, DARs[sign == 'neg', gene], seq_len(nrow(matches)))) %>%
        .[,feature := str_split(feature, '_') %>% map_chr(1)] %>% 
        .[mlog10Padj > -log10(0.05)]

to.plot = tmp2[order(-mlog10Padj)] %>% .[,I := .I]

fwrite(to.plot, file.path(args$outdir, 'DARs_edgeR_motif_neg.csv'), sep = ',')

# %%
ArchRProject <- addCellColData(ArchRProj = ArchRProject, 
                                    data = as.character(meta$celltype_v2),
                                    cells = meta$cell,
                                    name = "celltype_v2",
                                    force=TRUE)

# %%
markers = getMarkerFeatures(
        ArchRProj = ArchRProject,
        groupBy = "celltype_v2",
        useGroups = 'Early_Mes_EOd',
        bgdGroups = 'Early_Mes_EOi',
        useMatrix = "PeakMatrix",
      testMethod = "binomial",
  binarize = TRUE,

        verbose = F)
# Out:
# ArchR logging to : ArchRLogs/ArchR-getMarkerFeatures-210706d7516fe-Date-2024-12-03_Time-14-50-17.log
# If there is an issue, please report to github with logFile!
#
# MatrixClass = Sparse.Integer.Matrix
#
# Pairwise Test Early_Mes_EOd : Seqnames chr1
#
# Pairwise Test Early_Mes_EOd : Seqnames chr10
#
# Pairwise Test Early_Mes_EOd : Seqnames chr11
#
# Pairwise Test Early_Mes_EOd : Seqnames chr12
#
# Pairwise Test Early_Mes_EOd : Seqnames chr13
#
# Pairwise Test Early_Mes_EOd : Seqnames chr14
#
# Pairwise Test Early_Mes_EOd : Seqnames chr15
#
# Pairwise Test Early_Mes_EOd : Seqnames chr16
#
# Pairwise Test Early_Mes_EOd : Seqnames chr17
#
# Pairwise Test Early_Mes_EOd : Seqnames chr18
#
# Pairwise Test Early_Mes_EOd : Seqnames chr19
#
# Pairwise Test Early_Mes_EOd : Seqnames chr2
#
# Pairwise Test Early_Mes_EOd : Seqnames chr3
#
# Pairwise Test Early_Mes_EOd : Seqnames chr4
#
# Pairwise Test Early_Mes_EOd : Seqnames chr5
#
# Pairwise Test Early_Mes_EOd : Seqnames chr6
#
# Pairwise Test Early_Mes_EOd : Seqnames chr7
#
# Pairwise Test Early_Mes_EOd : Seqnames chr8
#
# Pairwise Test Early_Mes_EOd : Seqnames chr9
#
# Pairwise Test Early_Mes_EOd : Seqnames chrX
#
# ArchR logging successful to : ArchRLogs/ArchR-getMarkerFeatures-210706d7516fe-Date-2024-12-03_Time-14-50-17.log

# %%
DARs2 = data.table(peak = paste0(rowData(markers)$seqnames, ':', rowData(markers)$start, '-', rowData(markers)$end),
                              FDR = assay(markers[,1], 'FDR')[[1]],
                              log2FC = assay(markers[,1], 'Log2FC')[[1]]) %>% 
                    .[order(FDR)]

# %%
fwrite(DARs2, file.path(args$outdir, 'DARs_archr.csv'), sep = ',')

# %%
options(repr.plot.width = 10, repr.plot.height = 3)

tmp2 = as.data.table(ArchR:::.computeEnrichment(matches, DARs2[log2FC > 0.5 & FDR < 5e-2, peak], seq_len(nrow(matches)))) %>%
        .[,feature := str_split(feature, '_') %>% map_chr(1)] %>% 
        .[mlog10Padj > -log10(0.05)]

to.plot = tmp2[order(-mlog10Padj)] %>% .[,I := .I]
ggplot(head(to.plot, 50), aes(I, mlog10Padj, color = Enrichment)) + 
    geom_point() + 
    ggrepel::geom_text_repel(data = head(to.plot,10), aes(label = feature), color = 'black') + 
    theme_bw()

tmp2 = as.data.table(ArchR:::.computeEnrichment(matches, DARs2[log2FC < 0.5 & FDR < 5e-2, peak], seq_len(nrow(matches)))) %>%
        .[,feature := str_split(feature, '_') %>% map_chr(1)] %>% 
        .[mlog10Padj > -log10(0.05)]

to.plot = tmp2[order(-mlog10Padj)] %>% .[,I := .I]
ggplot(head(to.plot, 50), aes(I, mlog10Padj, color = Enrichment)) + 
    geom_point() + 
    ggrepel::geom_text_repel(data = head(to.plot,10), aes(label = feature), color = 'black') + 
    theme_bw()
# Out:
# plot without title
# plot without title

# %%
tmp2 = as.data.table(ArchR:::.computeEnrichment(matches, DARs[sign == 'pos', gene], seq_len(nrow(matches)))) %>%
        .[,feature := str_split(feature, '_') %>% map_chr(1)] %>% 
        .[mlog10Padj > -log10(0.05)]

to.plot = tmp2[order(-mlog10Padj)] %>% .[,I := .I]

fwrite(to.plot, file.path(args$outdir, 'DARs_archr_motif_pos.csv'), sep = ',')

tmp2 = as.data.table(ArchR:::.computeEnrichment(matches, DARs[sign == 'neg', gene], seq_len(nrow(matches)))) %>%
        .[,feature := str_split(feature, '_') %>% map_chr(1)] %>% 
        .[mlog10Padj > -log10(0.05)]

to.plot = tmp2[order(-mlog10Padj)] %>% .[,I := .I]

fwrite(to.plot, file.path(args$outdir, 'DARs_archr_motif_neg.csv'), sep = ',')

# %% [markdown]
# # ChromVAR comparison!!!

# %%
getAvailableMatrices(ArchRProject)
# Out:
#  [1] "DeviationMatrix_CISBP"   "DeviationMatrix_JASPAR"
#  [3] "GeneScoreMatrix_TSS"     "GeneScoreMatrix_distal"
#  [5] "MarkerPeaksMatrix"       "MotifMatrix"
#  [7] "PeakMatrix"              "PeakMatrix_atlas"
#  [9] "TileMatrix"              "silicoChIP_CISBPMatrix"
# [11] "silicoChIP_CISBP_v2"     "silicoChIP_JASPARMatrix"
# [13] "silicoChIP_JASPAR_v2"

# %%
diffMotif = getMarkerFeatures(
        ArchRProj = ArchRProject,
        groupBy = "celltype_v2",
        useGroups = 'Early_Mes_EOi',
        bgdGroups = 'Early_Mes_EOd',
        useMatrix = "silicoChIP_CISBP_v2",
        useSeqnames = 'z',
        verbose = F)
# Out:
# ArchR logging to : ArchRLogs/ArchR-getMarkerFeatures-2107069741174-Date-2024-12-03_Time-14-51-07.log
# If there is an issue, please report to github with logFile!
#
# MatrixClass = Sparse.Assays.Matrix
#
# Pairwise Test Early_Mes_EOi : Seqnames z
#
# ArchR logging successful to : ArchRLogs/ArchR-getMarkerFeatures-2107069741174-Date-2024-12-03_Time-14-51-07.log

# %%
diffMotif.dt = lapply(colnames(diffMotif), function(x){
    tmp = data.table(motif = str_split(rowData(diffMotif)$name, '_') %>% map_chr(1),
                                  FDR = assay(diffMotif[,x], 'FDR')[[1]],
                                  MeanDiff = assay(diffMotif[,x], 'MeanDiff')[[1]]) %>% 
                        .[order(-MeanDiff)] %>% 
                        .[,celltype_v2 := x]
    return(tmp)
}) %>% rbindlist() %>% .[MeanDiff != Inf]

# %%
fwrite(diffMotif.dt, file.path(args$outdir, 'diffChromVar_silicochip.csv'), sep = ',')

# %%
ggplot(diffMotif.dt, aes(MeanDiff, -log10(FDR))) + 
    geom_point()
# Out:
# plot without title

# %%
head(diffMotif.dt, 8)
tail(diffMotif.dt, 8)
# Out:
#   motif  FDR          MeanDiff  celltype_v2
# 1 TFAP2C 1.770134e-27 1.5125595 Early_Mes_EOi
# 2 SOX2   6.724976e-24 1.4250693 Early_Mes_EOi
# 3 CDX2   1.533863e-21 1.3758635 Early_Mes_EOi
# 4 TFAP2A 3.081478e-16 1.1635044 Early_Mes_EOi
# 5 HOXA9  7.778184e-10 1.0696529 Early_Mes_EOi
# 6 CDX1   8.335365e-13 0.9930758 Early_Mes_EOi
# 7 POU5F1 1.289584e-10 0.9496892 Early_Mes_EOi
# 8 CDX4   6.815070e-09 0.8801454 Early_Mes_EOi
#   motif FDR          MeanDiff  celltype_v2
# 1 HAND2 3.953712e-30 -1.480886 Early_Mes_EOi
# 2 LHX1  1.128973e-40 -1.489024 Early_Mes_EOi
# 3 SNAI1 7.351792e-52 -1.774248 Early_Mes_EOi
# 4 LEF1  5.245710e-33 -1.934893 Early_Mes_EOi
# 5 TBX20 2.522120e-72 -2.226068 Early_Mes_EOi
# 6 GATA5 3.483106e-60 -3.036763 Early_Mes_EOi
# 7 GATA4 9.342831e-71 -3.164833 Early_Mes_EOi
# 8 GATA6 1.688226e-72 -3.976190 Early_Mes_EOi

# %%
diffMotif.dt[motif == 'EOMES']
# Out:
#   motif FDR          MeanDiff   celltype_v2
# 1 EOMES 3.239685e-05 -0.7613385 Early_Mes_EOi

# %%
sce
# Out:
# Error in eval(expr, envir, enclos): object 'sce' not found
# Traceback:

# %%
gene = 'Mixl1'
meta$gene = as.vector(logcounts(rna.sce[gene, meta$cell]))
ggplot(meta[order(gene)], aes(UMAP1, UMAP2, color = gene)) + 
    geom_point(size = 0.2) + 
    theme_void()

ggplot(meta[order(gene)], aes(celltype_v2, gene, fill = celltype_v2)) + 
    geom_violin(scale = 'width') + 
    theme_void()
# Out:
# plot without title
# plot without title

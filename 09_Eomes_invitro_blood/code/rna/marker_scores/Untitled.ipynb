# %%
a = system(command = 'ls', intern=T)

# %%
command = 
'#!/bin/bash
#SBATCH -p cclake-himem #-himem #skylake-himem #icelake #skylake #-himem #cclake
#SBATCH -A gottgens-sl3-cpu
#SBATCH -N 1
#SBATCH -n 24
#SBATCH --time 11:00:00
#SBATCH --job-name 01_get_markers

Rscript 01_get_markers
'

# %%
system(command= command)

# %%
a
# Out:
# [1] "01_get_markers.ipynb"  "01_get_markers.R"      "01_run_get_markers.sh"
# [4] "slurm-13780813.out"    "slurm-13782220.out"    "slurm-13804559.out"
# [7] "Untitled.ipynb"

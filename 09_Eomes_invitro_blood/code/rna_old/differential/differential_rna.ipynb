# %% [markdown]
# # Differential expression on pseudobulk with replicates

# %%
here::i_am("rna/mapping/run/mnn/mapping_mnn.R")

# Load default settings
source(here::here("settings.R"))
source(here::here("utils.R"))

# Load packages
suppressPackageStartupMessages(library(scran))
suppressPackageStartupMessages(library(scater))
suppressPackageStartupMessages(library(edgeR))
suppressPackageStartupMessages(library(org.Mm.eg.db))
# Out:
# here() starts at /rds/project/rds-SDzz0CATGms/users/bt392/09_Eomes_invitro_blood/code

# %%
args = list()
args$sce = file.path(io$basedir, 'results/rna/pseudobulk/celltype_genotype/SingleCellExperiment_pseudobulk_with_replicates.rds')
args$groupA = 'wt'
args$groupB = 'eomes_ko'
args$celltypes = opts$celltypes
args$outdir = file.path(io$basedir, 'results/rna/differential')

# %%
meta = fread(file.path(io$basedir, 'processed/rna/metadata.txt.gz'))

# %%
dir.create(args$outdir, showWarnings = F)

# Define groups
opts$groups <- c(args$groupA,args$groupB)

# %%
sce = readRDS(args$sce)

# %%
# parse annotations
if (!"celltype" %in% colnames(colData(sce))) {
  sce$celltype <- colnames(sce) %>% strsplit("-") %>% map_chr(1)
}
if (!"genotype" %in% colnames(colData(sce))) {
  sce$genotype <- colnames(sce) %>% strsplit("-") %>% map_chr(2) %>% strsplit("_rep") %>% map_chr(1)
}
if (!"celltype_genotype" %in% colnames(colData(sce))) {
  sce$celltype_genotype <- sprintf("%s_%s",sce$celltype,sce$genotype)
}

# %%
sce_full = sce

# %%
DEGs = lapply(args$celltypes, function(ct){
    print(ct)
    tmp <- sprintf("%s_%s",ct,opts$groups)
    if (any(!tmp%in%unique(sce_full$celltype_genotype))) {
      warning("...")
      out <- data.table(gene=NA, logFC=NA, padj_fdr=NA, mean_groupA=NA, mean_groupB=NA)
      #fwrite(out, args$outfile, sep="\t", na="NA", quote=F)
    } else {
      sce <- sce_full[,sce_full$celltype %in% ct]
    

        # subset genotypes
        stopifnot(opts$groups%in%sce$genotype)
        sce$genotype <- factor(sce$genotype, levels=opts$groups)
        print(table(sce$celltype_genotype))

        #########################################
        ## Calculate average expression levels ##
        #########################################

        expr.dt <- data.table(
          gene = rownames(sce),
          mean_groupA = rowMeans(logcounts(sce[,sce$genotype==args$groupA])) %>% round(2),
          mean_groupB = rowMeans(logcounts(sce[,sce$genotype==args$groupB])) %>% round(2)
        )

        #######################
        ## Feature selection ##
        #######################

        opts$min.expr <- 4 # 2**4 = 16, at least an average of 8 counts per milion for each group

        genes.to.use <- expr.dt[mean_groupA>=opts$min.expr | mean_groupB>=opts$min.expr,gene]

        ################################################
        ## Differential expression testing with edgeR ##
        ################################################

        # Convert SCE to DGEList
        sce_edger <- scran::convertTo(sce[genes.to.use,], type="edgeR")

        # Define design matrix (with intercept)
        design <- model.matrix(~sce$genotype)

        # Estimate dispersions
        sce_edger  <- estimateDisp(sce_edger,design)

        # Fit GLM
        fit <- glmQLFit(sce_edger,design)

        # Likelihood ratio test
        lrt <- glmQLFTest(fit)

        # Construct output data.frame
        out <- topTags(lrt, n=nrow(lrt))$table %>% as.data.table(keep.rownames=T) %>%
          setnames(c("gene","logFC","logCPM","LR","p.value","padj_fdr")) %>%
          .[,c("logCPM","LR","p.value"):=NULL] %>%
          .[,c("padj_fdr","logFC"):=list(signif(padj_fdr,digits=3), round(logFC,3))] %>%
          merge(expr.dt, by="gene", all.y=TRUE) %>%
          setorder(padj_fdr, na.last=T)
    }
    out = out %>% .[,celltype:=ct]
    return(out)
})
# Out:
# [1] "Epiblast"
# Warning message in FUN(X[[i]], ...):
# “...”
# [1] "Primitive_Streak"
#
# Primitive_Streak_eomes_ko       Primitive_Streak_wt
#                         5                         5
# [1] "Caudal_epiblast"
# Warning message in FUN(X[[i]], ...):
# “...”
# [1] "PGC"
#
# PGC_eomes_ko       PGC_wt
#            5            5
# [1] "Anterior_Primitive_Streak"
#
# Anterior_Primitive_Streak_eomes_ko       Anterior_Primitive_Streak_wt
#                                  5                                  5
# [1] "Notochord"
# Warning message in FUN(X[[i]], ...):
# “...”
# [1] "Def._endoderm"
# Warning message in FUN(X[[i]], ...):
# “...”
# [1] "Gut"
# Warning message in FUN(X[[i]], ...):
# “...”
# [1] "Nascent_mesoderm"
#
# Nascent_mesoderm_eomes_ko       Nascent_mesoderm_wt
#                         5                         5
# [1] "Mixed_mesoderm"
#
# Mixed_mesoderm_eomes_ko       Mixed_mesoderm_wt
#                       5                       5
# [1] "Intermediate_mesoderm"
#
# Intermediate_mesoderm_eomes_ko       Intermediate_mesoderm_wt
#                              5                              5
# [1] "Caudal_Mesoderm"
# Warning message in FUN(X[[i]], ...):
# “...”
# [1] "Paraxial_mesoderm"
# Warning message in FUN(X[[i]], ...):
# “...”
# [1] "Somitic_mesoderm"
# Warning message in FUN(X[[i]], ...):
# “...”
# [1] "Pharyngeal_mesoderm"
#
# Pharyngeal_mesoderm_eomes_ko       Pharyngeal_mesoderm_wt
#                            5                            5
# [1] "Cardiomyocytes"
# Warning message in FUN(X[[i]], ...):
# “...”
# [1] "Allantois"
#
# Allantois_eomes_ko       Allantois_wt
#                  5                  5
# [1] "ExE_mesoderm"
#
# ExE_mesoderm_eomes_ko       ExE_mesoderm_wt
#                     5                     5
# [1] "Mesenchyme"
#
# Mesenchyme_eomes_ko       Mesenchyme_wt
#                   5                   5
# [1] "Haematoendothelial_progenitors"
#
# Haematoendothelial_progenitors_eomes_ko       Haematoendothelial_progenitors_wt
#                                       5                                       5
# [1] "Endothelium"
#
# Endothelium_eomes_ko       Endothelium_wt
#                    5                    5
# [1] "Blood_progenitors_1"
# Warning message in FUN(X[[i]], ...):
# “...”
# [1] "Blood_progenitors_2"
# Warning message in FUN(X[[i]], ...):
# “...”
# [1] "Erythroid1"
# Warning message in FUN(X[[i]], ...):
# “...”
# [1] "Erythroid2"
# Warning message in FUN(X[[i]], ...):
# “...”
# [1] "Erythroid3"
# Warning message in FUN(X[[i]], ...):
# “...”
# [1] "NMP"
# Warning message in FUN(X[[i]], ...):
# “...”
# [1] "Rostral_neurectoderm"
#
# Rostral_neurectoderm_eomes_ko       Rostral_neurectoderm_wt
#                             5                             5
# [1] "Caudal_neurectoderm"
# Warning message in FUN(X[[i]], ...):
# “...”
# [1] "Neural_crest"
# Warning message in FUN(X[[i]], ...):
# “...”
# [1] "Forebrain_Midbrain_Hindbrain"
#
# Forebrain_Midbrain_Hindbrain_eomes_ko       Forebrain_Midbrain_Hindbrain_wt
#                                     5                                     5
# [1] "Spinal_cord"
# Warning message in FUN(X[[i]], ...):
# “...”
# [1] "Surface_ectoderm"
#
# Surface_ectoderm_eomes_ko       Surface_ectoderm_wt
#                         5                         5
# [1] "Visceral_endoderm"
# Warning message in FUN(X[[i]], ...):
# “...”
# [1] "ExE_endoderm"
# Warning message in FUN(X[[i]], ...):
# “...”
# [1] "ExE_ectoderm"
# Warning message in FUN(X[[i]], ...):
# “...”
# [1] "Parietal_endoderm"
# Warning message in FUN(X[[i]], ...):
# “...”

# %%
DEGs = rbindlist(DEGs)

# %%
fwrite(DEGs, file.path(args$outdir, 'DEGs.txt.gz'))

# %%
head(DEGs)
# Out:
#   gene  logFC  padj_fdr mean_groupA mean_groupB celltype
# 1 NA        NA       NA    NA          NA       Epiblast
# 2 Hspd1 -0.700 1.06e-28 10.87       10.16       Primitive_Streak
# 3 Fat3  -2.694 4.60e-27  8.29        5.60       Primitive_Streak
# 4 Rplp1  0.507 4.60e-27 10.41       10.91       Primitive_Streak
# 5 Rps3   0.477 4.60e-27 10.42       10.89       Primitive_Streak
# 6 Aldoa  1.199 6.70e-27  7.70        8.89       Primitive_Streak

# %%
plot_DEGs = function(ct, nlabels=10){
    DEG_tmp = DEGs[celltype==ct & !is.na(logFC),] %>%
        .[, sig:=ifelse(abs(logFC)>1.5 & padj_fdr<0.05, TRUE, FALSE)]
   
    if(nrow(DEG_tmp)>1){
    labels_up = DEG_tmp[sig==TRUE & logFC>0,] %>% .[order(-logFC),] %>% head(nlabels)
    labels_down = DEG_tmp[sig==TRUE & logFC<0,] %>% .[order(logFC),] %>% head(nlabels)
    labels = rbind(labels_up, labels_down)
    
    xlim = max(abs(DEG_tmp$logFC))
    
    text = data.frame(dir=c('Up', 'Down'), 
                  gene=c(nrow(DEG_tmp[sig==TRUE & logFC>0,]), 
                          nrow(DEG_tmp[sig==TRUE & logFC<0,])),
                  logFC = c(xlim, -xlim), 
                  padj_fdr = min(DEG_tmp$padj_fdr),
                     sig=c('FALSE', 'FALSE'))
    
    DEG_plot = ggplot(DEG_tmp, aes(logFC, -log10(padj_fdr), col=sig, label=gene)) + 
        geom_point() + 
        geom_text(data=text, aes(logFC, -log10(padj_fdr), label=gene), size=8) + 
        xlim(-xlim, xlim) + 
        scale_color_manual(values=c('TRUE'='red', 'FALSE'='black')) + 
        geom_vline(xintercept = 0, col='red', linetype='dotted') +
        ggrepel::geom_text_repel(data=labels, 
                                 col='black', 
                                 max.overlaps=Inf,
                                 box.padding = 0.5) + 
        ggtitle(paste0(ct, ' - ', nrow(DEG_tmp), ' genes')) +
        theme_bw() + 
        theme(#text=element_text(size=15),
             legend.position='none')
    return(DEG_plot)

    }
}

plot_GO = function(ct, nlabels=10){
    DEG_tmp = DEGs[celltype==ct & !is.na(logFC),] %>%
        .[, sig:=ifelse(abs(logFC)>1.5 & padj_fdr<0.05, TRUE, FALSE)]
   
    if(nrow(DEG_tmp)>1){
    labels_up = DEG_tmp[sig==TRUE & logFC>0,] %>% .[order(-logFC),] %>% .$gene
    up_entrez = mapIds(org.Mm.eg.db, labels_up, 'ENTREZID', 'SYMBOL')
    up_GO = as.data.table(goana(up_entrez, species="Mm"), 
                          keep.rownames=T)[order(P.DE),] %>% .[Ont=='MF'] %>% head(nlabels) %>%
        .[,Term:=factor(Term, levels=Term)] %>%
        .[,direction:='up']
        
    labels_down = DEG_tmp[sig==TRUE & logFC<0,] %>% .[order(logFC),] %>% .$gene
    entrez = mapIds(org.Mm.eg.db, labels_down, 'ENTREZID', 'SYMBOL')
    down_entrez = entrez
    down_GO = as.data.table(goana(down_entrez, species="Mm"), 
                      keep.rownames=T)[order(P.DE),] %>% .[Ont=='MF'] %>% head(nlabels) %>%
        .[,Term:=factor(Term, levels=Term)] %>% 
        .[,direction:='down']
        
    GO_terms.plot = rbind(up_GO, down_GO)
    GO_terms.plot$Term = make.names(GO_terms.plot$Term, unique=TRUE)
    GO_terms.plot = GO_terms.plot[order(-P.DE),][,Term:=factor(Term, levels=Term)]

    GO_plot = ggplot(GO_terms.plot, aes(Term, -log10(P.DE), fill=direction)) +
        geom_bar(stat='identity', col='black') + 
        geom_point(y=0, size=8) + 
        coord_flip() + 
        geom_text(label=GO_terms.plot$DE, aes(y=0), col='white', fontface='bold', size=5) + 
        ggtitle('') +
        theme_bw() + 
        facet_wrap(~direction, scales='free', ncol=1) + 
        theme(text=element_text(size=15),
             legend.position='none',
             axis.title.y=element_blank(),
             axis.text.y=element_text(color='black'),
             axis.title.x=element_blank(),
             strip.background = element_rect(fill='white'))
    return(GO_plot)
    }
}

# %%
celltypes_keep = unique(DEGs[!is.na(gene),celltype])

# %%
DEG_plots = lapply(args$celltypes, plot_DEGs)
names(DEG_plots) = args$celltypes

DEG_plots_filt = list()
for(i in celltypes_keep){
DEG_plots_filt[[i]] = DEG_plots[[i]]
}

# %%
GO_plots = lapply(args$celltypes, plot_GO, nlabels=10)
names(GO_plots) = args$celltypes

GO_plots_filt = list()
for(i in celltypes_keep){
GO_plots_filt[[i]] = GO_plots[[i]]
}
# Out:
# 'select()' returned 1:1 mapping between keys and columns
#
# 'select()' returned 1:1 mapping between keys and columns
#
# 'select()' returned 1:1 mapping between keys and columns
#
# 'select()' returned 1:1 mapping between keys and columns
#
# 'select()' returned 1:1 mapping between keys and columns
#
# 'select()' returned 1:1 mapping between keys and columns
#
# 'select()' returned 1:1 mapping between keys and columns
#
# 'select()' returned 1:1 mapping between keys and columns
#
# 'select()' returned 1:1 mapping between keys and columns
#
# 'select()' returned 1:1 mapping between keys and columns
#
# 'select()' returned 1:1 mapping between keys and columns
#
# 'select()' returned 1:1 mapping between keys and columns
#
# 'select()' returned 1:1 mapping between keys and columns
#
# 'select()' returned 1:1 mapping between keys and columns
#
# 'select()' returned 1:1 mapping between keys and columns
#
# 'select()' returned 1:1 mapping between keys and columns
#
# 'select()' returned 1:1 mapping between keys and columns
#
# 'select()' returned 1:1 mapping between keys and columns
#
# 'select()' returned 1:1 mapping between keys and columns
#
# 'select()' returned 1:1 mapping between keys and columns
#
# 'select()' returned 1:1 mapping between keys and columns
#
# 'select()' returned 1:1 mapping between keys and columns
#
# 'select()' returned 1:1 mapping between keys and columns
#
# 'select()' returned 1:1 mapping between keys and columns
#
# 'select()' returned 1:1 mapping between keys and columns
#
# 'select()' returned 1:1 mapping between keys and columns
#
# 'select()' returned 1:1 mapping between keys and columns
#
# 'select()' returned 1:1 mapping between keys and columns
#
# 'select()' returned 1:1 mapping between keys and columns
#
# 'select()' returned 1:1 mapping between keys and columns

# %%
options(repr.plot.width=15, repr.plot.height=8) 
pdf(file.path(args$outdir, 'DEGs.pdf'), height=7, width=15)
for(i in celltypes_keep){
    print(ggarrange(DEG_plots_filt[[i]], GO_plots_filt[[i]]))
}
dev.off()
# Out:
# png
#   2

# %%
ct = 'Mixed_mesoderm'
nlabels=10

    DEG_tmp = DEGs[celltype==ct & !is.na(logFC),] %>%
        .[, sig:=ifelse(abs(logFC)>1.5 & padj_fdr<0.05, TRUE, FALSE)]
   
    if(nrow(DEG_tmp)>1){
    labels_up = DEG_tmp[sig==TRUE & logFC>0,] %>% .[order(-logFC),] %>% .$gene
    up_entrez = mapIds(org.Mm.eg.db, labels_up, 'ENTREZID', 'SYMBOL')
    up_GO = as.data.table(goana(up_entrez, species="Mm"), 
                          keep.rownames=T)[order(P.DE),] %>% .[Ont=='MF'] %>% head(nlabels) %>%
        .[,Term:=factor(Term, levels=Term)] %>%
        .[,direction:='up']
        
    labels_down = DEG_tmp[sig==TRUE & logFC<0,] %>% .[order(logFC),] %>% .$gene
    entrez = mapIds(org.Mm.eg.db, labels_down, 'ENTREZID', 'SYMBOL')
    down_entrez = entrez
    down_GO = as.data.table(goana(down_entrez, species="Mm"), 
                      keep.rownames=T)[order(P.DE),] %>% .[Ont=='MF'] %>% head(nlabels) %>%
        .[,Term:=factor(Term, levels=Term)] %>% 
        .[,direction:='down']
        
    GO_terms.plot = rbind(up_GO, down_GO)
    GO_terms.plot$Term = make.names(GO_terms.plot$Term, unique=TRUE)
    }
# Out:
# 'select()' returned 1:1 mapping between keys and columns
#
# 'select()' returned 1:1 mapping between keys and columns

# %%
down_GO
# Out:
#    rn         Term
# 1  GO:0005488 binding
# 2  GO:0046872 metal ion binding
# 3  GO:0043169 cation binding
# 4  GO:0038085 vascular endothelial growth factor binding
# 5  GO:0005021 vascular endothelial growth factor-activated receptor activity
# 6  GO:0004714 transmembrane receptor protein tyrosine kinase activity
# 7  GO:0043167 ion binding
# 8  GO:0045296 cadherin binding
# 9  GO:0017154 semaphorin receptor activity
# 10 GO:0019199 transmembrane receptor protein kinase activity
#    Ont N     DE P.DE         direction
# 1  MF  14025 32 5.593184e-07 down
# 2  MF   3576 15 9.517080e-06 down
# 3  MF   3674 15 1.325666e-05 down
# 4  MF      6  2 2.209497e-05 down
# 5  MF      7  2 3.090893e-05 down
# 6  MF     59  3 5.339756e-05 down
# 7  MF   5293 17 6.482028e-05 down
# 8  MF     69  3 8.533277e-05 down
# 9  MF     12  2 9.676563e-05 down
# 10 MF     77  3 1.183321e-04 down

# %%
GO_terms.plot
# Out:
#    rn         Term
# 1  GO:0048018 receptor.ligand.activity
# 2  GO:0030546 signaling.receptor.activator.activity
# 3  GO:0030545 signaling.receptor.regulator.activity
# 4  GO:0005125 cytokine.activity
# 5  GO:0050785 advanced.glycation.end.product.receptor.activity
# 6  GO:0051978 lysophospholipid.sodium.symporter.activity
# 7  GO:0140348 lysophosphatidylcholine.flippase.activity
# 8  GO:1901480 oleate.transmembrane.transporter.activity
# 9  GO:0004666 prostaglandin.endoperoxide.synthase.activity
# 10 GO:0034988 Fc.gamma.receptor.I.complex.binding
# 11 GO:0005488 binding
# 12 GO:0046872 metal.ion.binding
# 13 GO:0043169 cation.binding
# 14 GO:0038085 vascular.endothelial.growth.factor.binding
# 15 GO:0005021 vascular.endothelial.growth.factor.activated.receptor.activity
# 16 GO:0004714 transmembrane.receptor.protein.tyrosine.kinase.activity
# 17 GO:0043167 ion.binding
# 18 GO:0045296 cadherin.binding
# 19 GO:0017154 semaphorin.receptor.activity
# 20 GO:0019199 transmembrane.receptor.protein.kinase.activity
#    Ont N     DE P.DE         direction
# 1  MF    498  4 1.161561e-04 up
# 2  MF    506  4 1.235068e-04 up
# 3  MF    550  4 1.701362e-04 up
# 4  MF    228  3 2.249546e-04 up
# 5  MF      1  1 5.328893e-04 up
# 6  MF      1  1 5.328893e-04 up
# 7  MF      1  1 5.328893e-04 up
# 8  MF      2  1 1.065512e-03 up
# 9  MF      2  1 1.065512e-03 up
# 10 MF      3  1 1.597869e-03 up
# 11 MF  14025 32 5.593184e-07 down
# 12 MF   3576 15 9.517080e-06 down
# 13 MF   3674 15 1.325666e-05 down
# 14 MF      6  2 2.209497e-05 down
# 15 MF      7  2 3.090893e-05 down
# 16 MF     59  3 5.339756e-05 down
# 17 MF   5293 17 6.482028e-05 down
# 18 MF     69  3 8.533277e-05 down
# 19 MF     12  2 9.676563e-05 down
# 20 MF     77  3 1.183321e-04 down

# %%
head(up_GO)
# Out:
#   rn         Term                                             Ont N   DE
# 1 GO:0048018 receptor ligand activity                         MF  498 4
# 2 GO:0030546 signaling receptor activator activity            MF  506 4
# 3 GO:0030545 signaling receptor regulator activity            MF  550 4
# 4 GO:0005125 cytokine activity                                MF  228 3
# 5 GO:0050785 advanced glycation end-product receptor activity MF    1 1
# 6 GO:0051978 lysophospholipid:sodium symporter activity       MF    1 1
#   P.DE         direction
# 1 0.0001161561 up
# 2 0.0001235068 up
# 3 0.0001701362 up
# 4 0.0002249546 up
# 5 0.0005328893 up
# 6 0.0005328893 up

# %%
labels_up
# Out:
#  [1] "Lefty1" "Ccno"   "Mfsd2a" "Zfp462" "Wnt3a"  "Krt19"  "Crlf1"  "Scn9a"
#  [9] "Psmb8"  "Ptgs1"  "Fmn1"   "Sgcd"   "Msgn1"  "Lgals3" "Tapbpl" "Acnat1"

# %%
GO_terms.plot = GO_terms.plot[order(-P.DE),][,Term:=factor(Term, levels=Term)]
GO_plot = ggplot(GO_terms.plot, aes(Term, -log10(P.DE), fill=direction)) +
        geom_bar(stat='identity', col='black') + 
        geom_point(y=0, size=8) + 
        coord_flip() + 
        geom_text(label=GO_terms.plot$DE, aes(y=0), col='white', fontface='bold', size=5) + 
        ggtitle('') +
        theme_bw() + 
        facet_wrap(~direction, scales='free', ncol=1) + 
        theme(text=element_text(size=15),
             legend.position='none',
             axis.title.y=element_blank(),
             axis.text.y=element_text(color='black'),
             axis.title.x=element_blank(),
             strip.background = element_rect(fill='white'))
GO_plot
# Out:
# plot without title

# %%
GO_terms.plot
# Out:
#    rn         Term
# 1  GO:0048018 receptor.ligand.activity
# 2  GO:0030546 signaling.receptor.activator.activity
# 3  GO:0030545 signaling.receptor.regulator.activity
# 4  GO:0005125 cytokine.activity
# 5  GO:0050785 advanced.glycation.end.product.receptor.activity
# 6  GO:0051978 lysophospholipid.sodium.symporter.activity
# 7  GO:0140348 lysophosphatidylcholine.flippase.activity
# 8  GO:1901480 oleate.transmembrane.transporter.activity
# 9  GO:0004666 prostaglandin.endoperoxide.synthase.activity
# 10 GO:0034988 Fc.gamma.receptor.I.complex.binding
# 11 GO:0005488 binding
# 12 GO:0046872 metal.ion.binding
# 13 GO:0043169 cation.binding
# 14 GO:0038085 vascular.endothelial.growth.factor.binding
# 15 GO:0005021 vascular.endothelial.growth.factor.activated.receptor.activity
# 16 GO:0004714 transmembrane.receptor.protein.tyrosine.kinase.activity
# 17 GO:0043167 ion.binding
# 18 GO:0045296 cadherin.binding
# 19 GO:0017154 semaphorin.receptor.activity
# 20 GO:0019199 transmembrane.receptor.protein.kinase.activity
#    Ont N     DE P.DE         direction
# 1  MF    498  4 1.161561e-04 up
# 2  MF    506  4 1.235068e-04 up
# 3  MF    550  4 1.701362e-04 up
# 4  MF    228  3 2.249546e-04 up
# 5  MF      1  1 5.328893e-04 up
# 6  MF      1  1 5.328893e-04 up
# 7  MF      1  1 5.328893e-04 up
# 8  MF      2  1 1.065512e-03 up
# 9  MF      2  1 1.065512e-03 up
# 10 MF      3  1 1.597869e-03 up
# 11 MF  14025 32 5.593184e-07 down
# 12 MF   3576 15 9.517080e-06 down
# 13 MF   3674 15 1.325666e-05 down
# 14 MF      6  2 2.209497e-05 down
# 15 MF      7  2 3.090893e-05 down
# 16 MF     59  3 5.339756e-05 down
# 17 MF   5293 17 6.482028e-05 down
# 18 MF     69  3 8.533277e-05 down
# 19 MF     12  2 9.676563e-05 down
# 20 MF     77  3 1.183321e-04 down

# %% [markdown]
# # DEGs between celltypes rather than Eomes KO vs WT

# %%
args$sce = file.path(io$basedir, 'results/rna/pseudobulk/celltype/SingleCellExperiment_pseudobulk_with_replicates.rds')
sce = readRDS(args$sce)
# parse annotations
if (!"celltype" %in% colnames(colData(sce))) {
  sce$celltype <- colnames(sce) %>% strsplit("-") %>% map_chr(1)
}
sce_full = sce

# %%
DEGs = lapply(args$celltypes, function(ct){
    message(ct)
        args$groupA = ct
        args$groupB = setdiff(args$celltypes,ct)
    if(any(ct%in%unique(sce$celltype))==FALSE) {
      message(paste0(ct, ' skipped'))
      out <- data.table(gene=NA, logFC=NA, padj_fdr=NA, mean_groupA=NA, mean_groupB=NA)
      #fwrite(out, args$outfile, sep="\t", na="NA", quote=F)
    } else {
        #########################################
        ## Calculate average expression levels ##
        #########################################

        expr.dt <- data.table(
          gene = rownames(sce),
          mean_groupA = rowMeans(logcounts(sce[,sce$celltype==args$groupA])) %>% round(2),
          mean_groupB = rowMeans(logcounts(sce[,sce$celltype%in%args$groupB])) %>% round(2)
        )

        #######################
        ## Feature selection ##
        #######################

        opts$min.expr <- 4 # 2**4 = 16, at least an average of 8 counts per milion for each group

        genes.to.use <- expr.dt[mean_groupA>=opts$min.expr | mean_groupB>=opts$min.expr,gene]

        ################################################
        ## Differential expression testing with edgeR ##
        ################################################

        # Convert SCE to DGEList
        sce_edger <- scran::convertTo(sce[genes.to.use,], type="edgeR")
        sce_edger$design = ifelse(sce_edger$celltype==ct, 'group', 'bg')
        sce_edger$design = ifelse(sce_edger$samples$celltype==ct, 'group', 'bg')
    
        # Define design matrix (with intercept)
        design <- model.matrix(~sce_edger$design)

        # Estimate dispersions
        sce_edger  <- estimateDisp(sce_edger,design)

        # Fit GLM
        fit <- glmQLFit(sce_edger,design)

        # Likelihood ratio test
        lrt <- glmQLFTest(fit)

        # Construct output data.frame
        out <- topTags(lrt, n=nrow(lrt))$table %>% as.data.table(keep.rownames=T) %>%
          setnames(c("gene","logFC","logCPM","LR","p.value","padj_fdr")) %>%
          .[,c("logCPM","LR","p.value"):=NULL] %>%
          .[,c("padj_fdr","logFC"):=list(signif(padj_fdr,digits=3), round(logFC,3))] %>%
          merge(expr.dt, by="gene", all.y=TRUE) %>%
          setorder(padj_fdr, na.last=T)
    }
    out = out %>% .[,celltype:=ct]
    return(out)
}) %>% rbindlist(.)
# Out:
# Epiblast
#
# Primitive_Streak
#
# Caudal_epiblast
#
# PGC
#
# Anterior_Primitive_Streak
#
# Notochord
#
# Warning message in FUN(X[[i]], ...):
# “Notochord skipped”
# Def._endoderm
#
# Gut
#
# Nascent_mesoderm
#
# Mixed_mesoderm
#
# Intermediate_mesoderm
#
# Caudal_Mesoderm
#
# Warning message in FUN(X[[i]], ...):
# “Caudal_Mesoderm skipped”
# Paraxial_mesoderm
#
# Somitic_mesoderm
#
# Pharyngeal_mesoderm
#
# Cardiomyocytes
#
# Warning message in FUN(X[[i]], ...):
# “Cardiomyocytes skipped”
# Allantois
#
# ExE_mesoderm
#
# Mesenchyme
#
# Haematoendothelial_progenitors
#
# Endothelium
#
# Blood_progenitors_1
#
# Blood_progenitors_2
#
# Erythroid1
#
# Erythroid2
#
# Warning message in FUN(X[[i]], ...):
# “Erythroid2 skipped”
# Erythroid3
#
# Warning message in FUN(X[[i]], ...):
# “Erythroid3 skipped”
# NMP
#
# Warning message in FUN(X[[i]], ...):
# “NMP skipped”
# Rostral_neurectoderm
#
# Caudal_neurectoderm
#
# Warning message in FUN(X[[i]], ...):
# “Caudal_neurectoderm skipped”
# Neural_crest
#
# Warning message in FUN(X[[i]], ...):
# “Neural_crest skipped”
# Forebrain_Midbrain_Hindbrain
#
# Spinal_cord
#
# Warning message in FUN(X[[i]], ...):
# “Spinal_cord skipped”
# Surface_ectoderm
#
# Visceral_endoderm
#
# Warning message in FUN(X[[i]], ...):
# “Visceral_endoderm skipped”
# ExE_endoderm
#
# Warning message in FUN(X[[i]], ...):
# “ExE_endoderm skipped”
# ExE_ectoderm
#
# Warning message in FUN(X[[i]], ...):
# “ExE_ectoderm skipped”
# Parietal_endoderm
#
# Warning message in FUN(X[[i]], ...):
# “Parietal_endoderm skipped”

# %%
options(repr.plot.width=20, repr.plot.height=15) 

ggplot(DEGs[!is.na(logFC)], aes(logFC, -log10(padj_fdr), col=ifelse(abs(logFC)>0.5 & padj_fdr<0.05, 'TRUE', 'FALSE'))) + 
    geom_point() + 
    facet_wrap(~celltype, ncol = 4, scales='free') + 
    #scale_colour_discrete(values=c('red', 'black')) + 
    theme_bw()
# Out:
# plot without title

# %% [markdown]
# # single-cell instead of pseudobulk

# %%
args$sce = file.path(io$basedir, 'processed/rna/SingleCellExperiment.rds')

# %%
meta = fread(file.path(io$basedir, 'results/rna/mapping/sample_metadata_after_mapping.txt.gz'))

# %%
meta = meta[pass_rnaQC == TRUE & doublet_call == FALSE]

# %%
sce = load_SingleCellExperiment(args$sce, cells=meta$cell, normalise = TRUE)

# %%
summary(colnames(sce) == meta$cell)
# Out:
#    Mode    TRUE
# logical   38346

# %%
sce = sce[rowMeans(logcounts(sce))>0,]

# %%
sce
# Out:
# class: SingleCellExperiment
# dim: 28550 38346
# metadata(0):
# assays(2): counts logcounts
# rownames(28550): Xkr4 Gm1992 ... CAAA01147332.1 AC149090.1
# rowData names(0):
# colnames(38346): 1A_Eo_DEG_G9_day3#AAACAGCCAGCAAGAT-1
#   1A_Eo_DEG_G9_day3#AAACAGCCAGCACCAT-1 ...
#   rv_eo_deg_day4_dtag#TTTGTGTTCATTTGTC-1
#   rv_eo_deg_day4_dtag#TTTGTTGGTACTTAGG-1
# colData names(11): barcode sample ... pass_rnaQC sizeFactor
# reducedDimNames(0):
# mainExpName: RNA
# altExpNames(0):

# %%
DEGs = lapply(args$celltypes, function(ct, min_cells = 25, min.expr=0.5){

        args$groupA = ct
        args$groupB = setdiff(args$celltypes,ct)
    if (nrow(meta[celltype == args$groupA]) < min_cells | nrow(meta[celltype %in% args$groupB]) < min_cells) {
      message(paste0(ct, ' skipped'))
      out <- data.table(gene=NA, logFC=NA, padj_fdr=NA, mean_groupA=NA, mean_groupB=NA)
      #fwrite(out, args$outfile, sep="\t", na="NA", quote=F)
    } else {
        message(ct)
        #########################################
        ## Calculate average expression levels ##
        #########################################

        expr.dt <- data.table(
          gene = rownames(sce),
          mean_groupA = rowMeans(logcounts(sce[,meta$celltype==args$groupA])) %>% round(2),
          mean_groupB = rowMeans(logcounts(sce[,meta$celltype%in%args$groupB])) %>% round(2)
        )

        #######################
        ## Feature selection ##
        #######################

        # 2**4 = 16, at least an average of 8 counts per milion for each group

        genes.to.use <- expr.dt[mean_groupA>=min.expr | mean_groupB>=min.expr,gene]

        ################################################
        ## Differential expression testing with edgeR ##
        ################################################

        # Convert SCE to DGEList
        sce_edger <- scran::convertTo(sce[genes.to.use,], type="edgeR")
        sce_edger$design = ifelse(meta$celltype==ct, 'group', 'bg')

    
        # Define design matrix (with intercept)
        design <- model.matrix(~sce_edger$design)

        # Estimate dispersions
        sce_edger  <- estimateDisp(sce_edger,design)

        # Fit GLM
        fit <- glmQLFit(sce_edger,design)

        # Likelihood ratio test
        lrt <- glmQLFTest(fit)

        # Construct output data.frame
        out <- topTags(lrt, n=nrow(lrt))$table %>% as.data.table(keep.rownames=T) %>%
          setnames(c("gene","logFC","logCPM","LR","p.value","padj_fdr")) %>%
          .[,c("logCPM","LR","p.value"):=NULL] %>%
          .[,c("padj_fdr","logFC"):=list(signif(padj_fdr,digits=3), round(logFC,3))] %>%
          merge(expr.dt, by="gene", all.y=TRUE) %>%
          setorder(padj_fdr, na.last=T)
    }
    out = out %>% .[,celltype:=ct]
    return(out)
}) %>% rbindlist(.)
# Out:
# Epiblast
# Error in glmFit.default(sely, design, offset = seloffset, dispersion = 0.05, : nrow(design) disagrees with ncol(y)
# Traceback:
#
# 1. lapply(args$celltypes, function(ct, min_cells = 25, min.expr = 0.5) {
#  .     args$groupA = ct
#  .     args$groupB = setdiff(args$celltypes, ct)
#  .     if (nrow(meta[celltype == args$groupA]) < min_cells | nrow(meta[celltype %in%
#  .         args$groupB]) < min_cells) {
#  .         message(paste0(ct, " skipped"))
#  .         out <- data.table(gene = NA, logFC = NA, padj_fdr = NA,
#  .             mean_groupA = NA, mean_groupB = NA)
#  .     }
#  .     else {
#  .         message(ct)
#  .         expr.dt <- data.table(gene = rownames(sce), mean_groupA = rowMeans(logcounts(sce[,
#  .             meta$celltype == args$groupA])) %>% round(2), mean_groupB = rowMeans(logcounts(sce[,
#  .             meta$celltype %in% args$groupB])) %>% round(2))
#  .         genes.to.use <- expr.dt[mean_groupA >= min.expr | mean_groupB >=
#  .             min.expr, gene]
#  .         sce_edger <- scran::convertTo(sce[genes.to.use, ], type = "edgeR")
#  .         sce_edger$design = ifelse(sce_edger$celltype == ct, "group",
#  .             "bg")
#  .         sce_edger$design = ifelse(sce_edger$samples$celltype ==
#  .             ct, "group", "bg")
#  .         design <- model.matrix(~sce_edger$design)
#  .         sce_edger <- estimateDisp(sce_edger, design)
#  .         fit <- glmQLFit(sce_edger, design)
#  .         lrt <- glmQLFTest(fit)
#  .         out <- topTags(lrt, n = nrow(lrt))$table %>% as.data.table(keep.rownames = T) %>%
#  .             setnames(c("gene", "logFC", "logCPM", "LR", "p.value",
#  .                 "padj_fdr")) %>% .[, `:=`(c("logCPM", "LR", "p.value"),
#  .             NULL)] %>% .[, `:=`(c("padj_fdr", "logFC"), list(signif(padj_fdr,
#  .             digits = 3), round(logFC, 3)))] %>% merge(expr.dt,
#  .             by = "gene", all.y = TRUE) %>% setorder(padj_fdr,
#  .             na.last = T)
#  .     }
#  .     out = out %>% .[, `:=`(celltype, ct)]
#  .     return(out)
#  . }) %>% rbindlist(.)
# 2. rbindlist(.)
# 3. lapply(args$celltypes, function(ct, min_cells = 25, min.expr = 0.5) {
#  .     args$groupA = ct
#  .     args$groupB = setdiff(args$celltypes, ct)
#  .     if (nrow(meta[celltype == args$groupA]) < min_cells | nrow(meta[celltype %in%
#  .         args$groupB]) < min_cells) {
#  .         message(paste0(ct, " skipped"))
#  .         out <- data.table(gene = NA, logFC = NA, padj_fdr = NA,
#  .             mean_groupA = NA, mean_groupB = NA)
#  .     }
#  .     else {
#  .         message(ct)
#  .         expr.dt <- data.table(gene = rownames(sce), mean_groupA = rowMeans(logcounts(sce[,
#  .             meta$celltype == args$groupA])) %>% round(2), mean_groupB = rowMeans(logcounts(sce[,
#  .             meta$celltype %in% args$groupB])) %>% round(2))
#  .         genes.to.use <- expr.dt[mean_groupA >= min.expr | mean_groupB >=
#  .             min.expr, gene]
#  .         sce_edger <- scran::convertTo(sce[genes.to.use, ], type = "edgeR")
#  .         sce_edger$design = ifelse(sce_edger$celltype == ct, "group",
#  .             "bg")
#  .         sce_edger$design = ifelse(sce_edger$samples$celltype ==
#  .             ct, "group", "bg")
#  .         design <- model.matrix(~sce_edger$design)
#  .         sce_edger <- estimateDisp(sce_edger, design)
#  .         fit <- glmQLFit(sce_edger, design)
#  .         lrt <- glmQLFTest(fit)
#  .         out <- topTags(lrt, n = nrow(lrt))$table %>% as.data.table(keep.rownames = T) %>%
#  .             setnames(c("gene", "logFC", "logCPM", "LR", "p.value",
#  .                 "padj_fdr")) %>% .[, `:=`(c("logCPM", "LR", "p.value"),
#  .             NULL)] %>% .[, `:=`(c("padj_fdr", "logFC"), list(signif(padj_fdr,
#  .             digits = 3), round(logFC, 3)))] %>% merge(expr.dt,
#  .             by = "gene", all.y = TRUE) %>% setorder(padj_fdr,
#  .             na.last = T)
#  .     }
#  .     out = out %>% .[, `:=`(celltype, ct)]
#  .     return(out)
#  . })
# 4. lapply(args$celltypes, function(ct, min_cells = 25, min.expr = 0.5) {
#  .     args$groupA = ct
#  .     args$groupB = setdiff(args$celltypes, ct)
#  .     if (nrow(meta[celltype == args$groupA]) < min_cells | nrow(meta[celltype %in%
#  .         args$groupB]) < min_cells) {
#  .         message(paste0(ct, " skipped"))
#  .         out <- data.table(gene = NA, logFC = NA, padj_fdr = NA,
#  .             mean_groupA = NA, mean_groupB = NA)
#  .     }
#  .     else {
#  .         message(ct)
#  .         expr.dt <- data.table(gene = rownames(sce), mean_groupA = rowMeans(logcounts(sce[,
#  .             meta$celltype == args$groupA])) %>% round(2), mean_groupB = rowMeans(logcounts(sce[,
#  .             meta$celltype %in% args$groupB])) %>% round(2))
#  .         genes.to.use <- expr.dt[mean_groupA >= min.expr | mean_groupB >=
#  .             min.expr, gene]
#  .         sce_edger <- scran::convertTo(sce[genes.to.use, ], type = "edgeR")
#  .         sce_edger$design = ifelse(sce_edger$celltype == ct, "group",
#  .             "bg")
#  .         sce_edger$design = ifelse(sce_edger$samples$celltype ==
#  .             ct, "group", "bg")
#  .         design <- model.matrix(~sce_edger$design)
#  .         sce_edger <- estimateDisp(sce_edger, design)
#  .         fit <- glmQLFit(sce_edger, design)
#  .         lrt <- glmQLFTest(fit)
#  .         out <- topTags(lrt, n = nrow(lrt))$table %>% as.data.table(keep.rownames = T) %>%
#  .             setnames(c("gene", "logFC", "logCPM", "LR", "p.value",
#  .                 "padj_fdr")) %>% .[, `:=`(c("logCPM", "LR", "p.value"),
#  .             NULL)] %>% .[, `:=`(c("padj_fdr", "logFC"), list(signif(padj_fdr,
#  .             digits = 3), round(logFC, 3)))] %>% merge(expr.dt,
#  .             by = "gene", all.y = TRUE) %>% setorder(padj_fdr,
#  .             na.last = T)
#  .     }
#  .     out = out %>% .[, `:=`(celltype, ct)]
#  .     return(out)
#  . })
# 5. FUN(X[[i]], ...)
# 6. estimateDisp(sce_edger, design)   # at line 42 of file <text>
# 7. estimateDisp.DGEList(sce_edger, design)
# 8. estimateDisp(y = y$counts, design = design, group = group, lib.size = lib.size,
#  .     offset = getOffset(y), prior.df = prior.df, trend.method = trend.method,
#  .     tagwise = tagwise, span = span, min.row.sum = min.row.sum,
#  .     grid.length = grid.length, grid.range = grid.range, robust = robust,
#  .     winsor.tail.p = winsor.tail.p, tol = tol, weights = y$weights,
#  .     ...)
# 9. estimateDisp.default(y = y$counts, design = design, group = group,
#  .     lib.size = lib.size, offset = getOffset(y), prior.df = prior.df,
#  .     trend.method = trend.method, tagwise = tagwise, span = span,
#  .     min.row.sum = min.row.sum, grid.length = grid.length, grid.range = grid.range,
#  .     robust = robust, winsor.tail.p = winsor.tail.p, tol = tol,
#  .     weights = y$weights, ...)
# 10. glmFit(sely, design, offset = seloffset, dispersion = 0.05, prior.count = 0)
# 11. glmFit.default(sely, design, offset = seloffset, dispersion = 0.05,
#   .     prior.count = 0)
# 12. stop("nrow(design) disagrees with ncol(y)")

# %%
ct = 'Epiblast'
min.expr = 0.5

# %%
 message(ct)
        #########################################
        ## Calculate average expression levels ##
        #########################################

        expr.dt <- data.table(
          gene = rownames(sce),
          mean_groupA = rowMeans(logcounts(sce[,meta$celltype==args$groupA])) %>% round(2),
          mean_groupB = rowMeans(logcounts(sce[,meta$celltype%in%args$groupB])) %>% round(2)
        )

        #######################
        ## Feature selection ##
        #######################

        # 2**4 = 16, at least an average of 8 counts per milion for each group

        genes.to.use <- expr.dt[mean_groupA>=min.expr | mean_groupB>=min.expr,gene]
# Out:
# Epiblast

# %%
        ################################################
        ## Differential expression testing with edgeR ##
        ################################################

        # Convert SCE to DGEList
        sce_edger <- scran::convertTo(sce[genes.to.use,], type="edgeR")
        sce_edger$design = ifelse(meta$celltype==ct, 'group', 'bg')
    
        # Define design matrix (with intercept)
        design <- model.matrix(~sce_edger$design)

# %%
        # Estimate dispersions
        sce_edger  <- estimateDisp(sce_edger,design)

# %%
        # Fit GLM
        fit <- glmQLFit(sce_edger,design)

# %%
        # Likelihood ratio test
        lrt <- glmQLFTest(fit)

        # Construct output data.frame
        out <- topTags(lrt, n=nrow(lrt))$table %>% as.data.table(keep.rownames=T) %>%
          setnames(c("gene","logFC","logCPM","LR","p.value","padj_fdr")) %>%
          .[,c("logCPM","LR","p.value"):=NULL] %>%
          .[,c("padj_fdr","logFC"):=list(signif(padj_fdr,digits=3), round(logFC,3))] %>%
          merge(expr.dt, by="gene", all.y=TRUE) %>%
          setorder(padj_fdr, na.last=T)

# %%
DEGs = fread(file.path(args$outdir, 'DEGs.txt.gz'))

# %%
DEGs = DEGs %>% .[,sig:=ifelse(abs(logFC)>1 & padj_fdr<0.05, TRUE, FALSE)] %>%
    .[sig==TRUE]

# %%
DEGs[celltype=='Nascent_mesoderm' & logFC>0, gene]
# Out:
#  [1] "Zfp462"    "Grsf1"     "Igfbp3"    "Pdgfrl"    "Limch1"    "Tapbp"
#  [7] "Zfp934"    "Erap1"     "Cpeb2"     "Fzd10"     "Dscam"     "Nodal"
# [13] "Sgcd"      "Wnt3a"     "Ptgs1"     "Rtl8a"     "Hoxb1"     "Cdh1"
# [19] "Olfr539"   "Lefty1"    "Gm8797"    "Cited1"    "Dnaaf3"    "Irgm1"
# [25] "Adamts6"   "Psmb10"    "Tapbpl"    "Psmb8"     "Il15ra"    "Tlr4"
# [31] "Ccno"      "Pdzd2"     "Id2"       "B3gnt7"    "Efhd2"     "Scn9a"
# [37] "Erbb4"     "Rhbdf1"    "H2-K1"     "Grina"     "Cdx2"      "Nt5e"
# [43] "Rnaset2a"  "Parp8"     "Klf5"      "Tmem63a"   "Gabarapl1" "Parp10"
# [49] "Ifih1"     "Krt19"     "Mgat4a"    "Myof"      "Junb"      "Bicdl1"
# [55] "Parp9"     "Tnni3"     "Rpl9-ps6"  "Iigp1"     "Thsd4"     "Anxa3"
# [61] "Bst2"      "Lgals3"    "Itgb8"     "Fmn1"      "Amph"      "Acnat1"
# [67] "Zfhx4"     "Ttyh1"     "Slc29a1"   "Ccn1"      "Dqx1"      "Kcnh8"
# [73] "Msgn1"     "Rprm"      "Susd4"     "Pls1"      "Parp12"    "Kcne1l"
# [79] "Skap1"     "F2rl1"     "Pcsk1"     "Tm7sf3"    "Grin2a"    "Col25a1"
# [85] "Dusp5"     "Perp"      "Gm14164"   "Gjb3"      "Sbk1"      "Mtus1"

# %%
DEGs[celltype=='Nascent_mesoderm' & logFC<0, gene]
# Out:
#  [1] "Kdr"      "Hmga2"    "Nrp1"     "Prdm6"    "Cdh4"     "Cdh11"
#  [7] "Tbx3"     "Tenm4"    "Plxna4"   "Pdgfra"   "Fzd7"     "Fgf10"
# [13] "P3h2"     "Eomes"    "Klhl6"    "Cacna1c"  "Gata4"    "Mesp1"
# [19] "Etv2"     "Vstm2b"   "Gata6"    "Pcsk5"    "Zfp516"   "Fbln2"
# [25] "Thsd7a"   "Sh3rf3"   "Hs3st3b1" "Dlc1"     "Tbx20"    "Lmo1"
# [31] "Cyp26a1"  "Frzb"     "Adamts9"  "Gas1"     "Itga8"    "Galnt14"
# [37] "Upp1"     "Adrb1"    "Crb2"     "Rgl1"     "Alk"      "Vegfc"
# [43] "Fgf3"     "Plac1"    "Rimbp2"   "Cobll1"   "Bace2"    "Anpep"
# [49] "Cttnbp2"  "Ackr3"    "Cxcr4"    "Efna3"    "Unc80"    "Asb4"
# [55] "Cdh8"     "Gsc"      "Nrg1"     "Zic2"     "Cfc1"     "Itga9"
# [61] "Otx2"     "Kcnq5"    "Dlgap2"   "Sema6d"   "Hdac7"    "Arhgap22"
# [67] "St8sia2"  "Adra2b"   "Pdzd4"

# %%
DEGs[grep('Hox', DEGs$gene)]
# Out:
#    gene    logFC  padj_fdr mean_groupA mean_groupB
# 1  Hoxb1    3.388 4.14e-19 1.78        4.72
# 2  Hoxd9    1.755 1.17e-06 3.43        5.11
# 3  Hoxb1    1.745 1.63e-05 2.80        4.45
# 4  Hoxb1    2.778 8.34e-11 2.15        4.70
# 5  Hoxb1    1.291 5.17e-23 4.57        5.82
# 6  Hoxb1    1.230 6.29e-18 4.16        5.33
# 7  Hoxb1    1.192 1.96e-14 4.59        5.76
# 8  Hoxd9    2.482 6.04e-14 1.93        4.16
# 9  Hoxb3os  1.037 1.40e-12 4.54        5.56
# 10 Hoxb1    1.173 2.65e-04 4.16        5.33
# 11 Hoxd9   -1.050 1.72e-03 4.85        3.83
# 12 Hoxa9    2.576 3.08e-15 2.96        5.36
# 13 Hoxd11   2.786 3.83e-15 2.48        5.04
# 14 Hoxc9    2.141 5.32e-12 2.58        4.53
# 15 Hoxa10   1.313 1.42e-11 3.82        5.08
# 16 Hoxc4    2.396 8.46e-11 2.21        4.37
# 17 Hoxc8    1.913 8.54e-11 2.92        4.69
# 18 Hoxa7    2.820 1.10e-10 1.62        4.02
# 19 Hoxc6    1.855 2.41e-10 2.50        4.17
# 20 Hoxa11   1.330 1.11e-08 3.07        4.30
# 21 Hoxa9    2.513 2.40e-16 3.46        5.86
# 22 Hoxa7    2.866 4.91e-14 2.02        4.57
# 23 Hoxa10   1.882 3.80e-12 3.20        4.96
# 24 Hoxa11   2.057 1.24e-11 2.44        4.27
# 25 Hoxd9    1.146 8.30e-11 4.24        5.34
# 26 Hoxb2   -1.285 1.01e-10 4.99        3.77
# 27 Hoxd9    1.580 2.65e-06 3.06        4.52
# 28 Hoxa9    1.302 4.19e-06 3.40        4.65
# 29 Hoxa10   1.052 1.93e-05 3.80        4.82
# 30 Hoxb1    1.734 2.31e-04 3.11        4.99
# 31 Hoxd9    5.625 5.49e-07 0.00        4.11
# 32 Hoxb1    1.905 7.62e-08 2.67        4.43
#    celltype                       sig  N meanlogFC
# 1  Primitive_Streak               TRUE 9  1.826222
# 2  PGC                            TRUE 6  1.923000
# 3  PGC                            TRUE 9  1.826222
# 4  Anterior_Primitive_Streak      TRUE 9  1.826222
# 5  Nascent_mesoderm               TRUE 9  1.826222
# 6  Mixed_mesoderm                 TRUE 9  1.826222
# 7  Intermediate_mesoderm          TRUE 9  1.826222
# 8  Intermediate_mesoderm          TRUE 6  1.923000
# 9  Intermediate_mesoderm          TRUE 1  1.037000
# 10 Pharyngeal_mesoderm            TRUE 9  1.826222
# 11 Pharyngeal_mesoderm            TRUE 6  1.923000
# 12 Mesenchyme                     TRUE 3  2.130333
# 13 Mesenchyme                     TRUE 1  2.786000
# 14 Mesenchyme                     TRUE 1  2.141000
# 15 Mesenchyme                     TRUE 3  1.415667
# 16 Mesenchyme                     TRUE 1  2.396000
# 17 Mesenchyme                     TRUE 1  1.913000
# 18 Mesenchyme                     TRUE 2  2.843000
# 19 Mesenchyme                     TRUE 1  1.855000
# 20 Mesenchyme                     TRUE 2  1.693500
# 21 Haematoendothelial_progenitors TRUE 3  2.130333
# 22 Haematoendothelial_progenitors TRUE 2  2.843000
# 23 Haematoendothelial_progenitors TRUE 3  1.415667
# 24 Haematoendothelial_progenitors TRUE 2  1.693500
# 25 Haematoendothelial_progenitors TRUE 6  1.923000
# 26 Haematoendothelial_progenitors TRUE 1 -1.285000
# 27 Endothelium                    TRUE 6  1.923000
# 28 Endothelium                    TRUE 3  2.130333
# 29 Endothelium                    TRUE 3  1.415667
# 30 Rostral_neurectoderm           TRUE 9  1.826222
# 31 Forebrain_Midbrain_Hindbrain   TRUE 6  1.923000
# 32 Surface_ectoderm               TRUE 9  1.826222

# %%
DEGs[grep('Wnt', DEGs$gene)]
# Out:
#   gene  logFC padj_fdr mean_groupA mean_groupB celltype
# 1 Wnt5a 1.175 2.43e-12 3.99        5.10        Primitive_Streak
# 2 Wnt3a 1.821 1.37e-23 4.20        5.97        Nascent_mesoderm
# 3 Wnt3a 1.898 1.18e-24 3.81        5.63        Mixed_mesoderm
# 4 Wnt3a 1.481 5.90e-06 4.05        5.48        Forebrain_Midbrain_Hindbrain
# 5 Wnt3a 1.217 5.21e-07 4.04        5.21        Surface_ectoderm
#   sig  N meanlogFC
# 1 TRUE 1 1.17500
# 2 TRUE 4 1.60425
# 3 TRUE 4 1.60425
# 4 TRUE 4 1.60425
# 5 TRUE 4 1.60425

# %%
table(DEGs$celltype)
# Out:
#                      Allantois      Anterior_Primitive_Streak
#                             51                            620
#                    Endothelium                   ExE_mesoderm
#                            285                             39
#   Forebrain_Midbrain_Hindbrain Haematoendothelial_progenitors
#                           1365                            227
#          Intermediate_mesoderm                     Mesenchyme
#                             76                            273
#                 Mixed_mesoderm               Nascent_mesoderm
#                            158                            159
#                            PGC            Pharyngeal_mesoderm
#                             81                            373
#               Primitive_Streak           Rostral_neurectoderm
#                            304                           1181
#               Surface_ectoderm
#                             53

# %%
ct_keep = c('Primitive_Streak',
            'Nascent_mesoderm',
            'Mixed_mesoderm',
            'Intermediate_mesoderm',
            'Pharyngeal_mesoderm',
            'Allantois',
            'ExE_mesoderm',
            'Mesenchyme',
            'Haematoendothelial_progenitors',
            'Endothelium')

# %%
DEGs_stats = DEGs[celltype%in%ct_keep] %>% 
        .[,`:=`(N=.N, meanlogFC=mean(logFC)), by='gene'] %>% 
        unique(by='gene') %>% 
        .[abs(meanlogFC)>0.5] %>% 
        .[order(-N)]

# %%
ggplot(DEGs_stats, aes(meanlogFC, N)) + 
    geom_point() + 
    ggrepel::geom_text_repel(data=head(DEGs_stats, 25), aes(label=gene), max.overlaps=Inf, box.padding = 0.4) + 
    xlab('Mean LogFC across sign. celltypes') + ylab('Number of sign. celltypes') + 
    ggtitle('DEGs across celltypes') + 
    theme_bw()
# Out:
# plot without title

# %%
gene = 'Lefty1'
test = data.table(celltype = str_split(colnames(sce), '-') %>% map_chr(1), 
                  KO = str_split(colnames(sce), '-') %>% map_chr(2) %>% str_split(., '_') %>% map_chr(1),
                  gene = as.vector(logcounts(sce[gene]))) %>%
        .[,`:=`(mean=mean(gene), sd=sd(gene)), by=c('celltype', 'KO')] %>%
        .[celltype %in% ct_keep] %>% .[,celltype:=factor(celltype, levels=ct_keep)] #%>% 
     #   unique(by=c('celltype', 'KO'))

# %%
options(repr.plot.width=20, repr.plot.height=8) 
maxexpr = max(test$gene)
ggplot(test, aes(KO, gene, col=KO)) + 
    geom_boxplot() + 
    facet_wrap(~celltype, scales='free', ncol=5) + 
    ylim(0, maxexpr) + 
    ylab(paste0(gene, ' expression'))+ 
    theme_classic() + theme(text=element_text(size=20))
# Out:
# plot without title

# %%
sce_sc = readRDS(io$rna.sce)

# %%
sce_sc = logNormCounts(sce_sc)

# %%
meta = fread(file.path(io$basedir, 'results/rna/mapping/sample_metadata_after_mapping.txt.gz'))[match(colnames(sce_sc), cell)]

# %%
sce_sc$
# Out:
# class: SingleCellExperiment
# dim: 32285 41852
# metadata(0):
# assays(2): counts logcounts
# rownames(32285): Xkr4 Gm1992 ... AC234645.1 AC149090.1
# rowData names(0):
# colnames(41852): rv_eo_deg_day3_5_control#AAACAGCCAAACCTTG-1
#   rv_eo_deg_day3_5_control#AAACAGCCAGCAACCT-1 ...
#   2_Eo_DEG_G9_day5_VC#TTTGTGTTCACAGCCA-1
#   2_Eo_DEG_G9_day5_VC#TTTGTTGGTACCGGAT-1
# colData names(11): barcode sample ... pass_rnaQC sizeFactor
# reducedDimNames(0):
# mainExpName: RNA
# altExpNames(0):

# %%
gene = 'Alk'
test = data.table(celltype = meta$celltype, 
                  KO = meta$genotype,
                  gene = as.vector(logcounts(sce_sc[gene]))) %>%
        .[,`:=`(mean=mean(gene), sd=sd(gene)), by=c('celltype', 'KO')] %>%
        .[celltype %in% ct_keep] %>% .[,celltype:=factor(celltype, levels=ct_keep)] #%>% 
     #   unique(by=c('celltype', 'KO'))

# %%
options(repr.plot.width=20, repr.plot.height=8) 
maxexpr = max(test$gene)
ggplot(test, aes(KO, gene, col=KO)) + 
    geom_point(size=0.1, alpha=0.4, position=position_jitter(width=0.2)) + 
    geom_violin(color='black', alpha=0.3) + 
    geom_boxplot(width=0.1, color='black', outlier.size = 0) + 
    facet_wrap(~celltype, scales='free', ncol=5) + 
    ylim(0, maxexpr) + 
    ylab(paste0(gene, ' expression'))+ 
    theme_classic() + theme(text=element_text(size=20))
# Out:
# Warning message:
# “Removed 15529 rows containing missing values (geom_point).”
# plot without title

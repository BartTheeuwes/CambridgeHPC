# %%
library(ArchR)
library(data.table)

# %%
here::i_am("processed/atac/archR/Export_matrices.ipynb")

source(here::here("code/settings.R"))
source(here::here("code/utils.R"))
# Out:
# here() starts at /rds/project/rds-SDzz0CATGms/users/bt392/09_Eomes_invitro_blood

# %%
getwd()
# Out:
# [1] "/rds/project/rds-SDzz0CATGms/users/bt392/09_Eomes_invitro_blood/processed/atac/archR"

# %%
test = fread('/rds/project/rds-SDzz0CATGms/users/bt392/09_Eomes_invitro_blood/processed/atac/archR/PeakCalls/peaks_archR_macs2.bed.gz')

# %%
head(test)
# Out:
#   V1   V2      V3
# 1 chr1 3003470 3004070
# 2 chr1 3035598 3036198
# 3 chr1 3062639 3063239
# 4 chr1 3191587 3192187
# 5 chr1 3263590 3264190
# 6 chr1 3482948 3483548

# %%
test2 = readRDS('/rds/project/rds-SDzz0CATGms/users/bt392/09_Eomes_invitro_blood/processed/atac/archR/Matrices/PeakMatrix_summarized_experiment.rds')

# %%
head(test2)
# Out:
# class: RangedSummarizedExperiment
# dim: 6 35864
# metadata(0):
# assays(1): PeakMatrix
# rownames(6): chr1:3003470-3004070 chr1:3035598-3036198 ...
#   chr1:3263590-3264190 chr1:3482948-3483548
# rowData names(1): idx
# colnames(35864): 2_Eo_DEG_G9_day3_5_VC#CTACGAAGTGAGCACT-1
#   2_Eo_DEG_G9_day3_5_VC#TGGACAAAGCTCAATA-1 ...
#   2_Eo_DEG_G9_day5_VC#CTCCCTGAGGTGAAAT-1
#   2_Eo_DEG_G9_day5_VC#CGCTCCATCATCCTGC-1
# colData names(39): BlacklistRatio nDiFrags ... FRIP replicate

# %%
ArchRProject <- loadArchRProject(io$archR.directory)

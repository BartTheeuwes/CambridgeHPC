# %%
# Motif search using Homer
cmd = sprintf('/rds/project/rds-SDzz0CATGms/users/bt392/software/homer/bin/findMotifsGenome.pl %s/test.bed mm10 %s/HOMER_250/ -size 250 -S 10 -len 6,8 -p 24', 
                   getwd(),
                     getwd())
system(cmd)

# %%
cmd
# Out:
# [1] "/rds/project/rds-SDzz0CATGms/users/bt392/software/homer/bin/findMotifsGenome.pl /rds/project/rds-SDzz0CATGms/users/bt392/09_Eomes_invitro_blood/results/rna_atac/differential/Accessibility/test.bed.gz mm10 /rds/project/rds-SDzz0CATGms/users/bt392/09_Eomes_invitro_blood/results/rna_atac/differential/Accessibility/HOMER_250/ -size 250 -S 10 -len 6,8 -p 24"

# %%
library(data.table)

# %%
DARs = fread('Stable_invitro_DARs.csv', nThread = 24)

# %%
fwrite(DARs[!is.na(sig)], 'Stable_invitro_DARs_small.csv', nThread = 24)

# %%
tail(DARs[!is.na(sig)])
# Out:
#   celltype    peak                     logFC padj_fdr mean_WT mean_EomesKD
# 1 Endothelium chr7:133675912-133676512 0     1        2.69    2.70
# 2 Endothelium chr7:25321916-25322516   0     1        3.57    3.60
# 3 Endothelium chr7:45644086-45644686   0     1        2.95    2.98
# 4 Endothelium chr7:81453484-81454084   0     1        3.25    3.27
# 5 Endothelium chr9:43934558-43935158   0     1        2.65    2.71
# 6 Endothelium chrX:20658053-20658653   0     1        4.11    4.14
#   cdr_WT cdr_EomesKD sig
# 1 0.10   0.16        FALSE
# 2 0.16   0.29        FALSE
# 3 0.11   0.24        FALSE
# 4 0.16   0.26        FALSE
# 5 0.08   0.15        FALSE
# 6 0.27   0.43        FALSE

# %%
DEGs = fread('Stable_invitro_DEGs.csv', nThread = 24)

# %%
fwrite(DEGs[!is.na(sig)], 'Stable_invitro_DEGs_small.csv', nThread = 24)

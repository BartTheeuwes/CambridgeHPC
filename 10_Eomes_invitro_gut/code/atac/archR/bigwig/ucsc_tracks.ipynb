# %%
here::i_am("atac/archR/add_motif_annotation/add_motif_annotation_manual.R")
source(here::here("settings.R"))
# Out:
# here() starts at /rds/project/rds-SDzz0CATGms/users/bt392/10_Eomes_invitro_gut/code

# %%
args = list()
args$canaveral = 'http://bioinformatics.stemcells.cam.ac.uk/Files_for_transfer/Open/bart/10_Eomes_degron_gut/bigwigs/'
args$bw_in = file.path(io$basedir, 'processed/atac/archR/GroupBigWigs/celltype_genotype/')

# %%
io$basedir
# Out:
# [1] "/rds/project/rds-SDzz0CATGms/users/bt392/10_Eomes_invitro_gut"

# %%
files = list.files(args$bw_in, 'bw')
celltypes = files %>% str_split('-') %>% map(1)
ucsc_tracks = lapply(celltypes, function(x){
    paste0('track type=bigWig name="',x,
           '" description="',x,
           '" color=',paste(as.vector(col2rgb(opts$celltype.colors[x])), collapse = ","),
           ' visibility=2 bigDataUrl=',args$canaveral,x,
           '-TileSize-100-normMethod-ReadsInTSS-ArchR.bw')
}) %>% unlist() %>% noquote()

# %%
ucsc_tracks
# Out:
#  [1] track type=bigWig name="Anterior_Primitive_Streak.Eomes_KO" description="Anterior_Primitive_Streak.Eomes_KO" color=255,255,255 visibility=2 bigDataUrl=http://bioinformatics.stemcells.cam.ac.uk/Files_for_transfer/Open/10_Eomes_degron_gut/bigwigs/Anterior_Primitive_Streak.Eomes_KO-TileSize-100-normMethod-ReadsInTSS-ArchR.bw
#  [2] track type=bigWig name="Anterior_Primitive_Streak.WT" description="Anterior_Primitive_Streak.WT" color=255,255,255 visibility=2 bigDataUrl=http://bioinformatics.stemcells.cam.ac.uk/Files_for_transfer/Open/10_Eomes_degron_gut/bigwigs/Anterior_Primitive_Streak.WT-TileSize-100-normMethod-ReadsInTSS-ArchR.bw
#  [3] track type=bigWig name="Caudal_epiblast.Eomes_KO" description="Caudal_epiblast.Eomes_KO" color=255,255,255 visibility=2 bigDataUrl=http://bioinformatics.stemcells.cam.ac.uk/Files_for_transfer/Open/10_Eomes_degron_gut/bigwigs/Caudal_epiblast.Eomes_KO-TileSize-100-normMethod-ReadsInTSS-ArchR.bw
#  [4] track type=bigWig name="Caudal_epiblast.WT" description="Caudal_epiblast.WT" color=255,255,255 visibility=2 bigDataUrl=http://bioinformatics.stemcells.cam.ac.uk/Files_for_transfer/Open/10_Eomes_degron_gut/bigwigs/Caudal_epiblast.WT-TileSize-100-normMethod-ReadsInTSS-ArchR.bw
#  [5] track type=bigWig name="Caudal_Mesoderm.Eomes_KO" description="Caudal_Mesoderm.Eomes_KO" color=255,255,255 visibility=2 bigDataUrl=http://bioinformatics.stemcells.cam.ac.uk/Files_for_transfer/Open/10_Eomes_degron_gut/bigwigs/Caudal_Mesoderm.Eomes_KO-TileSize-100-normMethod-ReadsInTSS-ArchR.bw
#  [6] track type=bigWig name="Def._endoderm.WT" description="Def._endoderm.WT" color=255,255,255 visibility=2 bigDataUrl=http://bioinformatics.stemcells.cam.ac.uk/Files_for_transfer/Open/10_Eomes_degron_gut/bigwigs/Def._endoderm.WT-TileSize-100-normMethod-ReadsInTSS-ArchR.bw
#  [7] track type=bigWig name="Epiblast.Eomes_KO" description="Epiblast.Eomes_KO" color=255,255,255 visibility=2 bigDataUrl=http://bioinformatics.stemcells.cam.ac.uk/Files_for_transfer/Open/10_Eomes_degron_gut/bigwigs/Epiblast.Eomes_KO-TileSize-100-normMethod-ReadsInTSS-ArchR.bw
#  [8] track type=bigWig name="Epiblast.WT" description="Epiblast.WT" color=255,255,255 visibility=2 bigDataUrl=http://bioinformatics.stemcells.cam.ac.uk/Files_for_transfer/Open/10_Eomes_degron_gut/bigwigs/Epiblast.WT-TileSize-100-normMethod-ReadsInTSS-ArchR.bw
#  [9] track type=bigWig name="Forebrain_Midbrain_Hindbrain.Eomes_KO" description="Forebrain_Midbrain_Hindbrain.Eomes_KO" color=255,255,255 visibility=2 bigDataUrl=http://bioinformatics.stemcells.cam.ac.uk/Files_for_transfer/Open/10_Eomes_degron_gut/bigwigs/Forebrain_Midbrain_Hindbrain.Eomes_KO-TileSize-100-normMethod-ReadsInTSS-ArchR.bw
# [10] track type=bigWig name="Forebrain_Midbrain_Hindbrain.WT" description="Forebrain_Midbrain_Hindbrain.WT" color=255,255,255 visibility=2 bigDataUrl=http://bioinformatics.stemcells.cam.ac.uk/Files_for_transfer/Open/10_Eomes_degron_gut/bigwigs/Forebrain_Midbrain_Hindbrain.WT-TileSize-100-normMethod-ReadsInTSS-ArchR.bw
# [11] track type=bigWig name="Gut.WT" description="Gut.WT" color=255,255,255 visibility=2 bigDataUrl=http://bioinformatics.stemcells.cam.ac.uk/Files_for_transfer/Open/10_Eomes_degron_gut/bigwigs/Gut.WT-TileSize-100-normMethod-ReadsInTSS-ArchR.bw
# [12] track type=bigWig name="Intermediate_mesoderm.Eomes_KO" description="Intermediate_mesoderm.Eomes_KO" color=255,255,255 visibility=2 bigDataUrl=http://bioinformatics.stemcells.cam.ac.uk/Files_for_transfer/Open/10_Eomes_degron_gut/bigwigs/Intermediate_mesoderm.Eomes_KO-TileSize-100-normMethod-ReadsInTSS-ArchR.bw
# [13] track type=bigWig name="Intermediate_mesoderm.WT" description="Intermediate_mesoderm.WT" color=255,255,255 visibility=2 bigDataUrl=http://bioinformatics.stemcells.cam.ac.uk/Files_for_transfer/Open/10_Eomes_degron_gut/bigwigs/Intermediate_mesoderm.WT-TileSize-100-normMethod-ReadsInTSS-ArchR.bw
# [14] track type=bigWig name="Nascent_mesoderm.Eomes_KO" description="Nascent_mesoderm.Eomes_KO" color=255,255,255 visibility=2 bigDataUrl=http://bioinformatics.stemcells.cam.ac.uk/Files_for_transfer/Open/10_Eomes_degron_gut/bigwigs/Nascent_mesoderm.Eomes_KO-TileSize-100-normMethod-ReadsInTSS-ArchR.bw
# [15] track type=bigWig name="Nascent_mesoderm.WT" description="Nascent_mesoderm.WT" color=255,255,255 visibility=2 bigDataUrl=http://bioinformatics.stemcells.cam.ac.uk/Files_for_transfer/Open/10_Eomes_degron_gut/bigwigs/Nascent_mesoderm.WT-TileSize-100-normMethod-ReadsInTSS-ArchR.bw
# [16] track type=bigWig name="NMP.Eomes_KO" description="NMP.Eomes_KO" color=255,255,255 visibility=2 bigDataUrl=http://bioinformatics.stemcells.cam.ac.uk/Files_for_transfer/Open/10_Eomes_degron_gut/bigwigs/NMP.Eomes_KO-TileSize-100-normMethod-ReadsInTSS-ArchR.bw
# [17] track type=bigWig name="Notochord.WT" description="Notochord.WT" color=255,255,255 visibility=2 bigDataUrl=http://bioinformatics.stemcells.cam.ac.uk/Files_for_transfer/Open/10_Eomes_degron_gut/bigwigs/Notochord.WT-TileSize-100-normMethod-ReadsInTSS-ArchR.bw
# [18] track type=bigWig name="Paraxial_mesoderm.Eomes_KO" description="Paraxial_mesoderm.Eomes_KO" color=255,255,255 visibility=2 bigDataUrl=http://bioinformatics.stemcells.cam.ac.uk/Files_for_transfer/Open/10_Eomes_degron_gut/bigwigs/Paraxial_mesoderm.Eomes_KO-TileSize-100-normMethod-ReadsInTSS-ArchR.bw
# [19] track type=bigWig name="Paraxial_mesoderm.WT" description="Paraxial_mesoderm.WT" color=255,255,255 visibility=2 bigDataUrl=http://bioinformatics.stemcells.cam.ac.uk/Files_for_transfer/Open/10_Eomes_degron_gut/bigwigs/Paraxial_mesoderm.WT-TileSize-100-normMethod-ReadsInTSS-ArchR.bw
# [20] track type=bigWig name="PGC.Eomes_KO" description="PGC.Eomes_KO" color=255,255,255 visibility=2 bigDataUrl=http://bioinformatics.stemcells.cam.ac.uk/Files_for_transfer/Open/10_Eomes_degron_gut/bigwigs/PGC.Eomes_KO-TileSize-100-normMethod-ReadsInTSS-ArchR.bw
# [21] track type=bigWig name="PGC.WT" description="PGC.WT" color=255,255,255 visibility=2 bigDataUrl=http://bioinformatics.stemcells.cam.ac.uk/Files_for_transfer/Open/10_Eomes_degron_gut/bigwigs/PGC.WT-TileSize-100-normMethod-ReadsInTSS-ArchR.bw
# [22] track type=bigWig name="Primitive_Streak.Eomes_KO" description="Primitive_Streak.Eomes_KO" color=255,255,255 visibility=2 bigDataUrl=http://bioinformatics.stemcells.cam.ac.uk/Files_for_transfer/Open/10_Eomes_degron_gut/bigwigs/Primitive_Streak.Eomes_KO-TileSize-100-normMethod-ReadsInTSS-ArchR.bw
# [23] track type=bigWig name="Primitive_Streak.WT" description="Primitive_Streak.WT" color=255,255,255 visibility=2 bigDataUrl=http://bioinformatics.stemcells.cam.ac.uk/Files_for_transfer/Open/10_Eomes_degron_gut/bigwigs/Primitive_Streak.WT-TileSize-100-normMethod-ReadsInTSS-ArchR.bw
# [24] track type=bigWig name="Rostral_neurectoderm.Eomes_KO" description="Rostral_neurectoderm.Eomes_KO" color=255,255,255 visibility=2 bigDataUrl=http://bioinformatics.stemcells.cam.ac.uk/Files_for_transfer/Open/10_Eomes_degron_gut/bigwigs/Rostral_neurectoderm.Eomes_KO-TileSize-100-normMethod-ReadsInTSS-ArchR.bw
# [25] track type=bigWig name="Rostral_neurectoderm.WT" description="Rostral_neurectoderm.WT" color=255,255,255 visibility=2 bigDataUrl=http://bioinformatics.stemcells.cam.ac.uk/Files_for_transfer/Open/10_Eomes_degron_gut/bigwigs/Rostral_neurectoderm.WT-TileSize-100-normMethod-ReadsInTSS-ArchR.bw
# [26] track type=bigWig name="Somitic_mesoderm.Eomes_KO" description="Somitic_mesoderm.Eomes_KO" color=255,255,255 visibility=2 bigDataUrl=http://bioinformatics.stemcells.cam.ac.uk/Files_for_transfer/Open/10_Eomes_degron_gut/bigwigs/Somitic_mesoderm.Eomes_KO-TileSize-100-normMethod-ReadsInTSS-ArchR.bw
# [27] track type=bigWig name="Somitic_mesoderm.WT" description="Somitic_mesoderm.WT" color=255,255,255 visibility=2 bigDataUrl=http://bioinformatics.stemcells.cam.ac.uk/Files_for_transfer/Open/10_Eomes_degron_gut/bigwigs/Somitic_mesoderm.WT-TileSize-100-normMethod-ReadsInTSS-ArchR.bw
# [28] track type=bigWig name="Spinal_cord.Eomes_KO" description="Spinal_cord.Eomes_KO" color=255,255,255 visibility=2 bigDataUrl=http://bioinformatics.stemcells.cam.ac.uk/Files_for_transfer/Open/10_Eomes_degron_gut/bigwigs/Spinal_cord.Eomes_KO-TileSize-100-normMethod-ReadsInTSS-ArchR.bw
# [29] track type=bigWig name="Spinal_cord.WT" description="Spinal_cord.WT" color=255,255,255 visibility=2 bigDataUrl=http://bioinformatics.stemcells.cam.ac.uk/Files_for_transfer/Open/10_Eomes_degron_gut/bigwigs/Spinal_cord.WT-TileSize-100-normMethod-ReadsInTSS-ArchR.bw

# %%
here::i_am("atac/archR/peak_calling/peak_calling_archR.R")

source(here::here("settings.R"))
source(here::here("utils.R"))

suppressPackageStartupMessages(library(ArchR))
# Out:
# here() starts at /rds/project/rds-SDzz0CATGms/users/bt392/10_Eomes_invitro_gut/code
#
#
#                                                    / |
#                                                  /    \
#             .                                  /      |.
#             \\\                              /        |.
#               \\\                          /           `|.
#                 \\\                      /              |.
#                   \                    /                |\
#                   \\#####\           /                  ||
#                 ==###########>      /                   ||
#                  \\##==......\    /                     ||
#             ______ =       =|__ /__                     ||      \\\
#         ,--' ,----`-,__ ___/'  --,-`-===================##========>
#        \               '        ##_______ _____ ,--,__,=##,__   ///
#         ,    __==    ___,-,__,--'#'  ==='      `-'    | ##,-/
# ...

# %%
ArchRProject <- loadArchRProject(io$archR.directory)
# Out:
# Successfully loaded ArchRProject!
#
#
#                                                    / |
#                                                  /    \
#             .                                  /      |.
#             \\\                              /        |.
#               \\\                          /           `|.
#                 \\\                      /              |.
#                   \                    /                |\
#                   \\#####\           /                  ||
#                 ==###########>      /                   ||
#                  \\##==......\    /                     ||
#             ______ =       =|__ /__                     ||      \\\
#         ,--' ,----`-,__ ___/'  --,-`-===================##========>
#        \               '        ##_______ _____ ,--,__,=##,__   ///
#         ,    __==    ___,-,__,--'#'  ==='      `-'    | ##,-/
#         -,____,---'       \\####\\________________,--\\_##,/
# ...

# %%
getwd()
# Out:
# [1] "/rds/project/rds-SDzz0CATGms/users/bt392/10_Eomes_invitro_gut/code/atac/archR/peak_calling"

# %%
bed = as.data.table(ArchRProject@peakSet)[,1:3] %>%
fwrite(bed, '/rds/project/rds-SDzz0CATGms/users/bt392/10_Eomes_invitro_gut/code/atac/archR/peak_calling/peaks.bed',
       sep = '\t', 
       col.names = FALSE)

# %%
bed
# Out:
#       seqnames start     end
# 1     chr1     3191544   3192144
# 2     chr1     3549359   3549959
# 3     chr1     3648815   3649415
# 4     chr1     3670788   3671388
# 5     chr1     3671520   3672120
# 6     chr1     3672281   3672881
# 7     chr1     3681377   3681977
# 8     chr1     3953496   3954096
# 9     chr1     4150662   4151262
# 10    chr1     4412348   4412948
# 11    chr1     4416602   4417202
# 12    chr1     4491850   4492450
# 13    chr1     4492475   4493075
# 14    chr1     4493329   4493929
# 15    chr1     4496272   4496872
# 16    chr1     4571537   4572137
# 17    chr1     4640689   4641289
# 18    chr1     4644828   4645428
# 19    chr1     4659958   4660558
# 20    chr1     4722488   4723088
# 21    chr1     4724829   4725429
# 22    chr1     4785453   4786053
# 23    chr1     4802417   4803017
# 24    chr1     4807536   4808136
# 25    chr1     4855321   4855921
# 26    chr1     4857439   4858039
# 27    chr1     4914354   4914954
# ...

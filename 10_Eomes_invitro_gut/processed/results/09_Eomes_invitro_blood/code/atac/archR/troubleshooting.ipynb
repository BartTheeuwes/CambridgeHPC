# %%
here::i_am("atac/archR/processing/save_atac_matrices.R")

source(here::here("settings.R"))
source(here::here("utils.R"))

suppressPackageStartupMessages(library(ArchR))
# Out:
# here() starts at /rds/project/rds-SDzz0CATGms/users/bt392/09_Eomes_invitro_blood/code

# %%
# START TEST ##b
args <- list()
args$archr_directory <- file.path(io$basedir,"processed/atac/archR")
args$metadata <- file.path(io$basedir,"results/atac/archR/qc/sample_metadata_after_qc.txt.gz")
args$matrix <- "GeneScoreMatrix_TSS"
args$outfile <- file.path(io$basedir,sprintf("processed/atac/archR/Matrices/%s_summarized_experiment.rds",args$matrix))
# END TEST ##

# %%
args$group_by = 'celltype_genotype'
args$min_cells = 100
args$tile_size = 1000
args$threads = 1

# %%
########################
## Load cell metadata ##
########################

sample_metadata <- fread(args$metadata) %>%
  .[pass_atacQC==TRUE & sample%in%opts$samples]

# temporary
# sample_metadata[,day:=stringr::str_replace_all(sample,opts$sample2day)] %>%
#   .[,genotype:=stringr::str_replace_all(sample,opts$sample2genotype)] %>%
#   .[,day_genotype:=paste(day,genotype,sep="_")] %>%
#   .[,celltype_genotype:=paste(celltype.mapped_mnn,genotype,sep="_")]

# Filter groups by minimum number of cells
stopifnot(args$group_by%in%colnames(sample_metadata))
sample_metadata <- sample_metadata[!is.na(sample_metadata[[args$group_by]])]
sample_metadata <- sample_metadata[!grepl("NA",sample_metadata[[args$group_by]])]
sample_metadata <- sample_metadata[,N:=.N,by=c(args$group_by)] %>% .[N>=args$min_cells] %>% .[,N:=NULL]

table(sample_metadata[[args$group_by]])

########################
## Load ArchR project ##
########################

# source(here::here("atac/archR/load_archR_project.R"))

setwd(args$archr_directory)

addArchRGenome("mm10")
addArchRThreads(threads = args$threads)
# Out:
#                      Allantois-eomes_ko                            Allantois-wt
#                                     943                                     278
# Haematoendothelial_progenitors-eomes_ko
#                                     135
# Setting default genome to Mm10.
#
# Setting default number of Parallel threads to 1.

# %%
nrow(sample_metadata)
# Out:
# [1] 1356

# %%
ArchRProject <- loadArchRProject(args$archr_directory)
# Subset
ArchRProject.filt <- ArchRProject[sample_metadata$cell]
# Out:
# Successfully loaded ArchRProject!
#
#
#                                                    / |
#                                                  /    \
#             .                                  /      |.
#             \\\                              /        |.
#               \\\                          /           `|.
#                 \\\                      /              |.
#                   \                    /                |\
#                   \\#####\           /                  ||
#                 ==###########>      /                   ||
#                  \\##==......\    /                     ||
#             ______ =       =|__ /__                     ||      \\\
#         ,--' ,----`-,__ ___/'  --,-`-===================##========>
#        \               '        ##_______ _____ ,--,__,=##,__   ///
#         ,    __==    ___,-,__,--'#'  ==='      `-'    | ##,-/
#         -,____,---'       \\####\\________________,--\\_##,/
#            ___      .______        ______  __    __  .______
#           /   \     |   _  \      /      ||  |  |  | |   _  \
#          /  ^  \    |  |_)  |    |  ,----'|  |__|  | |  |_)  |
#         /  /_\  \   |      /     |  |     |   __   | |      /
#        /  _____  \  |  |\  \\___ |  `----.|  |  |  | |  |\  \\___.
#       /__/     \__\ | _| `._____| \______||__|  |__| | _| `._____|

# %%
ArchRProject
ArchRProject.filt
# Out:
#            ___      .______        ______  __    __  .______
#           /   \     |   _  \      /      ||  |  |  | |   _  \
#          /  ^  \    |  |_)  |    |  ,----'|  |__|  | |  |_)  |
#         /  /_\  \   |      /     |  |     |   __   | |      /
#        /  _____  \  |  |\  \\___ |  `----.|  |  |  | |  |\  \\___.
#       /__/     \__\ | _| `._____| \______||__|  |__| | _| `._____|
# class: ArchRProject
# outputDirectory: /rds/project/rds-SDzz0CATGms/users/bt392/09_Eomes_invitro_blood/processed/atac/archR
# samples(2): 2_Eo_DEG_G9_day5_dTAG 2_Eo_DEG_G9_day5_VC
# sampleColData names(1): ArrowFiles
# cellColData names(36): Sample TSSEnrichment ... nFrags_atac
#   BlacklistRatio_atac
# numberOfCells(1): 4376
# medianTSS(1): 14.2185
# medianFrags(1): 6850.5
#            ___      .______        ______  __    __  .______
#           /   \     |   _  \      /      ||  |  |  | |   _  \
#          /  ^  \    |  |_)  |    |  ,----'|  |__|  | |  |_)  |
#         /  /_\  \   |      /     |  |     |   __   | |      /
#        /  _____  \  |  |\  \\___ |  `----.|  |  |  | |  |\  \\___.
#       /__/     \__\ | _| `._____| \______||__|  |__| | _| `._____|
# class: ArchRProject
# outputDirectory: /rds/project/rds-SDzz0CATGms/users/bt392/09_Eomes_invitro_blood/processed/atac/archR
# samples(2): 2_Eo_DEG_G9_day5_dTAG 2_Eo_DEG_G9_day5_VC
# sampleColData names(1): ArrowFiles
# cellColData names(36): Sample TSSEnrichment ... nFrags_atac
#   BlacklistRatio_atac
# numberOfCells(1): 1356
# medianTSS(1): 14.3535
# medianFrags(1): 54250.5

# %%
# Unnecesary, but just to make sure projectMetadata is updated
tmp <- file.path(args$archr_directory,"projectMetadata.rds")
if (file.exists(tmp)) ArchRProject.filt@projectMetadata <- readRDS(tmp)

###########################
## Update ArchR metadata ##
###########################

sample_metadata.to.archr <- sample_metadata %>% 
  .[cell%in%rownames(ArchRProject.filt)] %>% setkey(cell) %>% .[rownames(ArchRProject.filt)] %>%
  as.data.frame() %>% tibble::column_to_rownames("cell")

stopifnot(all(rownames(sample_metadata.to.archr) == rownames(getCellColData(ArchRProject.filt))))
ArchRProject.filt <- addCellColData(
  ArchRProject.filt,
  data = sample_metadata.to.archr[[args$group_by]],
  name = args$group_by,
  cells = rownames(sample_metadata.to.archr),
  force = TRUE
)

# print cell numbers
# table(getCellColData(ArchRProject,"Sample")[[1]])
table(getCellColData(ArchRProject.filt,args$group_by)[[1]])
# Out:
# Overriding previous entry for celltype_genotype
#                      Allantois-eomes_ko                            Allantois-wt
#                                     943                                     278
# Haematoendothelial_progenitors-eomes_ko
#                                     135

# %%
ArchRProject.filt <- addGroupCoverages(ArchRProject.filt, 
  groupBy = args$group_by,
  useLabels = FALSE,  # do not use sample information
  minCells = args$min_cells,
  maxCells = 5000,
  force = TRUE
)
# Out:
# ArchR logging to : ArchRLogs/ArchR-addGroupCoverages-8692190c14d3-Date-2022-05-27_Time-17-12-12.log
# If there is an issue, please report to github with logFile!
#
# Allantois-eomes_ko (1 of 3) : CellGroups N = 2
#
# Allantois-wt (2 of 3) : CellGroups N = 2
#
# Haematoendothelial_progenitors-eomes_ko (3 of 3) : CellGroups N = 2
#
# 2022-05-27 17:12:14 : Creating Coverage Files!, 0.033 mins elapsed.
#
# 2022-05-27 17:12:14 : Batch Execution w/ safelapply!, 0.033 mins elapsed.
#
# 2022-05-27 17:12:14 : Group Allantois-eomes_ko._.Rep1 (1 of 6) : Creating Group Coverage File : Allantois.eomes_ko._.Rep1.insertions.coverage.h5, 0.033 mins elapsed.
#
# Number of Cells = 100
#
# Coverage File Exists!
#
# Added Coverage Group
#
# Added Metadata Group
#
# Added ArrowCoverage Class
#
# Added Coverage/Info
#
# Added Coverage/Info/CellNames
#
# 2022-05-27 17:12:42 : Group Allantois-eomes_ko._.Rep2 (2 of 6) : Creating Group Coverage File : Allantois.eomes_ko._.Rep2.insertions.coverage.h5, 0.499 mins elapsed.
#
# Number of Cells = 100
#
# Coverage File Exists!
#
# Added Coverage Group
#
# Added Metadata Group
#
# Added ArrowCoverage Class
#
# Added Coverage/Info
#
# Added Coverage/Info/CellNames
#
# 2022-05-27 17:13:07 : Group Allantois-wt._.Rep1 (3 of 6) : Creating Group Coverage File : Allantois.wt._.Rep1.insertions.coverage.h5, 0.929 mins elapsed.
#
# Number of Cells = 100
#
# Coverage File Exists!
#
# Added Coverage Group
#
# Added Metadata Group
#
# Added ArrowCoverage Class
#
# Added Coverage/Info
#
# Added Coverage/Info/CellNames
#
# 2022-05-27 17:13:27 : Group Allantois-wt._.Rep2 (4 of 6) : Creating Group Coverage File : Allantois.wt._.Rep2.insertions.coverage.h5, 1.251 mins elapsed.
#
# Number of Cells = 100
#
# Coverage File Exists!
#
# Added Coverage Group
#
# Added Metadata Group
#
# Added ArrowCoverage Class
#
# Added Coverage/Info
#
# Added Coverage/Info/CellNames
#
# 2022-05-27 17:13:45 : Group Haematoendothelial_progenitors-eomes_ko._.Rep1 (5 of 6) : Creating Group Coverage File : Haematoendothelial_progenitors.eomes_ko._.Rep1.insertions.coverage.h5, 1.56 mins elapsed.
#
# Number of Cells = 100
#
# Coverage File Exists!
#
# Added Coverage Group
#
# Added Metadata Group
#
# Added ArrowCoverage Class
#
# Added Coverage/Info
#
# Added Coverage/Info/CellNames
#
# 2022-05-27 17:14:12 : Group Haematoendothelial_progenitors-eomes_ko._.Rep2 (6 of 6) : Creating Group Coverage File : Haematoendothelial_progenitors.eomes_ko._.Rep2.insertions.coverage.h5, 2.001 mins elapsed.
#
# Number of Cells = 100
#
# Coverage File Exists!
#
# Added Coverage Group
#
# Added Metadata Group
#
# Added ArrowCoverage Class
#
# Added Coverage/Info
#
# Added Coverage/Info/CellNames
#
# 2022-05-27 17:14:37 : Adding Kmer Bias to Coverage Files!, 2.427 mins elapsed.
#
# Kmer Bias chr1 (1 of 21)
#
# chr1
# Coverage File chr1 (1 of 6)
#
# Coverage File chr1 (2 of 6)
#
# Coverage File chr1 (3 of 6)
#
# Coverage File chr1 (4 of 6)
#
# Coverage File chr1 (5 of 6)
#
# Coverage File chr1 (6 of 6)
#
# Kmer Bias chr10 (2 of 21)
#
# chr10
# Coverage File chr10 (1 of 6)
#
# Coverage File chr10 (2 of 6)
#
# Coverage File chr10 (3 of 6)
#
# Coverage File chr10 (4 of 6)
#
# Coverage File chr10 (5 of 6)
#
# Coverage File chr10 (6 of 6)
#
# Kmer Bias chr11 (3 of 21)
#
# chr11
# Coverage File chr11 (1 of 6)
#
# Coverage File chr11 (2 of 6)
#
# Coverage File chr11 (3 of 6)
#
# Coverage File chr11 (4 of 6)
#
# Coverage File chr11 (5 of 6)
#
# Coverage File chr11 (6 of 6)
#
# Kmer Bias chr12 (4 of 21)
#
# chr12
# Coverage File chr12 (1 of 6)
#
# Coverage File chr12 (2 of 6)
#
# Coverage File chr12 (3 of 6)
#
# Coverage File chr12 (4 of 6)
#
# Coverage File chr12 (5 of 6)
#
# Coverage File chr12 (6 of 6)
#
# Kmer Bias chr13 (5 of 21)
#
# chr13
# Coverage File chr13 (1 of 6)
#
# Coverage File chr13 (2 of 6)
#
# Coverage File chr13 (3 of 6)
#
# Coverage File chr13 (4 of 6)
#
# Coverage File chr13 (5 of 6)
#
# Coverage File chr13 (6 of 6)
#
# Kmer Bias chr14 (6 of 21)
#
# chr14
# Coverage File chr14 (1 of 6)
#
# Coverage File chr14 (2 of 6)
#
# Coverage File chr14 (3 of 6)
#
# Coverage File chr14 (4 of 6)
#
# Coverage File chr14 (5 of 6)
#
# Coverage File chr14 (6 of 6)
#
# Kmer Bias chr15 (7 of 21)
#
# chr15
# Coverage File chr15 (1 of 6)
#
# Coverage File chr15 (2 of 6)
#
# Coverage File chr15 (3 of 6)
#
# Coverage File chr15 (4 of 6)
#
# Coverage File chr15 (5 of 6)
#
# Coverage File chr15 (6 of 6)
#
# Kmer Bias chr16 (8 of 21)
#
# chr16
# Coverage File chr16 (1 of 6)
#
# Coverage File chr16 (2 of 6)
#
# Coverage File chr16 (3 of 6)
#
# Coverage File chr16 (4 of 6)
#
# Coverage File chr16 (5 of 6)
#
# Coverage File chr16 (6 of 6)
#
# Kmer Bias chr17 (9 of 21)
#
# chr17
# Coverage File chr17 (1 of 6)
#
# Coverage File chr17 (2 of 6)
#
# Coverage File chr17 (3 of 6)
#
# Coverage File chr17 (4 of 6)
#
# Coverage File chr17 (5 of 6)
#
# Coverage File chr17 (6 of 6)
#
# Kmer Bias chr18 (10 of 21)
#
# chr18
# Coverage File chr18 (1 of 6)
#
# Coverage File chr18 (2 of 6)
#
# Coverage File chr18 (3 of 6)
#
# Coverage File chr18 (4 of 6)
#
# Coverage File chr18 (5 of 6)
#
# Coverage File chr18 (6 of 6)
#
# Kmer Bias chr19 (11 of 21)
#
# chr19
# Coverage File chr19 (1 of 6)
#
# Coverage File chr19 (2 of 6)
#
# Coverage File chr19 (3 of 6)
#
# Coverage File chr19 (4 of 6)
#
# Coverage File chr19 (5 of 6)
#
# Coverage File chr19 (6 of 6)
#
# Kmer Bias chr2 (12 of 21)
#
# chr2
# Coverage File chr2 (1 of 6)
#
# Coverage File chr2 (2 of 6)
#
# Coverage File chr2 (3 of 6)
#
# Coverage File chr2 (4 of 6)
#
# Coverage File chr2 (5 of 6)
#
# Coverage File chr2 (6 of 6)
#
# Kmer Bias chr3 (13 of 21)
#
# chr3
# Coverage File chr3 (1 of 6)
#
# Coverage File chr3 (2 of 6)
#
# Coverage File chr3 (3 of 6)
#
# Coverage File chr3 (4 of 6)
#
# Coverage File chr3 (5 of 6)
#
# Coverage File chr3 (6 of 6)
#
# Kmer Bias chr4 (14 of 21)
#
# chr4
# Coverage File chr4 (1 of 6)
#
# Coverage File chr4 (2 of 6)
#
# Coverage File chr4 (3 of 6)
#
# Coverage File chr4 (4 of 6)
#
# Coverage File chr4 (5 of 6)
#
# Coverage File chr4 (6 of 6)
#
# Kmer Bias chr5 (15 of 21)
#
# chr5
# Coverage File chr5 (1 of 6)
#
# Coverage File chr5 (2 of 6)
#
# Coverage File chr5 (3 of 6)
#
# Coverage File chr5 (4 of 6)
#
# Coverage File chr5 (5 of 6)
#
# Coverage File chr5 (6 of 6)
#
# Kmer Bias chr6 (16 of 21)
#
# chr6
# Coverage File chr6 (1 of 6)
#
# Coverage File chr6 (2 of 6)
#
# Coverage File chr6 (3 of 6)
#
# Coverage File chr6 (4 of 6)
#
# Coverage File chr6 (5 of 6)
#
# Coverage File chr6 (6 of 6)
#
# Kmer Bias chr7 (17 of 21)
#
# chr7
# Coverage File chr7 (1 of 6)
#
# Coverage File chr7 (2 of 6)
#
# Coverage File chr7 (3 of 6)
#
# Coverage File chr7 (4 of 6)
#
# Coverage File chr7 (5 of 6)
#
# Coverage File chr7 (6 of 6)
#
# Kmer Bias chr8 (18 of 21)
#
# chr8
# Coverage File chr8 (1 of 6)
#
# Coverage File chr8 (2 of 6)
#
# Coverage File chr8 (3 of 6)
#
# Coverage File chr8 (4 of 6)
#
# Coverage File chr8 (5 of 6)
#
# Coverage File chr8 (6 of 6)
#
# Kmer Bias chr9 (19 of 21)
#
# chr9
# Coverage File chr9 (1 of 6)
#
# Coverage File chr9 (2 of 6)
#
# Coverage File chr9 (3 of 6)
#
# Coverage File chr9 (4 of 6)
#
# Coverage File chr9 (5 of 6)
#
# Coverage File chr9 (6 of 6)
#
# Kmer Bias chrX (20 of 21)
#
# chrX
# Coverage File chrX (1 of 6)
#
# Coverage File chrX (2 of 6)
#
# Coverage File chrX (3 of 6)
#
# Coverage File chrX (4 of 6)
#
# Coverage File chrX (5 of 6)
#
# Coverage File chrX (6 of 6)
#
# Kmer Bias chrY (21 of 21)
#
# chrY
# Coverage File chrY (1 of 6)
#
# Coverage File chrY (2 of 6)
#
# Coverage File chrY (3 of 6)
#
# Coverage File chrY (4 of 6)
#
# Coverage File chrY (5 of 6)
#
# Coverage File chrY (6 of 6)
#
# Completed Kmer Bias Calculation
#
# Adding Kmer Bias (1 of 6)
#
# Adding Kmer Bias (2 of 6)
#
# Adding Kmer Bias (3 of 6)
#
# Adding Kmer Bias (4 of 6)
#
# Adding Kmer Bias (5 of 6)
#
# Adding Kmer Bias (6 of 6)
#
# 2022-05-27 17:16:50 : Finished Creation of Coverage Files!, 4.643 mins elapsed.
#
# ArchR logging successful to : ArchRLogs/ArchR-addGroupCoverages-8692190c14d3-Date-2022-05-27_Time-17-12-12.log

# %%
projectmeta = ArchRProject.filt@projectMetadata

# %%
ArchRProject <- loadArchRProject(args$archr_directory)
# Subset
ArchRProject.filt <- ArchRProject[sample_metadata$cell]
# Out:
# Successfully loaded ArchRProject!
#
#
#                                                    / |
#                                                  /    \
#             .                                  /      |.
#             \\\                              /        |.
#               \\\                          /           `|.
#                 \\\                      /              |.
#                   \                    /                |\
#                   \\#####\           /                  ||
#                 ==###########>      /                   ||
#                  \\##==......\    /                     ||
#             ______ =       =|__ /__                     ||      \\\
#         ,--' ,----`-,__ ___/'  --,-`-===================##========>
#        \               '        ##_______ _____ ,--,__,=##,__   ///
#         ,    __==    ___,-,__,--'#'  ==='      `-'    | ##,-/
#         -,____,---'       \\####\\________________,--\\_##,/
#            ___      .______        ______  __    __  .______
#           /   \     |   _  \      /      ||  |  |  | |   _  \
#          /  ^  \    |  |_)  |    |  ,----'|  |__|  | |  |_)  |
#         /  /_\  \   |      /     |  |     |   __   | |      /
#        /  _____  \  |  |\  \\___ |  `----.|  |  |  | |  |\  \\___.
#       /__/     \__\ | _| `._____| \______||__|  |__| | _| `._____|

# %%
ArchRProject.filt@projectMetadata = projectmeta

# %%
saveRDS(ArchRProject.filt@projectMetadata, file.path(args$archr_directory,"projectMetadata.rds"))

# %%
readRDS(file.path(args$archr_directory,"projectMetadata.rds"))
# Out:
# List of length 2
# names(2): outputDirectory GroupCoverages

# %%
##################
## Peak calling ##
##################
args$pathToMacs2 = findMacs2()
args$pvalue_cutoff = 1e-3
args$extend_summits = 300

ArchRProject.filt <- addReproduciblePeakSet(
  ArchRProj = ArchRProject.filt, 
  groupBy = args$group_by, 
  peakMethod = "Macs2",
  excludeChr = c("chrM", "chrY"),
  pathToMacs2 = args$pathToMacs2,
  cutOff = args$pvalue_cutoff,
  extendSummits = args$extend_summits,
  plot = FALSE,
  force = TRUE
)

################
## Save peaks ##
################
# Out:
# Searching For MACS2..
#
# Found with $path!
#
# ArchR logging to : ArchRLogs/ArchR-addReproduciblePeakSet-86927c6bdca9-Date-2022-05-27_Time-17-35-50.log
# If there is an issue, please report to github with logFile!
#
# Calling Peaks with Macs2
#
# 2022-05-27 17:35:50 : Peak Calling Parameters!, 0.006 mins elapsed.
#                                                                           Group
# Allantois-eomes_ko                                           Allantois-eomes_ko
# Allantois-wt                                                       Allantois-wt
# Haematoendothelial_progenitors-eomes_ko Haematoendothelial_progenitors-eomes_ko
#                                         nCells nCellsUsed nReplicates nMin nMax
# Allantois-eomes_ko                         943        196           2  100  100
# Allantois-wt                               278        171           2  100  100
# Haematoendothelial_progenitors-eomes_ko    135        133           2  100  100
#                                         maxPeaks
# Allantois-eomes_ko                         98000
# Allantois-wt                               85500
# Haematoendothelial_progenitors-eomes_ko    66500
# 2022-05-27 17:35:50 : Batching Peak Calls!, 0.006 mins elapsed.
#
# 2022-05-27 17:35:50 : Batch Execution w/ safelapply!, 0 mins elapsed.
#
# 2022-05-27 17:35:50 : Group 1 of 6, Calling Peaks with MACS2!, 0 mins elapsed.

# %%
sample_metadata_bu = sample_metadata
args$min_cells = 200

# Filter groups by minimum number of cells
stopifnot(args$group_by%in%colnames(sample_metadata))
sample_metadata <- sample_metadata[!is.na(sample_metadata[[args$group_by]])]
sample_metadata <- sample_metadata[!grepl("NA",sample_metadata[[args$group_by]])]
sample_metadata <- sample_metadata[,N:=.N,by=c(args$group_by)] %>% .[N>=args$min_cells] %>% .[,N:=NULL]
unique(sample_metadata[[args$group_by]])
# Out:
# [1] "Allantois-wt"       "Allantois-eomes_ko"

# %%
ArchRProject.filt <- ArchRProject[sample_metadata$cell]

# %%
##################
## Peak calling ##
##################
args$pathToMacs2 = findMacs2()
args$pvalue_cutoff = 1e-3
args$extend_summits = 300

ArchRProject.filt <- addReproduciblePeakSet(
  ArchRProj = ArchRProject.filt, 
  groupBy = args$group_by, 
  peakMethod = "Macs2",
  excludeChr = c("chrM", "chrY"),
  pathToMacs2 = args$pathToMacs2,
  cutOff = args$pvalue_cutoff,
  extendSummits = args$extend_summits,
  plot = FALSE,
  force = TRUE
)

################
## Save peaks ##
################
# Out:
# Searching For MACS2..
#
# Found with $path!
#
# ArchR logging to : ArchRLogs/ArchR-addReproduciblePeakSet-447416d484195-Date-2022-05-27_Time-14-15-43.log
# If there is an issue, please report to github with logFile!
#
# Calling Peaks with Macs2
# Error in data.frame(Group = names(coverageParams$cellGroups)[y], nCells = tableGroups[names(coverageParams$cellGroups)[y]], : row names contain missing values
# Traceback:
#
# 1. addReproduciblePeakSet(ArchRProj = ArchRProject.filt, groupBy = args$group_by,
#  .     peakMethod = "Macs2", excludeChr = c("chrM", "chrY"), pathToMacs2 = args$pathToMacs2,
#  .     cutOff = args$pvalue_cutoff, extendSummits = args$extend_summits,
#  .     plot = FALSE, force = TRUE)
# 2. lapply(seq_along(coverageParams$cellGroups), function(y) {
#  .     x <- coverageParams$cellGroups[[y]]
#  .     uniq <- unique(unlist(x))
#  .     n <- lapply(x, length) %>% unlist %>% sum
#  .     nmin <- lapply(x, length) %>% unlist %>% min
#  .     nmax <- lapply(x, length) %>% unlist %>% max
#  .     data.frame(Group = names(coverageParams$cellGroups)[y], nCells = tableGroups[names(coverageParams$cellGroups)[y]],
#  .         nCellsUsed = length(uniq), nReplicates = length(x), nMin = nmin,
#  .         nMax = nmax, maxPeaks = min(maxPeaks, length(uniq) *
#  .             peaksPerCell))
#  . }) %>% Reduce("rbind", .)
# 3. Reduce("rbind", .)
# 4. lapply(seq_along(coverageParams$cellGroups), function(y) {
#  .     x <- coverageParams$cellGroups[[y]]
#  .     uniq <- unique(unlist(x))
#  .     n <- lapply(x, length) %>% unlist %>% sum
#  .     nmin <- lapply(x, length) %>% unlist %>% min
#  .     nmax <- lapply(x, length) %>% unlist %>% max
#  .     data.frame(Group = names(coverageParams$cellGroups)[y], nCells = tableGroups[names(coverageParams$cellGroups)[y]],
#  .         nCellsUsed = length(uniq), nReplicates = length(x), nMin = nmin,
#  .         nMax = nmax, maxPeaks = min(maxPeaks, length(uniq) *
#  .             peaksPerCell))
#  . })
# 5. FUN(X[[i]], ...)
# 6. data.frame(Group = names(coverageParams$cellGroups)[y], nCells = tableGroups[names(coverageParams$cellGroups)[y]],
#  .     nCellsUsed = length(uniq), nReplicates = length(x), nMin = nmin,
#  .     nMax = nmax, maxPeaks = min(maxPeaks, length(uniq) * peaksPerCell))
# 7. stop("row names contain missing values")

# %% [markdown]
# Peaks have to be called on the same cell/group_by set as reproducible peaks are called on, otherwise it gives an error.
#
# But we don't want to call peaks on group_by's with only <100 cells, so how do we exclude these?
#
# Maybe run everything as normal, and then exclude these peaks in hindsight

# %%
args$min_cells = 100

# %%
########################
## Load cell metadata ##
########################

sample_metadata <- fread(args$metadata) %>%
  .[pass_atacQC==TRUE & sample%in%opts$samples]

# temporary
# sample_metadata[,day:=stringr::str_replace_all(sample,opts$sample2day)] %>%
#   .[,genotype:=stringr::str_replace_all(sample,opts$sample2genotype)] %>%
#   .[,day_genotype:=paste(day,genotype,sep="_")] %>%
#   .[,celltype_genotype:=paste(celltype.mapped_mnn,genotype,sep="_")]

# Filter groups by minimum number of cells
stopifnot(args$group_by%in%colnames(sample_metadata))
sample_metadata <- sample_metadata[!is.na(sample_metadata[[args$group_by]])]
sample_metadata <- sample_metadata[!grepl("NA",sample_metadata[[args$group_by]])]
sample_metadata <- sample_metadata[,N:=.N,by=c(args$group_by)] %>% .[N>=args$min_cells] %>% .[,N:=NULL]

table(sample_metadata[[args$group_by]])

########################
## Load ArchR project ##
########################

# source(here::here("atac/archR/load_archR_project.R"))

setwd(args$archr_directory)

addArchRGenome("mm10")
addArchRThreads(threads = args$threads)
# Out:
#                      Allantois-eomes_ko                            Allantois-wt
#                                     943                                     278
# Haematoendothelial_progenitors-eomes_ko
#                                     135
# Setting default genome to Mm10.
#
# Setting default number of Parallel threads to 1.

# %%
ArchRProject.filt <- ArchRProject[head(sample_metadata$cell, 100)]

# %%
ArchRProject.filt

# %%
ArchRProject.filt <- addGroupCoverages(ArchRProject.filt, 
  groupBy = args$group_by,
  useLabels = FALSE,  # do not use sample information
  minCells = 200,
  maxCells = 1000,
  force = TRUE
)
# Out:
# ArchR logging to : ArchRLogs/ArchR-addGroupCoverages-4474178adb5bd-Date-2022-05-27_Time-14-18-16.log
# If there is an issue, please report to github with logFile!
#
# Allantois-eomes_ko (1 of 3) : CellGroups N = 2
#
# Allantois-wt (2 of 3) : CellGroups N = 2
#
# Haematoendothelial_progenitors-eomes_ko (3 of 3) : CellGroups N = 2
#
# 2022-05-27 14:18:17 : Creating Coverage Files!, 0.008 mins elapsed.
#
# 2022-05-27 14:18:17 : Batch Execution w/ safelapply!, 0.008 mins elapsed.
#
# 2022-05-27 14:18:17 : Group Allantois-eomes_ko._.Rep1 (1 of 6) : Creating Group Coverage File : Allantois.eomes_ko._.Rep1.insertions.coverage.h5, 0.009 mins elapsed.
#
# Number of Cells = 200
#
# Coverage File Exists!
#
# Added Coverage Group
#
# Added Metadata Group
#
# Added ArrowCoverage Class
#
# Added Coverage/Info
#
# Added Coverage/Info/CellNames
#
# 2022-05-27 14:18:52 : Group Allantois-eomes_ko._.Rep2 (2 of 6) : Creating Group Coverage File : Allantois.eomes_ko._.Rep2.insertions.coverage.h5, 0.589 mins elapsed.
#
# Number of Cells = 200
#
# Coverage File Exists!
#
# Added Coverage Group
#
# Added Metadata Group
#
# Added ArrowCoverage Class
#
# Added Coverage/Info
#
# Added Coverage/Info/CellNames
#
# 2022-05-27 14:19:29 : Group Allantois-wt._.Rep1 (3 of 6) : Creating Group Coverage File : Allantois.wt._.Rep1.insertions.coverage.h5, 1.218 mins elapsed.
#
# Number of Cells = 200
#
# Coverage File Exists!
#
# Added Coverage Group
#
# Added Metadata Group
#
# Added ArrowCoverage Class
#
# Added Coverage/Info
#
# Added Coverage/Info/CellNames
#
# 2022-05-27 14:19:53 : Group Allantois-wt._.Rep2 (4 of 6) : Creating Group Coverage File : Allantois.wt._.Rep2.insertions.coverage.h5, 1.611 mins elapsed.
#
# Number of Cells = 200
#
# Coverage File Exists!
#
# Added Coverage Group
#
# Added Metadata Group
#
# Added ArrowCoverage Class
#
# Added Coverage/Info
#
# Added Coverage/Info/CellNames
#
# 2022-05-27 14:20:17 : Group Haematoendothelial_progenitors-eomes_ko._.Rep1 (5 of 6) : Creating Group Coverage File : Haematoendothelial_progenitors.eomes_ko._.Rep1.insertions.coverage.h5, 2.013 mins elapsed.
#
# Number of Cells = 105
#
# Coverage File Exists!
#
# Added Coverage Group
#
# Added Metadata Group
#
# Added ArrowCoverage Class
#
# Added Coverage/Info
#
# Added Coverage/Info/CellNames
#
# 2022-05-27 14:20:45 : Group Haematoendothelial_progenitors-eomes_ko._.Rep2 (6 of 6) : Creating Group Coverage File : Haematoendothelial_progenitors.eomes_ko._.Rep2.insertions.coverage.h5, 2.478 mins elapsed.
#
# Number of Cells = 103
#
# Coverage File Exists!
#
# Added Coverage Group
#
# Added Metadata Group
#
# Added ArrowCoverage Class
#
# Added Coverage/Info
#
# Added Coverage/Info/CellNames
#
# 2022-05-27 14:21:16 : Adding Kmer Bias to Coverage Files!, 2.992 mins elapsed.
#
# Kmer Bias chr1 (1 of 21)
#
# chr1
# Coverage File chr1 (1 of 6)
#
# Coverage File chr1 (2 of 6)
#
# Coverage File chr1 (3 of 6)
#
# Coverage File chr1 (4 of 6)
#
# Coverage File chr1 (5 of 6)
#
# Coverage File chr1 (6 of 6)
#
# Kmer Bias chr10 (2 of 21)
#
# chr10
# Coverage File chr10 (1 of 6)
#
# Coverage File chr10 (2 of 6)
#
# Coverage File chr10 (3 of 6)
#
# Coverage File chr10 (4 of 6)
#
# Coverage File chr10 (5 of 6)
#
# Coverage File chr10 (6 of 6)
#
# Kmer Bias chr11 (3 of 21)
#
# chr11
# Coverage File chr11 (1 of 6)
#
# Coverage File chr11 (2 of 6)
#
# Coverage File chr11 (3 of 6)
#
# Coverage File chr11 (4 of 6)
#
# Coverage File chr11 (5 of 6)
#
# Coverage File chr11 (6 of 6)
#
# Kmer Bias chr12 (4 of 21)
#
# chr12
# Coverage File chr12 (1 of 6)
#
# Coverage File chr12 (2 of 6)
#
# Coverage File chr12 (3 of 6)
#
# Coverage File chr12 (4 of 6)
#
# Coverage File chr12 (5 of 6)
#
# Coverage File chr12 (6 of 6)
#
# Kmer Bias chr13 (5 of 21)
#
# chr13
# Coverage File chr13 (1 of 6)
#
# Coverage File chr13 (2 of 6)
#
# Coverage File chr13 (3 of 6)
#
# Coverage File chr13 (4 of 6)
#
# Coverage File chr13 (5 of 6)
#
# Coverage File chr13 (6 of 6)
#
# Kmer Bias chr14 (6 of 21)
#
# chr14
# Coverage File chr14 (1 of 6)
#
# Coverage File chr14 (2 of 6)
#
# Coverage File chr14 (3 of 6)
#
# Coverage File chr14 (4 of 6)
#
# Coverage File chr14 (5 of 6)
#
# Coverage File chr14 (6 of 6)
#
# Kmer Bias chr15 (7 of 21)
#
# chr15
# Coverage File chr15 (1 of 6)
#
# Coverage File chr15 (2 of 6)
#
# Coverage File chr15 (3 of 6)
#
# Coverage File chr15 (4 of 6)
#
# Coverage File chr15 (5 of 6)
#
# Coverage File chr15 (6 of 6)
#
# Kmer Bias chr16 (8 of 21)
#
# chr16
# Coverage File chr16 (1 of 6)
#
# Coverage File chr16 (2 of 6)
#
# Coverage File chr16 (3 of 6)
#
# Coverage File chr16 (4 of 6)
#
# Coverage File chr16 (5 of 6)
#
# Coverage File chr16 (6 of 6)
#
# Kmer Bias chr17 (9 of 21)
#
# chr17
# Coverage File chr17 (1 of 6)
#
# Coverage File chr17 (2 of 6)
#
# Coverage File chr17 (3 of 6)
#
# Coverage File chr17 (4 of 6)
#
# Coverage File chr17 (5 of 6)
#
# Coverage File chr17 (6 of 6)
#
# Kmer Bias chr18 (10 of 21)
#
# chr18
# Coverage File chr18 (1 of 6)
#
# Coverage File chr18 (2 of 6)
#
# Coverage File chr18 (3 of 6)
#
# Coverage File chr18 (4 of 6)
#
# Coverage File chr18 (5 of 6)
#
# Coverage File chr18 (6 of 6)
#
# Kmer Bias chr19 (11 of 21)
#
# chr19
# Coverage File chr19 (1 of 6)
#
# Coverage File chr19 (2 of 6)
#
# Coverage File chr19 (3 of 6)
#
# Coverage File chr19 (4 of 6)
#
# Coverage File chr19 (5 of 6)
#
# Coverage File chr19 (6 of 6)
#
# Kmer Bias chr2 (12 of 21)
#
# chr2
# Coverage File chr2 (1 of 6)
#
# Coverage File chr2 (2 of 6)
#
# Coverage File chr2 (3 of 6)
#
# Coverage File chr2 (4 of 6)
#
# Coverage File chr2 (5 of 6)
#
# Coverage File chr2 (6 of 6)
#
# Kmer Bias chr3 (13 of 21)
#
# chr3
# Coverage File chr3 (1 of 6)
#
# Coverage File chr3 (2 of 6)
#
# Coverage File chr3 (3 of 6)
#
# Coverage File chr3 (4 of 6)
#
# Coverage File chr3 (5 of 6)
#
# Coverage File chr3 (6 of 6)
#
# Kmer Bias chr4 (14 of 21)
#
# chr4
# Coverage File chr4 (1 of 6)
#
# Coverage File chr4 (2 of 6)
#
# Coverage File chr4 (3 of 6)
#
# Coverage File chr4 (4 of 6)
#
# Coverage File chr4 (5 of 6)
#
# Coverage File chr4 (6 of 6)
#
# Kmer Bias chr5 (15 of 21)
#
# chr5
# Coverage File chr5 (1 of 6)
#
# Coverage File chr5 (2 of 6)
#
# Coverage File chr5 (3 of 6)
#
# Coverage File chr5 (4 of 6)
#
# Coverage File chr5 (5 of 6)
#
# Coverage File chr5 (6 of 6)
#
# Kmer Bias chr6 (16 of 21)
#
# chr6
# Coverage File chr6 (1 of 6)
#
# Coverage File chr6 (2 of 6)
#
# Coverage File chr6 (3 of 6)
#
# Coverage File chr6 (4 of 6)
#
# Coverage File chr6 (5 of 6)
#
# Coverage File chr6 (6 of 6)
#
# Kmer Bias chr7 (17 of 21)
#
# chr7
# Coverage File chr7 (1 of 6)
#
# Coverage File chr7 (2 of 6)
#
# Coverage File chr7 (3 of 6)
#
# Coverage File chr7 (4 of 6)
#
# Coverage File chr7 (5 of 6)
#
# Coverage File chr7 (6 of 6)
#
# Kmer Bias chr8 (18 of 21)
#
# chr8
# Coverage File chr8 (1 of 6)
#
# Coverage File chr8 (2 of 6)
#
# Coverage File chr8 (3 of 6)
#
# Coverage File chr8 (4 of 6)
#
# Coverage File chr8 (5 of 6)
#
# Coverage File chr8 (6 of 6)
#
# Kmer Bias chr9 (19 of 21)
#
# chr9
# Coverage File chr9 (1 of 6)
#
# Coverage File chr9 (2 of 6)
#
# Coverage File chr9 (3 of 6)
#
# Coverage File chr9 (4 of 6)
#
# Coverage File chr9 (5 of 6)
#
# Coverage File chr9 (6 of 6)
#
# Kmer Bias chrX (20 of 21)
#
# chrX
# Coverage File chrX (1 of 6)
#
# Coverage File chrX (2 of 6)
#
# Coverage File chrX (3 of 6)
#
# Coverage File chrX (4 of 6)
#
# Coverage File chrX (5 of 6)
#
# Coverage File chrX (6 of 6)
#
# Kmer Bias chrY (21 of 21)
#
# chrY
# Coverage File chrY (1 of 6)
#
# Coverage File chrY (2 of 6)
#
# Coverage File chrY (3 of 6)
#
# Coverage File chrY (4 of 6)
#
# Coverage File chrY (5 of 6)
#
# Coverage File chrY (6 of 6)
#
# Completed Kmer Bias Calculation
#
# Adding Kmer Bias (1 of 6)
#
# Adding Kmer Bias (2 of 6)
#
# Adding Kmer Bias (3 of 6)
#
# Adding Kmer Bias (4 of 6)
#
# Adding Kmer Bias (5 of 6)
#
# Adding Kmer Bias (6 of 6)
#
# 2022-05-27 14:23:46 : Finished Creation of Coverage Files!, 5.498 mins elapsed.
#
# ArchR logging successful to : ArchRLogs/ArchR-addGroupCoverages-4474178adb5bd-Date-2022-05-27_Time-14-18-16.log

# %%
##################
## Peak calling ##
##################
args$pathToMacs2 = findMacs2()
args$pvalue_cutoff = 1e-3
args$extend_summits = 300

ArchRProject.filt <- addReproduciblePeakSet(
  ArchRProj = ArchRProject.filt, 
  groupBy = args$group_by, 
  peakMethod = "Macs2",
  excludeChr = c("chrM", "chrY"),
  pathToMacs2 = args$pathToMacs2,
  cutOff = args$pvalue_cutoff,
  extendSummits = args$extend_summits,
  plot = FALSE,
  force = TRUE
)

################
## Save peaks ##
################
# Out:
# Searching For MACS2..
#
# Found with $path!
#
# ArchR logging to : ArchRLogs/ArchR-addReproduciblePeakSet-447413bc7a65f-Date-2022-05-27_Time-14-26-15.log
# If there is an issue, please report to github with logFile!
#
# Calling Peaks with Macs2
#
# 2022-05-27 14:26:15 : Peak Calling Parameters!, 0.004 mins elapsed.
#                                                                           Group
# Allantois-eomes_ko                                           Allantois-eomes_ko
# Allantois-wt                                                       Allantois-wt
# Haematoendothelial_progenitors-eomes_ko Haematoendothelial_progenitors-eomes_ko
#                                         nCells nCellsUsed nReplicates nMin nMax
# Allantois-eomes_ko                         943        369           2  200  200
# Allantois-wt                               278        265           2  200  200
# Haematoendothelial_progenitors-eomes_ko    135        133           2  103  105
#                                         maxPeaks
# Allantois-eomes_ko                        150000
# Allantois-wt                              132500
# Haematoendothelial_progenitors-eomes_ko    66500
# 2022-05-27 14:26:15 : Batching Peak Calls!, 0.004 mins elapsed.
#
# 2022-05-27 14:26:15 : Batch Execution w/ safelapply!, 0 mins elapsed.
#
# 2022-05-27 14:26:15 : Group 1 of 6, Calling Peaks with MACS2!, 0 mins elapsed.
#
# Running Macs2 with Params : macs2 callpeak -g 1.87e+09 --name Allantois.eomes_ko._.Rep1-1 --treatment /rds/project/rds-SDzz0CATGms/users/bt392/09_Eomes_invitro_blood/processed/atac/archR/PeakCalls/InsertionBeds/Allantois.eomes_ko._.Rep1-1.insertions.bed --outdir /rds/project/rds-SDzz0CATGms/users/bt392/09_Eomes_invitro_blood/processed/atac/archR/PeakCalls/InsertionBeds --format BED --call-summits --keep-dup all --nomodel --nolambda --shift -75 --extsize 150 -q 0.001
#
# Warning message in data.table::fread(summitsFile, select = c(1, 2, 3, 5)):
# “File '/rds/project/rds-SDzz0CATGms/users/bt392/09_Eomes_invitro_blood/processed/atac/archR/PeakCalls/InsertionBeds/Allantois.eomes_ko._.Rep1-1_summits.bed' has size 0. Returning a NULL data.table.”
# 2022-05-27 14:26:57 : Group 2 of 6, Calling Peaks with MACS2!, 0.689 mins elapsed.
#
# Running Macs2 with Params : macs2 callpeak -g 1.87e+09 --name Allantois.eomes_ko._.Rep2-2 --treatment /rds/project/rds-SDzz0CATGms/users/bt392/09_Eomes_invitro_blood/processed/atac/archR/PeakCalls/InsertionBeds/Allantois.eomes_ko._.Rep2-2.insertions.bed --outdir /rds/project/rds-SDzz0CATGms/users/bt392/09_Eomes_invitro_blood/processed/atac/archR/PeakCalls/InsertionBeds --format BED --call-summits --keep-dup all --nomodel --nolambda --shift -75 --extsize 150 -q 0.001
# Error in data.table::fread(summitsFile, select = c(1, 2, 3, 5)): File '/rds/project/rds-SDzz0CATGms/users/bt392/09_Eomes_invitro_blood/processed/atac/archR/PeakCalls/InsertionBeds/Allantois.eomes_ko._.Rep2-2_summits.bed' does not exist or is non-readable. getwd()=='/rds/project/rds-SDzz0CATGms/users/bt392/09_Eomes_invitro_blood/processed/atac/archR'
# Traceback:
#
# 1. addReproduciblePeakSet(ArchRProj = ArchRProject.filt, groupBy = args$group_by,
#  .     peakMethod = "Macs2", excludeChr = c("chrM", "chrY"), pathToMacs2 = args$pathToMacs2,
#  .     cutOff = args$pvalue_cutoff, extendSummits = args$extend_summits,
#  .     plot = FALSE, force = TRUE)
# 2. unlist(.batchlapply(args))
# 3. .batchlapply(args)
# 4. do.call(.safelapply, args)
# 5. (function (..., threads = 1, preschedule = FALSE)
#  . {
#  .     if (tolower(.Platform$OS.type) == "windows") {
#  .         threads <- 1
#  .     }
#  .     if (threads > 1) {
#  .         o <- mclapply(..., mc.cores = threads, mc.preschedule = preschedule)
#  .         errorMsg <- list()
#  .         for (i in seq_along(o)) {
#  .             if (inherits(o[[i]], "try-error")) {
#  .                 capOut <- utils::capture.output(o[[i]])
#  .                 capOut <- capOut[!grepl("attr\\(\\,|try-error",
#  .                   capOut)]
#  .                 capOut <- head(capOut, 10)
#  .                 capOut <- unlist(lapply(capOut, function(x) substr(x,
#  .                   1, 250)))
#  .                 capOut <- paste0("\t", capOut)
#  .                 errorMsg[[length(errorMsg) + 1]] <- paste0(c(paste0("Error Found Iteration ",
#  .                   i, " : "), capOut), "\n")
#  .             }
#  .         }
#  .         if (length(errorMsg) != 0) {
#  .             errorMsg <- unlist(errorMsg)
#  .             errorMsg <- head(errorMsg, 50)
#  .             errorMsg[1] <- paste0("\n", errorMsg[1])
#  .             stop(errorMsg)
#  .         }
#  .     }
#  .     else {
#  .         o <- lapply(...)
#  .     }
#  .     o
#  . })(X = 1:6, FUN = function (i = NULL, coverageFiles = NULL, outFiles = NULL,
#  .     peakParams = NULL, bedDir = NULL, excludeChr = NULL, subThreads = 1,
#  .     tstart = NULL, logFile = NULL)
#  . {
#  .     .logDiffTime(sprintf("Group %s of %s, Calling Peaks with MACS2!",
#  .         i, length(coverageFiles)), tstart, verbose = TRUE, logFile = logFile)
#  .     bedFile <- file.path(bedDir, paste0(make.names(basename(names(coverageFiles)[i])),
#  .         "-", i, ".insertions.bed"))
#  .     o <- .writeCoverageToBed(coverageFiles[i], bedFile, excludeChr = excludeChr,
#  .         logFile = logFile)
#  .     peakParams$bedFile <- bedFile
#  .     peakParams$logFile <- logFile
#  .     summits <- do.call(.callSummitsMACS2, peakParams)
#  .     rmf <- file.remove(bedFile)
#  .     saveRDS(summits, outFiles[i])
#  .     outFiles[i]
#  . }, coverageFiles = c(`Allantois-eomes_ko._.Rep1` = "/rds/project/rds-SDzz0CATGms/users/bt392/09_Eomes_invitro_blood/processed/atac/archR/GroupCoverages/celltype_genotype/Allantois.eomes_ko._.Rep1.insertions.coverage.h5",
#  . `Allantois-eomes_ko._.Rep2` = "/rds/project/rds-SDzz0CATGms/users/bt392/09_Eomes_invitro_blood/processed/atac/archR/GroupCoverages/celltype_genotype/Allantois.eomes_ko._.Rep2.insertions.coverage.h5",
#  . `Allantois-wt._.Rep1` = "/rds/project/rds-SDzz0CATGms/users/bt392/09_Eomes_invitro_blood/processed/atac/archR/GroupCoverages/celltype_genotype/Allantois.wt._.Rep1.insertions.coverage.h5",
#  . `Allantois-wt._.Rep2` = "/rds/project/rds-SDzz0CATGms/users/bt392/09_Eomes_invitro_blood/processed/atac/archR/GroupCoverages/celltype_genotype/Allantois.wt._.Rep2.insertions.coverage.h5",
#  . `Haematoendothelial_progenitors-eomes_ko._.Rep1` = "/rds/project/rds-SDzz0CATGms/users/bt392/09_Eomes_invitro_blood/processed/atac/archR/GroupCoverages/celltype_genotype/Haematoendothelial_progenitors.eomes_ko._.Rep1.insertions.coverage.h5",
#  . `Haematoendothelial_progenitors-eomes_ko._.Rep2` = "/rds/project/rds-SDzz0CATGms/users/bt392/09_Eomes_invitro_blood/processed/atac/archR/GroupCoverages/celltype_genotype/Haematoendothelial_progenitors.eomes_ko._.Rep2.insertions.coverage.h5"
#  . ), outFiles = c("/rds/project/rds-SDzz0CATGms/users/bt392/09_Eomes_invitro_blood/processed/atac/archR/PeakCalls/ReplicateCalls/Allantois.eomes_ko._.Rep1-summits.rds",
#  . "/rds/project/rds-SDzz0CATGms/users/bt392/09_Eomes_invitro_blood/processed/atac/archR/PeakCalls/ReplicateCalls/Allantois.eomes_ko._.Rep2-summits.rds",
#  . "/rds/project/rds-SDzz0CATGms/users/bt392/09_Eomes_invitro_blood/processed/atac/archR/PeakCalls/ReplicateCalls/Allantois.wt._.Rep1-summits.rds",
#  . "/rds/project/rds-SDzz0CATGms/users/bt392/09_Eomes_invitro_blood/processed/atac/archR/PeakCalls/ReplicateCalls/Allantois.wt._.Rep2-summits.rds",
#  . "/rds/project/rds-SDzz0CATGms/users/bt392/09_Eomes_invitro_blood/processed/atac/archR/PeakCalls/ReplicateCalls/Haematoendothelial_progenitors.eomes_ko._.Rep1-summits.rds",
#  . "/rds/project/rds-SDzz0CATGms/users/bt392/09_Eomes_invitro_blood/processed/atac/archR/PeakCalls/ReplicateCalls/Haematoendothelial_progenitors.eomes_ko._.Rep2-summits.rds"
#  . ), bedDir = "/rds/project/rds-SDzz0CATGms/users/bt392/09_Eomes_invitro_blood/processed/atac/archR/PeakCalls/InsertionBeds",
#  .     excludeChr = c("chrM", "chrY"), peakParams = list(pathToMacs2 = "macs2",
#  .         genomeSize = 1.87e+09, shift = -75, extsize = 150, cutOff = 0.001,
#  .         method = "q", additionalParams = "--nomodel --nolambda"),
#  .     threads = 1L, logFile = "ArchRLogs/ArchR-addReproduciblePeakSet-447413bc7a65f-Date-2022-05-27_Time-14-26-15.log",
#  .     tstart = structure(1653657975.76233, class = c("POSIXct",
#  .     "POSIXt")), subThreads = 1)
# 6. lapply(...)
# 7. FUN(X[[i]], ...)
# 8. do.call(.callSummitsMACS2, peakParams)
# 9. (function (bedFile = NULL, pathToMacs2 = "macs2", genomeSize = 2.7e+09,
#  .     shift = -75, extsize = 150, cutOff = 0.05, method = "q",
#  .     additionalParams = "--nomodel --nolambda", logFile = NULL)
#  . {
#  .     stopifnot(tolower(method) %in% c("p", "q"))
#  .     stopifnot(!is.null(genomeSize))
#  .     utility <- .checkPath(pathToMacs2)
#  .     bedName <- gsub("\\.insertions.bed", "", bedFile)
#  .     summitsFile <- paste0(bedName, "_summits.bed")
#  .     narrowPeaksFile <- paste0(bedName, "_peaks.narrowPeak")
#  .     xlsFile <- paste0(bedName, "_peaks.xls")
#  .     cmd <- sprintf("callpeak -g %s --name %s --treatment %s --outdir %s --format BED --call-summits --keep-dup all %s",
#  .         genomeSize, basename(bedName), bedFile, dirname(bedName),
#  .         additionalParams)
#  .     if (!is.null(shift) & !is.null(extsize)) {
#  .         cmd <- sprintf("%s --shift %s --extsize %s", cmd, shift,
#  .             extsize)
#  .     }
#  .     if (tolower(method) == "p") {
#  .         cmd <- sprintf("%s -p %s", cmd, cutOff)
#  .     }
#  .     else {
#  .         cmd <- sprintf("%s -q %s", cmd, cutOff)
#  .     }
#  .     .logMessage(paste0("Running Macs2 with Params : macs2 ",
#  .         cmd), logFile = logFile)
#  .     run <- system2(pathToMacs2, cmd, wait = TRUE, stdout = NULL,
#  .         stderr = NULL)
#  .     out <- data.table::fread(summitsFile, select = c(1, 2, 3,
#  .         5))
#  .     out <- GRanges(out$V1, IRanges(out$V2 + 1, out$V3), score = out$V5)
#  .     r2 <- suppressWarnings(file.remove(summitsFile, narrowPeaksFile,
#  .         xlsFile))
#  .     return(out)
#  . })(pathToMacs2 = "macs2", genomeSize = 1.87e+09, shift = -75,
#  .     extsize = 150, cutOff = 0.001, method = "q", additionalParams = "--nomodel --nolambda",
#  .     bedFile = "/rds/project/rds-SDzz0CATGms/users/bt392/09_Eomes_invitro_blood/processed/atac/archR/PeakCalls/InsertionBeds/Allantois.eomes_ko._.Rep2-2.insertions.bed",
#  .     logFile = "ArchRLogs/ArchR-addReproduciblePeakSet-447413bc7a65f-Date-2022-05-27_Time-14-26-15.log")
# 10. data.table::fread(summitsFile, select = c(1, 2, 3, 5))
# 11. stop("File '", file, "' does not exist or is non-readable. getwd()=='",
#   .     getwd(), "'")

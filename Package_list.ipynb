# %% [markdown]
# # Container

# %%
import warnings, sys
warnings.filterwarnings('ignore')

# %load_ext rpy2.ipython

# %%
sys.version
# Out:
# '3.8.6 (default, Sep 30 2020, 04:00:38) \n[GCC 10.2.0]'

# %%
# %%bash
# pip list
# Out:
# Package                           Version              Location
# --------------------------------- -------------------- -----------------------
# absl-py                           0.12.0
# adjustText                        0.7.3
# aiohttp                           3.7.4.post0
# alabaster                         0.7.12
# altair                            4.1.0
# anndata                           0.7.4
# anndata2ri                        1.0.6
# annoy                             1.17.0
# anyio                             2.0.2
# appdirs                           1.4.4
# arboreto                          0.1.6
# argon2-cffi                       20.1.0
# arrow                             0.17.0
# astunparse                        1.6.3
# async-generator                   1.10
# async-timeout                     3.0.1
# atomicwrites                      1.4.0
# attrs                             20.3.0
# Babel                             2.8.0
# backcall                          0.2.0
# bash-kernel                       0.7.2
# batchglm                          0.7.4
# bbknn                             1.3.12
# beautifulsoup4                    4.9.3
# bioservices                       1.7.9
# bleach                            3.2.1
# bokeh                             2.2.3
# boltons                           20.2.1
# boto3                             1.12.49
# botocore                          1.15.49
# Brotli                            1.0.9
# CacheControl                      0.12.6
# cachetools                        4.2.1
# cellrank                          1.0.0
# certifi                           2020.11.8
# cffi                              1.14.3
# chardet                           3.0.4
# CITE-seq-Count                    1.4.3
# click                             7.1.2
# cloudpickle                       1.6.0
# cmake                             3.18.2.post1
# colorama                          0.4.4
# colorlog                          4.6.2
# colorlover                        0.3.0
# commonmark                        0.9.1
# csscompressor                     0.9.5
# custom-inherit                    2.3.0
# cycler                            0.10.0
# Cython                            0.29.21
# cytoolz                           0.11.0
# daiquiri                          3.0.0
# dash                              1.17.0
# dash-core-components              1.13.0
# dash-html-components              1.1.1
# dash-renderer                     1.8.3
# dash-table                        4.11.0
# dask                              2.30.0
# dataclasses                       0.6
# decorator                         4.4.2
# defusedxml                        0.6.0
# Deprecated                        1.2.10
# descartes                         1.1.0
# diffxpy                           0.7.4
# dill                              0.3.3
# distributed                       2.30.1
# docrep                            0.3.1
# docutils                          0.15.2
# dotscore                          0.0.1                /node-v14.15.4/dotscore
# easydev                           0.10.1
# entrypoints                       0.3
# fa2                               0.3.5
# fastcluster                       1.1.26
# fbpca                             1.0
# fcsparser                         0.2.1
# filetype                          1.0.7
# Flask                             1.1.2
# Flask-Compress                    1.8.0
# flatbuffers                       1.12
# frozendict                        1.2
# fsspec                            2021.4.0
# future                            0.18.2
# future-fstrings                   1.2.0
# gast                              0.3.3
# GEOparse                          2.0.2
# geosketch                         1.1
# get-version                       2.1
# gevent                            20.9.0
# Ghost.py                          0.2.3
# google-auth                       1.29.0
# google-auth-oauthlib              0.4.4
# google-pasta                      0.2.0
# graphtools                        1.5.2
# greenlet                          0.4.17
# grequests                         0.6.0
# grpcio                            1.32.0
# gseapy                            0.10.1
# h5py                              2.10.0
# harmonypy                         0.0.5
# hca-util                          0.2.12
# hdbscan                           0.8.26
# hdmedians                         0.14.2
# HeapDict                          1.0.1
# hnswlib                           0.4.0
# hyperopt                          0.1.2
# idna                              2.10
# imageio                           2.9.0
# imagesize                         1.2.0
# iniconfig                         1.1.1
# interlap                          0.2.7
# intervaltree                      2.1.0
# ipyevents                         0.8.1
# ipykernel                         5.3.4
# ipympl                            0.5.8
# ipyparallel                       6.3.0
# ipython                           7.19.0
# ipython-genutils                  0.2.0
# ipywidgets                        7.5.1
# itsdangerous                      1.1.0
# jedi                              0.17.2
# Jinja2                            2.11.2
# jmespath                          0.10.0
# joblib                            0.17.0
# joypy                             0.2.5
# json5                             0.9.5
# jsonschema                        3.2.0
# jupyter                           1.0.0
# jupyter-client                    6.1.7
# jupyter-console                   6.2.0
# jupyter-contrib-core              0.3.3
# jupyter-contrib-nbextensions      0.5.1
# jupyter-core                      4.6.3
# jupyter-datatables                0.3.9
# jupyter-highlight-selected-word   0.2.0
# jupyter-latex-envs                1.4.6
# jupyter-nbextensions-configurator 0.4.1
# jupyter-nbutils                   0.1.3
# jupyter-require                   0.6.1
# jupyter-server                    1.2.2
# jupyterlab                        3.0.7
# jupyterlab-pygments               0.1.2
# jupyterlab-server                 2.1.3
# jupytext                          1.6.0
# Keras                             2.4.3
# Keras-Preprocessing               1.1.2
# kiwisolver                        1.3.1
# legacy-api-wrap                   1.2
# leidenalg                         0.8.2
# llvmlite                          0.35.0
# locket                            0.2.1
# lockfile                          0.12.2
# loompy                            3.0.6
# louvain                           0.7.0
# lxml                              4.6.1
# magic-impute                      2.0.4
# Markdown                          3.3.4
# markdown-it-py                    0.5.6
# MarkupSafe                        1.1.1
# matplotlib                        3.3.2
# matplotlib-venn                   0.11.6
# mistune                           0.8.4
# mizani                            0.7.3
# mnnpy                             0.1.9.5
# more-itertools                    8.6.0
# mpi4py                            3.0.3
# msgpack                           1.0.2
# MulticoreTSNE                     0.1
# multidict                         5.1.0
# MultiMAP                          0.0.1
# multipledispatch                  0.6.0
# multiprocess                      0.70.11.1
# multiprocessing-on-dill           3.5.0a4
# natsort                           7.0.1
# nbbrowserpdf                      0.2.0
# nbclassic                         0.2.6
# nbclient                          0.5.1
# nbconvert                         6.0.7
# nbformat                          5.0.8
# nest-asyncio                      1.4.2
# networkx                          2.5
# notebook                          6.1.5
# npyscreen                         4.10.5
# numba                             0.52.0
# numexpr                           2.7.1
# numpy                             1.19.4
# numpy-groupies                    0.9.13
# oauthlib                          3.1.0
# opt-einsum                        3.3.0
# ordered-set                       4.0.2
# packaging                         20.4
# pacman-mirrors                    4.16.4
# palantir                          1.0.0
# palettable                        3.3.0
# pandas                            1.1.4
# pandocfilters                     1.4.3
# parso                             0.7.1
# partd                             1.2.0
# patsy                             0.5.1
# petsc                             3.14.1
# petsc4py                          3.14.0
# pexpect                           4.8.0
# phate                             1.0.4
# PhenoGraph                        1.5.7
# pickleshare                       0.7.5
# Pillow                            8.0.1
# pip                               21.1.3
# plotly                            4.0.0
# plotnine                          0.8.0
# pluggy                            0.13.1
# POT                               0.7.0
# progressbar2                      3.53.1
# prometheus-client                 0.8.0
# prompt-toolkit                    3.0.8
# protobuf                          3.15.8
# psutil                            5.7.3
# ptyprocess                        0.6.0
# py                                1.9.0
# pyarrow                           0.16.0
# pyasn1                            0.4.8
# pyasn1-modules                    0.2.8
# pybind11                          2.6.0
# pybktree                          1.1
# pycparser                         2.20
# pygam                             0.8.0
# Pygments                          2.7.2
# PyGSP                             0.5.1
# pymongo                           3.11.0
# pynndescent                       0.5.4
# pyparsing                         2.4.7
# PyPDF2                            1.26.0
# pypng                             0.0.20
# pyrsistent                        0.17.3
# pysam                             0.16.0.1
# pyscenic                          0.11.1
# pytest                            4.1.0
# pytest-dependency                 0.4.0
# python-dateutil                   2.8.1
# python-igraph                     0.8.3
# python-json-logger                2.0.1
# python-Levenshtein                0.12.0
# python-utils                      2.4.0
# pytz                              2020.4
# PyWavelets                        1.1.1
# PyYAML                            5.3.1
# pyzmq                             19.0.2
# qtconsole                         4.7.7
# QtPy                              1.9.0
# regex                             2020.10.28
# reportlab                         3.5.55
# requests                          2.24.0
# requests-cache                    0.5.2
# requests-oauthlib                 1.3.0
# retrying                          1.3.3
# rich                              9.2.0
# rpy2                              3.4.2
# rsa                               4.7.2
# s-gd2                             1.8
# s3transfer                        0.3.3
# sam-algorithm                     0.7.6
# scanorama                         1.6
# scanpy                            1.8.1
# scgen                             1.1.3
# scikit-bio                        0.5.6
# scikit-image                      0.17.2
# scikit-learn                      0.23.2
# scikit-misc                       0.1.3
# scipy                             1.5.4
# scprep                            1.0.10
# scrublet                          0.2.1
# scvelo                            0.2.3.dev34+gf7498c1
# scvi-tools                        0.7.1
# seaborn                           0.11.0
# Send2Trash                        1.5.0
# setuptools                        50.3.2
# setuptools-scm                    4.1.2
# simplegeneric                     0.8.1
# sinfo                             0.3.1
# six                               1.15.0
# slepc                             3.14.0
# slepc4py                          3.14.0
# smqpp                             0.1.2
# sniffio                           1.2.0
# snowballstemmer                   2.0.0
# sortedcontainers                  2.3.0
# soupsieve                         2.0.1
# sparse                            0.11.2
# Sphinx                            3.3.0
# sphinxcontrib-applehelp           1.0.2
# sphinxcontrib-devhelp             1.0.2
# sphinxcontrib-htmlhelp            1.0.3
# sphinxcontrib-jsmath              1.0.1
# sphinxcontrib-qthelp              1.0.3
# sphinxcontrib-serializinghtml     1.1.4
# statsmodels                       0.12.1
# stdlib-list                       0.7.0
# suds-jurko                        0.6
# tables                            3.6.1
# tabulate                          0.8.7
# tasklogger                        1.0.0
# tblib                             1.7.0
# tensorboard                       2.4.1
# tensorboard-plugin-wit            1.8.0
# tensorflow                        2.4.1
# tensorflow-estimator              2.4.0
# termcolor                         1.1.0
# terminado                         0.9.1
# testpath                          0.4.4
# texttable                         1.6.3
# threadpoolctl                     2.1.0
# tifffile                          2020.10.1
# toml                              0.10.2
# toolz                             0.11.1
# torch                             1.7.0
# tornado                           6.1
# toyplot                           0.19.0
# tqdm                              4.51.0
# traitlets                         5.0.5
# typing-extensions                 3.7.4.3
# tzlocal                           2.1
# umap-learn                        0.5.1
# umi-tools                         1.0.0
# urllib3                           1.25.10
# vendorize                         0.2.1
# wcwidth                           0.2.5
# webencodings                      0.5.1
# Werkzeug                          1.0.1
# wheel                             0.35.1
# widgetsnbextension                3.5.1
# wot                               1.0.8.post2
# wrapt                             1.12.1
# xlrd                              1.2.0
# xmltodict                         0.12.0
# yarl                              1.6.3
# zict                              2.0.0
# zope.event                        4.5.0
# zope.interface                    5.2.0
# WARNING: You are using pip version 21.1.3; however, version 21.2.4 is available.
# You should consider upgrading via the '/bin/python -m pip install --upgrade pip' command.

# %%
# %%bash
#
# R --version
# Out:
# R version 4.0.3 (2020-10-10) -- "Bunny-Wunnies Freak Out"
# Copyright (C) 2020 The R Foundation for Statistical Computing
# Platform: x86_64-pc-linux-gnu (64-bit)
#
# R is free software and comes with ABSOLUTELY NO WARRANTY.
# You are welcome to redistribute it under the terms of the
# GNU General Public License versions 2 or 3.
# For more information about these matters see
# https://www.gnu.org/licenses/.

# %%
# %%R
#
# ip <- as.data.frame(installed.packages()[,c(1,3:4)])
# rownames(ip) <- NULL
# ip <- ip[is.na(ip$Priority),1:2,drop=FALSE]
# print(ip, row.names=FALSE)
# Out:
#                             Package    Version
#                               abind      1.4-5
#                                ade4     1.7-16
#                                amap     0.8-18
#                             anndata    0.7.5.1
#                            annotate     1.68.0
#                       AnnotationDbi     1.52.0
#                    AnnotationFilter     1.14.0
#                       AnnotationHub     2.22.0
#                                 ape      5.4-1
#                                 ash     1.0-15
#                                ashr     2.2-47
#                             askpass        1.1
#                          assertthat      0.2.1
#                           backports      1.2.0
#                           base64enc      0.1-3
#                            basilisk      1.2.1
#                      basilisk.utils      1.2.2
#                           batchelor      1.6.2
#                               bbmle   1.0.23.1
#                           bdsmatrix      1.3-4
#                            beachmat      2.6.4
#                            beeswarm      0.2.3
#                         benchmarkme      1.0.5
#                     benchmarkmeData      1.0.4
#                               bglab        1.1
#                                  BH   1.75.0-0
#                             Biobase     2.50.0
#                       BiocFileCache     1.14.0
#                        BiocGenerics     0.36.0
#                         BiocManager    1.30.10
#                       BiocNeighbors      1.8.2
#                        BiocParallel     1.24.1
#                        BiocSingular      1.6.0
#                         BiocVersion     3.12.0
#                           biocViews     1.58.0
#                             biomaRt     2.46.0
#                          Biostrings     2.58.0
#                           bipartite       2.15
#                                 bit      4.0.4
#                               bit64      4.0.5
#                              bitops      1.0-6
#                                blob      1.2.1
#                             bluster      1.0.0
#                                brew      1.0-6
#                                brio      1.1.1
#                               broom      0.7.2
#                         broom.mixed      0.2.6
#                            BSgenome     1.58.0
#                               bslib      0.2.4
#                              cachem      1.0.1
#                               Cairo   1.5-12.2
#                               callr      3.5.1
#                                 car     3.0-10
#                             carData      3.0-4
#                               caret     6.0-86
#                             caTools     1.18.1
#                                 cba     0.2-21
#                          cellranger      1.1.0
#                           checkmate      2.0.0
#                        chemometrics      1.4.2
#                        ChIPpeakAnno     3.24.1
#                          ChIPseeker     1.26.0
#                            classInt      0.4-3
#                                 cli      2.3.0
#                               clipr      0.7.1
#                          clisymbols      1.2.0
#                   clusterExperiment     2.10.1
#                            ClusterR      1.2.2
#                           clusteval        0.1
#                                CNEr     1.26.0
#                                coda     0.19-4
#                                coin      1.3-1
#                          colorspace      2.0-0
#                            combinat      0.0-8
#                          commonmark        1.7
#                             conquer      1.0.2
#                            contrast       0.22
#                                coop      0.6-2
#                                covr      3.5.1
#                             cowplot      1.1.1
#                               cpp11      0.2.6
#                              crayon      1.4.1
#                           crosstalk      1.1.1
#                             cubelyr      1.0.0
#                                curl        4.3
#                           cyclocomp      1.1.0
#                          data.table     1.13.6
#                                 DBI      1.1.0
#                              dbplyr      2.0.0
#                             DDRTree      0.1.5
#                             debugme      1.1.0
#                        DelayedArray     0.16.1
#                  DelayedMatrixStats     1.12.0
#                              deldir      0.2-9
#                          dendextend     1.14.0
#                        densityClust        0.3
#                            DEoptimR      1.0-8
#                                desc      1.2.0
#                           DescTools    0.99.38
#                              DESeq2     1.30.0
#                             destiny      3.4.0
#                            devtools      2.3.2
#                             dfoptim  2020.10-1
#                           dichromat      2.0-0
#                             diffobj      0.3.3
#                              digest     0.6.27
#                             diptest     0.75-7
#                               DO.db        2.9
#                              docopt      0.7.1
#                          doParallel     1.0.16
#                                DOSE     3.16.0
#                              doSNOW     1.0.19
#                           dotCall64      1.0-0
#                             downlit      0.2.1
#                               dplyr 1.0.4.9000
#                               dqrng      0.2.1
#                        DropletUtils     1.10.0
#                                  DT       0.16
#                            dygraphs    1.1.1.6
#                      dynamicTreeCut     1.63-1
#                               e1071      1.7-4
#                               edgeR     3.32.1
#                            ellipsis      0.3.1
#                     EnhancedVolcano      1.8.0
#                          enrichplot     1.10.0
#                           ensembldb     2.14.0
#                             entropy      1.2.1
#                             etrunct        0.1
#                            evaluate       0.14
#                               Exact        2.1
#                       ExperimentHub     1.16.0
#                                expm    0.999-5
#                           extrafont       0.17
#                         extrafontdb        1.0
#                               fansi      0.4.2
#                              farver      2.0.3
#                         fastcluster     1.1.25
#                             fastICA      1.2-2
#                             fastmap      1.1.0
#                           fastmatch      1.1-0
#                              FateID      0.1.9
#                             fdrtool     1.2.15
#                             feather      0.3.5
#                               fgsea     1.16.0
#                              fields       11.6
#                            filehash      2.4-2
#                            filelock      1.0.2
#                        fitdistrplus      1.1-3
#                             flexmix     2.3-17
#                                fmsb      0.7.0
#                                 FNN      1.1.3
#                             foghorn      1.3.1
#                   fontBitstreamVera      0.1.1
#                      fontLiberation      0.1.0
#                          fontquiver      0.2.1
#                             forcats      0.5.0
#                             foreach      1.5.1
#                             formatR        1.7
#                             Formula      1.2-4
#                                 fpc      2.2-8
#                    freetypeharfbuzz      0.2.5
#                                  fs      1.5.0
#                       futile.logger      1.4.3
#                      futile.options      1.0.1
#                              future     1.21.0
#                        future.apply      1.7.0
#                               gamm4      0.2-6
#                              gargle      0.5.0
#                                gbRd     0.4-11
#                               gdata     2.18.0
#                             gdtools      0.2.2
#                          genefilter     1.72.0
#                         geneplotter     1.68.0
#                            generics      0.1.0
#                              GENIE3     1.12.0
#                        GenomeInfoDb     1.26.2
#                    GenomeInfoDbData      1.2.4
#                   GenomicAlignments     1.26.0
#                     GenomicFeatures     1.42.0
#                       GenomicRanges     1.42.0
#                            geometry      0.4.5
#                           geosphere     1.5-10
#                             getPass      0.2-2
#                              GGally      2.0.0
#                               ggalt      0.4.0
#                           gganimate      1.0.7
#                          ggbeeswarm      0.6.0
#                             ggforce      0.3.2
#                   ggplot.multistats      1.0.0
#                             ggplot2      3.3.3
#                       ggplot2movies      0.0.1
#                              ggraph      2.0.4
#                             ggrastr      0.2.1
#                             ggrepel      0.9.1
#                            ggridges      0.5.3
#                               ggsci        2.9
#                            ggthemes      4.2.0
#                             ggupset      0.3.0
#                                  gh      1.1.0
#                              gifski      0.8.6
#                               git2r     0.27.1
#                                 gld      2.6.2
#                             globals     0.14.0
#                                glue      1.4.2
#                              gmailr      1.0.0
#                             gmodels     2.18.1
#                                 gmp      0.6-2
#                               GO.db     3.12.1
#                             goftest      1.2-2
#                           googleVis      0.6.9
#                            GOSemSim     2.16.1
#                               gower      0.2.2
#                              gplots      3.1.1
#                               graph     1.68.0
#                        graphlayouts      0.7.1
#                            graphsim      1.0.1
#                            gridBase      0.4-7
#                           gridExtra        2.3
#                        gridGraphics      0.5-0
#                                 grr      0.9.5
#                              gtable      0.3.0
#                              gtools      3.8.2
#                             harmony        1.0
#                               haven      2.3.1
#                           HDF5Array     1.18.0
#                               hdf5r      1.3.3
#                              hexbin     1.28.1
#                               highr        0.8
#                               Hmisc      4.4-1
#                                 hms      0.5.3
#                              hopach     2.50.0
#                             howmany      0.3-1
#                              HSAUR3     1.0-10
#                      HSMMSingleCell     1.10.0
#                           htmlTable      2.1.0
#                           htmltools    0.5.1.1
#                         htmlwidgets      1.5.3
#                              httpuv      1.5.5
#                                httr      1.4.2
#                                hues      0.2.0
#                            hunspell        3.0
#                                 ica      1.0-2
#                              igraph      1.2.6
#                                 ini      0.3.1
#              interactiveDisplayBase     1.28.0
#                          intergraph      2.0-2
#                              interp     1.0-33
#                            invgamma        1.1
#                               ipred      0.9-9
#                             IRanges     2.24.1
#                           IRdisplay      0.7.0
#                            IRkernel 1.1.1.9000
#                               irlba      2.3.3
#                             isoband      0.2.3
#                           iterators     1.0.13
#                           itertools      0.1-3
#                                jomo      2.7-2
#                                jpeg    0.1-8.1
#                           jquerylib      0.1.3
#                            jsonlite      1.7.2
#                           JuliaCall     0.17.1
#                            KEGGREST     1.30.0
#                             kernlab     0.9-29
#                               knitr       1.30
#                       knn.covertree        1.0
#                            labeling      0.4.2
#                              laeken      0.5.1
#                            lambda.r      1.2.4
#                                lars        1.2
#                               later    1.1.0.1
#                        latticeExtra     0.6-29
#                                lava    1.6.8.1
#                            lazyeval      0.2.2
#                              leiden      0.3.7
#                             libcoin      1.0-6
#                           lifecycle      0.2.0
#                               limma     3.46.0
#                             linprog      0.9-2
#                               lintr      2.0.1
#                             listenv      0.8.0
#                          listviewer      3.0.0
#                                 lle        1.1
#                                lme4     1.1-25
#                                lmom        2.8
#                              lmtest     0.9-38
#                              locfdr      1.1-8
#                              locfit    1.5-9.4
#                               loomR      0.2.0
#                             lpSolve     5.6.15
#                           lubridate      1.7.9
#                              M3Drop     1.16.0
#                               magic      1.5-9
#                              magick      2.5.1
#                            magrittr      2.0.1
#                    manipulateWidget     0.10.1
#                             mapproj      1.2.7
#                                maps      3.3.0
#                            maptools      1.0-2
#                            markdown        1.1
#                                MAST     1.16.0
#                            mathjaxr      1.0-1
#                        Matrix.utils      0.9.8
#                          matrixcalc      1.0-3
#                      MatrixGenerics      1.2.1
#                        MatrixModels      0.4-1
#                         matrixStats     0.58.0
#                              maxLik      1.4-4
#                            mbkmeans      1.6.1
#                              mclust      5.4.6
#                             memoise      1.1.0
#                               MEMSS      0.9-3
#                               metap        1.4
#                                mice     3.11.0
#                            miceadds    3.10-28
#                               miloR      0.1.0
#                                mime        0.9
#                            minidown      0.0.2
#                              miniUI    0.1.1.1
#                          minpack.lm      1.2-1
#                               minqa      1.2.4
#                           miscTools     0.6-26
#                               mitml      0.3-7
#                             mitools        2.4
#                              mixsqp     0.3-43
#                            mixtools      1.2.0
#                              mlmRev      1.0-8
#                              mnormt      2.0.2
#                             mockery      0.4.2
#                        ModelMetrics    1.2.2.2
#                              modelr      0.1.8
#                          modeltools     0.2-23
#                             monocle     2.18.0
#                               MUDAN      0.1.0
#                            multcomp     1.4-14
#                            multtest     2.46.0
#                             munsell      0.5.0
#                              mutoss     0.1-12
#                             mvtnorm      1.1-1
#                               nabor      0.5.0
#                            nanotime      0.3.2
#                             network     1.16.1
#                              nloptr    1.2.2.2
#                                 NMF     0.23.0
#                            numDeriv 2016.8-1.1
#                        nycflights13      1.0.1
#                             openssl      1.4.3
#                            openxlsx      4.2.3
#                              optimx   2020-4.2
#                             ordinal 2019.12-10
#                           orientlib     0.10.4
#                             packrat      0.5.0
#                                 pan        1.6
#                          parallelly     1.23.0
#                           parsedate      1.2.0
#                               PASWR        1.1
#                           patchwork      1.1.1
#                             pbapply      1.4-3
#                              pbdZMQ    0.3-3.1
#                            pbkrtest    0.4-8.6
#                           pbmcapply      1.5.0
#                          pcaMethods     1.82.0
#                               pcaPP     1.9-73
#                             permute      0.9-5
#                            pheatmap     1.0.12
#                           phylobase     0.8.10
#                              pillar      1.4.7
#                               pingr      2.0.1
#                              pixmap     0.4-12
#                            pkgbuild      1.2.0
#                           pkgconfig      2.0.3
#                             pkgdown      1.6.1
#                             pkgload      1.1.0
#                            pkgmaker     0.32.2
#                          PKPDmodels      0.3.2
#                                 plm      2.2-5
#                               plogr      0.2.0
#                              plotly      4.9.3
#                     plotlyGeoAssets      0.0.2
#                             plotrix      3.7-8
#                                 pls      2.7-3
#                                plyr      1.8.6
#                                 png      0.1-7
#                           polspline     1.1.19
#                            polyclip     1.10-0
#                            poweRlaw     0.70.6
#                            prabclus      2.3-2
#                              pracma      2.2.9
#                              praise      1.0.0
#                              presto      1.0.0
#                           prettydoc      0.4.0
#                         prettyunits      1.1.1
#                           princurve      2.1.5
#                                pROC     1.16.2
#                            processx      3.4.5
#                             prodlim 2019.11.13
#                             profvis      0.3.7
#                            progress      1.2.2
#                               proj4   1.0-10.1
#                            promises      1.1.1
#                               propr      4.2.6
#                        ProtGenerics     1.22.0
#                               proxy     0.4-24
#                                  ps      1.5.0
#                               purrr      0.3.4
#                           qlcMatrix      0.9.7
#                            quadprog      1.5-8
#                            quantreg       5.75
#                              qvalue     2.22.0
#                             R.cache     0.14.0
#                            R.matlab      3.6.2
#                         R.methodsS3      1.8.1
#                                R.oo     1.24.0
#                               R.rsp     0.44.0
#                             R.utils     2.10.1
#                                  R6      2.5.0
#                              RaceID      0.2.2
#                                ragg      0.4.0
#                        randomForest     4.6-14
#                              ranger     0.12.1
#                                RANN      2.6.1
#                            rappdirs      0.3.3
#                             rARPACK     0.11-0
#                              raster     3.3-13
#                           rasterVis       0.49
#                                RBGL     1.66.0
#                           rbibutils        1.4
#                           rcmdcheck      1.3.3
#                        RColorBrewer      1.1-2
#                                Rcpp      1.0.6
#                           RcppAnnoy     0.0.18
#                       RcppArmadillo 0.10.2.1.0
#                            RcppCCTZ      0.2.9
#                            RcppDate      0.0.1
#                           RcppEigen  0.3.3.9.1
#                            RcppHNSW      0.3.0
#                        RcppProgress      0.4.2
#                               RCurl   1.98-1.2
#                              Rdpack        2.1
#                               readr      1.4.0
#                              readxl      1.3.1
#                             REBayes        2.2
#                             recipes     0.1.14
#                            regioneR     1.22.0
#                            registry      0.5-1
#                             reldist      1.6-6
#                              reliaR       0.01
#                             rematch      1.0.1
#                            rematch2      2.1.2
#                             remotes      2.2.0
#                                repr      1.1.0
#                              reprex      0.3.0
#                             reshape      0.8.8
#                            reshape2      1.4.4
#                      ResidualMatrix      1.0.0
#                          reticulate       1.18
#                                 rex      1.2.0
#                               rgdal     1.5-18
#                               rgeos      0.5-5
#                               rhdf5     2.34.0
#                        rhdf5filters      1.2.0
#                            Rhdf5lib     1.12.0
#                             Rhtslib     1.22.0
#                                rhub      1.1.1
#                                 rio     0.5.16
#                               rJava     0.9-13
#                               rjson     0.2.20
#                               rlang     0.4.10
#                                 rle      0.9.2
#                           rmarkdown        2.5
#                                 rms      6.1-1
#                                rncl      0.8.4
#                              RNeXML      2.4.5
#                            rngtools        1.5
#                          robustbase     0.93-6
#                                ROCR     1.0-11
#                               ROGUE        1.0
#                           rootSolve    1.8.2.1
#                            roxygen2      7.1.1
#                           rprojroot      2.0.2
#                           Rsamtools      2.6.0
#                           rsconnect     0.8.16
#                            RSpectra     0.16-0
#                             RSQLite      2.2.1
#                          rstudioapi       0.13
#                                rsvd      1.0.3
#                         rtracklayer     1.50.0
#                               Rtsne       0.15
#                            Rttf2pt1      1.3.8
#                               RUnit     0.4.32
#                             rvcheck      0.1.8
#                           rversions      2.0.2
#                               rvest      0.3.6
#                           S4Vectors     0.28.1
#                            sandwich      3.0-0
#                                sass      0.3.1
#                         scagnostics    0.2-4.1
#                              scales      1.1.1
#                              scater     1.18.3
#                         scattermore        0.7
#                          scatterpie      0.1.5
#                       scatterplot3d     0.3-41
#                             scClust      0.3.0
#                                scDC      0.1.0
#                              scdney      0.1.5
#                               scmap     1.12.0
#                               scran     1.18.1
#                            scRNAseq      2.4.0
#                         sctransform      0.3.2
#                             scuttle      1.0.0
#                           segmented      1.3-0
#                             selectr      0.4-2
#                             seqLogo     1.56.0
#                         sessioninfo      1.1.1
#                              Seurat      4.0.0
#                          SeuratDisk 0.0.0.9013
#                        SeuratObject      4.0.0
#                      SeuratWrappers      0.3.0
#                          shadowtext      0.0.7
#                               shiny      1.6.0
#                           shinytest      1.4.0
#                           showimage      1.0.0
#                            showtext        0.9
#                          showtextdb        3.0
#                SingleCellExperiment     1.12.0
#                               sitmo      2.0.1
#                                slam     0.1-47
#                           slingshot      1.8.0
#                            smoother        1.1
#                                  sn      1.6-2
#                                 sna        2.6
#                                snow      0.4-3
#                            snowfall   1.84-6.1
#                          softImpute        1.4
#                                 som    0.3-5.1
#                         sourcetools      0.1.7
#                                  sp      1.4-4
#                                spam      2.5-1
#                             SparseM       1.78
#                   sparseMatrixStats      1.2.0
#                           sparsesvd        0.2
#                            spatstat     1.64-1
#                       spatstat.data      1.7-0
#                      spatstat.utils      2.0-0
#                            spelling        2.2
#                             SQUAREM     2020.5
#                             statmod     1.4.35
#                      statnet.common      4.4.1
#                             stringi      1.5.3
#                             stringr      1.4.0
#                              styler      1.3.2
#                SummarizedExperiment     1.20.0
#                                 sva     3.38.0
#                             svglite    1.2.3.2
#                                 sys        3.4
#                            sysfonts      0.8.1
#                         systemfonts      0.3.2
#                              tensor        1.5
#                              testit       0.12
#                            testthat      3.0.2
#                         textshaping      0.1.2
#                             TFisher      0.2.0
#                           TFMPvalue      0.0.8
#                             TH.data     1.0-10
#                              tibble      3.0.6
#                           tidygraph      1.2.0
#                               tidyr      1.1.2
#                          tidyselect      1.1.0
#                           tidyverse      1.3.0
#                          tikzDevice   0.12.3.1
#                            timeDate   3043.102
#                            tinytest      1.2.3
#                             tinytex       0.27
#                                 TMB     1.7.18
#                             tmvnsim      1.0-2
#                            tradeSeq      1.4.0
#                             tripack    1.3-9.1
#                           truncnorm      1.0-8
#                                 TTR     0.24.2
#                               tufte        0.8
#                             tweedie      2.3.2
#                              tweenr      1.0.1
#   TxDb.Hsapiens.UCSC.hg19.knownGene      3.2.2
#   TxDb.Hsapiens.UCSC.hg38.knownGene     3.10.0
#  TxDb.Mmusculus.UCSC.mm10.knownGene     3.10.0
#                              ucminf      1.1-4
#                                umap    0.2.7.0
#                             usethis      1.6.3
#                                utf8      1.1.4
#                                uuid      0.1-4
#                                uwot     0.1.10
#                                 vcd      1.4-8
#                               vctrs      0.3.6
#                              vdiffr      0.3.3
#                               vegan      2.5-6
#                         VennDiagram     1.6.20
#                          Vennerable 3.1.0.9000
#                                VGAM      1.1-4
#                                 VIM      6.0.0
#                               vipor      0.4.5
#                             viridis      0.5.1
#                         viridisLite      0.3.0
#                               waldo      0.2.4
#                           webdriver      1.0.5
#                             webshot      0.5.2
#                            webutils        1.1
#                             whisker        0.4
#                              whoami      1.3.0
#                               withr      2.4.1
#                                xfun       0.19
#                                 XML   3.99-0.5
#                                xml2      1.3.2
#                        xmlparsedata      1.0.4
#                               xopen      1.0.0
#                              xtable      1.8-4
#                                 xts     0.12.1
#                             XVector     0.30.0
#                                yaml      2.2.1
#                       zellkonverter      1.0.2
#                            zinbwave     1.12.0
#                                 zip      2.1.1
#                            zlibbioc     1.36.0
#                                 zoo      1.8-8

# %% [markdown]
# # env_scvi

# %%
import warnings, sys
warnings.filterwarnings('ignore')

# %load_ext rpy2.ipython
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# File ~/miniconda3/envs/env_scvi/lib/python3.9/site-packages/rpy2/rinterface_lib/openrlib.py:14, in <module>
#      13 try:
# ---> 14     import _rinterface_cffi_api as _rinterface_cffi
#      15 except ImportError:
#
# ImportError: libffi.so.7: cannot open shared object file: No such file or directory
#
# During handling of the above exception, another exception occurred:
#
# ImportError                               Traceback (most recent call last)
# Input In [1], in <module>
#       1 import warnings, sys
#       2 warnings.filterwarnings('ignore')
# ----> 4 get_ipython().run_line_magic('load_ext', 'rpy2.ipython')
#
# File ~/miniconda3/envs/env_scvi/lib/python3.9/site-packages/IPython/core/interactiveshell.py:2204, in InteractiveShell.run_line_magic(self, magic_name, line, _stack_depth)
#    2202     kwargs['local_ns'] = self.get_local_scope(stack_depth)
#    2203 with self.builtin_trap:
# -> 2204     result = fn(*args, **kwargs)
#    2205 return result
#
# File ~/miniconda3/envs/env_scvi/lib/python3.9/site-packages/IPython/core/magics/extension.py:33, in ExtensionMagics.load_ext(self, module_str)
#      31 if not module_str:
#      32     raise UsageError('Missing module name.')
# ---> 33 res = self.shell.extension_manager.load_extension(module_str)
#      35 if res == 'already loaded':
#      36     print("The %s extension is already loaded. To reload it, use:" % module_str)
#
# File ~/miniconda3/envs/env_scvi/lib/python3.9/site-packages/IPython/core/extensions.py:76, in ExtensionManager.load_extension(self, module_str)
#      69 """Load an IPython extension by its module name.
#      70
#      71 Returns the string "already loaded" if the extension is already loaded,
#      72 "no load function" if the module doesn't have a load_ipython_extension
#      73 function, or None if it succeeded.
#      74 """
#      75 try:
# ---> 76     return self._load_extension(module_str)
#      77 except ModuleNotFoundError:
#      78     if module_str in BUILTINS_EXTS:
#
# File ~/miniconda3/envs/env_scvi/lib/python3.9/site-packages/IPython/core/extensions.py:92, in ExtensionManager._load_extension(self, module_str)
#      90 if module_str not in sys.modules:
#      91     with prepended_to_syspath(self.ipython_extension_dir):
# ---> 92         mod = import_module(module_str)
#      93         if mod.__file__.startswith(self.ipython_extension_dir):
#      94             print(("Loading extensions from {dir} is deprecated. "
#      95                    "We recommend managing extensions like any "
#      96                    "other Python packages, in site-packages.").format(
#      97                   dir=compress_user(self.ipython_extension_dir)))
#
# File ~/miniconda3/envs/env_scvi/lib/python3.9/importlib/__init__.py:127, in import_module(name, package)
#     125             break
#     126         level += 1
# --> 127 return _bootstrap._gcd_import(name[level:], package, level)
#
# File <frozen importlib._bootstrap>:1030, in _gcd_import(name, package, level)
#
# File <frozen importlib._bootstrap>:1007, in _find_and_load(name, import_)
#
# File <frozen importlib._bootstrap>:986, in _find_and_load_unlocked(name, import_)
#
# File <frozen importlib._bootstrap>:680, in _load_unlocked(spec)
#
# File <frozen importlib._bootstrap_external>:850, in exec_module(self, module)
#
# File <frozen importlib._bootstrap>:228, in _call_with_frames_removed(f, *args, **kwds)
#
# File ~/miniconda3/envs/env_scvi/lib/python3.9/site-packages/rpy2/ipython/__init__.py:1, in <module>
# ----> 1 from . import rmagic
#       3 load_ipython_extension = rmagic.load_ipython_extension
#
# File ~/miniconda3/envs/env_scvi/lib/python3.9/site-packages/rpy2/ipython/rmagic.py:55, in <module>
#      51 import textwrap
#      53 # numpy and rpy2 imports
# ---> 55 import rpy2.rinterface as ri
#      56 import rpy2.rinterface_lib.callbacks
#      57 import rpy2.robjects as ro
#
# File ~/miniconda3/envs/env_scvi/lib/python3.9/site-packages/rpy2/rinterface.py:12, in <module>
#      10 import warnings
#      11 from typing import Union
# ---> 12 from rpy2.rinterface_lib import openrlib
#      13 import rpy2.rinterface_lib._rinterface_capi as _rinterface
#      14 import rpy2.rinterface_lib.embedded as embedded
#
# File ~/miniconda3/envs/env_scvi/lib/python3.9/site-packages/rpy2/rinterface_lib/openrlib.py:16, in <module>
#      14         import _rinterface_cffi_api as _rinterface_cffi
#      15     except ImportError:
# ---> 16         import _rinterface_cffi_abi as _rinterface_cffi
#      18 ffi = _rinterface_cffi.ffi
#      20 # TODO: Separate the functions in the module from the side-effect of
#      21 # finding R_HOME and opening the shared library.
#
# File ~/miniconda3/envs/env_scvi/lib/python3.9/site-packages/_rinterface_cffi_abi.py:2, in <module>
#       1 # auto-generated file
# ----> 2 import _cffi_backend
#       4 ffi = _cffi_backend.FFI('_rinterface_cffi_abi',
#       5     _version = 0x2601,
#       6     _types = b'\ ...
#    (...)
#      10     _typenames = (b'\x00\x00\x00\xC5DL_FUNC',b'\x00\x00\x01\x1CDllInfo',b'\x00\x00\x01\x1EFILE',b'\x00\x00\x01\x1FParseStatus',b'\x00\x00\x01\x12R_CFinalizer_t',b'\x00\x00\x01\x20R_CMethodDef',b'\x00\x00\x01\x21R_CallMethodDef',b'\x00\x00\x01\x21R_ExternalMethodDef',b'\x00\x00\x01\x20R_FortranMethodDef',b'\x00\x00\x00\xC1R_NativePrimitiveArgType',b'\x00\x00\x00\x2DR_len_t',b'\x00\x00\x00\x0ER_xlen_t',b'\x00\x00\x00\x44Rboolean',b'\x00\x00\x00\xBERbyte',b'\x00\x00\x00\x5DRcomplex',b'\x00\x00\x01\x15Rstart',b'\x00\x00\x00\xD9SA_TYPE',b'\x00\x00\x00\x03SEXP',b'\x00\x00\x01\x23SEXPREC',b'\x00\x00\x01\x24SEXPREC_ALIGN',b'\x00\x00\x00\xC1SEXPTYPE',b'\x00\x00\x01\x25VECSEXP',b'\x00\x00\x01\x26VECTOR_SEXPREC',b'\x00\x00\x00\x64cetype_t',b'\x00\x00\x00\x4Cnchar_type',b'\x00\x00\x01\x38structRstart'),
#      11 )
#
# ImportError: libffi.so.7: cannot open shared object file: No such file or directory

# %%
# %load_ext rpy2
# Out:
# The rpy2 module is not an IPython extension.

# %%
sys.version
# Out:
# '3.9.9 | packaged by conda-forge | (main, Dec 20 2021, 02:41:03) \n[GCC 9.4.0]'

# %%
# %%bash
# pip list
# Out:
# Package                       Version
# ----------------------------- -----------
# anndata                       0.6.19
# anyio                         3.5.0
# argon2-cffi                   21.3.0
# argon2-cffi-bindings          21.2.0
# asttokens                     2.0.5
# attrs                         21.4.0
# Babel                         2.9.1
# backcall                      0.2.0
# backports.functools-lru-cache 1.6.4
# bleach                        4.1.0
# brotlipy                      0.7.0
# cached-property               1.5.2
# certifi                       2021.10.8
# cffi                          1.15.0
# charset-normalizer            2.0.12
# colorama                      0.4.4
# colormath                     3.0.0
# conda                         4.11.0
# conda-package-handling        1.7.3
# cryptography                  36.0.1
# cycler                        0.11.0
# debugpy                       1.5.1
# decorator                     5.1.1
# defusedxml                    0.7.1
# entrypoints                   0.4
# executing                     0.8.2
# flit_core                     3.6.0
# fonttools                     4.29.1
# h5py                          3.6.0
# idna                          3.3
# igraph                        0.9.9
# importlib-metadata            4.11.1
# importlib-resources           5.4.0
# ipykernel                     6.9.1
# ipython                       8.0.1
# ipython-genutils              0.2.0
# jedi                          0.18.1
# Jinja2                        3.0.3
# joblib                        1.1.0
# json5                         0.9.5
# jsonschema                    4.4.0
# jupyter-client                7.1.2
# jupyter-core                  4.9.2
# jupyter-server                1.13.5
# jupyterlab                    3.2.9
# jupyterlab-pygments           0.1.2
# jupyterlab-server             2.10.3
# kiwisolver                    1.3.2
# libmambapy                    0.21.2
# llvmlite                      0.36.0
# louvain                       0.7.1
# mamba                         0.21.2
# MarkupSafe                    2.0.1
# matplotlib                    3.5.1
# matplotlib-inline             0.1.3
# mistune                       0.8.4
# munkres                       1.1.4
# natsort                       8.1.0
# nbclassic                     0.3.5
# nbclient                      0.5.11
# nbconvert                     6.4.2
# nbformat                      5.1.3
# nest-asyncio                  1.5.4
# networkx                      2.6.3
# notebook                      6.4.8
# numba                         0.53.1
# numexpr                       2.8.0
# numpy                         1.22.2
# packaging                     21.3
# pandas                        1.4.1
# pandocfilters                 1.5.0
# parso                         0.8.3
# patsy                         0.5.2
# pexpect                       4.8.0
# pickleshare                   0.7.5
# Pillow                        9.0.1
# pip                           22.0.3
# prometheus-client             0.13.1
# prompt-toolkit                3.0.27
# ptyprocess                    0.7.0
# pure-eval                     0.2.2
# pycosat                       0.6.3
# pycparser                     2.21
# Pygments                      2.11.2
# pynndescent                   0.5.6
# pyOpenSSL                     22.0.0
# pyparsing                     3.0.7
# PyQt5                         5.12.3
# PyQt5_sip                     4.19.18
# PyQtChart                     5.12
# PyQtWebEngine                 5.12.1
# pyrsistent                    0.18.1
# PySocks                       1.7.1
# python-dateutil               2.8.2
# pytz                          2021.3
# pytz-deprecation-shim         0.1.0.post0
# pyzmq                         22.3.0
# requests                      2.27.1
# rpy2                          3.4.5
# ruamel-yaml-conda             0.15.80
# scanpy                        1.4.4.post1
# scikit-learn                  1.0.2
# scipy                         1.8.0
# seaborn                       0.11.2
# Send2Trash                    1.8.0
# setuptools                    60.9.2
# simplegeneric                 0.8.1
# six                           1.16.0
# sniffio                       1.2.0
# spectra                       0.0.11
# stack-data                    0.2.0
# statsmodels                   0.13.2
# tables                        3.7.0
# terminado                     0.13.1
# testpath                      0.5.0
# texttable                     1.6.4
# threadpoolctl                 3.1.0
# tornado                       6.1
# tqdm                          4.62.3
# traitlets                     5.1.1
# tzdata                        2021.5
# tzlocal                       4.1
# umap-learn                    0.5.2
# unicodedata2                  14.0.0
# urllib3                       1.26.8
# wcwidth                       0.2.5
# webencodings                  0.5.1
# websocket-client              1.2.3
# wheel                         0.37.1
# zipp                          3.7.0

# %%
# %%bash
#
# R --version
# Out:
# R version 3.6.3 (2020-02-29) -- "Holding the Windsock"
# Copyright (C) 2020 The R Foundation for Statistical Computing
# Platform: x86_64-conda-linux-gnu (64-bit)
#
# R is free software and comes with ABSOLUTELY NO WARRANTY.
# You are welcome to redistribute it under the terms of the
# GNU General Public License versions 2 or 3.
# For more information about these matters see
# https://www.gnu.org/licenses/.

# %%
# %%R
#
# ip <- as.data.frame(installed.packages()[,c(1,3:4)])
# rownames(ip) <- NULL
# ip <- ip[is.na(ip$Priority),1:2,drop=FALSE]
# print(ip, row.names=FALSE)
# Out:
# UsageError: Cell magic `%%R` not found.

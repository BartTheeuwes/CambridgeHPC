# %%
import scanpy as sc

# %%
pwd()
# Out:
# '/rds/project/rds-SDzz0CATGms/users/bt392/atlasses/gastrulation/code'

# %%
scanpy = sc.read_h5ad('/rds/project/rds-SDzz0CATGms/users/mb2338/gata1/batch_cor/cosine_norm/adata_gata1_plus_annotations_Bart.h5ad')

# %%
scanpy.obs['cell'] = scanpy.obs.index

# %%
scanpy.obs.to_csv('/rds/project/rds-SDzz0CATGms/users/bt392/atlasses/Gata1/metadata_melania.txt', sep='\t', index=False)

# %%
sc.pl.umap(scanpy, color="haem_gephiX")

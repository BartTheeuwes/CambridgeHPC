# %%
sce = readRDS('processed/SingleCellExperiment.rds')

# %%
library(ggplot2)
library(data.table)

# %%
umap = fread('results/dim_reduction/umap.csv', header=TRUE)

# %%
colnames(umap) = c('row','umap1', 'umap2')

# %%
meta = fread('meta.tab')

# %%
sce
# Out:
# Loading required package: SingleCellExperiment
#
# Loading required package: SummarizedExperiment
#
# Loading required package: MatrixGenerics
#
# Loading required package: matrixStats
#
#
# Attaching package: ‘MatrixGenerics’
#
#
# The following objects are masked from ‘package:matrixStats’:
#
#     colAlls, colAnyNAs, colAnys, colAvgsPerRowSet, colCollapse,
#     colCounts, colCummaxs, colCummins, colCumprods, colCumsums,
#     colDiffs, colIQRDiffs, colIQRs, colLogSumExps, colMadDiffs,
#     colMads, colMaxs, colMeans2, colMedians, colMins, colOrderStats,
#     colProds, colQuantiles, colRanges, colRanks, colSdDiffs, colSds,
#     colSums2, colTabulates, colVarDiffs, colVars, colWeightedMads,
#     colWeightedMeans, colWeightedMedians, colWeightedSds,
#     colWeightedVars, rowAlls, rowAnyNAs, rowAnys, rowAvgsPerColSet,
#     rowCollapse, rowCounts, rowCummaxs, rowCummins, rowCumprods,
#     rowCumsums, rowDiffs, rowIQRDiffs, rowIQRs, rowLogSumExps,
# ...

# %%
sce
# Out:
# class: SingleCellExperiment
# dim: 23972 115559
# metadata(0):
# assays(1): counts
# rownames(23972): ENSMUSG00000001138 ENSMUSG00000001143 ...
#   ENSMUSG00000108929 ENSMUSG00000109022
# rowData names(0):
# colnames(115559): cell_1 cell_2 ... ext_cell_334312 ext_cell_311352
# colData names(1): sizeFactor
# reducedDimNames(0):
# mainExpName: NULL
# altExpNames(0):

# %%
head(umap)
# Out:
#   row umap1     umap2
# 1 0    8.460464 10.0109240
# 2 1    9.358822  7.9172244
# 3 2   -4.289973  0.6886436
# 4 3    8.038439  9.0527120
# 5 4    7.796390  9.6794100
# 6 5    8.488477 10.1488050

# %%
plot_gene = function(gene){
    count = 
    ggplot(umap, aes(umap1, umap2, col=as.vector(count))) + 
        geom_point(size=0.2) +
        viridis::scale_color_viridis() + 
        theme_void()
}

# %%
test = data.table(sox6= as.vector(counts(sce['ENSMUSG00000051910',])), hbbbh1=as.vector(counts(sce['ENSMUSG00000052217',])),hbbbs=as.vector(counts(sce['ENSMUSG00000052305',])))

# %%
test = cbind(test, meta)

# %%
ggplot(test[celltype %in% c('Erythroids','Blood progenitors')], aes(hbbbs, hbbbh1)) + geom_point() +theme_bw()
# Out:
# plot without title

# %%
plot_gene('ENSMUSG00000000861')

# %%
plot_gene('ENSMUSG00000048251')
# Out:
# plot without title

# %%
plot_gene('ENSMUSG00000052217')
# Out:
# plot without title

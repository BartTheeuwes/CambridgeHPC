# %% [markdown]
# # convert atlas anndata to sce

# %%
suppressPackageStartupMessages({
    library(data.table)
    library(Matrix)
    library(dplyr)
    library(Seurat)
    library(reticulate)
    library(scater)
    library(SingleCellExperiment)
})

ad <- import("anndata", convert = FALSE)

# %%
main = '/rds/project/rds-SDzz0CATGms/users/bt392/atlasses/extended/'

# %%
meta = fread(file.path(main, 'blood/blood_meta.csv'))

# %%
atlas = ad$read_h5ad(file.path(main, 'embryo_mnn_bbknn_shiny.h5ad'))

# %%
matrix = as.matrix(atlas$X)

# %%
str(atlas)
# Out:
# AnnData object with n_obs × n_vars = 430339 × 27669
#     obs: 'cell', 'sample', 'stage', 'stage.mapped', 'stage.collapsed', 'stage.mapped.collapsed', 'somite_count', 'tube_name', 'tube_name_corrected', 'celltype', 'celltype.extended', 'celltype.descendant', 'celltype.descendant.somites', 'doub.density', 'cluster', 'cluster.sub', 'embryo_version', 'S_score', 'G2M_score', 'phase', 'louvain', 'leiden'
#     var: 'highly_variable', 'means', 'dispersions', 'dispersions_norm', 'mgi_symbol'
#     uns: 'draw_graph', 'leiden', 'louvain', 'neighbors', 'pca', 'umap'
#     obsm: 'X_draw_graph_fa', 'X_pca', 'X_tsne', 'X_umap'
#     varm: 'PCs'
#     obsp: 'distances', 'connectivities'

# %%
atlas <- as.seurat(atlas)
# Out:
# Error in as.seurat(atlas): could not find function "as.seurat"
# Traceback:

# %%
saveRDS(atlas, file.path(main, 'blood/atlas_blood.rds'))

# %%
sessionInfo()
# Out:
# R version 4.1.1 (2021-08-10)
# Platform: x86_64-conda-linux-gnu (64-bit)
# Running under: Scientific Linux 7.9 (Nitrogen)
#
# Matrix products: default
# BLAS/LAPACK: /rds/project/rds-SDzz0CATGms/users/bt392/miniconda3/envs/env_multiome/lib/libopenblasp-r0.3.18.so
#
# locale:
#  [1] LC_CTYPE=en_GB.UTF-8       LC_NUMERIC=C
#  [3] LC_TIME=en_GB.UTF-8        LC_COLLATE=en_GB.UTF-8
#  [5] LC_MONETARY=en_GB.UTF-8    LC_MESSAGES=en_GB.UTF-8
#  [7] LC_PAPER=en_GB.UTF-8       LC_NAME=C
#  [9] LC_ADDRESS=C               LC_TELEPHONE=C
# [11] LC_MEASUREMENT=en_GB.UTF-8 LC_IDENTIFICATION=C
#
# attached base packages:
# [1] stats4    stats     graphics  grDevices utils     datasets  methods
# [8] base
#
# other attached packages:
#  [1] scater_1.22.0               ggplot2_3.3.5
#  [3] scuttle_1.4.0               SingleCellExperiment_1.16.0
#  [5] SummarizedExperiment_1.24.0 Biobase_2.54.0
#  [7] GenomicRanges_1.46.1        GenomeInfoDb_1.30.0
#  [9] IRanges_2.28.0              S4Vectors_0.32.3
# ...

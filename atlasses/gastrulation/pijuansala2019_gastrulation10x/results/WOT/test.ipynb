# %%
import scanpy as sc

# %%
adata = sc.read_h5ad('predictions.h5ad')

# %%
sc.pp.scale(adata, max_value=10)
sc.tl.pca(adata, svd_solver='arpack')
sc.pl.pca(adata)
sc.pl.pca_variance_ratio(adata, log=True)
sc.pp.neighbors(adata, n_neighbors=25, n_pcs=35)

sc.tl.umap(adata, min_dist=0.3)
# Out:
# /home/bt392/miniconda3/envs/env_all/lib/python3.8/site-packages/scanpy/plotting/_tools/scatterplots.py:392: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap', 'norm' will be ignored
#   cax = scatter(
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[24], line 8
#       5 sc.pp.neighbors(adata, n_neighbors=25, n_pcs=35)
#       7 sc.tl.umap(adata, min_dist=0.3)
# ----> 8 sc.pl.umap(adata, color=['Eomes', 'T', 'Gata1', 'Gata2', 'Foxa2', 'Pax6'], size=100)
#
# File ~/miniconda3/envs/env_all/lib/python3.8/site-packages/scanpy/plotting/_tools/scatterplots.py:669, in umap(adata, **kwargs)
#     610 @_wraps_plot_scatter
#     611 @_doc_params(
#     612     adata_color_etc=doc_adata_color_etc,
#    (...)
#     616 )
#     617 def umap(adata, **kwargs) -> Union[Axes, List[Axes], None]:
#     618     """\
#     619     Scatter plot in UMAP basis.
#     620
#    (...)
#     667     tl.umap
#     668     """
# --> 669     return embedding(adata, 'umap', **kwargs)
#
# File ~/miniconda3/envs/env_all/lib/python3.8/site-packages/scanpy/plotting/_tools/scatterplots.py:257, in embedding(adata, basis, color, gene_symbols, use_raw, sort_order, edges, edges_width, edges_color, neighbors_key, arrows, arrows_kwds, groups, components, dimensions, layer, projection, scale_factor, color_map, cmap, palette, na_color, na_in_legend, size, frameon, legend_fontsize, legend_fontweight, legend_loc, legend_fontoutline, colorbar_loc, vmax, vmin, vcenter, norm, add_outline, outline_width, outline_color, ncols, hspace, wspace, title, show, save, ax, return_fig, **kwargs)
#     250 # use itertools.product to make a plot for each color and for each component
#     251 # For example if color=[gene1, gene2] and components=['1,2, '2,3'].
#     252 # The plots are: [
#     253 #     color=gene1, components=[1,2], color=gene1, components=[2,3],
#     254 #     color=gene2, components = [1, 2], color=gene2, components=[2,3],
#     255 # ]
#     256 for count, (value_to_plot, dims) in enumerate(zip(color, dimensions)):
# --> 257     color_source_vector = _get_color_source_vector(
#     258         adata,
#     259         value_to_plot,
#     260         layer=layer,
#     261         use_raw=use_raw,
#     262         gene_symbols=gene_symbols,
#     263         groups=groups,
#     264     )
#     265     color_vector, categorical = _color_vector(
#     266         adata,
#     267         value_to_plot,
#    (...)
#     270         na_color=na_color,
#     271     )
#     273     # Order points
#
# File ~/miniconda3/envs/env_all/lib/python3.8/site-packages/scanpy/plotting/_tools/scatterplots.py:1169, in _get_color_source_vector(adata, value_to_plot, use_raw, gene_symbols, layer, groups)
#    1167     values = adata.raw.obs_vector(value_to_plot)
#    1168 else:
# -> 1169     values = adata.obs_vector(value_to_plot, layer=layer)
#    1170 if groups and is_categorical_dtype(values):
#    1171     values = values.replace(values.categories.difference(groups), np.nan)
#
# File ~/miniconda3/envs/env_all/lib/python3.8/site-packages/anndata/_core/anndata.py:1397, in AnnData.obs_vector(self, k, layer)
#    1391         warnings.warn(
#    1392             "In a future version of AnnData, access to `.X` by passing"
#    1393             " `layer='X'` will be removed. Instead pass `layer=None`.",
#    1394             FutureWarning,
#    1395         )
#    1396         layer = None
# -> 1397 return get_vector(self, k, "obs", "var", layer=layer)
#
# File ~/miniconda3/envs/env_all/lib/python3.8/site-packages/anndata/_core/index.py:179, in get_vector(adata, k, coldim, idxdim, layer)
#     175     raise ValueError(
#     176         f"Key {k} could be found in both .{idxdim}_names and .{coldim}.columns"
#     177     )
#     178 elif (in_col + in_idx) == 0:
# --> 179     raise KeyError(
#     180         f"Could not find key {k} in .{idxdim}_names or .{coldim}.columns."
#     181     )
#     182 elif in_col:
#     183     return getattr(adata, coldim)[k].values
#
# KeyError: 'Could not find key Eomes in .var_names or .obs.columns.'

# %%
sc.pl.umap(adata)
# Out:
# /home/bt392/miniconda3/envs/env_all/lib/python3.8/site-packages/scanpy/plotting/_tools/scatterplots.py:392: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap', 'norm' will be ignored
#   cax = scatter(

# %%
sc.pl.umap(adata, color='241')

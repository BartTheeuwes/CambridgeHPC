# %%
dplyr::%>%
# Out:
# Error in parse(text = x, srcfile = src): <text>:1:8: unexpected SPECIAL
# 1: dplyr::%>%
#            ^
# Traceback:

# %%
library(roxygen2)

# %%
#`@importFrom dplyr %>%

# %%
dplyr::%>%
# Out:
# Error in parse(text = x, srcfile = src): <text>:1:8: unexpected SPECIAL
# 1: dplyr::%>%
#            ^
# Traceback:

# %%
library(usethis)

# %%
a = requireNamespace("ggrastr", quietly = TRUE)

# %%
a
# Out:
# [1] TRUE

# %%
if(requireNamespace("ggrastr", quietly = TRUE)){print('package installed')}
# Out:
# [1] "package installed"

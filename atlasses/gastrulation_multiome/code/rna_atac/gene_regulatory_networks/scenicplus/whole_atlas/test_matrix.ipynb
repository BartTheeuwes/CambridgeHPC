# %%
import scipy as sci

# %%
atac_mtx = sci.io.mmread("/rds/project/rds-SDzz0CATGms/users/bt392/atlasses/gastrulation_multiome/whole_atlas_atac_mtx.mtx")

# %%
atac_mtx
# Out:
# <192251x68793 sparse matrix of type '<class 'numpy.int64'>'
# 	with 961470107 stored elements in COOrdinate format>

# %%
from pycisTopic.cistopic_class import *

# %%
cistopic_obj = create_cistopic_object(fragment_matrix=atac_mtx)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [6], in <cell line: 1>()
# ----> 1 cistopic_obj = create_cistopic_object(fragment_matrix=atac_mtx)
#
# File ~/miniconda3/envs/scenicplus/lib/python3.8/site-packages/pycisTopic/cistopic_class.py:569, in create_cistopic_object(fragment_matrix, cell_names, region_names, path_to_blacklist, min_frag, min_cell, is_acc, path_to_fragments, project, tag_cells, split_pattern)
#     565     fragment_matrix = sparse.csr_matrix(fragment_matrix.to_numpy(), dtype=np.int32)
#     567 if tag_cells:
#     568     cell_names = [
# --> 569         cell_names[x] + split_pattern + project for x in range(len(cell_names))
#     570     ]
#     572 if isinstance(path_to_blacklist, str):
#     573     log.info("Removing blacklisted regions")
#
# TypeError: object of type 'NoneType' has no len()

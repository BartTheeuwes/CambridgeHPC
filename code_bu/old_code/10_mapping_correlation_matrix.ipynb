# %%
suppressPackageStartupMessages({
    library(dplyr)
    library(ggplot2)
    library(Matrix)
    library(scran)
    library(Rtsne)
    library(BiocParallel)
    require(irlba)
    library(batchelor)
    library(stringr)
    library(gridExtra) ## can be replaced by just cowplot
    library(cowplot)
    library(M3C)
    library(Seurat)
    library(tidyr)
})

# %%
out_folder = "/rds/project/bg200/rds-bg200-hphi-gottgens/users/bt392/mouse/Mixl1_KO/data/"
big_meta_in = paste0(out_folder, 'big_meta_mapping.tab')

# %%
big_meta = read.table(big_meta_in, header = TRUE, sep = "\t", stringsAsFactors = FALSE, comment.char = "$")

# %%
head(big_meta)
# Out:
#   cell         sample  stage barcode        sequencing.batch stripped doublet
# 1 atlas_cell_1 atlas_1 E6.5  AAAGGCCTCCACAA 1                FALSE    FALSE
# 2 atlas_cell_2 atlas_1 E6.5  AACAAACTCGCCTT 1                FALSE    FALSE
# 3 atlas_cell_5 atlas_1 E6.5  AACAGAGAATCAGC 1                FALSE    FALSE
# 4 atlas_cell_6 atlas_1 E6.5  AACATATGAATCGC 1                FALSE    FALSE
# 5 atlas_cell_8 atlas_1 E6.5  AACCGATGGCTTCC 1                FALSE    FALSE
# 6 atlas_cell_9 atlas_1 E6.5  AACGTGTGCTCTAT 1                FALSE    FALSE
#   theiler doub.density cluster ⋯ endo_trajectoryDPT endo_gutX endo_gutY
# 1 TS9     0.0431142     2      ⋯ NA                 NA        NA
# 2 TS9     1.1297133    12      ⋯ NA                 NA        NA
# 3 TS9     0.1121205     3      ⋯ NA                 NA        NA
# 4 TS9     1.2547088     1      ⋯ NA                 NA        NA
# 5 TS9     1.3457586     2      ⋯ NA                 NA        NA
# 6 TS9     1.1463686     2      ⋯ NA                 NA        NA
#   endo_gutDPT endo_gutCluster weight stage.mapped celltype.mapped closest.cell
# 1 NA          NA              1      NA           NA              NA
# 2 NA          NA              2      NA           NA              NA
# 3 NA          NA              5      NA           NA              NA
# 4 NA          NA              6      NA           NA              NA
# 5 NA          NA              8      NA           NA              NA
# 6 NA          NA              9      NA           NA              NA
#   tdTom
# 1 NA
# 2 NA
# 3 NA
# 4 NA
# 5 NA
# 6 NA

# %%
cor = cor(big_meta)
# Out:
# Error in cor(big_meta): 'x' must be numeric
# Traceback:
#
# 1. cor(big_meta)
# 2. cor(big_meta)
# 3. stop("'x' must be numeric")

# %%
cor

# %% [markdown]
# # SCE to adata object conversion for analysis in python

# %% [markdown]
# ### Load packages

# %%
import anndata2ri
import scanpy as sc
import pandas as pd
import numpy as np

# %%
def matrix(df):
  temp = pd.DataFrame.sparse.from_spmatrix(df)
  return temp

# %% [markdown]
# ### Convert Chimaera + atlas to adata object

# %%
anndata2ri.activate()

# %%
# %reload_ext rpy2.ipython

# %%
# %%R -o adata
# adata <- readRDS("/rds/project/bg200/rds-bg200-hphi-gottgens/users/mb2338/annabelle/12_march/big_sce_norm.rds")

# %%
adata.X = adata.layers['logcounts']

# %%
### add metadata
metadata = '/rds/project/bg200/rds-bg200-hphi-gottgens/users/mb2338/annabelle/12_march/big_meta_mapping.tab'
meta = pd.read_csv(metadata, '\t')

meta = meta.set_index('cell')
meta['sizeFactor'] = adata.obs.loc[:, 'sizeFactor']
adata.obs = meta

# genes 
#genes_in = '/rds/project/bg200/rds-bg200-hphi-gottgens/users/aamw4/bt392/mouse/Mixl1_KO/wildtype_injection/chimera-wt/genes.tab'
#genes = pd.read_csv(genes_in, '\t')

# PCs
corrected_pcs = '/rds/project/bg200/rds-bg200-hphi-gottgens/users/mb2338/annabelle/12_march/corrected_pc_complete.csv'
pcs = pd.read_csv(corrected_pcs, ',', index_col=0)

adata.obsm['X_pca'] = pcs.to_numpy()

# %%
adata.write("/rds/project/bg200/rds-bg200-hphi-gottgens/users/aamw4/bt392/mouse/Mixl1_KO/wildtype_injection/chimera-wt/data/wt_chim_atlas.h5")

# %% [markdown]
# ### Chimaera only #not necessary

# %%
# %%R -o adata
# adata <- readRDS("/rds/project/bg200/rds-bg200-hphi-gottgens/users/bt392/mouse/Mixl1_KO/Chimaera_only/mixl_sce_norm.rds")

# %%
adata.X = adata.layers['logcounts']

# %%
adata
# Out:
# AnnData object with n_obs × n_vars = 37208 × 31053
#     obs: 'sizeFactor'
#     layers: 'logcounts'

# %%
### add metadata
metadata = '/rds/project/bg200/rds-bg200-hphi-gottgens/users/bt392/mouse/Mixl1_KO/data/big_meta_mapping.tab'
meta = pd.read_csv(metadata, '\t')

meta = meta.set_index('cell')
# Out:
# /home/bt392/miniconda3/envs/env_rna/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3145: DtypeWarning: Columns (7,13,14,19,22,27,28,30,31,32) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
### add metadata
metadata = '/rds/project/bg200/rds-bg200-hphi-gottgens/users/bt392/mouse/Mixl1_KO/data/big_meta_mapping.tab'
meta = pd.read_csv(metadata, '\t')

meta = meta.set_index('cell')
meta = meta[~meta['tdTom'].isna()]
meta['sizeFactor'] = adata.obs.loc[:, 'sizeFactor']
adata.obs = meta

# PCs
corrected_pcs = "/rds/project/bg200/rds-bg200-hphi-gottgens/users/bt392/mouse/Mixl1_KO/Chimaera_only/corrected_pc_complete.csv"
pcs = pd.read_csv(corrected_pcs, ',', index_col=0)

adata.obsm['X_pca'] = pcs.to_numpy()
# Out:
# /home/bt392/miniconda3/envs/env_rna/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3145: DtypeWarning: Columns (7,13,14,19,22,27,28,30,31,32) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
adata.write("/rds/project/bg200/rds-bg200-hphi-gottgens/users/bt392/mouse/Mixl1_KO/Chimaera_only/mixl_chim_atlas.h5")
# Out:
# /home/bt392/miniconda3/envs/env_rna/lib/python3.8/site-packages/anndata/_core/anndata.py:1192: FutureWarning: is_categorical is deprecated and will be removed in a future version.  Use is_categorical_dtype instead
#   if is_string_dtype(df[key]) and not is_categorical(df[key])
# ... storing 'sample' as categorical
# ... storing 'stage' as categorical
# ... storing 'barcode' as categorical
# ... storing 'theiler' as categorical
# ... storing 'celltype' as categorical
# ... storing 'colour' as categorical
# ... storing 'haem_subclust' as categorical
# ... storing 'endo_trajectoryName' as categorical
# ... storing 'endo_gutCluster' as categorical
# ... storing 'tdTom' as categorical
# ... storing 'stage.mapped' as categorical
# ... storing 'celltype.mapped' as categorical
# ... storing 'closest.cell' as categorical

# %% [markdown]
# # Mapping mouse WTchim to atlas

# %% [markdown]
# Atlas is big enough to crash the notebook so try out different partitions?

# %% [markdown]
# ### Load packages

# %%
suppressPackageStartupMessages({
    library(dplyr)
    library(ggplot2)
    library(Matrix)
    library(scran)
    library(Rtsne)
    library(BiocParallel)
    require(irlba)
    library(batchelor)
    library(stringr)
    library(gridExtra) ## can be replaced by just cowplot
    library(cowplot)
    library(M3C)
})

# %% [markdown]
# ### I/O

# %%
# out folder
in_folder = "/rds/project/bg200/rds-bg200-hphi-gottgens/users/mb2338/annabelle/12_march/"
out_folder = "/rds/project/bg200/rds-bg200-hphi-gottgens/users/mb2338/annabelle/12_march/haem/"
plot_folder = "/rds/project/bg200/rds-bg200-hphi-gottgens/users/aamw4/bt392/mouse/Mixl1_KO/haem/plots/"

# %% [markdown]
# ### Load data

# %%
big_sce <- readRDS(paste0(in_folder,"big_sce.rds"))
big_meta <- read.table(paste0(in_folder,"big_meta_mapping.tab"), header = TRUE, sep = "\t", stringsAsFactors = FALSE, comment.char = "$")

# %%
big_meta
# Out:
#        cell          barcode          sample  stage sequencing.batch stripped
# 1      atlas_cell_1  AAAGGCCTCCACAA   atlas_1 E6.5  1                FALSE
# 2      atlas_cell_2  AACAAACTCGCCTT   atlas_1 E6.5  1                FALSE
# 3      atlas_cell_5  AACAGAGAATCAGC   atlas_1 E6.5  1                FALSE
# 4      atlas_cell_6  AACATATGAATCGC   atlas_1 E6.5  1                FALSE
# 5      atlas_cell_8  AACCGATGGCTTCC   atlas_1 E6.5  1                FALSE
# 6      atlas_cell_9  AACGTGTGCTCTAT   atlas_1 E6.5  1                FALSE
# 7      atlas_cell_10 AACTGTCTTCGCAA   atlas_1 E6.5  1                FALSE
# 8      atlas_cell_11 AAGAACGACCAATG   atlas_1 E6.5  1                FALSE
# 9      atlas_cell_12 AAGATGGACATTGG   atlas_1 E6.5  1                FALSE
# 10     atlas_cell_13 AAGCGACTGCCTTC   atlas_1 E6.5  1                FALSE
# 11     atlas_cell_14 AAGGTCTGGAAAGT   atlas_1 E6.5  1                FALSE
# 12     atlas_cell_15 AAGGTGCTCCACAA   atlas_1 E6.5  1                FALSE
# 13     atlas_cell_16 AAGTCTCTCCAGTA   atlas_1 E6.5  1                FALSE
# 14     atlas_cell_17 AAGTTCCTAGTGCT   atlas_1 E6.5  1                FALSE
# 15     atlas_cell_18 AATAAGCTTCAGAC   atlas_1 E6.5  1                FALSE
# 16     atlas_cell_19 AATCCTACACTCAG   atlas_1 E6.5  1                FALSE
# 17     atlas_cell_20 AATCCTACCTCAAG   atlas_1 E6.5  1                FALSE
# 18     atlas_cell_21 AATCCTACTATTCC   atlas_1 E6.5  1                FALSE
# 19     atlas_cell_22 AATCTAGATGTTTC   atlas_1 E6.5  1                FALSE
# 20     atlas_cell_23 AATGAGGACTGTCC   atlas_1 E6.5  1                FALSE
# 21     atlas_cell_24 AATGATACCTACTT   atlas_1 E6.5  1                FALSE
# 22     atlas_cell_25 AATGGAGATCGCTC   atlas_1 E6.5  1                FALSE
# 23     atlas_cell_26 AATGTTGATCTTAC   atlas_1 E6.5  1                FALSE
# 24     atlas_cell_27 ACAAGAGAGCGAGA   atlas_1 E6.5  1                FALSE
# 25     atlas_cell_28 ACAAGAGATTCTGT   atlas_1 E6.5  1                FALSE
# 26     atlas_cell_29 ACACCCTGAAGTGA   atlas_1 E6.5  1                FALSE
# 27     atlas_cell_30 ACACGAACACCAAC   atlas_1 E6.5  1                FALSE
# 28     atlas_cell_31 ACCACCTGCGTACA   atlas_1 E6.5  1                FALSE
# 29     atlas_cell_32 ACCCAGCTTTACTC   atlas_1 E6.5  1                FALSE
# 30     atlas_cell_33 ACCCGTTGCTCCAC   atlas_1 E6.5  1                FALSE
# ⋮      ⋮             ⋮                ⋮       ⋮     ⋮                ⋮
# 129764 wt_cell_13452 TTGCGTCCAGTCACTA mixl_6  E8.5  0                FALSE
# 129765 wt_cell_13453 TTGCGTCGTAGTAGTA mixl_6  E8.5  0                FALSE
# 129766 wt_cell_13454 TTGCGTCTCCTATTCA mixl_6  E8.5  0                FALSE
# 129767 wt_cell_13455 TTGGAACAGCTACCTA mixl_6  E8.5  0                FALSE
# 129768 wt_cell_13456 TTGGAACAGTGCGATG mixl_6  E8.5  0                FALSE
# 129769 wt_cell_13457 TTGGAACGTAAGGGCT mixl_6  E8.5  0                FALSE
# 129770 wt_cell_13458 TTGGCAAAGGCCCTTG mixl_6  E8.5  0                FALSE
# 129771 wt_cell_13459 TTGGCAAAGTACGATA mixl_6  E8.5  0                FALSE
# 129772 wt_cell_13460 TTGGCAAGTAAGAGAG mixl_6  E8.5  0                FALSE
# 129773 wt_cell_13461 TTGGCAAGTTACCGAT mixl_6  E8.5  0                FALSE
# 129774 wt_cell_13462 TTGTAGGCACACCGAC mixl_6  E8.5  0                FALSE
# 129775 wt_cell_13463 TTGTAGGGTAGCGTAG mixl_6  E8.5  0                FALSE
# 129776 wt_cell_13464 TTGTAGGGTATTCTCT mixl_6  E8.5  0                FALSE
# 129777 wt_cell_13465 TTGTAGGTCGTTGACA mixl_6  E8.5  0                FALSE
# 129778 wt_cell_13466 TTTACTGCATACGCCG mixl_6  E8.5  0                FALSE
# 129779 wt_cell_13467 TTTACTGCATAGAAAC mixl_6  E8.5  0                FALSE
# 129780 wt_cell_13468 TTTCCTCAGTTGCAGG mixl_6  E8.5  0                FALSE
# 129781 wt_cell_13469 TTTCCTCGTCCATGAT mixl_6  E8.5  0                FALSE
# 129782 wt_cell_13470 TTTCCTCGTCTAACGT mixl_6  E8.5  0                FALSE
# 129783 wt_cell_13471 TTTCCTCGTTCCGTCT mixl_6  E8.5  0                FALSE
# 129784 wt_cell_13472 TTTCCTCTCTGTCTCG mixl_6  E8.5  0                FALSE
# 129785 wt_cell_13473 TTTGCGCAGATAGTCA mixl_6  E8.5  0                FALSE
# 129786 wt_cell_13474 TTTGCGCAGTACGATA mixl_6  E8.5  0                FALSE
# 129787 wt_cell_13475 TTTGCGCAGTGAAGAG mixl_6  E8.5  0                FALSE
# 129788 wt_cell_13476 TTTGCGCTCTGCAGTA mixl_6  E8.5  0                FALSE
# 129789 wt_cell_13477 TTTGGTTGTGATGCCC mixl_6  E8.5  0                FALSE
# 129790 wt_cell_13478 TTTGGTTTCGCTTAGA mixl_6  E8.5  0                FALSE
# 129791 wt_cell_13479 TTTGTCAAGACAATAC mixl_6  E8.5  0                FALSE
# 129792 wt_cell_13480 TTTGTCAAGGTAGCTG mixl_6  E8.5  0                FALSE
# 129793 wt_cell_13481 TTTGTCACACGTGAGA mixl_6  E8.5  0                FALSE
#        doublet stage.mapped celltype.mapped              closest.cell
# 1      FALSE   NA           NA                           NA
# 2      FALSE   NA           NA                           NA
# 3      FALSE   NA           NA                           NA
# 4      FALSE   NA           NA                           NA
# 5      FALSE   NA           NA                           NA
# 6      FALSE   NA           NA                           NA
# 7      FALSE   NA           NA                           NA
# 8      FALSE   NA           NA                           NA
# 9      FALSE   NA           NA                           NA
# 10     FALSE   NA           NA                           NA
# 11     FALSE   NA           NA                           NA
# 12     FALSE   NA           NA                           NA
# 13     FALSE   NA           NA                           NA
# 14     FALSE   NA           NA                           NA
# 15     FALSE   NA           NA                           NA
# 16     FALSE   NA           NA                           NA
# 17     FALSE   NA           NA                           NA
# 18     FALSE   NA           NA                           NA
# 19     FALSE   NA           NA                           NA
# 20     FALSE   NA           NA                           NA
# 21     FALSE   NA           NA                           NA
# 22     FALSE   NA           NA                           NA
# 23     FALSE   NA           NA                           NA
# 24     FALSE   NA           NA                           NA
# 25     FALSE   NA           NA                           NA
# 26     FALSE   NA           NA                           NA
# 27     FALSE   NA           NA                           NA
# 28     FALSE   NA           NA                           NA
# 29     FALSE   NA           NA                           NA
# 30     FALSE   NA           NA                           NA
# ⋮      ⋮       ⋮            ⋮                            ⋮
# 129764 FALSE   E8.5         Erythroid3                   atlas_cell_131689
# 129765 FALSE   E7.75        Somitic mesoderm             atlas_cell_9653
# 129766 FALSE   E8.5         Spinal cord                  atlas_cell_102247
# 129767 FALSE   E8.25        Surface ectoderm             atlas_cell_138999
# 129768 FALSE   E8.25        Paraxial mesoderm            atlas_cell_131055
# 129769 FALSE   E8.5         ExE mesoderm                 atlas_cell_131231
# 129770 FALSE   E8.25        Pharyngeal mesoderm          atlas_cell_99895
# 129771 FALSE   E8.25        Pharyngeal mesoderm          atlas_cell_66393
# 129772 FALSE   E8.25        Paraxial mesoderm            atlas_cell_92186
# 129773 FALSE   E8.5         Gut                          atlas_cell_76231
# 129774 FALSE   E8.25        Spinal cord                  atlas_cell_38955
# 129775 FALSE   E8.25        Forebrain/Midbrain/Hindbrain atlas_cell_93556
# 129776 FALSE   E8.5         Erythroid3                   atlas_cell_138960
# 129777 FALSE   E8.5         NMP                          atlas_cell_41045
# 129778 FALSE   E8.25        Paraxial mesoderm            atlas_cell_130929
# 129779 FALSE   E8.25        NMP                          atlas_cell_66523
# 129780 FALSE   E8.5         Erythroid3                   atlas_cell_132863
# 129781 FALSE   E8.5         Surface ectoderm             atlas_cell_102308
# 129782 FALSE   E8.5         Erythroid3                   atlas_cell_69097
# 129783 FALSE   E8.5         Erythroid3                   atlas_cell_136305
# 129784 FALSE   E8.25        Endothelium                  atlas_cell_135844
# 129785 FALSE   E8.5         Erythroid3                   atlas_cell_40308
# 129786 FALSE   E8.5         Forebrain/Midbrain/Hindbrain atlas_cell_98380
# 129787 FALSE   E8.25        Paraxial mesoderm            atlas_cell_116901
# 129788 FALSE   E8.5         Allantois                    atlas_cell_96755
# 129789 FALSE   E7.75        Rostral neurectoderm         atlas_cell_8750
# 129790 FALSE   E8.5         Erythroid3                   atlas_cell_97649
# 129791 FALSE   E8.5         Erythroid3                   atlas_cell_38655
# 129792 FALSE   E8.5         Erythroid2                   atlas_cell_133630
# 129793 FALSE   E8.5         Spinal cord                  atlas_cell_91103
#        tdTom haem_subclust celltype
# 1      NA    NA            NA
# 2      NA    NA            NA
# 3      NA    NA            NA
# 4      NA    NA            NA
# 5      NA    NA            NA
# 6      NA    NA            NA
# 7      NA    NA            NA
# 8      NA    NA            NA
# 9      NA    NA            NA
# 10     NA    NA            NA
# 11     NA    NA            NA
# 12     NA    NA            NA
# 13     NA    NA            NA
# 14     NA    NA            NA
# 15     NA    NA            NA
# 16     NA    NA            NA
# 17     NA    NA            NA
# 18     NA    NA            NA
# 19     NA    NA            NA
# 20     NA    NA            NA
# 21     NA    NA            NA
# 22     NA    NA            NA
# 23     NA    NA            NA
# 24     NA    NA            NA
# 25     NA    NA            NA
# 26     NA    NA            NA
# 27     NA    NA            NA
# 28     NA    NA            NA
# 29     NA    NA            NA
# 30     NA    NA            NA
# ⋮      ⋮     ⋮             ⋮
# 129764 neg   NA            NA
# 129765 neg   NA            NA
# 129766 neg   NA            NA
# 129767 neg   NA            NA
# 129768 neg   NA            NA
# 129769 neg   NA            NA
# 129770 neg   NA            NA
# 129771 neg   NA            NA
# 129772 neg   NA            NA
# 129773 neg   NA            NA
# 129774 neg   NA            NA
# 129775 neg   NA            NA
# 129776 neg   NA            NA
# 129777 neg   NA            NA
# 129778 neg   NA            NA
# 129779 neg   NA            NA
# 129780 neg   NA            NA
# 129781 neg   NA            NA
# 129782 neg   NA            NA
# 129783 neg   NA            NA
# 129784 neg   NA            NA
# 129785 neg   NA            NA
# 129786 neg   NA            NA
# 129787 neg   NA            NA
# 129788 neg   NA            NA
# 129789 neg   NA            NA
# 129790 neg   NA            NA
# 129791 neg   NA            NA
# 129792 neg   NA            NA
# 129793 neg   NA            NA

# %%
big_meta$haem_subclust <- NA

# %%
#big_meta$haem_subclust <- big_meta %>% filter() %>% select
big_meta$celltype <- NA
big_meta$celltype = as.character(big_meta$celltype.mapped[match(names(big_meta$cell), big_meta$closest.cell))])

# %%
big_meta$celltype <- big_meta %>% filter(big_meta$closest.cell %in% big_meta$cell) %>% .$celltype.mapped
# Out:
# Error in `$<-.data.frame`(`*tmp*`, celltype, value = c("Haematoendothelial progenitors", : replacement has 13481 rows, data has 129793
# Traceback:
#
# 1. `$<-`(`*tmp*`, celltype, value = c("Haematoendothelial progenitors",
#  . "Mesenchyme", "Primitive Streak", "NMP", "Caudal Mesoderm", "Surface ectoderm",
#  . "NMP", "Somitic mesoderm", "Haematoendothelial progenitors",
#  . "Somitic mesoderm", "Pharyngeal mesoderm", "Paraxial mesoderm",
#  . "NMP", "Paraxial mesoderm", "Forebrain/Midbrain/Hindbrain", "Rostral neurectoderm",
#  . "Rostral neurectoderm", "Mesenchyme", "Rostral neurectoderm",
#  . "Pharyngeal mesoderm", "ExE mesoderm", "Rostral neurectoderm",
#  . "Mesenchyme", "Forebrain/Midbrain/Hindbrain", "Neural crest",
#  . "Mesenchyme", "Somitic mesoderm", "NMP", "Haematoendothelial progenitors",
#  . "Nascent mesoderm", "Haematoendothelial progenitors", "Somitic mesoderm",
#  . "Rostral neurectoderm", "Mesenchyme", "Nascent mesoderm", "Rostral neurectoderm",
#  . "Haematoendothelial progenitors", "Gut", "Rostral neurectoderm",
#  . "Surface ectoderm", "NMP", "Notochord", "Caudal Mesoderm", "Forebrain/Midbrain/Hindbrain",
#  . "Rostral neurectoderm", "Blood progenitors 2", "Pharyngeal mesoderm",
#  . "Intermediate mesoderm", "Rostral neurectoderm", "ExE mesoderm",
#  . "Intermediate mesoderm", "Mixed mesoderm", "Blood progenitors 2",
#  . "Nascent mesoderm", "NMP", "Anterior Primitive Streak", "Pharyngeal mesoderm",
#  . "NMP", "Forebrain/Midbrain/Hindbrain", "Nascent mesoderm", "ExE mesoderm",
#  . "ExE mesoderm", "Caudal epiblast", "Mesenchyme", "Nascent mesoderm",
#  . "Nascent mesoderm", "Surface ectoderm", "Rostral neurectoderm",
#  . "Forebrain/Midbrain/Hindbrain", "Pharyngeal mesoderm", "Nascent mesoderm",
#  . "Paraxial mesoderm", "Somitic mesoderm", "Pharyngeal mesoderm",
#  . "Blood progenitors 2", "Epiblast", "Rostral neurectoderm", "Def. endoderm",
#  . "Haematoendothelial progenitors", "Rostral neurectoderm", "Forebrain/Midbrain/Hindbrain",
#  . "Neural crest", "Intermediate mesoderm", "Pharyngeal mesoderm",
#  . "Surface ectoderm", "Allantois", "Mesenchyme", "Caudal epiblast",
#  . "Epiblast", "NMP", "Caudal Mesoderm", "Haematoendothelial progenitors",
#  . "Intermediate mesoderm", "Haematoendothelial progenitors", "Mesenchyme",
#  . "Blood progenitors 2", "Paraxial mesoderm", "Intermediate mesoderm",
#  . "Surface ectoderm", "Epiblast", "Mesenchyme", "Paraxial mesoderm",
#  . "Spinal cord", "NMP", "Intermediate mesoderm", "NMP", "Haematoendothelial progenitors",
#  . "Nascent mesoderm", "Rostral neurectoderm", "Surface ectoderm",
#  . "Mesenchyme", "Haematoendothelial progenitors", "Forebrain/Midbrain/Hindbrain",
#  . "Intermediate mesoderm", "NMP", "Rostral neurectoderm", "Intermediate mesoderm",
#  . "Caudal Mesoderm", "Mesenchyme", "Rostral neurectoderm", "Paraxial mesoderm",
#  . "Surface ectoderm", "Surface ectoderm", "Intermediate mesoderm",
#  . "Def. endoderm", "Forebrain/Midbrain/Hindbrain", "Haematoendothelial progenitors",
#  . "Pharyngeal mesoderm", "Forebrain/Midbrain/Hindbrain", "Gut",
#  . "Pharyngeal mesoderm", "Surface ectoderm", "Haematoendothelial progenitors",
#  . "Somitic mesoderm", "Intermediate mesoderm", "Paraxial mesoderm",
#  . "Spinal cord", "Rostral neurectoderm", "Pharyngeal mesoderm",
#  . "Paraxial mesoderm", "Paraxial mesoderm", "Somitic mesoderm",
#  . "Surface ectoderm", "Intermediate mesoderm", "NMP", "Rostral neurectoderm",
#  . "Nascent mesoderm", "Paraxial mesoderm", "Mesenchyme", "Haematoendothelial progenitors",
#  . "Pharyngeal mesoderm", "Forebrain/Midbrain/Hindbrain", "Rostral neurectoderm",
#  . "Paraxial mesoderm", "Def. endoderm", "Rostral neurectoderm",
#  . "ExE mesoderm", "Mesenchyme", "Intermediate mesoderm", "Gut",
#  . "Allantois", "Rostral neurectoderm", "Def. endoderm", "Caudal Mesoderm",
#  . "Epiblast", "Paraxial mesoderm", "Forebrain/Midbrain/Hindbrain",
#  . "Mesenchyme", "NMP", "Mesenchyme", "Forebrain/Midbrain/Hindbrain",
#  . "Rostral neurectoderm", "NMP", "Paraxial mesoderm", "Mesenchyme",
#  . "Paraxial mesoderm", "Blood progenitors 2", "Intermediate mesoderm",
#  . "ExE mesoderm", "Caudal Mesoderm", "Intermediate mesoderm", "Gut",
#  . "Blood progenitors 2", "ExE mesoderm", "Surface ectoderm", "Mesenchyme",
#  . "Mesenchyme", "Haematoendothelial progenitors", "Rostral neurectoderm",
#  . "Rostral neurectoderm", "NMP", "Paraxial mesoderm", "NMP", "Blood progenitors 2",
#  . "Haematoendothelial progenitors", "Gut", "Rostral neurectoderm",
#  . "Caudal epiblast", "Paraxial mesoderm", "Rostral neurectoderm",
#  . "Rostral neurectoderm", "Neural crest", "Nascent mesoderm", "Intermediate mesoderm",
#  . "Mesenchyme", "NMP", "Mesenchyme", "Def. endoderm", "NMP", "Intermediate mesoderm",
#  . "Surface ectoderm", "NMP", "Nascent mesoderm", "Nascent mesoderm",
#  . "Caudal Mesoderm", "ExE mesoderm", "Mesenchyme", "Paraxial mesoderm",
#  . "Mixed mesoderm", "Somitic mesoderm", "Forebrain/Midbrain/Hindbrain",
#  . "Caudal epiblast", "Spinal cord", "ExE mesoderm", "Spinal cord",
#  . "Rostral neurectoderm", "Surface ectoderm", "Mesenchyme", "ExE mesoderm",
#  . "Caudal Mesoderm", "Haematoendothelial progenitors", "Mesenchyme",
#  . "ExE mesoderm", "Pharyngeal mesoderm", "Nascent mesoderm", "NMP",
#  . "Paraxial mesoderm", "Rostral neurectoderm", "Rostral neurectoderm",
#  . "ExE mesoderm", "Rostral neurectoderm", "Surface ectoderm", "Primitive Streak",
#  . "Paraxial mesoderm", "Gut", "NMP", "Rostral neurectoderm", "Rostral neurectoderm",
#  . "Rostral neurectoderm", "Spinal cord", "NMP", "ExE mesoderm",
#  . "Nascent mesoderm", "Intermediate mesoderm", "Haematoendothelial progenitors",
#  . "Intermediate mesoderm", "Rostral neurectoderm", "Paraxial mesoderm",
#  . "Nascent mesoderm", "Forebrain/Midbrain/Hindbrain", "ExE mesoderm",
#  . "Forebrain/Midbrain/Hindbrain", "Rostral neurectoderm", "Anterior Primitive Streak",
#  . "Nascent mesoderm", "Nascent mesoderm", "NMP", "ExE mesoderm",
#  . "Paraxial mesoderm", "Notochord", "Haematoendothelial progenitors",
#  . "ExE mesoderm", "Forebrain/Midbrain/Hindbrain", "Blood progenitors 1",
#  . "Mesenchyme", "ExE mesoderm", "Blood progenitors 2", "Caudal Mesoderm",
#  . "Surface ectoderm", "Notochord", "Surface ectoderm", "Rostral neurectoderm",
#  . "Intermediate mesoderm", "Surface ectoderm", "Surface ectoderm",
#  . "Surface ectoderm", "ExE mesoderm", "Blood progenitors 2", "Paraxial mesoderm",
#  . "Haematoendothelial progenitors", "Blood progenitors 1", "Forebrain/Midbrain/Hindbrain",
#  . "ExE mesoderm", "Nascent mesoderm", "Spinal cord", "NMP", "Blood progenitors 2",
#  . "Mixed mesoderm", "Somitic mesoderm", "Pharyngeal mesoderm",
#  . "Mesenchyme", "Intermediate mesoderm", "Nascent mesoderm", "Rostral neurectoderm",
#  . "Forebrain/Midbrain/Hindbrain", "Caudal Mesoderm", "Haematoendothelial progenitors",
#  . "Intermediate mesoderm", "Rostral neurectoderm", "Mesenchyme",
#  . "Primitive Streak", "ExE mesoderm", "NMP", "Nascent mesoderm",
#  . "Somitic mesoderm", "Haematoendothelial progenitors", "Mesenchyme",
#  . "Rostral neurectoderm", "Caudal Mesoderm", "Surface ectoderm",
#  . "Spinal cord", "Spinal cord", "Haematoendothelial progenitors",
#  . "Caudal Mesoderm", "Surface ectoderm", "Paraxial mesoderm", "Intermediate mesoderm",
#  . "Intermediate mesoderm", "Rostral neurectoderm", "Blood progenitors 1",
#  . "Forebrain/Midbrain/Hindbrain", "NMP", "Nascent mesoderm", "Intermediate mesoderm",
#  . "Mesenchyme", "NMP", "Mesenchyme", "Anterior Primitive Streak",
#  . "Nascent mesoderm", "Surface ectoderm", "NMP", "Forebrain/Midbrain/Hindbrain",
#  . "Haematoendothelial progenitors", "Nascent mesoderm", "ExE mesoderm",
#  . "Intermediate mesoderm", "Pharyngeal mesoderm", "ExE mesoderm",
#  . "Mesenchyme", "Def. endoderm", "Paraxial mesoderm", "Intermediate mesoderm",
#  . "Pharyngeal mesoderm", "Haematoendothelial progenitors", "Blood progenitors 2",
#  . "Rostral neurectoderm", "Somitic mesoderm", "ExE mesoderm", "Caudal Mesoderm",
#  . "NMP", "Pharyngeal mesoderm", "Rostral neurectoderm", "Mesenchyme",
#  . "Pharyngeal mesoderm", "Rostral neurectoderm", "Nascent mesoderm",
#  . "Rostral neurectoderm", "Paraxial mesoderm", "Mesenchyme", "Intermediate mesoderm",
#  . "Haematoendothelial progenitors", "Paraxial mesoderm", "Nascent mesoderm",
#  . "Pharyngeal mesoderm", "Epiblast", "Forebrain/Midbrain/Hindbrain",
#  . "Pharyngeal mesoderm", "Surface ectoderm", "ExE mesoderm", "Rostral neurectoderm",
#  . "Surface ectoderm", "Intermediate mesoderm", "Mesenchyme", "Rostral neurectoderm",
#  . "Surface ectoderm", "Mesenchyme", "Somitic mesoderm", "Caudal Mesoderm",
#  . "Spinal cord", "Paraxial mesoderm", "Gut", "Nascent mesoderm",
#  . "Gut", "Pharyngeal mesoderm", "Epiblast", "Spinal cord", "Rostral neurectoderm",
#  . "Somitic mesoderm", "Spinal cord", "NMP", "Pharyngeal mesoderm",
#  . "Forebrain/Midbrain/Hindbrain", "Forebrain/Midbrain/Hindbrain",
#  . "NMP", "Somitic mesoderm", "Surface ectoderm", "NMP", "Paraxial mesoderm",
#  . "Paraxial mesoderm", "Paraxial mesoderm", "Neural crest", "Mixed mesoderm",
#  . "Neural crest", "Mesenchyme", "Forebrain/Midbrain/Hindbrain",
#  . "Surface ectoderm", "Paraxial mesoderm", "Somitic mesoderm",
#  . "Pharyngeal mesoderm", "Rostral neurectoderm", "Haematoendothelial progenitors",
#  . "Rostral neurectoderm", "Pharyngeal mesoderm", "Intermediate mesoderm",
#  . "Nascent mesoderm", "Surface ectoderm", "Gut", "Surface ectoderm",
#  . "Mesenchyme", "NMP", "Caudal epiblast", "Mesenchyme", "NMP",
#  . "Caudal epiblast", "ExE mesoderm", "Forebrain/Midbrain/Hindbrain",
#  . "Blood progenitors 2", "Mesenchyme", "Mesenchyme", "Gut", "Haematoendothelial progenitors",
#  . "Rostral neurectoderm", "NMP", "Mesenchyme", "Somitic mesoderm",
#  . "ExE mesoderm", "ExE mesoderm", "Primitive Streak", "Somitic mesoderm",
#  . "Rostral neurectoderm", "Pharyngeal mesoderm", "Intermediate mesoderm",
#  . "Allantois", "Mesenchyme", "Blood progenitors 1", "Mesenchyme",
#  . "NMP", "Intermediate mesoderm", "Haematoendothelial progenitors",
#  . "Mesenchyme", "Paraxial mesoderm", "Forebrain/Midbrain/Hindbrain",
#  . "Pharyngeal mesoderm", "Paraxial mesoderm", "Spinal cord", "ExE mesoderm",
#  . "Gut", "Somitic mesoderm", "Somitic mesoderm", "Surface ectoderm",
#  . "Pharyngeal mesoderm", "Paraxial mesoderm", "Nascent mesoderm",
#  . "Somitic mesoderm", "Pharyngeal mesoderm", "Gut", "Surface ectoderm",
#  . "Mesenchyme", "ExE mesoderm", "Mixed mesoderm", "Blood progenitors 2",
#  . "Forebrain/Midbrain/Hindbrain", "Blood progenitors 1", "Forebrain/Midbrain/Hindbrain",
#  . "Intermediate mesoderm", "Mixed mesoderm", "Rostral neurectoderm",
#  . "Rostral neurectoderm", "Def. endoderm", "Forebrain/Midbrain/Hindbrain",
#  . "Forebrain/Midbrain/Hindbrain", "Paraxial mesoderm", "NMP", "NMP",
#  . "Endothelium", "Rostral neurectoderm", "Forebrain/Midbrain/Hindbrain",
#  . "NMP", "Rostral neurectoderm", "Rostral neurectoderm", "Caudal neurectoderm",
#  . "Surface ectoderm", "Rostral neurectoderm", "Haematoendothelial progenitors",
#  . "Forebrain/Midbrain/Hindbrain", "Gut", "Primitive Streak", "Somitic mesoderm",
#  . "Paraxial mesoderm", "Blood progenitors 1", "Rostral neurectoderm",
#  . "Paraxial mesoderm", "Surface ectoderm", "Caudal Mesoderm", "Blood progenitors 2",
#  . "Def. endoderm", "NMP", "Blood progenitors 2", "Neural crest",
#  . "Paraxial mesoderm", "Gut", "Intermediate mesoderm", "ExE mesoderm",
#  . "Nascent mesoderm", "Mesenchyme", "Forebrain/Midbrain/Hindbrain",
#  . "Rostral neurectoderm", "Pharyngeal mesoderm", "Primitive Streak",
#  . "Mesenchyme", "Allantois", "Spinal cord", "Mesenchyme", "Haematoendothelial progenitors",
#  . "Caudal Mesoderm", "Pharyngeal mesoderm", "Somitic mesoderm",
#  . "Mixed mesoderm", "Paraxial mesoderm", "NMP", "Forebrain/Midbrain/Hindbrain",
#  . "Spinal cord", "ExE mesoderm", "Def. endoderm", "Pharyngeal mesoderm",
#  . "Forebrain/Midbrain/Hindbrain", "Anterior Primitive Streak",
#  . "Nascent mesoderm", "Pharyngeal mesoderm", "Erythroid1", "ExE mesoderm",
#  . "Paraxial mesoderm", "Mesenchyme", "Rostral neurectoderm", "Nascent mesoderm",
#  . "Blood progenitors 2", "NMP", "Forebrain/Midbrain/Hindbrain",
#  . "Somitic mesoderm", "Blood progenitors 1", "Blood progenitors 1",
#  . "Rostral neurectoderm", "Mesenchyme", "Blood progenitors 2",
#  . "NMP", "Nascent mesoderm", "Intermediate mesoderm", "Forebrain/Midbrain/Hindbrain",
#  . "Paraxial mesoderm", "Mesenchyme", "Rostral neurectoderm", "Paraxial mesoderm",
#  . "Pharyngeal mesoderm", "NMP", "Nascent mesoderm", "Mesenchyme",
#  . "Pharyngeal mesoderm", "Surface ectoderm", "Mesenchyme", "Pharyngeal mesoderm",
#  . "Mesenchyme", "ExE mesoderm", "Caudal Mesoderm", "Blood progenitors 2",
#  . "Rostral neurectoderm", "Rostral neurectoderm", "Nascent mesoderm",
#  . "Erythroid1", "Rostral neurectoderm", "Mixed mesoderm", "Caudal Mesoderm",
#  . "Nascent mesoderm", "Intermediate mesoderm", "Primitive Streak",
#  . "Paraxial mesoderm", "Spinal cord", "Paraxial mesoderm", "Mesenchyme",
#  . "Pharyngeal mesoderm", "Forebrain/Midbrain/Hindbrain", "Mesenchyme",
#  . "ExE mesoderm", "Rostral neurectoderm", "Blood progenitors 2",
#  . "Rostral neurectoderm", "Caudal Mesoderm", "Mesenchyme", "ExE mesoderm",
#  . "Blood progenitors 2", "Notochord", "Intermediate mesoderm",
#  . "ExE mesoderm", "Rostral neurectoderm", "Blood progenitors 2",
#  . "Rostral neurectoderm", "Surface ectoderm", "Rostral neurectoderm",
#  . "Surface ectoderm", "NMP", "Mesenchyme", "Paraxial mesoderm",
#  . "Paraxial mesoderm", "NMP", "Pharyngeal mesoderm", "Haematoendothelial progenitors",
#  . "Mesenchyme", "Caudal epiblast", "Mesenchyme", "Pharyngeal mesoderm",
#  . "Mesenchyme", "Rostral neurectoderm", "Rostral neurectoderm",
#  . "NMP", "Somitic mesoderm", "Gut", "Paraxial mesoderm", "NMP",
#  . "Blood progenitors 2", "Surface ectoderm", "Intermediate mesoderm",
#  . "Rostral neurectoderm", "ExE mesoderm", "Notochord", "Surface ectoderm",
#  . "Pharyngeal mesoderm", "Blood progenitors 1", "Nascent mesoderm",
#  . "Surface ectoderm", "ExE mesoderm", "Surface ectoderm", "Nascent mesoderm",
#  . "NMP", "Somitic mesoderm", "Epiblast", "Intermediate mesoderm",
#  . "Blood progenitors 2", "Mesenchyme", "Nascent mesoderm", "Rostral neurectoderm",
#  . "Caudal Mesoderm", "Forebrain/Midbrain/Hindbrain", "Paraxial mesoderm",
#  . "Rostral neurectoderm", "NMP", "Surface ectoderm", "Caudal epiblast",
#  . "Blood progenitors 1", "Primitive Streak", "Intermediate mesoderm",
#  . "Blood progenitors 2", "ExE mesoderm", "Intermediate mesoderm",
#  . "ExE mesoderm", "Blood progenitors 2", "Paraxial mesoderm", "Haematoendothelial progenitors",
#  . "Intermediate mesoderm", "ExE mesoderm", "Pharyngeal mesoderm",
#  . "Anterior Primitive Streak", "Def. endoderm", "Gut", "Blood progenitors 2",
#  . "Nascent mesoderm", "Somitic mesoderm", "Neural crest", "Blood progenitors 2",
#  . "Surface ectoderm", "Forebrain/Midbrain/Hindbrain", "Notochord",
#  . "Rostral neurectoderm", "Rostral neurectoderm", "Def. endoderm",
#  . "Rostral neurectoderm", "Paraxial mesoderm", "Mesenchyme", "ExE mesoderm",
#  . "ExE mesoderm", "Primitive Streak", "Rostral neurectoderm", "Rostral neurectoderm",
#  . "ExE mesoderm", "Pharyngeal mesoderm", "Spinal cord", "Surface ectoderm",
#  . "NMP", "Haematoendothelial progenitors", "Epiblast", "Caudal epiblast",
#  . "Nascent mesoderm", "Caudal Mesoderm", "Pharyngeal mesoderm",
#  . "Surface ectoderm", "Rostral neurectoderm", "Notochord", "Forebrain/Midbrain/Hindbrain",
#  . "Erythroid1", "Surface ectoderm", "Haematoendothelial progenitors",
#  . "Intermediate mesoderm", "Blood progenitors 2", "NMP", "Intermediate mesoderm",
#  . "Neural crest", "Blood progenitors 2", "Rostral neurectoderm",
#  . "ExE mesoderm", "Spinal cord", "Pharyngeal mesoderm", "Gut",
#  . "Caudal neurectoderm", "Somitic mesoderm", "Mesenchyme", "Blood progenitors 2",
#  . "Spinal cord", "Paraxial mesoderm", "NMP", "Forebrain/Midbrain/Hindbrain",
#  . "Nascent mesoderm", "Anterior Primitive Streak", "Paraxial mesoderm",
#  . "Rostral neurectoderm", "Paraxial mesoderm", "Pharyngeal mesoderm",
#  . "Forebrain/Midbrain/Hindbrain", "Rostral neurectoderm", "Forebrain/Midbrain/Hindbrain",
#  . "Surface ectoderm", "Pharyngeal mesoderm", "Mesenchyme", "Surface ectoderm",
#  . "Mesenchyme", "Mesenchyme", "Nascent mesoderm", "NMP", "Haematoendothelial progenitors",
#  . "Paraxial mesoderm", "Haematoendothelial progenitors", "ExE mesoderm",
#  . "Forebrain/Midbrain/Hindbrain", "NMP", "Rostral neurectoderm",
#  . "Paraxial mesoderm", "ExE mesoderm", "Surface ectoderm", "Caudal Mesoderm",
#  . "Paraxial mesoderm", "Haematoendothelial progenitors", "Surface ectoderm",
#  . "Forebrain/Midbrain/Hindbrain", "Forebrain/Midbrain/Hindbrain",
#  . "Somitic mesoderm", "Paraxial mesoderm", "Pharyngeal mesoderm",
#  . "Rostral neurectoderm", "NMP", "Rostral neurectoderm", "Spinal cord",
#  . "Neural crest", "Gut", "Spinal cord", "NMP", "Haematoendothelial progenitors",
#  . "Haematoendothelial progenitors", "Mesenchyme", "Surface ectoderm",
#  . "Paraxial mesoderm", "Mesenchyme", "Pharyngeal mesoderm", "Somitic mesoderm",
#  . "Surface ectoderm", "Caudal neurectoderm", "ExE mesoderm", "NMP",
#  . "ExE mesoderm", "Rostral neurectoderm", "Surface ectoderm", "Rostral neurectoderm",
#  . "Pharyngeal mesoderm", "Paraxial mesoderm", "NMP", "ExE mesoderm",
#  . "ExE mesoderm", "Haematoendothelial progenitors", "Somitic mesoderm",
#  . "Nascent mesoderm", "Gut", "Paraxial mesoderm", "Somitic mesoderm",
#  . "Caudal Mesoderm", "Blood progenitors 2", "NMP", "Forebrain/Midbrain/Hindbrain",
#  . "Notochord", "Mesenchyme", "Primitive Streak", "Nascent mesoderm",
#  . "Blood progenitors 2", "Paraxial mesoderm", "Somitic mesoderm",
#  . "Gut", "ExE mesoderm", "Surface ectoderm", "Rostral neurectoderm",
#  . "Mixed mesoderm", "Pharyngeal mesoderm", "Pharyngeal mesoderm",
#  . "Nascent mesoderm", "ExE mesoderm", "Notochord", "Somitic mesoderm",
#  . "Anterior Primitive Streak", "Somitic mesoderm", "Gut", "Forebrain/Midbrain/Hindbrain",
#  . "Pharyngeal mesoderm", "Intermediate mesoderm", "Paraxial mesoderm",
#  . "Forebrain/Midbrain/Hindbrain", "Forebrain/Midbrain/Hindbrain",
#  . "Blood progenitors 2", "Intermediate mesoderm", "Gut", "Forebrain/Midbrain/Hindbrain",
#  . "Intermediate mesoderm", "Intermediate mesoderm", "Paraxial mesoderm",
#  . "Somitic mesoderm", "ExE mesoderm", "Intermediate mesoderm",
#  . "Forebrain/Midbrain/Hindbrain", "Intermediate mesoderm", "Surface ectoderm",
#  . "Paraxial mesoderm", "Paraxial mesoderm", "Haematoendothelial progenitors",
#  . "Rostral neurectoderm", "Forebrain/Midbrain/Hindbrain", "NMP",
#  . "Rostral neurectoderm", "Nascent mesoderm", "Pharyngeal mesoderm",
#  . "Pharyngeal mesoderm", "Rostral neurectoderm", "Paraxial mesoderm",
#  . "Haematoendothelial progenitors", "ExE mesoderm", "Rostral neurectoderm",
#  . "Caudal epiblast", "Mesenchyme", "Erythroid1", "Pharyngeal mesoderm",
#  . "Blood progenitors 1", "Paraxial mesoderm", "Rostral neurectoderm",
#  . "Rostral neurectoderm", "NMP", "Surface ectoderm", "Surface ectoderm",
#  . "NMP", "Intermediate mesoderm", "Rostral neurectoderm", "Somitic mesoderm",
#  . "Rostral neurectoderm", "Erythroid1", "Somitic mesoderm", "Spinal cord",
#  . "Rostral neurectoderm", "Haematoendothelial progenitors", "Intermediate mesoderm",
#  . "Mesenchyme", "NMP", "Blood progenitors 2", "Mesenchyme", "Rostral neurectoderm",
#  . "Gut", "Mesenchyme", "Forebrain/Midbrain/Hindbrain", "Somitic mesoderm",
#  . "Gut", "Gut", "Mixed mesoderm", "Intermediate mesoderm", "Notochord",
#  . "Pharyngeal mesoderm", "Forebrain/Midbrain/Hindbrain", "Forebrain/Midbrain/Hindbrain",
#  . "Caudal epiblast", "Notochord", "Nascent mesoderm", "Mesenchyme",
#  . "Haematoendothelial progenitors", "Rostral neurectoderm", "Surface ectoderm",
#  . "Rostral neurectoderm", "Paraxial mesoderm", "Mesenchyme", "NMP",
#  . "Pharyngeal mesoderm", "Primitive Streak", "Blood progenitors 2",
#  . "Gut", "Somitic mesoderm", "Caudal epiblast", "Def. endoderm",
#  . "Somitic mesoderm", "Gut", "Caudal Mesoderm", "ExE mesoderm",
#  . "Forebrain/Midbrain/Hindbrain", "Rostral neurectoderm", "Surface ectoderm",
#  . "Intermediate mesoderm", "Mesenchyme", "Haematoendothelial progenitors",
#  . "Blood progenitors 1", "Spinal cord", "ExE mesoderm", "Intermediate mesoderm",
#  . "Notochord", "Primitive Streak", "Forebrain/Midbrain/Hindbrain",
#  . "NMP", "Paraxial mesoderm", "Blood progenitors 2", "ExE mesoderm",
#  . "Primitive Streak", "Blood progenitors 2", "Mesenchyme", "Paraxial mesoderm",
#  . "Forebrain/Midbrain/Hindbrain", "Somitic mesoderm", "Forebrain/Midbrain/Hindbrain",
#  . "Mesenchyme", "Paraxial mesoderm", "Rostral neurectoderm", "Rostral neurectoderm",
#  . "Pharyngeal mesoderm", "Rostral neurectoderm", "Surface ectoderm",
#  . "Forebrain/Midbrain/Hindbrain", "Somitic mesoderm", "Intermediate mesoderm",
#  . "Caudal epiblast", "Forebrain/Midbrain/Hindbrain", "Notochord",
#  . "Somitic mesoderm", "Surface ectoderm", "Surface ectoderm", "NMP",
#  . "Rostral neurectoderm", "Mesenchyme", "Surface ectoderm", "Paraxial mesoderm",
#  . "ExE mesoderm", "Pharyngeal mesoderm", "ExE mesoderm", "Mixed mesoderm",
#  . "Mesenchyme", "Blood progenitors 2", "Anterior Primitive Streak",
#  . "Intermediate mesoderm", "Pharyngeal mesoderm", "Mesenchyme",
#  . "Forebrain/Midbrain/Hindbrain", "ExE mesoderm", "Blood progenitors 2",
#  . "Forebrain/Midbrain/Hindbrain", "Caudal epiblast", "Nascent mesoderm",
#  . "Gut", "Def. endoderm", "Forebrain/Midbrain/Hindbrain", "Pharyngeal mesoderm",
#  . "ExE mesoderm", "Forebrain/Midbrain/Hindbrain", "Paraxial mesoderm",
#  . "Surface ectoderm", "Def. endoderm", "Blood progenitors 2", "Haematoendothelial progenitors",
#  . "Intermediate mesoderm", "Mesenchyme", "Rostral neurectoderm",
#  . "Forebrain/Midbrain/Hindbrain", "NMP", "Blood progenitors 1",
#  . "NMP", "ExE mesoderm", "Mesenchyme", "Haematoendothelial progenitors",
#  . "Intermediate mesoderm", "Surface ectoderm", "Paraxial mesoderm",
#  . "Anterior Primitive Streak", "NMP", "Mesenchyme", "Haematoendothelial progenitors",
#  . "Haematoendothelial progenitors", "Gut", "Spinal cord", "Paraxial mesoderm",
#  . "Forebrain/Midbrain/Hindbrain", "Pharyngeal mesoderm", "Forebrain/Midbrain/Hindbrain",
#  . "Nascent mesoderm", "Paraxial mesoderm", "Pharyngeal mesoderm",
#  . "Primitive Streak", "Pharyngeal mesoderm", "NMP", "Spinal cord",
#  . "Surface ectoderm", "Pharyngeal mesoderm", "Epiblast", "Caudal neurectoderm",
#  . "Mesenchyme", "Rostral neurectoderm", "Rostral neurectoderm",
#  . "Rostral neurectoderm", "Intermediate mesoderm", "Blood progenitors 2",
#  . "Rostral neurectoderm", "Rostral neurectoderm", "Mesenchyme",
#  . "NMP", "Def. endoderm", "Forebrain/Midbrain/Hindbrain", "Intermediate mesoderm",
#  . "Rostral neurectoderm", "Spinal cord", "Rostral neurectoderm",
#  . "Intermediate mesoderm", "Mesenchyme", "Allantois", "Paraxial mesoderm",
#  . "Somitic mesoderm", "Rostral neurectoderm", "Paraxial mesoderm",
#  . "Def. endoderm", "Blood progenitors 2", "NMP", "Nascent mesoderm",
#  . "Surface ectoderm", "Spinal cord", "Nascent mesoderm", "Forebrain/Midbrain/Hindbrain",
#  . "Caudal Mesoderm", "ExE mesoderm", "Rostral neurectoderm", "Intermediate mesoderm",
#  . "Surface ectoderm", "Mesenchyme", "Paraxial mesoderm", "Anterior Primitive Streak",
#  . "Intermediate mesoderm", "Surface ectoderm", "NMP", "Mesenchyme",
#  . "Nascent mesoderm", "Rostral neurectoderm", "Blood progenitors 1",
#  . "Forebrain/Midbrain/Hindbrain", "Mesenchyme", "ExE mesoderm",
#  . "NMP", "Mesenchyme", "NMP", "Pharyngeal mesoderm", "Rostral neurectoderm",
#  . "Primitive Streak", "Rostral neurectoderm", "Spinal cord", "Surface ectoderm",
#  . "Mesenchyme", "ExE mesoderm", "Mesenchyme", "Paraxial mesoderm",
#  . "Surface ectoderm", "Rostral neurectoderm", "Blood progenitors 2",
#  . "ExE mesoderm", "Rostral neurectoderm", "NMP", "NMP", "Intermediate mesoderm",
#  . "Mesenchyme", "Pharyngeal mesoderm", "NMP", "Forebrain/Midbrain/Hindbrain",
#  . "ExE mesoderm", "Mixed mesoderm", "Intermediate mesoderm", "Forebrain/Midbrain/Hindbrain",
#  . "Blood progenitors 2", "Rostral neurectoderm", "Intermediate mesoderm",
#  . "Rostral neurectoderm", "Somitic mesoderm", "ExE mesoderm", "Somitic mesoderm",
#  . "Paraxial mesoderm", "Nascent mesoderm", "ExE mesoderm", "Rostral neurectoderm",
#  . "Gut", "Haematoendothelial progenitors", "Surface ectoderm",
#  . "Blood progenitors 2", "Forebrain/Midbrain/Hindbrain", "Paraxial mesoderm",
#  . "Rostral neurectoderm", "ExE mesoderm", "Gut", "Def. endoderm",
#  . "Forebrain/Midbrain/Hindbrain", "Haematoendothelial progenitors",
#  . "Caudal Mesoderm", "Mesenchyme", "NMP", "Blood progenitors 2",
#  . "Surface ectoderm", "Notochord", "NMP", "Rostral neurectoderm",
#  . "Nascent mesoderm", "Spinal cord", "Forebrain/Midbrain/Hindbrain",
#  . "Caudal Mesoderm", "ExE mesoderm", "Mesenchyme", "Haematoendothelial progenitors",
#  . "Rostral neurectoderm", "Blood progenitors 2", "Rostral neurectoderm",
#  . "Gut", "Intermediate mesoderm", "NMP", "Caudal epiblast", "Surface ectoderm",
#  . "Somitic mesoderm", "Blood progenitors 1", "Caudal Mesoderm",
#  . "ExE mesoderm", "Mesenchyme", "Paraxial mesoderm", "Forebrain/Midbrain/Hindbrain",
#  . "Pharyngeal mesoderm", "Gut", "Somitic mesoderm", "Blood progenitors 2",
#  . "Mesenchyme", "Primitive Streak", "ExE mesoderm", "Paraxial mesoderm",
#  . "Def. endoderm", "Surface ectoderm", "Forebrain/Midbrain/Hindbrain",
#  . "Nascent mesoderm", "ExE mesoderm", "Def. endoderm", "Nascent mesoderm",
#  . "Blood progenitors 1", "Surface ectoderm", "ExE mesoderm", "Nascent mesoderm",
#  . "NMP", "Mesenchyme", "Somitic mesoderm", "Paraxial mesoderm",
#  . "Forebrain/Midbrain/Hindbrain", "Intermediate mesoderm", "Paraxial mesoderm",
#  . "Forebrain/Midbrain/Hindbrain", "Pharyngeal mesoderm", "Intermediate mesoderm",
#  . "Blood progenitors 2", "NMP", "Caudal Mesoderm", "Mesenchyme",
#  . "Mesenchyme", "Mesenchyme", "Spinal cord", "Rostral neurectoderm",
#  . "Paraxial mesoderm", "Caudal epiblast", "NMP", "Somitic mesoderm",
#  . "Mesenchyme", "Primitive Streak", "Intermediate mesoderm", "Rostral neurectoderm",
#  . "Paraxial mesoderm", "Gut", "Blood progenitors 2", "Gut", "ExE mesoderm",
#  . "Rostral neurectoderm", "Surface ectoderm", "Blood progenitors 2",
#  . "Forebrain/Midbrain/Hindbrain", "Haematoendothelial progenitors",
#  . "Mesenchyme", "Gut", "Nascent mesoderm", "Nascent mesoderm",
#  . "Paraxial mesoderm", "ExE mesoderm", "Paraxial mesoderm", "Paraxial mesoderm",
#  . "NMP", "Gut", "Gut", "Rostral neurectoderm", "NMP", "Nascent mesoderm",
#  . "Gut", "Pharyngeal mesoderm", "Surface ectoderm", "Caudal Mesoderm",
#  . "NMP", "Rostral neurectoderm", "ExE mesoderm", "Caudal Mesoderm",
#  . "Blood progenitors 2", "Mesenchyme", "Somitic mesoderm", "Rostral neurectoderm",
#  . "Caudal Mesoderm", "ExE mesoderm", "ExE mesoderm", "ExE mesoderm",
#  . "Pharyngeal mesoderm", "Rostral neurectoderm", "Rostral neurectoderm",
#  . "Mesenchyme", "Mesenchyme", "Mesenchyme", "Notochord", "Surface ectoderm",
#  . "Haematoendothelial progenitors", "Rostral neurectoderm", "Mesenchyme",
#  . "Paraxial mesoderm", "ExE mesoderm", "NMP", "Gut", "NMP", "NMP",
#  . "Rostral neurectoderm", "Rostral neurectoderm", "Forebrain/Midbrain/Hindbrain",
#  . "Pharyngeal mesoderm", "Pharyngeal mesoderm", "Surface ectoderm",
#  . "NMP", "NMP", "Blood progenitors 2", "Pharyngeal mesoderm", "Epiblast",
#  . "Rostral neurectoderm", "Caudal Mesoderm", "Intermediate mesoderm",
#  . "Mesenchyme", "Somitic mesoderm", "Intermediate mesoderm", "Mesenchyme",
#  . "Rostral neurectoderm", "Haematoendothelial progenitors", "Mesenchyme",
#  . "ExE mesoderm", "Pharyngeal mesoderm", "Intermediate mesoderm",
#  . "Blood progenitors 2", "Gut", "Somitic mesoderm", "Intermediate mesoderm",
#  . "Blood progenitors 2", "ExE mesoderm", "NMP", "Nascent mesoderm",
#  . "Mesenchyme", "ExE mesoderm", "Pharyngeal mesoderm", "Rostral neurectoderm",
#  . "Pharyngeal mesoderm", "Blood progenitors 2", "Blood progenitors 2",
#  . "Pharyngeal mesoderm", "Spinal cord", "Somitic mesoderm", "Surface ectoderm",
#  . "Nascent mesoderm", "Caudal epiblast", "Intermediate mesoderm",
#  . "NMP", "Blood progenitors 2", "Caudal Mesoderm", "Paraxial mesoderm",
#  . "Surface ectoderm", "Forebrain/Midbrain/Hindbrain", "Mesenchyme",
#  . "Paraxial mesoderm", "Intermediate mesoderm", "Pharyngeal mesoderm",
#  . "NMP", "NMP", "Caudal Mesoderm", "Forebrain/Midbrain/Hindbrain",
#  . "Paraxial mesoderm", "Mesenchyme", "Mesenchyme", "Nascent mesoderm",
#  . "Rostral neurectoderm", "Intermediate mesoderm", "Mesenchyme",
#  . "Mesenchyme", "Allantois", "Caudal Mesoderm", "Mesenchyme", "Primitive Streak",
#  . "Haematoendothelial progenitors", "Surface ectoderm", "Rostral neurectoderm",
#  . "Nascent mesoderm", "ExE mesoderm", "Epiblast", "Blood progenitors 1",
#  . "Blood progenitors 1", "Forebrain/Midbrain/Hindbrain", "Somitic mesoderm",
#  . "Pharyngeal mesoderm", "Mixed mesoderm", "Caudal neurectoderm",
#  . "Blood progenitors 2", "Mesenchyme", "Def. endoderm", "Forebrain/Midbrain/Hindbrain",
#  . "Mesenchyme", "Surface ectoderm", "Mesenchyme", "Paraxial mesoderm",
#  . "Forebrain/Midbrain/Hindbrain", "Rostral neurectoderm", "ExE mesoderm",
#  . "Intermediate mesoderm", "Rostral neurectoderm", "Notochord",
#  . "ExE mesoderm", "Rostral neurectoderm", "Rostral neurectoderm",
#  . "Blood progenitors 1", "Caudal Mesoderm", "Mesenchyme", "Mesenchyme",
#  . "NMP", "Blood progenitors 1", "Rostral neurectoderm", "Blood progenitors 1",
#  . "ExE mesoderm", "Somitic mesoderm", "Haematoendothelial progenitors",
#  . "Surface ectoderm", "Forebrain/Midbrain/Hindbrain", "Somitic mesoderm",
#  . "ExE mesoderm", "Somitic mesoderm", "Somitic mesoderm", "Nascent mesoderm",
#  . "Mesenchyme", "Somitic mesoderm", "Mesenchyme", "Rostral neurectoderm",
#  . "Paraxial mesoderm", "Paraxial mesoderm", "Intermediate mesoderm",
#  . "Forebrain/Midbrain/Hindbrain", "NMP", "Forebrain/Midbrain/Hindbrain",
#  . "Forebrain/Midbrain/Hindbrain", "Surface ectoderm", "Intermediate mesoderm",
#  . "Epiblast", "Caudal Mesoderm", "Paraxial mesoderm", "Intermediate mesoderm",
#  . "Primitive Streak", "Intermediate mesoderm", "Forebrain/Midbrain/Hindbrain",
#  . "Notochord", "Anterior Primitive Streak", "Somitic mesoderm",
#  . "Pharyngeal mesoderm", "Pharyngeal mesoderm", "Spinal cord",
#  . "Mesenchyme", "Forebrain/Midbrain/Hindbrain", "Mesenchyme", "Mesenchyme",
#  . "Pharyngeal mesoderm", "Forebrain/Midbrain/Hindbrain", "Paraxial mesoderm",
#  . "Rostral neurectoderm", "Mesenchyme", "Caudal epiblast", "Blood progenitors 2",
#  . "Rostral neurectoderm", "Intermediate mesoderm", "Surface ectoderm",
#  . "Somitic mesoderm", "Nascent mesoderm", "Nascent mesoderm", "ExE mesoderm",
#  . "NMP", "Intermediate mesoderm", "NMP", "Forebrain/Midbrain/Hindbrain",
#  . "Nascent mesoderm", "Haematoendothelial progenitors", "Intermediate mesoderm",
#  . "Nascent mesoderm", "Paraxial mesoderm", "ExE mesoderm", "Blood progenitors 2",
#  . "Forebrain/Midbrain/Hindbrain", "Rostral neurectoderm", "Paraxial mesoderm",
#  . "Nascent mesoderm", "Somitic mesoderm", "Rostral neurectoderm",
#  . "Surface ectoderm", "Def. endoderm", "Haematoendothelial progenitors",
#  . "Somitic mesoderm", "Caudal epiblast", "NMP", "Mesenchyme", "ExE mesoderm",
#  . "Surface ectoderm", "Gut", "Haematoendothelial progenitors",
#  . "Neural crest", "Caudal neurectoderm", "Blood progenitors 2",
#  . "Surface ectoderm", "Nascent mesoderm", "Notochord", "Somitic mesoderm",
#  . "Def. endoderm", "Haematoendothelial progenitors", "Intermediate mesoderm",
#  . "Intermediate mesoderm", "Mesenchyme", "Anterior Primitive Streak",
#  . "Pharyngeal mesoderm", "ExE mesoderm", "Caudal Mesoderm", "NMP",
#  . "Rostral neurectoderm", "Somitic mesoderm", "Def. endoderm",
#  . "NMP", "Forebrain/Midbrain/Hindbrain", "NMP", "Intermediate mesoderm",
#  . "Nascent mesoderm", "Intermediate mesoderm", "Somitic mesoderm",
#  . "Mesenchyme", "Forebrain/Midbrain/Hindbrain", "Gut", "NMP", "ExE mesoderm",
#  . "NMP", "Nascent mesoderm", "Pharyngeal mesoderm", "ExE mesoderm",
#  . "Forebrain/Midbrain/Hindbrain", "Forebrain/Midbrain/Hindbrain",
#  . "Blood progenitors 2", "Pharyngeal mesoderm", "Forebrain/Midbrain/Hindbrain",
#  . "Somitic mesoderm", "Paraxial mesoderm", "Intermediate mesoderm",
#  . "Rostral neurectoderm", "Paraxial mesoderm", "Blood progenitors 2",
#  . "Spinal cord", "Intermediate mesoderm", "Forebrain/Midbrain/Hindbrain",
#  . "Nascent mesoderm", "Blood progenitors 2", "ExE mesoderm", "Spinal cord",
#  . "Paraxial mesoderm", "Surface ectoderm", "Haematoendothelial progenitors",
#  . "Intermediate mesoderm", "Somitic mesoderm", "Intermediate mesoderm",
#  . "Mesenchyme", "Spinal cord", "Surface ectoderm", "Mesenchyme",
#  . "Blood progenitors 1", "Surface ectoderm", "ExE mesoderm", "ExE mesoderm",
#  . "Gut", "Haematoendothelial progenitors", "NMP", "Spinal cord",
#  . "Haematoendothelial progenitors", "Rostral neurectoderm", "NMP",
#  . "Spinal cord", "Rostral neurectoderm", "NMP", "Forebrain/Midbrain/Hindbrain",
#  . "Mesenchyme", "Forebrain/Midbrain/Hindbrain", "Epiblast", "NMP",
#  . "Forebrain/Midbrain/Hindbrain", "Blood progenitors 2", "Forebrain/Midbrain/Hindbrain",
#  . "Rostral neurectoderm", "Caudal epiblast", "Mixed mesoderm",
#  . "Mesenchyme", "Forebrain/Midbrain/Hindbrain", "Pharyngeal mesoderm",
#  . "Rostral neurectoderm", "Forebrain/Midbrain/Hindbrain", "Somitic mesoderm",
#  . "Paraxial mesoderm", "Surface ectoderm", "Blood progenitors 2",
#  . "Surface ectoderm", "Nascent mesoderm", "Forebrain/Midbrain/Hindbrain",
#  . "Surface ectoderm", "ExE mesoderm", "Notochord", "Blood progenitors 2",
#  . "Intermediate mesoderm", "Haematoendothelial progenitors", "Somitic mesoderm",
#  . "Primitive Streak", "Pharyngeal mesoderm", "Somitic mesoderm",
#  . "Somitic mesoderm", "Nascent mesoderm", "ExE mesoderm", "Intermediate mesoderm",
#  . "Pharyngeal mesoderm", "Intermediate mesoderm", "Cardiomyocytes",
#  . "Forebrain/Midbrain/Hindbrain", "Blood progenitors 2", "Surface ectoderm",
#  . "Haematoendothelial progenitors", "Forebrain/Midbrain/Hindbrain",
#  . "Rostral neurectoderm", "Rostral neurectoderm", "Mesenchyme",
#  . "Erythroid1", "Pharyngeal mesoderm", "Mesenchyme", "Gut", "Rostral neurectoderm",
#  . "Forebrain/Midbrain/Hindbrain", "Paraxial mesoderm", "Blood progenitors 2",
#  . "Notochord", "Blood progenitors 2", "Intermediate mesoderm",
#  . "Forebrain/Midbrain/Hindbrain", "Caudal Mesoderm", "Surface ectoderm",
#  . "Rostral neurectoderm", "Rostral neurectoderm", "ExE mesoderm",
#  . "Forebrain/Midbrain/Hindbrain", "Mesenchyme", "Blood progenitors 2",
#  . "Nascent mesoderm", "Caudal neurectoderm", "Surface ectoderm",
#  . "Pharyngeal mesoderm", "Haematoendothelial progenitors", "Forebrain/Midbrain/Hindbrain",
#  . "Rostral neurectoderm", "Intermediate mesoderm", "Mesenchyme",
#  . "Gut", "Allantois", "ExE mesoderm", "Caudal Mesoderm", "Pharyngeal mesoderm",
#  . "ExE mesoderm", "Paraxial mesoderm", "Forebrain/Midbrain/Hindbrain",
#  . "Paraxial mesoderm", "Intermediate mesoderm", "Def. endoderm",
#  . "Nascent mesoderm", "Spinal cord", "Pharyngeal mesoderm", "Blood progenitors 2",
#  . "NMP", "Primitive Streak", "Nascent mesoderm", "Mesenchyme",
#  . "Intermediate mesoderm", "ExE mesoderm", "Surface ectoderm",
#  . "Somitic mesoderm", "Mesenchyme", "Blood progenitors 2", "Rostral neurectoderm",
#  . "Pharyngeal mesoderm", "Forebrain/Midbrain/Hindbrain", "Nascent mesoderm",
#  . "Intermediate mesoderm", "Rostral neurectoderm", "Pharyngeal mesoderm",
#  . "Intermediate mesoderm", "Blood progenitors 1", "Forebrain/Midbrain/Hindbrain",
#  . "Pharyngeal mesoderm", "NMP", "Nascent mesoderm", "Mesenchyme",
#  . "Spinal cord", "Rostral neurectoderm", "Mesenchyme", "Haematoendothelial progenitors",
#  . "Blood progenitors 2", "Mesenchyme", "Haematoendothelial progenitors",
#  . "Blood progenitors 2", "Anterior Primitive Streak", "Surface ectoderm",
#  . "Rostral neurectoderm", "Nascent mesoderm", "NMP", "Anterior Primitive Streak",
#  . "NMP", "Rostral neurectoderm", "Forebrain/Midbrain/Hindbrain",
#  . "Caudal neurectoderm", "Mesenchyme", "Paraxial mesoderm", "Paraxial mesoderm",
#  . "Paraxial mesoderm", "Paraxial mesoderm", "Gut", "Forebrain/Midbrain/Hindbrain",
#  . "ExE mesoderm", "Mesenchyme", "Surface ectoderm", "NMP", "ExE mesoderm",
#  . "Mixed mesoderm", "Mesenchyme", "Rostral neurectoderm", "Intermediate mesoderm",
#  . "Surface ectoderm", "Rostral neurectoderm", "Caudal Mesoderm",
#  . "Caudal epiblast", "Paraxial mesoderm", "Surface ectoderm", "Blood progenitors 2",
#  . "Blood progenitors 2", "NMP", "Paraxial mesoderm", "ExE mesoderm",
#  . "Mesenchyme", "Blood progenitors 2", "Rostral neurectoderm",
#  . "Pharyngeal mesoderm", "Rostral neurectoderm", "Rostral neurectoderm",
#  . "Notochord", "Caudal Mesoderm", "Caudal Mesoderm", "Somitic mesoderm",
#  . "Caudal epiblast", "Paraxial mesoderm", "Blood progenitors 2",
#  . "Forebrain/Midbrain/Hindbrain", "Haematoendothelial progenitors",
#  . "Rostral neurectoderm", "Pharyngeal mesoderm", "Paraxial mesoderm",
#  . "Rostral neurectoderm", "Caudal epiblast", "Allantois", "Rostral neurectoderm",
#  . "Intermediate mesoderm", "Nascent mesoderm", "Blood progenitors 1",
#  . "ExE mesoderm", "Blood progenitors 1", "Neural crest", "Somitic mesoderm",
#  . "Rostral neurectoderm", "NMP", "Haematoendothelial progenitors",
#  . "Primitive Streak", "Caudal Mesoderm", "Paraxial mesoderm", "Pharyngeal mesoderm",
#  . "Somitic mesoderm", "Pharyngeal mesoderm", "NMP", "Haematoendothelial progenitors",
#  . "NMP", "Haematoendothelial progenitors", "Pharyngeal mesoderm",
#  . "Nascent mesoderm", "Blood progenitors 2", "Paraxial mesoderm",
#  . "ExE mesoderm", "Somitic mesoderm", "Mesenchyme", "Mesenchyme",
#  . "Mesenchyme", "Def. endoderm", "NMP", "Pharyngeal mesoderm",
#  . "ExE mesoderm", "Blood progenitors 2", "Rostral neurectoderm",
#  . "Surface ectoderm", "Forebrain/Midbrain/Hindbrain", "Blood progenitors 2",
#  . "Haematoendothelial progenitors", "Rostral neurectoderm", "Surface ectoderm",
#  . "Pharyngeal mesoderm", "NMP", "Pharyngeal mesoderm", "Rostral neurectoderm",
#  . "Gut", "Pharyngeal mesoderm", "Paraxial mesoderm", "Forebrain/Midbrain/Hindbrain",
#  . "ExE mesoderm", "Epiblast", "Nascent mesoderm", "Nascent mesoderm",
#  . "NMP", "NMP", "Intermediate mesoderm", "Notochord", "Paraxial mesoderm",
#  . "Blood progenitors 2", "ExE mesoderm", "Paraxial mesoderm", "ExE mesoderm",
#  . "Forebrain/Midbrain/Hindbrain", "NMP", "Surface ectoderm", "Paraxial mesoderm",
#  . "Allantois", "Spinal cord", "Rostral neurectoderm", "Paraxial mesoderm",
#  . "Nascent mesoderm", "Haematoendothelial progenitors", "Rostral neurectoderm",
#  . "Rostral neurectoderm", "Mesenchyme", "Intermediate mesoderm",
#  . "Blood progenitors 1", "Intermediate mesoderm", "Surface ectoderm",
#  . "Blood progenitors 2", "NMP", "Mesenchyme", "Caudal Mesoderm",
#  . "Rostral neurectoderm", "Blood progenitors 2", "Caudal epiblast",
#  . "Gut", "Haematoendothelial progenitors", "Surface ectoderm",
#  . "Rostral neurectoderm", "Forebrain/Midbrain/Hindbrain", "Surface ectoderm",
#  . "NMP", "Mesenchyme", "Mesenchyme", "Caudal epiblast", "Intermediate mesoderm",
#  . "Forebrain/Midbrain/Hindbrain", "ExE mesoderm", "Notochord",
#  . "NMP", "Forebrain/Midbrain/Hindbrain", "Intermediate mesoderm",
#  . "NMP", "ExE mesoderm", "Mesenchyme", "NMP", "Somitic mesoderm",
#  . "Somitic mesoderm", "Mesenchyme", "Forebrain/Midbrain/Hindbrain",
#  . "Mesenchyme", "ExE mesoderm", "Def. endoderm", "Surface ectoderm",
#  . "Pharyngeal mesoderm", "Haematoendothelial progenitors", "Mesenchyme",
#  . "Def. endoderm", "Mesenchyme", "Intermediate mesoderm", "Caudal Mesoderm",
#  . "ExE mesoderm", "Forebrain/Midbrain/Hindbrain", "Rostral neurectoderm",
#  . "Paraxial mesoderm", "Gut", "NMP", "Nascent mesoderm", "Mesenchyme",
#  . "Pharyngeal mesoderm", "Intermediate mesoderm", "Somitic mesoderm",
#  . "Rostral neurectoderm", "Blood progenitors 2", "Forebrain/Midbrain/Hindbrain",
#  . "NMP", "Gut", "Surface ectoderm", "Rostral neurectoderm", "Def. endoderm",
#  . "NMP", "Surface ectoderm", "Mesenchyme", "Paraxial mesoderm",
#  . "Paraxial mesoderm", "Caudal epiblast", "Forebrain/Midbrain/Hindbrain",
#  . "Nascent mesoderm", "Intermediate mesoderm", "Surface ectoderm",
#  . "Rostral neurectoderm", "Mixed mesoderm", "Gut", "Somitic mesoderm",
#  . "Forebrain/Midbrain/Hindbrain", "Nascent mesoderm", "Intermediate mesoderm",
#  . "Paraxial mesoderm", "Somitic mesoderm", "Def. endoderm", "Def. endoderm",
#  . "Haematoendothelial progenitors", "NMP", "Nascent mesoderm",
#  . "NMP", "Caudal neurectoderm", "Mesenchyme", "Surface ectoderm",
#  . "Pharyngeal mesoderm", "Rostral neurectoderm", "Nascent mesoderm",
#  . "Caudal Mesoderm", "Forebrain/Midbrain/Hindbrain", "Mesenchyme",
#  . "Intermediate mesoderm", "Intermediate mesoderm", "Blood progenitors 1",
#  . "Mesenchyme", "Mixed mesoderm", "ExE mesoderm", "Gut", "Rostral neurectoderm",
#  . "NMP", "ExE mesoderm", "Gut", "Surface ectoderm", "Cardiomyocytes",
#  . "Pharyngeal mesoderm", "Rostral neurectoderm", "NMP", "ExE mesoderm",
#  . "Forebrain/Midbrain/Hindbrain", "Mesenchyme", "Somitic mesoderm",
#  . "Rostral neurectoderm", "Surface ectoderm", "Spinal cord", "Rostral neurectoderm",
#  . "Surface ectoderm", "Spinal cord", "ExE mesoderm", "Nascent mesoderm",
#  . "Pharyngeal mesoderm", "Forebrain/Midbrain/Hindbrain", "Rostral neurectoderm",
#  . "Somitic mesoderm", "Nascent mesoderm", "Def. endoderm", "Paraxial mesoderm",
#  . "Forebrain/Midbrain/Hindbrain", "Somitic mesoderm", "Blood progenitors 2",
#  . "Mesenchyme", "Blood progenitors 2", "Nascent mesoderm", "Paraxial mesoderm",
#  . "Haematoendothelial progenitors", "Rostral neurectoderm", "Primitive Streak",
#  . "ExE mesoderm", "Somitic mesoderm", "Gut", "Spinal cord", "Rostral neurectoderm",
#  . "Haematoendothelial progenitors", "ExE mesoderm", "Epiblast",
#  . "Rostral neurectoderm", "Rostral neurectoderm", "Paraxial mesoderm",
#  . "Blood progenitors 2", "Caudal epiblast", "NMP", "Nascent mesoderm",
#  . "ExE mesoderm", "Gut", "Somitic mesoderm", "Forebrain/Midbrain/Hindbrain",
#  . "Blood progenitors 2", "Caudal Mesoderm", "Nascent mesoderm",
#  . "Neural crest", "ExE mesoderm", "Pharyngeal mesoderm", "Surface ectoderm",
#  . "Paraxial mesoderm", "Forebrain/Midbrain/Hindbrain", "Pharyngeal mesoderm",
#  . "Forebrain/Midbrain/Hindbrain", "Caudal Mesoderm", "Paraxial mesoderm",
#  . "Rostral neurectoderm", "Gut", "Blood progenitors 1", "Forebrain/Midbrain/Hindbrain",
#  . "Primitive Streak", "Forebrain/Midbrain/Hindbrain", "Mesenchyme",
#  . "Surface ectoderm", "NMP", "ExE mesoderm", "Mesenchyme", "Blood progenitors 2",
#  . "Gut", "Nascent mesoderm", "Mesenchyme", "Forebrain/Midbrain/Hindbrain",
#  . "NMP", "Erythroid1", "Gut", "Caudal Mesoderm", "Rostral neurectoderm",
#  . "Blood progenitors 2", "Notochord", "Blood progenitors 2", "Spinal cord",
#  . "NMP", "Blood progenitors 1", "Anterior Primitive Streak", "Mesenchyme",
#  . "Notochord", "Intermediate mesoderm", "Rostral neurectoderm",
#  . "NMP", "Rostral neurectoderm", "Surface ectoderm", "Blood progenitors 2",
#  . "Rostral neurectoderm", "Somitic mesoderm", "NMP", "Forebrain/Midbrain/Hindbrain",
#  . "Blood progenitors 1", "Mesenchyme", "Mixed mesoderm", "Pharyngeal mesoderm",
#  . "Surface ectoderm", "Gut", "Somitic mesoderm", "Forebrain/Midbrain/Hindbrain",
#  . "Caudal neurectoderm", "Haematoendothelial progenitors", "Paraxial mesoderm",
#  . "NMP", "Rostral neurectoderm", "Intermediate mesoderm", "Caudal epiblast",
#  . "Mesenchyme", "Nascent mesoderm", "Haematoendothelial progenitors",
#  . "Mesenchyme", "NMP", "NMP", "Mesenchyme", "Spinal cord", "Rostral neurectoderm",
#  . "Paraxial mesoderm", "Gut", "Epiblast", "Rostral neurectoderm",
#  . "Pharyngeal mesoderm", "Pharyngeal mesoderm", "Mesenchyme", "Forebrain/Midbrain/Hindbrain",
#  . "Surface ectoderm", "Rostral neurectoderm", "ExE mesoderm", "Mesenchyme",
#  . "Intermediate mesoderm", "Neural crest", "ExE ectoderm", "ExE mesoderm",
#  . "Spinal cord", "Gut", "Caudal Mesoderm", "Mesenchyme", "NMP",
#  . "NMP", "Caudal Mesoderm", "Rostral neurectoderm", "NMP", "Anterior Primitive Streak",
#  . "NMP", "ExE mesoderm", "Paraxial mesoderm", "ExE mesoderm", "ExE mesoderm",
#  . "Mesenchyme", "Notochord", "Haematoendothelial progenitors",
#  . "Paraxial mesoderm", "Nascent mesoderm", "Intermediate mesoderm",
#  . "Spinal cord", "NMP", "Blood progenitors 2", "Mesenchyme", "Gut",
#  . "ExE mesoderm", "Gut", "Rostral neurectoderm", "Forebrain/Midbrain/Hindbrain",
#  . "Haematoendothelial progenitors", "NMP", "Epiblast", "Haematoendothelial progenitors",
#  . "Forebrain/Midbrain/Hindbrain", "Allantois", "Rostral neurectoderm",
#  . "Spinal cord", "Mesenchyme", "Rostral neurectoderm", "NMP", "Gut",
#  . "Somitic mesoderm", "ExE mesoderm", "Paraxial mesoderm", "Mesenchyme",
#  . "Forebrain/Midbrain/Hindbrain", "Notochord", "Nascent mesoderm",
#  . "NMP", "Somitic mesoderm", "Mesenchyme", "Forebrain/Midbrain/Hindbrain",
#  . "Surface ectoderm", "Paraxial mesoderm", "NMP", "Allantois",
#  . "Mesenchyme", "Pharyngeal mesoderm", "Blood progenitors 2", "Blood progenitors 2",
#  . "Gut", "Rostral neurectoderm", "Haematoendothelial progenitors",
#  . "Caudal epiblast", "Blood progenitors 2", "Rostral neurectoderm",
#  . "Paraxial mesoderm", "Rostral neurectoderm", "Primitive Streak",
#  . "ExE mesoderm", "Rostral neurectoderm", "Forebrain/Midbrain/Hindbrain",
#  . "Mesenchyme", "Caudal Mesoderm", "Blood progenitors 1", "Rostral neurectoderm",
#  . "NMP", "Rostral neurectoderm", "Mesenchyme", "Intermediate mesoderm",
#  . "Rostral neurectoderm", "Blood progenitors 2", "Rostral neurectoderm",
#  . "NMP", "ExE mesoderm", "Mesenchyme", "Rostral neurectoderm",
#  . "Mesenchyme", "Caudal Mesoderm", "Paraxial mesoderm", "Mesenchyme",
#  . "Rostral neurectoderm", "Mixed mesoderm", "Forebrain/Midbrain/Hindbrain",
#  . "Erythroid1", "Haematoendothelial progenitors", "Mesenchyme",
#  . "ExE mesoderm", "Haematoendothelial progenitors", "NMP", "Rostral neurectoderm",
#  . "Caudal epiblast", "Blood progenitors 1", "ExE mesoderm", "NMP",
#  . "NMP", "Mesenchyme", "Anterior Primitive Streak", "Primitive Streak",
#  . "Pharyngeal mesoderm", "Rostral neurectoderm", "Notochord", "Mesenchyme",
#  . "Mesenchyme", "Pharyngeal mesoderm", "Gut", "Haematoendothelial progenitors",
#  . "Haematoendothelial progenitors", "Surface ectoderm", "ExE mesoderm",
#  . "Intermediate mesoderm", "Surface ectoderm", "Rostral neurectoderm",
#  . "Nascent mesoderm", "Surface ectoderm", "Forebrain/Midbrain/Hindbrain",
#  . "Blood progenitors 2", "Haematoendothelial progenitors", "Somitic mesoderm",
#  . "Paraxial mesoderm", "Blood progenitors 2", "Surface ectoderm",
#  . "Mesenchyme", "Caudal neurectoderm", "Notochord", "Paraxial mesoderm",
#  . "Blood progenitors 2", "Spinal cord", "Somitic mesoderm", "Nascent mesoderm",
#  . "Rostral neurectoderm", "Surface ectoderm", "Pharyngeal mesoderm",
#  . "Somitic mesoderm", "Rostral neurectoderm", "Neural crest", "ExE mesoderm",
#  . "Surface ectoderm", "Intermediate mesoderm", "Paraxial mesoderm",
#  . "Nascent mesoderm", "Pharyngeal mesoderm", "Forebrain/Midbrain/Hindbrain",
#  . "Rostral neurectoderm", "Blood progenitors 2", "Paraxial mesoderm",
#  . "Somitic mesoderm", "Intermediate mesoderm", "Caudal Mesoderm",
#  . "Intermediate mesoderm", "Forebrain/Midbrain/Hindbrain", "Nascent mesoderm",
#  . "Paraxial mesoderm", "ExE mesoderm", "Notochord", "NMP", "Surface ectoderm",
#  . "Rostral neurectoderm", "Surface ectoderm", "ExE mesoderm", "Blood progenitors 2",
#  . "ExE mesoderm", "ExE mesoderm", "Caudal neurectoderm", "ExE mesoderm",
#  . "Rostral neurectoderm", "Mesenchyme", "Def. endoderm", "Rostral neurectoderm",
#  . "Rostral neurectoderm", "ExE mesoderm", "Paraxial mesoderm",
#  . "Blood progenitors 2", "Forebrain/Midbrain/Hindbrain", "Spinal cord",
#  . "Forebrain/Midbrain/Hindbrain", "Intermediate mesoderm", "Surface ectoderm",
#  . "Haematoendothelial progenitors", "NMP", "Surface ectoderm",
#  . "Blood progenitors 2", "Caudal Mesoderm", "Surface ectoderm",
#  . "Gut", "Forebrain/Midbrain/Hindbrain", "Blood progenitors 2",
#  . "Paraxial mesoderm", "Paraxial mesoderm", "Mesenchyme", "Gut",
#  . "NMP", "Intermediate mesoderm", "Caudal Mesoderm", "Blood progenitors 2",
# ...
#  . "Paraxial mesoderm", "Paraxial mesoderm", "Spinal cord", "Paraxial mesoderm",
#  . "Somitic mesoderm", "Forebrain/Midbrain/Hindbrain", "Allantois",
#  . "Erythroid2", "Erythroid3", "Spinal cord", "ExE mesoderm", "Erythroid3",
#  . "ExE mesoderm", "Paraxial mesoderm", "Intermediate mesoderm",
#  . "Somitic mesoderm", "Neural crest", "Pharyngeal mesoderm", "Forebrain/Midbrain/Hindbrain",
#  . "Erythroid3", "Erythroid2", "Somitic mesoderm", "Erythroid3",
#  . "Mesenchyme", "Surface ectoderm", "Erythroid3", "Neural crest",
#  . "Forebrain/Midbrain/Hindbrain", "Paraxial mesoderm", "Haematoendothelial progenitors",
#  . "Forebrain/Midbrain/Hindbrain", "Mesenchyme", "Paraxial mesoderm",
#  . "Forebrain/Midbrain/Hindbrain", "Paraxial mesoderm", "Forebrain/Midbrain/Hindbrain",
#  . "NMP", "Surface ectoderm", "Surface ectoderm", "Erythroid3",
#  . "NMP", "Paraxial mesoderm", "Spinal cord", "Erythroid3", "Caudal Mesoderm",
#  . "NMP", "Erythroid3", "Forebrain/Midbrain/Hindbrain", "Erythroid3",
#  . "Erythroid3", "Forebrain/Midbrain/Hindbrain", "Forebrain/Midbrain/Hindbrain",
#  . "Spinal cord", "Erythroid3", "Endothelium", "Forebrain/Midbrain/Hindbrain",
#  . "Blood progenitors 2", "Paraxial mesoderm", "Intermediate mesoderm",
#  . "Erythroid2", "Neural crest", "Erythroid1", "Paraxial mesoderm",
#  . "Erythroid1", "Forebrain/Midbrain/Hindbrain", "Erythroid2", "Forebrain/Midbrain/Hindbrain",
#  . "Forebrain/Midbrain/Hindbrain", "Paraxial mesoderm", "Surface ectoderm",
#  . "Surface ectoderm", "Haematoendothelial progenitors", "Forebrain/Midbrain/Hindbrain",
#  . "Intermediate mesoderm", "Spinal cord", "Erythroid3", "Forebrain/Midbrain/Hindbrain",
#  . "Erythroid3", "Mesenchyme", "Forebrain/Midbrain/Hindbrain", "Cardiomyocytes",
#  . "Forebrain/Midbrain/Hindbrain", "Erythroid2", "Surface ectoderm",
#  . "Surface ectoderm", "Forebrain/Midbrain/Hindbrain", "Erythroid3",
#  . "Spinal cord", "Spinal cord", "Erythroid3", "Haematoendothelial progenitors",
#  . "Erythroid3", "Blood progenitors 1", "Endothelium", "Spinal cord",
#  . "NMP", "Paraxial mesoderm", "Erythroid2", "Erythroid3", "Forebrain/Midbrain/Hindbrain",
#  . "Pharyngeal mesoderm", "NMP", "Erythroid2", "Forebrain/Midbrain/Hindbrain",
#  . "Endothelium", "Blood progenitors 1", "Erythroid2", "ExE endoderm",
#  . "ExE ectoderm", "Spinal cord", "Spinal cord", "NMP", "Forebrain/Midbrain/Hindbrain",
#  . "Paraxial mesoderm", "Erythroid3", "Forebrain/Midbrain/Hindbrain",
#  . "Surface ectoderm", "Forebrain/Midbrain/Hindbrain", "Mesenchyme",
#  . "Erythroid1", "Neural crest", "Forebrain/Midbrain/Hindbrain",
#  . "Erythroid3", "Erythroid3", "ExE mesoderm", "Erythroid3", "Gut",
#  . "Forebrain/Midbrain/Hindbrain", "Erythroid3", "Forebrain/Midbrain/Hindbrain",
#  . "Mesenchyme", "Cardiomyocytes", "Erythroid2", "Forebrain/Midbrain/Hindbrain",
#  . "Spinal cord", "Surface ectoderm", "Erythroid1", "Caudal epiblast",
#  . "Erythroid3", "Spinal cord", "Paraxial mesoderm", "Gut", "Spinal cord",
#  . "Allantois", "Erythroid3", "ExE mesoderm", "Erythroid3", "Erythroid3",
#  . "ExE mesoderm", "Intermediate mesoderm", "Forebrain/Midbrain/Hindbrain",
#  . "Forebrain/Midbrain/Hindbrain", "ExE endoderm", "Forebrain/Midbrain/Hindbrain",
#  . "Cardiomyocytes", "Erythroid3", "Erythroid3", "Endothelium",
#  . "Erythroid3", "Gut", "Intermediate mesoderm", "ExE mesoderm",
#  . "Pharyngeal mesoderm", "Erythroid3", "Paraxial mesoderm", "Paraxial mesoderm",
#  . "Pharyngeal mesoderm", "Forebrain/Midbrain/Hindbrain", "Erythroid3",
#  . "Erythroid3", "ExE mesoderm", "Surface ectoderm", "Forebrain/Midbrain/Hindbrain",
#  . "Mesenchyme", "Spinal cord", "Forebrain/Midbrain/Hindbrain",
#  . "NMP", "Erythroid3", "ExE ectoderm", "Forebrain/Midbrain/Hindbrain",
#  . "Mesenchyme", "Spinal cord", "NMP", "ExE mesoderm", "Erythroid3",
#  . "Forebrain/Midbrain/Hindbrain", "Mesenchyme", "Forebrain/Midbrain/Hindbrain",
#  . "Erythroid3", "Spinal cord", "Forebrain/Midbrain/Hindbrain",
#  . "Paraxial mesoderm", "Gut", "Paraxial mesoderm", "ExE mesoderm",
#  . "Spinal cord", "Erythroid3", "Erythroid3", "Erythroid1", "NMP",
#  . "Mesenchyme", "Gut", "Forebrain/Midbrain/Hindbrain", "Mesenchyme",
#  . "ExE mesoderm", "Forebrain/Midbrain/Hindbrain", "Forebrain/Midbrain/Hindbrain",
#  . "Forebrain/Midbrain/Hindbrain", "Spinal cord", "Erythroid3",
#  . "Forebrain/Midbrain/Hindbrain", "Forebrain/Midbrain/Hindbrain",
#  . "Mesenchyme", "Paraxial mesoderm", "Erythroid3", "Erythroid3",
#  . "Gut", "Rostral neurectoderm", "Surface ectoderm", "Forebrain/Midbrain/Hindbrain",
#  . "NMP", "Erythroid3", "Forebrain/Midbrain/Hindbrain", "Neural crest",
#  . "Mesenchyme", "Paraxial mesoderm", "Forebrain/Midbrain/Hindbrain",
#  . "Caudal Mesoderm", "Surface ectoderm", "Neural crest", "Erythroid2",
#  . "NMP", "Erythroid3", "Pharyngeal mesoderm", "ExE mesoderm", "Paraxial mesoderm",
#  . "Paraxial mesoderm", "NMP", "Neural crest", "Erythroid2", "Spinal cord",
#  . "Mesenchyme", "Spinal cord", "Surface ectoderm", "Gut", "Blood progenitors 1",
#  . "Paraxial mesoderm", "Erythroid3", "Cardiomyocytes", "Somitic mesoderm",
#  . "Endothelium", "Neural crest", "Erythroid3", "Pharyngeal mesoderm",
#  . "Surface ectoderm", "Mesenchyme", "Spinal cord", "Erythroid2",
#  . "Erythroid3", "ExE mesoderm", "Forebrain/Midbrain/Hindbrain",
#  . "Intermediate mesoderm", "NMP", "Spinal cord", "Forebrain/Midbrain/Hindbrain",
#  . "Mesenchyme", "Erythroid3", "Forebrain/Midbrain/Hindbrain", "Gut",
#  . "ExE ectoderm", "Spinal cord", "Erythroid3", "Forebrain/Midbrain/Hindbrain",
#  . "Neural crest", "Forebrain/Midbrain/Hindbrain", "Paraxial mesoderm",
#  . "Mesenchyme", "Surface ectoderm", "Forebrain/Midbrain/Hindbrain",
#  . "Forebrain/Midbrain/Hindbrain", "Intermediate mesoderm", "Gut",
#  . "Gut", "Somitic mesoderm", "Spinal cord", "Endothelium", "Somitic mesoderm",
#  . "NMP", "Forebrain/Midbrain/Hindbrain", "Spinal cord", "Erythroid1",
#  . "Neural crest", "Blood progenitors 2", "Forebrain/Midbrain/Hindbrain",
#  . "Forebrain/Midbrain/Hindbrain", "Paraxial mesoderm", "Paraxial mesoderm",
#  . "Gut", "Somitic mesoderm", "Forebrain/Midbrain/Hindbrain", "Erythroid3",
#  . "NMP", "Cardiomyocytes", "Forebrain/Midbrain/Hindbrain", "Endothelium",
#  . "NMP", "Intermediate mesoderm", "Erythroid3", "NMP", "Paraxial mesoderm",
#  . "Forebrain/Midbrain/Hindbrain", "Paraxial mesoderm", "Spinal cord",
#  . "NMP", "Cardiomyocytes", "Paraxial mesoderm", "Forebrain/Midbrain/Hindbrain",
#  . "Mesenchyme", "Forebrain/Midbrain/Hindbrain", "Erythroid3", "NMP",
#  . "Surface ectoderm", "Erythroid2", "Erythroid3", "Spinal cord",
#  . "ExE endoderm", "Spinal cord", "Erythroid2", "ExE mesoderm",
#  . "Intermediate mesoderm", "Intermediate mesoderm", "Forebrain/Midbrain/Hindbrain",
#  . "Erythroid3", "Erythroid3", "Erythroid1", "NMP", "Mesenchyme",
#  . "Erythroid3", "Erythroid3", "Mesenchyme", "Forebrain/Midbrain/Hindbrain",
#  . "Mesenchyme", "Erythroid3", "Paraxial mesoderm", "Forebrain/Midbrain/Hindbrain",
#  . "Mesenchyme", "Cardiomyocytes", "Gut", "Spinal cord", "ExE endoderm",
#  . "NMP", "Forebrain/Midbrain/Hindbrain", "Erythroid3", "Blood progenitors 1",
#  . "Mesenchyme", "Intermediate mesoderm", "NMP", "Mesenchyme", "Haematoendothelial progenitors",
#  . "Spinal cord", "Gut", "Spinal cord", "Endothelium", "Spinal cord",
#  . "Paraxial mesoderm", "Allantois", "Paraxial mesoderm", "Somitic mesoderm",
#  . "ExE mesoderm", "Forebrain/Midbrain/Hindbrain", "Spinal cord",
#  . "Blood progenitors 2", "ExE mesoderm", "Mesenchyme", "Spinal cord",
#  . "Parietal endoderm", "Surface ectoderm", "Erythroid3", "Erythroid3",
#  . "Blood progenitors 2", "Pharyngeal mesoderm", "Cardiomyocytes",
#  . "Erythroid3", "Forebrain/Midbrain/Hindbrain", "Erythroid2", "Mesenchyme",
#  . "Gut", "Erythroid3", "Mesenchyme", "Gut", "Somitic mesoderm",
#  . "Erythroid3", "Intermediate mesoderm", "Gut", "ExE mesoderm",
#  . "Forebrain/Midbrain/Hindbrain", "Erythroid3", "Erythroid2", "Paraxial mesoderm",
#  . "Erythroid3", "Forebrain/Midbrain/Hindbrain", "Mesenchyme", "Def. endoderm",
#  . "Neural crest", "Mesenchyme", "Spinal cord", "Forebrain/Midbrain/Hindbrain",
#  . "Endothelium", "Pharyngeal mesoderm", "Erythroid3", "Erythroid2",
#  . "Forebrain/Midbrain/Hindbrain", "Paraxial mesoderm", "Erythroid3",
#  . "Gut", "Forebrain/Midbrain/Hindbrain", "Neural crest", "Erythroid1",
#  . "Erythroid2", "Surface ectoderm", "Surface ectoderm", "Forebrain/Midbrain/Hindbrain",
#  . "Gut", "NMP", "Spinal cord", "Erythroid3", "Spinal cord", "Forebrain/Midbrain/Hindbrain",
#  . "Neural crest", "Erythroid3", "Forebrain/Midbrain/Hindbrain",
#  . "Spinal cord", "Gut", "Forebrain/Midbrain/Hindbrain", "Neural crest",
#  . "Erythroid1", "Paraxial mesoderm", "Forebrain/Midbrain/Hindbrain",
#  . "Forebrain/Midbrain/Hindbrain", "Erythroid2", "Forebrain/Midbrain/Hindbrain",
#  . "Spinal cord", "NMP", "Erythroid3", "Forebrain/Midbrain/Hindbrain",
#  . "Spinal cord", "Paraxial mesoderm", "Mesenchyme", "Endothelium",
#  . "Gut", "Forebrain/Midbrain/Hindbrain", "Forebrain/Midbrain/Hindbrain",
#  . "Somitic mesoderm", "Paraxial mesoderm", "Erythroid2", "Pharyngeal mesoderm",
#  . "NMP", "Forebrain/Midbrain/Hindbrain", "ExE mesoderm", "Erythroid3",
#  . "Neural crest", "NMP", "Erythroid3", "NMP", "Endothelium", "NMP",
#  . "ExE mesoderm", "Cardiomyocytes", "Forebrain/Midbrain/Hindbrain",
#  . "Paraxial mesoderm", "Neural crest", "ExE mesoderm", "Mesenchyme",
#  . "NMP", "Haematoendothelial progenitors", "Paraxial mesoderm",
#  . "Forebrain/Midbrain/Hindbrain", "Forebrain/Midbrain/Hindbrain",
#  . "Erythroid3", "Forebrain/Midbrain/Hindbrain", "Surface ectoderm",
#  . "Erythroid2", "Forebrain/Midbrain/Hindbrain", "NMP", "Mesenchyme",
#  . "Pharyngeal mesoderm", "Erythroid1", "NMP", "Forebrain/Midbrain/Hindbrain",
#  . "Paraxial mesoderm", "Pharyngeal mesoderm", "Intermediate mesoderm",
#  . "Gut", "Erythroid1", "Cardiomyocytes", "Forebrain/Midbrain/Hindbrain",
#  . "Paraxial mesoderm", "Forebrain/Midbrain/Hindbrain", "Gut", "Pharyngeal mesoderm",
#  . "ExE mesoderm", "Cardiomyocytes", "Somitic mesoderm", "Pharyngeal mesoderm",
#  . "Spinal cord", "Surface ectoderm", "Forebrain/Midbrain/Hindbrain",
#  . "Somitic mesoderm", "Paraxial mesoderm", "Forebrain/Midbrain/Hindbrain",
#  . "Erythroid1", "Def. endoderm", "Paraxial mesoderm", "ExE endoderm",
#  . "Pharyngeal mesoderm", "Gut", "Endothelium", "Forebrain/Midbrain/Hindbrain",
#  . "Erythroid1", "Erythroid3", "Paraxial mesoderm", "Erythroid3",
#  . "Erythroid3", "Erythroid3", "Erythroid2", "Cardiomyocytes", "Blood progenitors 2",
#  . "Forebrain/Midbrain/Hindbrain", "Erythroid2", "NMP", "Forebrain/Midbrain/Hindbrain",
#  . "Paraxial mesoderm", "NMP", "Gut", "ExE mesoderm", "Erythroid3",
#  . "Mesenchyme", "NMP", "Erythroid3", "Forebrain/Midbrain/Hindbrain",
#  . "Mesenchyme", "Paraxial mesoderm", "NMP", "Erythroid3", "Somitic mesoderm",
#  . "Forebrain/Midbrain/Hindbrain", "Blood progenitors 2", "Erythroid2",
#  . "Gut", "Cardiomyocytes", "Pharyngeal mesoderm", "Pharyngeal mesoderm",
#  . "Forebrain/Midbrain/Hindbrain", "Erythroid3", "Erythroid3", "Erythroid2",
#  . "Spinal cord", "Forebrain/Midbrain/Hindbrain", "Erythroid2",
#  . "Neural crest", "Erythroid3", "NMP", "Forebrain/Midbrain/Hindbrain",
#  . "Forebrain/Midbrain/Hindbrain", "Spinal cord", "Intermediate mesoderm",
#  . "Gut", "Rostral neurectoderm", "Pharyngeal mesoderm", "Erythroid1",
#  . "Erythroid3", "Paraxial mesoderm", "Gut", "Paraxial mesoderm",
#  . "Haematoendothelial progenitors", "NMP", "Forebrain/Midbrain/Hindbrain",
#  . "Erythroid1", "Erythroid3", "Erythroid3", "Caudal Mesoderm",
#  . "Forebrain/Midbrain/Hindbrain", "Somitic mesoderm", "Forebrain/Midbrain/Hindbrain",
#  . "Cardiomyocytes", "Allantois", "Somitic mesoderm", "Erythroid3",
#  . "Surface ectoderm", "ExE mesoderm", "Forebrain/Midbrain/Hindbrain",
#  . "Mesenchyme", "Forebrain/Midbrain/Hindbrain", "ExE mesoderm",
#  . "Surface ectoderm", "Surface ectoderm", "Pharyngeal mesoderm",
#  . "Paraxial mesoderm", "Forebrain/Midbrain/Hindbrain", "Forebrain/Midbrain/Hindbrain",
#  . "Neural crest", "Surface ectoderm", "Forebrain/Midbrain/Hindbrain",
#  . "Spinal cord", "Somitic mesoderm", "Forebrain/Midbrain/Hindbrain",
#  . "Erythroid1", "Pharyngeal mesoderm", "Mesenchyme", "Erythroid2",
#  . "ExE mesoderm", "NMP", "Erythroid2", "Forebrain/Midbrain/Hindbrain",
#  . "Erythroid2", "ExE mesoderm", "Paraxial mesoderm", "Paraxial mesoderm",
#  . "NMP", "Paraxial mesoderm", "NMP", "Endothelium", "NMP", "Endothelium",
#  . "Surface ectoderm", "Gut", "Surface ectoderm", "NMP", "Pharyngeal mesoderm",
#  . "ExE mesoderm", "Pharyngeal mesoderm", "Erythroid2", "ExE mesoderm",
#  . "Somitic mesoderm", "Erythroid3", "Erythroid2", "Paraxial mesoderm",
#  . "Neural crest", "Surface ectoderm", "Forebrain/Midbrain/Hindbrain",
#  . "ExE mesoderm", "Erythroid2", "Paraxial mesoderm", "Erythroid2",
#  . "Caudal Mesoderm", "Mesenchyme", "Erythroid3", "Forebrain/Midbrain/Hindbrain",
#  . "Erythroid2", "Erythroid3", "Paraxial mesoderm", "NMP", "Paraxial mesoderm",
#  . "NMP", "ExE mesoderm", "Spinal cord", "Gut", "Erythroid3", "Allantois",
#  . "Surface ectoderm", "Erythroid2", "Forebrain/Midbrain/Hindbrain",
#  . "Forebrain/Midbrain/Hindbrain", "Allantois", "Somitic mesoderm",
#  . "Forebrain/Midbrain/Hindbrain", "Spinal cord", "Erythroid3",
#  . "Allantois", "Erythroid3", "Def. endoderm", "Caudal Mesoderm",
#  . "NMP", "Erythroid3", "Mesenchyme", "Neural crest", "Forebrain/Midbrain/Hindbrain",
#  . "NMP", "Paraxial mesoderm", "Neural crest", "Forebrain/Midbrain/Hindbrain",
#  . "Forebrain/Midbrain/Hindbrain", "Erythroid3", "Pharyngeal mesoderm",
#  . "Erythroid2", "Neural crest", "Forebrain/Midbrain/Hindbrain",
#  . "NMP", "Paraxial mesoderm", "Somitic mesoderm", "Somitic mesoderm",
#  . "Erythroid3", "Gut", "Spinal cord", "Paraxial mesoderm", "Somitic mesoderm",
#  . "Pharyngeal mesoderm", "Paraxial mesoderm", "Spinal cord", "Erythroid3",
#  . "Intermediate mesoderm", "Neural crest", "ExE ectoderm", "Neural crest",
#  . "Erythroid3", "Surface ectoderm", "Erythroid2", "Gut", "Spinal cord",
#  . "Erythroid2", "ExE mesoderm", "Rostral neurectoderm", "NMP",
#  . "Erythroid3", "Pharyngeal mesoderm", "Haematoendothelial progenitors",
#  . "Spinal cord", "Spinal cord", "Rostral neurectoderm", "Somitic mesoderm",
#  . "Cardiomyocytes", "Intermediate mesoderm", "Gut", "Forebrain/Midbrain/Hindbrain",
#  . "Surface ectoderm", "Gut", "ExE mesoderm", "Surface ectoderm",
#  . "Forebrain/Midbrain/Hindbrain", "Erythroid3", "Paraxial mesoderm",
#  . "Erythroid3", "Erythroid3", "Visceral endoderm", "Paraxial mesoderm",
#  . "Cardiomyocytes", "Erythroid2", "ExE mesoderm", "Erythroid3",
#  . "Spinal cord", "Erythroid3", "Surface ectoderm", "Paraxial mesoderm",
#  . "Gut", "Erythroid3", "Gut", "Paraxial mesoderm", "Erythroid2",
#  . "Surface ectoderm", "Forebrain/Midbrain/Hindbrain", "Forebrain/Midbrain/Hindbrain",
#  . "Erythroid3", "Spinal cord", "Intermediate mesoderm", "Erythroid3",
#  . "Forebrain/Midbrain/Hindbrain", "NMP", "Endothelium", "Spinal cord",
#  . "Intermediate mesoderm", "Erythroid3", "Surface ectoderm", "Paraxial mesoderm",
#  . "NMP", "Endothelium", "Spinal cord", "Gut", "Erythroid1", "Mesenchyme",
#  . "Forebrain/Midbrain/Hindbrain", "Erythroid1", "Neural crest",
#  . "Forebrain/Midbrain/Hindbrain", "Spinal cord", "Forebrain/Midbrain/Hindbrain",
#  . "Somitic mesoderm", "Erythroid2", "Intermediate mesoderm", "Blood progenitors 1",
#  . "Mesenchyme", "Forebrain/Midbrain/Hindbrain", "Erythroid3", "Somitic mesoderm",
#  . "Spinal cord", "Surface ectoderm", "Paraxial mesoderm", "ExE mesoderm",
#  . "Pharyngeal mesoderm", "Pharyngeal mesoderm", "Paraxial mesoderm",
#  . "Gut", "Spinal cord", "Forebrain/Midbrain/Hindbrain", "Erythroid3",
#  . "NMP", "Paraxial mesoderm", "NMP", "Erythroid3", "Surface ectoderm",
#  . "Erythroid3", "Erythroid3", "Endothelium", "Erythroid3", "Forebrain/Midbrain/Hindbrain",
#  . "Paraxial mesoderm", "Allantois", "Rostral neurectoderm", "Erythroid3",
#  . "Erythroid3", "Erythroid2", "Spinal cord"))
# 3. stop(sprintf(ngettext(N, "replacement has %d row, data has %d",
#  .     "replacement has %d rows, data has %d"), N, nrows), domain = NA)

# %%
unique(test$celltype)
# Out:
# [1] NA

# %%
test <- big_meta[!is.na(big_meta$haem_subclust),]
unique(test$haem_subclust)
unique(test$celltype)
# Out:
#  [1] "ExE ectoderm"                   "Haematoendothelial progenitors"
#  [3] "Surface ectoderm"               "Intermediate mesoderm"
#  [5] "Rostral neurectoderm"           "Mesenchyme"
#  [7] "Nascent mesoderm"               "Def. endoderm"
#  [9] "Visceral endoderm"              "ExE endoderm"
# [11] "Blood progenitors 1"            "ExE mesoderm"
# [13] "Primitive Streak"               "Notochord"
# [15] "Forebrain/Midbrain/Hindbrain"   "Anterior Primitive Streak"
# [17] "Epiblast"                       "Parietal endoderm"
# [19] "Blood progenitors 2"            "Mixed mesoderm"
# [21] "Pharyngeal mesoderm"            "Gut"
# [23] "Caudal epiblast"                "PGC"
# [25] "Caudal Mesoderm"                "Caudal neurectoderm"
# [27] "Somitic mesoderm"               "Paraxial mesoderm"
# [29] "Allantois"                      "Erythroid1"
# [31] "Cardiomyocytes"                 "Erythroid2"
# [33] "Spinal cord"                    "NMP"
# [35] "Endothelium"                    "Erythroid3"
# [37] "Neural crest"
# [1] NA

# %% [markdown]
# #### Quality filter cells & retain only haem

# %%
# extract cells to keep
haem_lineages = c('Erythroid3','Haematoendothelial progenitors','Erythroid2','Endothelium','Blood progenitors 2','Erythroid1','Blood progenitors 1')
keep <- big_meta %>% filter(stripped == FALSE & doublet == FALSE & celltype.mapped %in% haem_lineages | celltype.mapped %in% haem_lineages) %>% .$cell
# keep only those cells in big_sce
big_sce <- big_sce[, keep]
# save big_sce
saveRDS(big_sce, file = paste0(out_folder,"big_sce.rds"))

# %%
# clean meta
big_meta <- big_meta %>% filter(stripped == FALSE & doublet == FALSE & celltype %in% haem_lineages | celltype.mapped %in% haem_lineages)
# save meta after cleaning
write.table(big_meta, file = paste0(out_folder,"big_meta.tab"), row.names = F, col.names = T, quote = F, sep = "\t")

# %%
# confirm SCE and metadata still overlap
summary(big_meta$cell == colnames(big_sce))
# Out:
#    Mode    TRUE
# logical   19663

# %% [markdown]
# #### Normalize

# %%
# calculate sizefactors
clusts = as.numeric(quickCluster(big_sce, method = "igraph", min.size = 100, BPPARAM = mcparam))
min.clust = min(table(clusts))/2
new_sizes = c(floor(min.clust/3), floor(min.clust/2), floor(min.clust))
big_sce = computeSumFactors(big_sce, clusters = clusts, sizes = new_sizes, max.cluster.size = 3000)
write.table(sizeFactors(big_sce), quote = F, col.names = F, row.names = F, file = paste0(out_folder,"sizefactors_big.tab"))

# %%
lib.sizes = Matrix::colSums(counts(big_sce))
ggplot(data = data.frame(X = lib.sizes, Y = sizeFactors(big_sce)),
              mapping = aes(x = X, y = Y)) +
  geom_point() +
  scale_x_log10(breaks = c(5000, 10000, 50000, 100000), labels = c("5,000", "10,000", "50,000", "100,000") ) +
  scale_y_log10(breaks = c(0.2, 1, 5)) +
  labs(x = "Number of UMIs", y = "Size Factor") + 
    theme_classic()
# Out:
# plot without title

# %%
# Normalize
sfs = read.table(paste0(out_folder,"sizefactors_big.tab"), stringsAsFactors = F)[,1]
sizeFactors(big_sce) = sfs
big_sce = scater::logNormCounts(big_sce)

# %%
# save normalized sce
saveRDS(big_sce, file = paste0(out_folder,"big_sce_norm.rds"))

# %% [markdown]
# #### HVGs

# %%
big_sce <- readRDS(paste0(out_folder, "big_sce_norm.rds"))

# %%
# ygenes
ygenes_in = "/rds/project/bg200/rds-bg200-hphi-gottgens/users/bt392/mouse/Mixl1_KO/data/ygenes.tab"

# %%
# load genes
ychr_e = read.table(ygenes_in, stringsAsFactors = F)[,1]
genes_meta = read.table(paste0(in_folder,"big_genes.tab"), stringsAsFactors = F)
rownames(genes_meta) = genes_meta$V1

# filter sex genes (Xist + ygenes)
paste0('genes before filtering: ', length(rownames(big_sce)))
big_sce   <- big_sce[!rownames(big_sce) %in% c('ENSMUSG00000086503', ychr_e),]
paste0('genes after filtering: ', length(rownames(big_sce)))
# Out:
# [1] "genes before filtering: 31217"
# [1] "genes after filtering: 30483"

# %%
p.val_th = 0.05 # p-value threshold

# determine top HVGs
dec <- modelGeneVar(big_sce)
hvg_p <- getTopHVGs(dec, fdr.threshold = p.val_th)
paste0('number of HVGs based on P value: ', length(hvg_p))
hvg_n <- getTopHVGs(dec, n = 3000)

# save
write.csv(hvg_p, file =  paste0(out_folder,"big_hvgs_p.csv"))
write.csv(hvg_n, file =  paste0(out_folder,"big_hvgs_3000.csv"))
# Out:
# [1] "number of HVGs based on P value: 286"

# %% [markdown]
# #### Batch correction

# %%
BPPARAM = SerialParam()

# I/O
big_sce <- readRDS(paste0(out_folder, "big_sce_norm.rds"))
big_meta = read.table(paste0(out_folder,"big_meta.tab"), header = TRUE, sep = "\t", stringsAsFactors = FALSE, comment.char = "$")
hvgs = read.csv(paste0(out_folder,"big_hvgs_3000.csv"))$x

# %%
#### Cosine normalisation ##### 
# add metadata combining stage & sample
big_meta$comb <- paste0(big_meta$stage, "_", big_meta$sample)

# extract counts for each combination
mat_temp = logcounts(big_sce)
mat = mat_temp[hvgs,]

# seperate count matrices based on combination
comb <- list()
for(i in unique(big_meta$comb)){
    comb[[i]] <- mat[, big_meta$comb == i]
}
paste0('nr of combinations: ', length(comb))

# cosine normalize
comb_cos <- list()
for(i in 1:length(comb)){
    comb_cos[[i]] <- cosineNorm(comb[[i]])
}
# Out:
# [1] "nr of combinations: 39"

# %%
######## from here on everything takes a while so may be better to run in Rscript rather than notebook
#### calculate PCs #####
big_pca = multiBatchPCA(comb_cos ,BPPARAM = BPPARAM,d = 50)

# %%
saveRDS(big_pca, file=paste0(out_folder, 'uncorrected_PCs_multibatch.rds'))
big_pca <- do.call(rbind, big_pca)
saveRDS(big_pca, file=paste0(out_folder, 'uncorrected_PCs.rds'))

# %% [markdown]
# ### pay attention from here!!

# %%
big_pca <- readRDS(paste0(out_folder, 'uncorrected_PCs.rds'))
big_meta = read.table(paste0(out_folder,"big_meta.tab"), header = TRUE, sep = "\t", stringsAsFactors = FALSE, comment.char = "$")

# %%
# give chimaera different stage value to make batch correction easier
big_meta$origin <- sapply(strsplit(big_meta$cell,"_"), `[`, 1)
big_meta$stage[which(big_meta$origin == "chim")] <- 'E8.5_chim'

# %%
#### reducedMNN preparation ##### (run in next cell)
set.seed(42)
# over several iterations 

# order of batch corrections --> input chimaera as seperate timepoint to make looping easier
#### This way chimaera's will still be batch corrected separately from atlas.
order_df = big_meta[!duplicated(big_meta$sample), c("stage", "sample")]
order_df$ncells = sapply(order_df$sample, function(x) sum(big_meta$sample == x))
order_df$stage = factor(order_df$stage,
                          levels = rev(c("E8.5",  ##### this may not work this time since we have every timepoint --> remove those with no samples in them
                                         "E8.25", 
                                         "E8.0", 
                                         "E7.75", 
                                         "E7.5", 
                                         "E7.25", 
                                         "mixed_gastrulation", 
                                         "E7.0", 
                                         "E6.75", 
                                         "E6.5",
                                         "E8.5_chim"))) # Chimaera last!
order_df = order_df[order(order_df$stage, order_df$ncells, decreasing = TRUE),]
order_df$stage = as.character(order_df$stage)
order_df$comb <- paste0(order_df$stage, "_", order_df$sample)

# defenitions for creating nested lists                         
timepoints = big_meta$stage
samples = big_meta$sample
timepoint_order = order_df$stage
sample_order = order_df$sample

#create nested list
  pc_list = lapply(unique(timepoints), function(tp){
    sub_pc = big_pca[timepoints == tp, , drop = FALSE]
    sub_samp = samples[timepoints == tp]
    list = lapply(unique(sub_samp), function(samp){
     sub_pc[sub_samp == samp, , drop = FALSE]
    })
    names(list) = unique(sub_samp)
    return(list)
  })

  names(pc_list) = unique(timepoints)

  #arrange to match timepoint order
  pc_list = pc_list[order(match(names(pc_list), timepoint_order))]
  pc_list = lapply(pc_list, function(x){
    x[order(match(names(x), sample_order))]
  })

# create if statement for following numbers in next cell:
print('create if statement for following values: ')
    for(i in 1:length(pc_list)){
    print(length(pc_list[[i]]))
}
# Out:
# [1] "create if statement for following values: "
# [1] 4
# [1] 3
# [1] 4
# [1] 4
# [1] 6
# [1] 3
# [1] 2
# [1] 6
# [1] 1
# [1] 6

# %%
# reducedMNN within timepoints
# reducedMNN is too stupid to understand looping over list so each list element has to be inputted as seperate object
# done with if statement so you don't have to write a seperate line for each nested list
corrected_pcs <- list()
for(i in 1:length(pc_list)){
    if(length(pc_list[[i]]) == 1){
        corrected_pcs[[i]] <- unlist(pc_list[[i]][[1]])
    }
    if(length(pc_list[[i]]) == 2){
        corrected_pcs[[i]] <- reducedMNN(pc_list[[i]][[1]], pc_list[[i]][[2]], BPPARAM = SerialParam())$corrected
    }
    if(length(pc_list[[i]]) == 3){
        corrected_pcs[[i]] <- reducedMNN(pc_list[[i]][[1]], pc_list[[i]][[2]], pc_list[[i]][[3]],BPPARAM = SerialParam())$corrected
    }
    if(length(pc_list[[i]]) == 4){
        corrected_pcs[[i]] <- reducedMNN(pc_list[[i]][[1]], pc_list[[i]][[2]], pc_list[[i]][[3]],pc_list[[i]][[4]],BPPARAM = SerialParam())$corrected
    }
    if(length(pc_list[[i]]) == 5){
        corrected_pcs[[i]] <- reducedMNN(pc_list[[i]][[1]], pc_list[[i]][[2]], pc_list[[i]][[3]],pc_list[[i]][[4]], pc_list[[i]][[5]],BPPARAM = SerialParam())$corrected
    }
    if(length(pc_list[[i]]) == 6){
        corrected_pcs[[i]] <- reducedMNN(pc_list[[i]][[1]], pc_list[[i]][[2]], pc_list[[i]][[3]],pc_list[[i]][[4]], pc_list[[i]][[5]], pc_list[[i]][[6]],BPPARAM = SerialParam())$corrected
    }
    if(length(pc_list[[i]]) == 10){
        corrected_pcs[[i]] <- reducedMNN(pc_list[[i]][[1]], pc_list[[i]][[2]], pc_list[[i]][[3]],pc_list[[i]][[4]], pc_list[[i]][[5]], pc_list[[i]][[6]],pc_list[[i]][[7]], pc_list[[i]][[8]], pc_list[[i]][[9]],pc_list[[i]][[10]],BPPARAM = SerialParam())$corrected
    }
}

saveRDS(corrected_pcs, file=paste0(out_folder, 'corrected_PCs_time_multibatch.rds'))
temp = do.call(rbind, corrected_pcs)
write.csv(temp, paste0(out_folder, 'corrected_pc_time.csv'))
# Out:
# Warning message in .refine_k(k, precomputed, query = TRUE):
# “'k' capped at the number of observations”
# Warning message in .refine_k(k, precomputed, query = TRUE):
# “'k' capped at the number of observations”
# Warning message in .refine_k(k, precomputed, query = TRUE):
# “'k' capped at the number of observations”

# %%
nrow(temp) == nrow(big_meta) # sanity check if we still have the same amount of cells
# Out:
# [1] TRUE

# %%
#### Check which element in pc_list is chimaera!!
# all before that should be merged with atlas
head(pc_list[[10]][[1]])
# Out:
#              [,1]       [,2]        [,3]         [,4]        [,5]
# chim_cell_2  -0.3678663 -0.12831515 -0.019755588 -0.02072619 -0.041407856
# chim_cell_8  -0.3636280 -0.12120548 -0.020883800 -0.02114076 -0.050885405
# chim_cell_10 -0.3430219 -0.10897326 -0.019798051 -0.01044511 -0.021069446
# chim_cell_12 -0.2939923 -0.09508229  0.020528495 -0.04756583 -0.003613296
# chim_cell_13 -0.3321009 -0.11788299  0.005688014 -0.01206577 -0.040791767
# chim_cell_18 -0.3347955 -0.12451003  0.017054111 -0.03354535 -0.031025198
#              [,6]         [,7]          [,8]          [,9]
# chim_cell_2   0.005668602  0.0047471953 -0.0012146869  0.0237818257
# chim_cell_8   0.015820205 -0.0021403842  0.0077602543 -0.0009523884
# chim_cell_10  0.009034295  0.0183478704  0.0055712633  0.0160406693
# chim_cell_12 -0.017004631 -0.0001365382  0.0126666069 -0.0163670009
# chim_cell_13  0.002573428 -0.0063581584  0.0032323869 -0.0220238891
# chim_cell_18  0.013482883  0.0160527701  0.0007185295  0.0287402050
#              [,10]        [,11] [,12]        [,13]        [,14]
# chim_cell_2  -0.013462645 ⋯     -0.004690628 -0.001916259  0.0121737443
# chim_cell_8  -0.006448398 ⋯     -0.007409928  0.004194626 -0.0007980831
# chim_cell_10 -0.016110956 ⋯      0.006137664  0.017407392  0.0032438973
# chim_cell_12  0.017285034 ⋯     -0.006394539  0.000951609  0.0129392726
# chim_cell_13 -0.003457312 ⋯     -0.004361393 -0.005707288 -0.0005726179
# chim_cell_18 -0.033662802 ⋯     -0.012902046  0.011068961  0.0057575448
#              [,15]         [,16]        [,17]        [,18]         [,19]
# chim_cell_2   0.0119514240 -0.011488199 -0.011045682  0.0009124111  0.004791638
# chim_cell_8  -0.0007371569 -0.006773412 -0.006127364 -0.0049856861 -0.004886991
# chim_cell_10  0.0061006107 -0.002855715 -0.005930768  0.0030292404  0.002102196
# chim_cell_12  0.0001156298  0.007780632 -0.014940051 -0.0142976952 -0.010187140
# chim_cell_13  0.0086582844  0.005509412 -0.017775398 -0.0035741419  0.001892698
# chim_cell_18  0.0067426764  0.007460338 -0.009839001 -0.0112767822 -0.003051312
#              [,20]         [,21]
# chim_cell_2  -0.0057998842 -0.012393610
# chim_cell_8   0.0003893368 -0.004751586
# chim_cell_10 -0.0057339333  0.011986368
# chim_cell_12  0.0003020272 -0.003834635
# chim_cell_13 -0.0087565050  0.009161131
# chim_cell_18 -0.0062960618 -0.002779194

# %%
# correct across timepoints of atlas only (corrected_pcs 1 - 9)
correct_atlas = reducedMNN(corrected_pcs[[1]], corrected_pcs[[2]], corrected_pcs[[3]],corrected_pcs[[4]], corrected_pcs[[5]], corrected_pcs[[6]],corrected_pcs[[7]], corrected_pcs[[8]], corrected_pcs[[9]], BPPARAM = SerialParam())$corrected
# Out:
# Warning message in .refine_k(k, precomputed, query = TRUE):
# “'k' capped at the number of observations”

# %%
# correct atlas + chimaera
correct_complete = reducedMNN(correct_atlas, corrected_pcs[[10]], BPPARAM = SerialParam())$corrected
# save temp corrected PCs
write.csv(correct_complete, paste0(out_folder, 'corrected_pc_complete_unordered.csv'))

# %%
correct_complete_bu <- correct_complete

# %%
correct_complete <- correct_complete_bu

# %%
#### don't fuck up the naming of PCs ---> should be fine but maybe check intermediate steps before running



# order pcs according to metadata
big_meta = read.table(paste0(out_folder,"big_meta.tab"), header = TRUE, sep = "\t", stringsAsFactors = FALSE, comment.char = "$")
cells <- big_meta$cell
keyDF <- data.frame(key=cells,weight=1:length(cells))
correct_complete <- as.data.frame(correct_complete)
correct_complete$cell <- rownames(correct_complete)
merged <- merge(correct_complete,keyDF,by.x='cell',by.y='key',all.x=T,all.y=T)
correct_complete <- merged %>% arrange(weight)
correct_complete$weight <- NULL
rownames(correct_complete) <- correct_complete$cell
correct_complete$cell <- NULL

# %%
# save final corrected PCs
write.csv(correct_complete, paste0(out_folder, 'corrected_pc_complete.csv'))

# %% [markdown]
# ### UMAP visualisation

# %%
# Load in data
big_meta = read.table(paste0(out_folder,"big_meta.tab"), header = TRUE, sep = "\t", stringsAsFactors = FALSE, comment.char = "$")
pca_before = as.data.frame(readRDS(paste0(out_folder, 'uncorrected_PCs.rds')))
pca_before$cell <- rownames(pca_before)
pca_after = as.data.frame(read.csv(paste0(out_folder, 'corrected_pc_complete.csv'), header=T, row.names=1,sep=","))
pca_after$cell <- rownames(pca_after)

# %%
# add metadata to PCs
pca_before <- merge(pca_before, big_meta, by='cell')
rownames(pca_before) <- pca_before$cell
pca_after <- merge(pca_after, big_meta, by='cell')
rownames(pca_after) <- pca_after$cell

# %%
# calculate umap's on whole object and chimeara seperately
### chimaera only
# before correction
pca_before$origin <- sapply(strsplit(pca_before$cell,"_"), `[`, 1)
chim_before <- pca_before %>% filter(origin=='chim') %>% select(2:51) # Use all 50 PCs for UMAP
chim_before_umap = umap(t(chim_before))$data
chim_before_umap <- as.data.frame(chim_before_umap)
colnames(chim_before_umap) <- c('umap1','umap2')
chim_before_umap$cell <- rownames(chim_before)
chim_before_umap <- merge(chim_before_umap, big_meta, by='cell')
# write
write.csv(chim_before_umap, paste0(out_folder, 'umap_before_correction_chim.csv')) 
print('finished first umap')


# after correction
pca_after$origin <- sapply(strsplit(pca_after$cell,"_"), `[`, 1)
chim_after <- pca_after %>% filter(origin=='chim') %>% select(2:51) 
chim_after_umap = umap(t(chim_after))$data
chim_after_umap<- as.data.frame(chim_after_umap)
colnames(chim_after_umap) <- c('umap1','umap2')
chim_after_umap$cell <- rownames(chim_after)
chim_after_umap <- merge(chim_after_umap, big_meta, by='cell')
# write
write.csv(chim_after_umap, paste0(out_folder, 'umap_after_correction_chim.csv')) 
print('finished second umap')

### whole object
# before correction
pca_before$origin <- sapply(strsplit(pca_before$cell,"_"), `[`, 1)
pca_before <- pca_before %>% select(2:51)
pca_before_umap = umap(t(pca_before))$data
pca_before_umap <- as.data.frame(pca_before_umap)
colnames(pca_before_umap) <- c('umap1','umap2')
pca_before_umap$cell <- rownames(pca_before)
pca_before_umap <- merge(pca_before_umap, big_meta, by='cell')
# write
write.csv(pca_before_umap, paste0(out_folder, 'umap_before_correction.csv')) 
print('finished third umap')

# after correction
pca_after$origin <- sapply(strsplit(pca_after$cell,"_"), `[`, 1)
pca_after <- pca_after %>% select(2:51)
pca_after_umap = umap(t(pca_after))$data
pca_after_umap <- as.data.frame(pca_after_umap)
colnames(pca_after_umap) <- c('umap1','umap2')
pca_after_umap$cell <- rownames(pca_after)
pca_after_umap <- merge(pca_after_umap, big_meta, by='cell')
# write
write.csv(pca_after_umap, paste0(out_folder, 'umap_after_correction.csv')) 
print('finished fourth umap')
# Out:
# ***UMAP wrapper function***
#
# running...
#
# done.
# [1] "finished first umap"
# ***UMAP wrapper function***
#
# running...
#
# done.
# [1] "finished second umap"
# ***UMAP wrapper function***
#
# running...
#
# done.
# [1] "finished third umap"
# ***UMAP wrapper function***
#
# running...
#
# done.
# [1] "finished fourth umap"

# %%
# load in data
chim_before_umap = as.data.frame(read.csv(paste0(out_folder, 'umap_before_correction_chim.csv'), header=T, row.names=1,sep=","))
chim_after_umap = as.data.frame(read.csv(paste0(out_folder, 'umap_after_correction_chim.csv'), header=T, row.names=1,sep=","))
pca_before_umap = as.data.frame(read.csv(paste0(out_folder, 'umap_before_correction.csv'), header=T, row.names=1,sep=","))
pca_after_umap = as.data.frame(read.csv(paste0(out_folder, 'umap_after_correction.csv'), header=T, row.names=1,sep=","))

# %%
# plot umaps

# colors
source("/rds/project/bg200/rds-bg200-hphi-gottgens/users/bt392/mouse/Mixl1_KO/plot_colours.R")

# chimaera
options(repr.plot.width = 10, repr.plot.height = 5)
p1 <- ggplot(chim_before_umap, aes(umap1, umap2, color=sample)) +
    geom_point(alpha=0.4, size = 0.8) +
    theme_classic() +
    ggtitle('chimaera only, before correction, color = samples')
p2 <- ggplot(chim_before_umap, aes(umap1, umap2, color=tdTom)) +
    geom_point(alpha=0.4, size = 0.8) +
    theme_classic() +
    ggtitle('chimaera only, before correction, color =  tomato')

p3 <- ggplot(chim_after_umap, aes(umap1, umap2, color=sample)) +
    geom_point(alpha=0.4, size = 0.8) +
    theme_classic() +
    ggtitle('chimaera only, after correction, color = samples')
p4 <- ggplot(chim_after_umap, aes(umap1, umap2, color=tdTom)) +
    geom_point(alpha=0.4, size = 0.8) +
    theme_classic() +
    ggtitle('chimaera only, after correction, color = tomato')

# whole object
p5 <- ggplot(pca_before_umap, aes(umap1, umap2, color=sample)) +
    geom_point(alpha=0.4, size = 0.8) +
    theme_classic() +
    ggtitle('whole object before correction, color = sample')
p6 <- ggplot(pca_after_umap, aes(umap1, umap2, color=sample)) +
    geom_point(alpha=0.4, size = 0.8) +
    theme_classic() +
    ggtitle('whole object after correction, color = sample')

p7 <- ggplot(pca_before_umap, aes(umap1, umap2, color=tdTom)) +
    geom_point(alpha=0.4, size = 0.8) +
    theme_classic() +
    ggtitle('whole object before correction, color = tomato')
p8 <- ggplot(pca_after_umap, aes(umap1, umap2, color=tdTom)) +
    geom_point(alpha=0.4, size = 0.8) +
    theme_classic() +
    ggtitle('whole object after correction, color = tomato')

p9 <- ggplot(pca_before_umap, aes(umap1, umap2, color=stage)) +
    geom_point(alpha=0.4, size = 0.8) +
    theme_classic() +
    scale_colour_manual(values = stage_colours, labels = stage_labels, name = "stage") +
    ggtitle('whole object before correction, color = timepoint')
p10 <- ggplot(pca_after_umap, aes(umap1, umap2, color=stage)) +
    geom_point(alpha=0.4, size = 0.8) +
    theme_classic() +
    scale_colour_manual(values = stage_colours, labels = stage_labels, name = "stage") +
    ggtitle('whole object after correction, color = timepoint')

atlas_before_umap <- pca_before_umap %>% filter(!is.na(celltype))
p11 <- ggplot(atlas_before_umap, aes(umap1, umap2, color=celltype)) +
    geom_point(alpha=0.4, size = 0.8) +
    theme_classic() +
    scale_colour_manual(values = celltype_colours, labels = celltype_labels, name = "celltype") +
    ggtitle('atlas only before correction, color = celltype')
atlas_after_umap <- pca_after_umap %>% filter(!is.na(celltype))
p12 <- ggplot(atlas_after_umap, aes(umap1, umap2, color=celltype)) +
    geom_point(alpha=0.4, size = 0.8) +
    theme_classic() +
    scale_colour_manual(values = celltype_colours, labels = celltype_labels, name = "celltype") +
    ggtitle('atlas only after correction, color = celltype')

pca_before_85 <- pca_before_umap %>% filter(stage == 'E8.5')
p13 <- ggplot(pca_before_85, aes(umap1, umap2, color=tdTom)) +
    geom_point(alpha=0.4, size = 0.8) +
    theme_classic() +
    ggtitle('E8.5 before correction, color = tomato')
pca_after_85 <- pca_after_umap %>% filter(stage == 'E8.5')
p14 <- ggplot(pca_after_85, aes(umap1, umap2, color=tdTom)) +
    geom_point(alpha=0.4, size = 0.8) +
    theme_classic() +
    ggtitle('E8.5 after correction, color = tomato')

pca_before_umap$origin <- sapply(strsplit(pca_before_umap$cell,"_"), `[`, 1)
p15 <- ggplot(pca_before_umap, aes(umap1, umap2, color= origin)) +
    geom_point(alpha=0.2, size = 0.8) +
    theme_classic() +
    ggtitle('whole object after correction, color = experiment')
pca_after_umap$origin <- sapply(strsplit(pca_after_umap$cell,"_"), `[`, 1)
p16 <- ggplot(pca_after_umap, aes(umap1, umap2, color= origin)) +
    geom_point(alpha=0.2, size = 0.8) +
    theme_classic() +
    ggtitle('whole object after correction, color = experiment')

# %%
options(repr.plot.width = 20, repr.plot.height = 30)
    grid.arrange(p1, p3, p2, p4, p5, p6, p7, p8, p9, p10, p11, p12, p13, p14, nrow =7)
# Out:
# plot without title

# %%
# plot to png instead of pdf to stop laptop from burning
png(paste0(plot_folder, "umap_batch_correction_comparisons.png"), height=5000, width=3500)
    grid.arrange(p1, p3, p2, p4, p5, p6, p7, p8, p9, p10, p11, p12, p13, p14, nrow =7)
dev.off()

png(paste0(plot_folder, "umap_batch_correction_comparisons_chimaera.png"), height=1000, width=1000)
    grid.arrange(p1, p3, p2, p4, nrow =2)
dev.off()

png(paste0(plot_folder, "umap_batch_correction_comparisons_sample.png"), height=1000, width=2500)
    grid.arrange(p5, p6, nrow =1)
dev.off()

png(paste0(plot_folder, "umap_batch_correction_comparisons_tomato.png"), height=1000, width=2500)
    grid.arrange(p7, p8, nrow =1)
dev.off()

png(paste0(plot_folder, "umap_batch_correction_comparisons_timepoint.png"), height=1000, width=2500)
    grid.arrange(p9, p10, nrow =1)
dev.off()

png(paste0(plot_folder, "umap_batch_correction_comparisons_celltype.png"), height=1000, width=2500)
    grid.arrange(p11, p12, nrow =1)
dev.off()

png(paste0(plot_folder, "umap_batch_correction_comparisons_E85.png"), height=1000, width=2500)
    grid.arrange(p13, p14, nrow =1)
dev.off()

png(paste0(plot_folder, "umap_batch_corrected_plots.png"), height=2000, width=3500)
    grid.arrange(p6, p8, p12, p10, nrow =2)
dev.off()

png(paste0(plot_folder, "umap_batch_corrected_origin.png"), height=1000, width=2500)
    grid.arrange(p15, p16, nrow =1)
dev.off()
# Out:
# png
#   2
# png
#   2
# png
#   2
# png
#   2
# png
#   2
# png
#   2
# png
#   2
# png
#   2
# png
#   2

# %%
pca_after_85 <- pca_after_umap %>% filter(stage == 'E8.5')
p14 <- ggplot(pca_after_85, aes(umap1, umap2, color=tdTom)) +
    geom_point(alpha=0.2, size = 1, color='grey') +
    geom_point(data=pca_after_85, aes(umap1, umap2, color=tdTom),alpha=0.2, size = 1) +
    theme_classic() +
    scale_colour_manual(values = c('pos' = 'red', 'neg' = 'black'), labels = c('pos' = 'pos', 'neg' = 'neg')) +
    ggtitle('E8.5 only, color = tomato')

# %%
options(repr.plot.width = 10, repr.plot.height = 5)
p14
# Out:
# Warning message:
# “Removed 3892 rows containing missing values (geom_point).”
# plot without title

# %%
png(paste0(plot_folder, "umap_85_tomato.png"), height=1000, width=1300)
    grid.arrange(p14)
dev.off()
# Out:
# Warning message:
# “Removed 3892 rows containing missing values (geom_point).”
# png
#   2

# %% [markdown]
# #### Map

# %%
# Load in data
big_meta = read.table(paste0(out_folder,"big_meta.tab"), header = TRUE, sep = "\t", stringsAsFactors = FALSE, comment.char = "$")
pca_after = as.data.frame(read.csv(paste0(out_folder, 'corrected_pc_complete.csv'), header=T, row.names=1,sep=","))
pca_after$cell <- rownames(pca_after)

# %%
# label origin in metdata
big_meta$origin <- sapply(strsplit(big_meta$cell,"_"), `[`, 1)

# %%
# split atlas and chimaera
atlas_cells = big_meta %>% filter(origin=='atlas') %>% .$cell
correct_atlas = pca_after %>% filter(cell %in% atlas_cells)
atlas_meta = big_meta %>% filter(origin=='atlas')
correct_map = pca_after %>% filter(!cell %in% atlas_cells) %>% select(1:50) # keep only PC columns
map_meta = big_meta %>% filter(origin!='atlas')

# %%
# Downsample atlas to 10k cells per timepoint
keep = lapply(unique(atlas_meta$stage), function(x){
  if(x == "mixed_gastrulation"){
    return(atlas_meta[atlas_meta$stage == x,]$cell)
  } else if(sum(atlas_meta$stage == x) < 10000) {
    return(atlas_meta[atlas_meta$stage == x,]$cell)
  } else {
    return(atlas_meta[atlas_meta$stage == x,]$cell)
    return(sample(hits, 10000))
  }
})
keep = do.call(c, keep)
keep <- as.list(keep)

atlas_meta = atlas_meta %>% filter(cell %in% keep)
correct_atlas = correct_atlas %>% filter(cell %in% keep) %>% select(1:50)

# %%
atlas_meta$count = 1
test = atlas_meta %>% group_by(stage) %>% summarize(cells = sum(count))
test
# Out:
# `summarise()` ungrouping output (override with `.groups` argument)
#   stage              cells
# 1 E6.75                 3
# 2 E7.0                249
# 3 E7.25               310
# 4 E7.5                726
# 5 E7.75              2180
# 6 E8.0               3552
# 7 E8.25              2504
# 8 E8.5               3892
# 9 mixed_gastrulation  465

# %%
## standard mapping only on stage & celltype, add extra columns if you want to map them, e.g. haem_subclust
# indicated by ## ADD HERE

# %%
## Code for mapping:

getmode <- function(v, dist) {
  tab = table(v)
  #if tie, break to shortest distance
  if(sum(tab == max(tab)) > 1){
    tied = names(tab)[tab == max(tab)]
    sub = dist[v %in% tied]
    names(sub) = v[v %in% tied]
    return(names(sub)[which.min(sub)])
  } else {
    return(names(tab)[which.max(tab)])
  }
}

mnnMap = function(atlas_pca, atlas_meta, map_pca, map_meta, k_map = 10){
  require(BiocNeighbors)
  require(scran)
  
  knns = BiocNeighbors::queryKNN(correct_atlas, correct_map, k = k_map, get.index = TRUE, get.distance = FALSE)
  
  #get closest k matching cells
  k.mapped = t(apply(knns$index, 1, function(x) atlas_meta$cell[x]))
  celltypes = t(apply(k.mapped, 1, function(x) atlas_meta$celltype[match(x, atlas_meta$cell)]))
  stages = t(apply(k.mapped, 1, function(x) atlas_meta$stage[match(x, atlas_meta$cell)]))
  haem_subclust = t(apply(k.mapped, 1, function(x) atlas_meta$haem_subclust[match(x, atlas_meta$cell)]))
  celltype.mapped = apply(celltypes, 1, function(x) getmode(x, 1:length(x)))
  stage.mapped = apply(stages, 1, function(x) getmode(x, 1:length(x)))
  haem_subclust.mapped = apply(haem_subclust, 1, function(x) getmode(x, 1:length(x))) ## ADD HERE
  
  out = lapply(1:length(celltype.mapped), function(x){
    list(cells.mapped = k.mapped[x,],
         celltype.mapped = celltype.mapped[x],
         haem_subclust.mapped = haem_subclust.mapped[x],     ## ADD HERE
         stage.mapped = stage.mapped[x])
  })
  
  names(out) = map_meta$cell

  return(out)
  
}

# %%
# Perform mapping:
mapping = mnnMap(correct_atlas, atlas_meta, correct_map, map_meta, k_map = 10)
  
  cn = substr(names(mapping), 5, nchar(names(mapping))) # remove 
  ct = sapply(mapping, function(x) x$celltype.mapped)
  st = sapply(mapping, function(x) x$stage.mapped)
  hm = sapply(mapping, function(x) x$haem_subclust.mapped) ## ADD HERE
  closest = sapply(mapping, function(x) x$cells.mapped[1])
  
  out = data.frame(cell = cn, celltype.mapped = ct, stage.mapped = st, closest.cell = closest, haem_subclust.mapped = hm) ## ADD HERE
# save mapped celltypes
write.csv(out, paste0(out_folder, 'chimaera_mapped_celltypes.csv'))
# Out:
# Loading required package: BiocNeighbors
#
#
# Attaching package: ‘BiocNeighbors’
#
#
# The following object is masked from ‘package:batchelor’:
#
#     findMutualNN

# %%
### visualise mapping
big_meta = read.table(paste0(out_folder,"big_meta.tab"), header = TRUE, sep = "\t", stringsAsFactors = FALSE, comment.char = "$")
mapping <- read.csv(paste0(out_folder, 'chimaera_mapped_celltypes.csv'), row.names=1)
mapping$cell <- rownames(mapping)

# add cell mapping to metadata
big_meta$stage.mapped = as.character(mapping$stage.mapped[match(big_meta$cell, mapping$cell)])
big_meta$celltype.mapped = as.character(mapping$celltype.mapped[match(big_meta$cell, mapping$cell)])
big_meta$haem_subclust.mapped = as.character(mapping$haem_subclust.mapped[match(big_meta$cell, mapping$cell)]) ## ADD HERE
big_meta$closest.cell = as.character(mapping$closest.cell[match(big_meta$cell, mapping$cell)])

# only plot chimaera cells
meta <- big_meta %>% filter(!is.na(big_meta$tdTom))

# %%
### save big meta with mapping
write.table(big_meta, file = paste0(out_folder,"big_meta_mapping.tab"), row.names = F, col.names = T, quote = F, sep = "\t")

# %%
source("/rds/project/bg200/rds-bg200-hphi-gottgens/users/bt392/mouse/Mixl1_KO/plot_colours.R")

# %%
big_meta = read.csv(paste0(out_folder,"big_meta_mapping.tab"), sep='\t')

# %%
big_meta$tdTom = NULL
big_meta$tdTom[big_meta$sample %in% c('mixl_1', 'mixl_3', 'mixl_5')] <- "neg"
big_meta$tdTom[big_meta$sample %in% c('mixl_2', 'mixl_4', 'mixl_6')] <- "pos"

meta <- big_meta %>% filter(!is.na(big_meta$tdTom))

# %%
embryo1 <- c('mixl_1','mixl_2','mixl_3','mixl_4')
embryo2 <- c('mixl_6','mixl_5')

p1 = ggplot(mapping = aes(x = meta$stage.mapped)) +
  geom_bar(stat = "count", position = "dodge") +
  labs(x = "Atlas stage", y = "# cells") +
    theme_classic() +
  theme(axis.text.x = element_text(angle = -30, hjust = 0),
        axis.title.x =  element_blank()) +
  scale_x_discrete(breaks = unique(meta$stage.mapped)[order(unique(meta$stage.mapped))])
  

pdf1 = table(meta$stage.mapped[meta$sample %in% embryo1], meta$tdTom[meta$sample %in% embryo1])
pdf1 = as.data.frame(sweep(pdf1, 2, colSums(pdf1), "/"))

p2 = ggplot(data = pdf1, mapping = aes(x = Var1, y = Freq, fill = Var2)) +
  geom_bar(stat = "identity", position = "dodge") +
  scale_fill_manual(values = c("pos" = "red", "neg" = "black"), 
                    labels = c("pos" = "Tomato+", "neg" = "Tomato-"),
                    name = "") +
  labs(x = "Atlas stage", y = "Fraction of cells") +
  ggtitle("KO cell line 1 chimeras") +
    theme_classic() +
  theme(axis.text.x = element_text(angle = -30, hjust = 0),
        legend.position = "none",
        axis.title.x = element_blank()) +
  scale_x_discrete(breaks = unique(meta$stage.mapped)[order(unique(meta$stage.mapped))])


pdf2 = table(meta$stage.mapped[meta$sample %in% embryo2], meta$tdTom[meta$sample %in% embryo2])
pdf2 = as.data.frame(sweep(pdf2, 2, colSums(pdf2), "/"))

p3 = ggplot(data = pdf2, mapping = aes(x = factor(Var1, levels = unique(meta$stage.mapped)[order(unique(meta$stage.mapped))]), 
                                       y = Freq, fill = Var2)) +
  geom_bar(stat = "identity", position = "dodge") +
  scale_fill_manual(values = c("pos" = "red", "neg" = "black"), 
                    labels = c("pos" = "Tomato+", "neg" = "Tomato-"),
                    name = "",
                    drop = FALSE) +
  labs(x = "Atlas stage", y = "Fraction of cells") +
  ggtitle("KO cell line 2 chimeras") +
    theme_classic() +
  theme(axis.text.x = element_text(angle = -30, hjust = 0),
        legend.position = "none",
        axis.title.x = element_blank()) +
  scale_x_discrete(breaks = unique(meta$stage.mapped)[order(unique(meta$stage.mapped))], 
                   drop = FALSE)

pdf3 = table(meta$stage.mapped, meta$tdTom)
pdf3 = as.data.frame(sweep(pdf3, 2, colSums(pdf3), "/"))

p4 = ggplot(data = pdf3, mapping = aes(x = Var1, y = Freq, fill = Var2)) +
  geom_bar(stat = "identity", position = "dodge") +
  scale_fill_manual(values = c("pos" = "red", "neg" = "black"), 
                    labels = c("pos" = "Tomato+", "neg" = "Tomato-"),
                    name = "") +
  labs(x = "Atlas stage", y = "Fraction of cells") +
  ggtitle("all pools chimeras") +
    theme_classic() + 
    theme(axis.text.x = element_text(angle = -30, hjust = 0),
        legend.position = "none",
        axis.title.x = element_blank()) +
  scale_x_discrete(breaks = unique(meta$stage.mapped)[order(unique(meta$stage.mapped))])

options(repr.plot.width = 15, repr.plot.height = 10)
grid.arrange(p1, p2, p3, p4, nrow =2)
# Out:
# plot without title

# %%
pdf(paste0(plot_folder, "chimaera_stage_mapping.pdf"), height=8, width=10)
    grid.arrange(p1, p2, p3, p4, nrow =2)
dev.off()
# Out:
# png
#   2

# %%
embryo1 <- c('mixl_1','mixl_2','mixl_3','mixl_4') # not actually embryo but KO cell line pool
embryo2 <- c('mixl_6','mixl_5')

p1 = ggplot(mapping = aes(x = meta$haem_subclust.mapped)) +
  geom_bar(stat = "count", position = "dodge") +
  labs(x = "Atlas haem_subclust", y = "# cells") +
    theme_classic() +
  theme(axis.text.x = element_text(angle = -30, hjust = 0),
        axis.title.x =  element_blank()) +
  scale_x_discrete(breaks = unique(meta$haem_subclust.mapped)[order(unique(meta$haem_subclust.mapped))])
  
  

pdf1 = table(meta$haem_subclust.mapped[meta$sample %in% embryo1], meta$tdTom[meta$sample %in% embryo1])
pdf1 = as.data.frame(sweep(pdf1, 2, colSums(pdf1), "/"))

p2 = ggplot(data = pdf1, mapping = aes(x = Var1, y = Freq, fill = Var2)) +
  geom_bar(stat = "identity", position = "dodge") +
  scale_fill_manual(values = c("pos" = "red", "neg" = "black"), 
                    labels = c("pos" = "Tomato+", "neg" = "Tomato-"),
                    name = "") +
  labs(x = "Atlas haem_subclust", y = "Fraction of cells") +
  ggtitle("KO cell line 1 chimeras") +
    theme_classic() +
  theme(axis.text.x = element_text(angle = -30, hjust = 0),
        legend.position = "none",
        axis.title.x = element_blank()) +
  scale_x_discrete(breaks = unique(meta$haem_subclust.mapped)[order(unique(meta$haem_subclust.mapped))])


pdf2 = table(meta$haem_subclust.mapped[meta$sample %in% embryo2], meta$tdTom[meta$sample %in% embryo2])
pdf2 = as.data.frame(sweep(pdf2, 2, colSums(pdf2), "/"))

p3 = ggplot(data = pdf2, mapping = aes(x = factor(Var1, levels = unique(meta$haem_subclust.mapped)[order(unique(meta$haem_subclust.mapped))]), 
                                       y = Freq, fill = Var2)) +
  geom_bar(stat = "identity", position = "dodge") +
  scale_fill_manual(values = c("pos" = "red", "neg" = "black"), 
                    labels = c("pos" = "Tomato+", "neg" = "Tomato-"),
                    name = "",
                    drop = FALSE) +
  labs(x = "Atlas haem_subclust", y = "Fraction of cells") +
  ggtitle("KO cell line 2 chimeras") +
    theme_classic() +
  theme(axis.text.x = element_text(angle = -30, hjust = 0),
        legend.position = "none",
        axis.title.x = element_blank()) +
  scale_x_discrete(breaks = unique(meta$haem_subclust.mapped)[order(unique(meta$haem_subclust.mapped))], 
                   drop = FALSE)

pdf3 = table(meta$haem_subclust.mapped, meta$tdTom)
pdf3 = as.data.frame(sweep(pdf3, 2, colSums(pdf3), "/"))

p4 = ggplot(data = pdf3, mapping = aes(x = Var1, y = Freq, fill = Var2)) +
  geom_bar(stat = "identity", position = "dodge") +
  scale_fill_manual(values = c("pos" = "red", "neg" = "black"), 
                    labels = c("pos" = "Tomato+", "neg" = "Tomato-"),
                    name = "") +
  labs(x = "Atlas haem_subclust", y = "Fraction of cells") +
  ggtitle("all pools chimeras") +
  theme_classic() +
  theme(axis.text.x = element_text(angle = -30, hjust = 0),
        legend.position = "none",
        axis.title.x = element_blank()) +
  scale_x_discrete(breaks = unique(meta$haem_subclust.mapped)[order(unique(meta$haem_subclust.mapped))])

options(repr.plot.width = 20, repr.plot.height = 10)
grid.arrange(p1, p2, p3, p4, nrow =2)
# Out:
# plot without title

# %%
pdf(paste0(plot_folder, "chimaera_celltype_mapping.pdf"), height=8, width=20)
    grid.arrange(p1, p2, p3, p4, nrow =2)
dev.off()
# Out:
# png
#   2

# %%
pdfall = table(meta$haem_subclust.mapped, meta$tdTom)
colnames(pdfall) = c("TomT", "TomF")[match(colnames(pdfall), c("pos", "neg"))]
pdfall = sweep(pdfall, 2, colSums(pdfall), "/")
pdfall = as.data.frame.matrix(pdfall)


plegend = ggplot(data = pdfall, mapping = aes(x = TomT, y = TomF, col = rownames(pdfall))) +
  geom_abline(slope = 1, intercept = 0) +
  geom_point(size = 2) +
  scale_colour_manual(values = c(haem_colours, "Doublet" = "black", "Stripped" = "black"), name = "") +
  labs(x = "Fraction of Tomato+ cells", y = "Fraction of Tomato- cells") +
  ggtitle("all cells") +
  scale_x_log10() +
  scale_y_log10() +
  guides(col = guide_legend(ncol = 5, override.aes = list(size = 5)))

p1 = ggplot(data = pdfall, mapping = aes(x = TomT, y = TomF, col = rownames(pdfall))) +
  geom_abline(slope = 1, intercept = 0) +
  geom_point(size = 4) +
  scale_colour_manual(values = c(haem_colours, "Doublet" = "black", "Stripped" = "black"), name = "") +
  labs(x = "Tomato+ cells", y = "Tomato- cells") +
  ggtitle("All cells") +
  theme_classic() +
  scale_x_log10(breaks = c(0.1, 0.01, 0.001, 0.0001), labels = c("10%", "1%", "0.1%", "0.01%")) +
  scale_y_log10(breaks = c(0.1, 0.01, 0.001, 0.0001), labels = c("10%", "1%", "0.1%", "0.01%")) +
  theme(legend.position = "none")

pdf1 = table(meta$haem_subclust.mapped[meta$sample %in% embryo1], meta$tdTom[meta$sample %in% embryo1])
colnames(pdf1) = c("TomT", "TomF")[match(colnames(pdf1), c("pos", "neg"))]
pdf1 = sweep(pdf1, 2, colSums(pdf1), "/")
pdf1 = as.data.frame.matrix(pdf1)

p2 = ggplot(data = pdf1, mapping = aes(x = TomT, y = TomF, col = rownames(pdf1))) +
  geom_abline(slope = 1, intercept = 0) +
  geom_point(size = 4) +
  scale_colour_manual(values = c(haem_colours, "Doublet" = "black", "Stripped" = "black"), name = "") +
  labs(x = "Tomato+ cells", y = "Tomato- cells") +
  ggtitle("KO cell line 1 chimeras") +
  theme_classic() +
  scale_x_log10(breaks = c(0.1, 0.01, 0.001, 0.0001), labels = c("10%", "1%", "0.1%", "0.01%")) +
  scale_y_log10(breaks = c(0.1, 0.01, 0.001, 0.0001), labels = c("10%", "1%", "0.1%", "0.01%")) +
  theme(legend.position = "none")



pdf2 = table(meta$haem_subclust.mapped[meta$sample %in% embryo2], meta$tdTom[meta$sample %in% embryo2])
colnames(pdf2) = c("TomT", "TomF")[match(colnames(pdf2), c("pos", "neg"))]
pdf2 = sweep(pdf2, 2, colSums(pdf2), "/")
pdf2 = as.data.frame.matrix(pdf2)

p3 = ggplot(data = pdf2, mapping = aes(x = TomT, y = TomF, col = rownames(pdf2))) +
  geom_abline(slope = 1, intercept = 0) +
  geom_point(size = 4) +
  scale_colour_manual(values = c(haem_colours, "Doublet" = "black", "Stripped" = "black"), name = "") +
  labs(x = "Tomato+ cells", y = "Tomato- cells") +
  ggtitle("KO cell line 2 chimeras") +
  theme_classic() +
  scale_x_log10(breaks = c(0.1, 0.01, 0.001, 0.0001), labels = c("10%", "1%", "0.1%", "0.01%")) +
  scale_y_log10(breaks = c(0.1, 0.01, 0.001, 0.0001), labels = c("10%", "1%", "0.1%", "0.01%")) +
  theme(legend.position = "none")



p = plot_grid(plot_grid(p1, p2, p3), get_legend(plegend), rel_heights = c(0.75, 0.25), ncol = 1)

#psave = plot_grid(p1 + coord_fixed(xlim = c(0.00003, 0.25), ylim = c(0.00003, 0.25)), 
#                  p2 + coord_fixed(xlim = c(0.00003, 0.25), ylim = c(0.00003, 0.25)), p3 + coord_fixed(xlim = c(0.00003, 0.25), ylim = c(0.00003, 0.25)))
options(repr.plot.width = 15, repr.plot.height = 10)
p
# Out:
# Warning message:
# “Transformation introduced infinite values in continuous y-axis”
# Warning message:
# “Transformation introduced infinite values in continuous y-axis”
# Warning message:
# “Transformation introduced infinite values in continuous y-axis”
# Warning message:
# “Transformation introduced infinite values in continuous y-axis”
# plot without title

# %%
pdf(paste0(plot_folder, "chimaera_celltype_fraction.pdf"), height=8, width=10)
    p
dev.off()
# Out:
# png
#   2

# %%
# plot projected cell type on UMAP
big_meta = read.table(paste0(out_folder,"big_meta_mapping.tab"), header = TRUE, sep = "\t", stringsAsFactors = FALSE, comment.char = "$")
umap = as.data.frame(read.csv(paste0(out_folder, 'umap_after_correction.csv'), header=T, row.names=1,sep=",")) %>% select(1:3)
big_meta = merge(big_meta, umap, by='cell')
source("/rds/project/bg200/rds-bg200-hphi-gottgens/users/bt392/mouse/Mixl1_KO/plot_colours.R")

# %%
big_meta_85 <- big_meta # %>% filter(stage%in% c('E8.25','E8.5'))

p1 <- ggplot(big_meta_85, aes(umap1, umap2, color= haem_subclust.mapped)) +
    geom_point(alpha=0.5, size = 0.4, color='grey') +
    geom_point(data=big_meta_85,aes(color=haem_subclust),alpha=0.2, size = 0.4) +
    theme_classic() +
    scale_colour_manual(values = haem_colours, labels = haem_labels, name = "haem_colours") +
    ggtitle('color = haem_colours (chim in grey)') #+
    #theme(legend.position = "none")
p2 <- ggplot(big_meta_85, aes(umap1, umap2, color=haem_subclust)) +
   geom_point(alpha=0.2, size = 0.4, color='grey') +
    geom_point(data=big_meta_85,aes(color=haem_subclust.mapped),alpha=0.5, size = 0.4) +
    theme_classic() +
    scale_colour_manual(values = haem_colours, labels = haem_labels, name = "haem_colours") +
    ggtitle('color = haem_colours (atlas in grey)') +
    theme(legend.position = "none")

options(repr.plot.width = 15, repr.plot.height = 8)
plot_grid(p1, p2)
# Out:
# Warning message:
# “Removed 5782 rows containing missing values (geom_point).”
# Warning message:
# “Removed 13881 rows containing missing values (geom_point).”
# plot without title

# %%
png(paste0(plot_folder, "umap_celltype_mapping.png"), height=1000, width=1000)
    grid.arrange(p1, p2)
dev.off()
# Out:
# Warning message:
# “Removed 5782 rows containing missing values (geom_point).”
# Warning message:
# “Removed 13881 rows containing missing values (geom_point).”
# png
#   2

# %%
haem <- c( "Haematoendothelial progenitors",
                     "Endothelium",
                     "Blood progenitors 1",
                     "Blood progenitors 2",
                     "Erythroid1",
                     "Erythroid2",
                     "Erythroid3")
haem_plot <- big_meta %>% filter(celltype %in% haem | celltype.mapped %in% haem)
p1 <- ggplot(haem_plot, aes(umap1, umap2)) +
    geom_point(alpha=0.2, size = 0.4, color='grey') +
    geom_point(data=haem_plot,aes(color=haem_subclust.mapped),alpha=0.5, size = 0.4) +
    theme_classic() +
    scale_colour_manual(values = haem_colours, labels = haem_labels, name = "celltype") +
    ggtitle('color = celltype (atlas in grey)')

p2 <- ggplot(haem_plot, aes(umap1, umap2)) +
    geom_point(alpha=0.2, size = 0.4, color='grey') +
    geom_point(data=haem_plot,aes(color=tdTom),alpha=0.5, size = 0.4) +
    theme_classic() +
    scale_colour_manual(values = c('pos' = 'red', 'neg' = 'black'), labels = c('pos' = 'pos', 'neg' = 'neg')) + 
    ggtitle('color = celltype (atlas in grey)')
                        
grid.arrange(p1, p2, nrow=1)
# Out:
# Warning message:
# “Removed 13881 rows containing missing values (geom_point).”
# Warning message:
# “Removed 13881 rows containing missing values (geom_point).”
# plot without title

# %%
png(paste0(plot_folder, "umap_haem_mapping.png"), height=750, width=500)
    grid.arrange(p1, p2, nrow = 2)
dev.off()
# Out:
# Warning message:
# “Removed 13881 rows containing missing values (geom_point).”
# Warning message:
# “Removed 13881 rows containing missing values (geom_point).”
# png
#   2

# %% [markdown]
# #### Integration

# %%
import pandas as pd
import numpy as np
import pyranges as pr

# %%
file_name ="/rds/project/bg200/rds-bg200-hphi-gottgens/users/bt392/mouse/Mixl1_KO/velocity/genes.gtf"

# %%
from gtfparse import read_gtf

df = read_gtf(
    file_name)
# Out:
# INFO:root:Extracted GTF attributes: ['gene_id', 'gene_version', 'gene_name', 'gene_source', 'gene_biotype', 'transcript_id', 'transcript_version', 'transcript_name', 'transcript_source', 'transcript_biotype', 'transcript_support_level', 'exon_number', 'exon_id', 'exon_version', 'tag', 'ccds_id', 'protein_id', 'protein_version']

# %%
df.head()
# Out:
#   seqname          source     feature    start      end  score strand frame  \
# 0       1  ensembl_havana        gene  3205901  3671498    NaN      -     0
# 1       1          havana  transcript  3205901  3216344    NaN      -     0
# 2       1          havana        exon  3213609  3216344    NaN      -     0
# 3       1          havana        exon  3205901  3207317    NaN      -     0
# 4       1          havana  transcript  3206523  3215632    NaN      -     0
#
#               gene_id gene_version  ... transcript_source  \
# 0  ENSMUSG00000051951            5  ...
# 1  ENSMUSG00000051951            5  ...            havana
# 2  ENSMUSG00000051951            5  ...            havana
# 3  ENSMUSG00000051951            5  ...            havana
# 4  ENSMUSG00000051951            5  ...            havana
#
#      transcript_biotype transcript_support_level exon_number  \
# 0
# 1  processed_transcript                        1
# ...

# %%
df = df.loc[:,['gene_id','gene_name']]

# %%
df = df.drop_duplicates()

# %%
df.to_csv('/rds/project/bg200/rds-bg200-hphi-gottgens/users/bt392/mouse/gene_id_name_conversion.csv')

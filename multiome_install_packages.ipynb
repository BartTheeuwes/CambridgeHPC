# %%
library(devtools)
library(BiocManager)
# Out:
# Attaching package: ‘BiocManager’
#
#
# The following object is masked from ‘package:devtools’:
#
#     install

# %%
devtools::install_github("GreenleafLab/ArchR", ref="master", repos = BiocManager::repositories())
# Out:
# Downloading GitHub repo GreenleafLab/ArchR@master
#
# 'getOption("repos")' replaces Bioconductor standard repositories, see
# '?repositories' for details
#
# replacement repositories:
#     CRAN: https://cran.r-project.org
# GlobalOpt... (NA     -> 0.1.2   ) [CRAN]
# rjson        (NA     -> 0.2.20  ) [CRAN]
# shape        (NA     -> 1.4.6   ) [CRAN]
# zlibbioc     (NA     -> 1.40.0  ) [CRAN]
# later        (1.2.0  -> 1.3.0   ) [CRAN]
# fansi        (0.4.2  -> 0.5.0   ) [CRAN]
# formatR      (NA     -> 1.11    ) [CRAN]
# futile.op... (NA     -> 1.0.1   ) [CRAN]
# lambda.r     (NA     -> 1.2.4   ) [CRAN]
# snow         (NA     -> 0.4-4   ) [CRAN]
# futile.lo... (NA     -> 1.4.3   ) [CRAN]
# GenomeInf... (NA     -> 1.2.7   ) [CRAN]
# RCurl        (NA     -> 1.98-1.5) [CRAN]
# Rhtslib      (NA     -> 1.26.0  ) [CRAN]
# BiocParallel (NA     -> 1.28.0  ) [CRAN]
# XVector      (NA     -> 0.34.0  ) [CRAN]
# IRanges      (2.26.0 -> 2.28.0  ) [CRAN]
# S4Vectors    (0.30.0 -> 0.32.0  ) [CRAN]
# BiocGenerics (0.38.0 -> 0.40.0  ) [CRAN]
# Biostrings   (NA     -> 2.62.0  ) [CRAN]
# GenomicRa... (NA     -> 1.46.0  ) [CRAN]
# GenomeInfoDb (NA     -> 1.30.0  ) [CRAN]
# DelayedArray (NA     -> 0.20.0  ) [CRAN]
# Biobase      (NA     -> 2.54.0  ) [CRAN]
# MatrixGen... (NA     -> 1.6.0   ) [CRAN]
# Summarize... (NA     -> 1.24.0  ) [CRAN]
# restfulr     (NA     -> 0.0.13  ) [CRAN]
# BiocIO       (NA     -> 1.4.0   ) [CRAN]
# GenomicAl... (NA     -> 1.30.0  ) [CRAN]
# XML          (NA     -> 3.99-0.8) [CRAN]
# Rsamtools    (NA     -> 2.10.0  ) [CRAN]
# rtracklayer  (NA     -> 1.54.0  ) [CRAN]
# pracma       (NA     -> 2.3.3   ) [CRAN]
# Annotatio... (NA     -> 1.56.1  ) [CRAN]
# plogr        (NA     -> 0.2.0   ) [CRAN]
# blob         (NA     -> 1.2.2   ) [CRAN]
# KEGGREST     (NA     -> 1.34.0  ) [CRAN]
# GO.db        (NA     -> 3.14.0  ) [CRAN]
# annotate     (NA     -> 1.72.0  ) [CRAN]
# poweRlaw     (NA     -> 0.70.6  ) [CRAN]
# TFMPvalue    (NA     -> 0.0.8   ) [CRAN]
# seqLogo      (NA     -> 1.60.0  ) [CRAN]
# RSQLite      (NA     -> 2.2.8   ) [CRAN]
# DBI          (NA     -> 1.1.1   ) [CRAN]
# Dirichlet... (NA     -> 1.36.0  ) [CRAN]
# CNEr         (NA     -> 1.30.0  ) [CRAN]
# BSgenome     (NA     -> 1.62.0  ) [CRAN]
# doParallel   (NA     -> 1.0.16  ) [CRAN]
# clue         (NA     -> 0.3-60  ) [CRAN]
# GetoptLong   (NA     -> 1.0.5   ) [CRAN]
# circlize     (NA     -> 0.4.13  ) [CRAN]
# TFBSTools    (NA     -> 1.32.0  ) [CRAN]
# nabor        (NA     -> 0.5.0   ) [CRAN]
# ComplexHe... (NA     -> 2.10.0  ) [CRAN]
# chromVAR     (NA     -> 1.16.0  ) [CRAN]
# motifmatchr  (NA     -> 1.16.0  ) [CRAN]
# Installing 56 packages: GlobalOptions, rjson, shape, zlibbioc, later, fansi, formatR, futile.options, lambda.r, snow, futile.logger, GenomeInfoDbData, RCurl, Rhtslib, BiocParallel, XVector, IRanges, S4Vectors, BiocGenerics, Biostrings, GenomicRanges, GenomeInfoDb, DelayedArray, Biobase, MatrixGenerics, SummarizedExperiment, restfulr, BiocIO, GenomicAlignments, XML, Rsamtools, rtracklayer, pracma, AnnotationDbi, plogr, blob, KEGGREST, GO.db, annotate, poweRlaw, TFMPvalue, seqLogo, RSQLite, DBI, DirichletMultinomial, CNEr, BSgenome, doParallel, clue, GetoptLong, circlize, TFBSTools, nabor, ComplexHeatmap, chromVAR, motifmatchr
#
# Updating HTML index of packages in '.Library'
#
# Making 'packages.html' ...
#  done
# ✔  checking for file ‘/tmp/RtmpyAwFHX/remotes3f55131c74fab/GreenleafLab-ArchR-422f0ff/DESCRIPTION’
# ─  preparing ‘ArchR’:
# ✔  checking DESCRIPTION meta-information
# ─  cleaning src
# ─  checking for LF line-endings in source and make files and shell scripts
# ─  checking for empty or unneeded directories
# ─  building ‘ArchR_1.0.1.tar.gz’
#    Warning in utils::tar(filepath, pkgname, compression = compression, compression_level = 9L,  :
#      storing paths of more than 100 bytes is not portable:
#      ‘ArchR/.github/ISSUE_TEMPLATE/bug-error-report---no-usage-questions---feature-requests--use-discussions--.md’
# Warning message in i.p(...):
# “installation of package ‘/tmp/RtmpyAwFHX/file3f551665fc295/ArchR_1.0.1.tar.gz’ had non-zero exit status”

# %%
library(rhdf5)
# Out:
# Error: package or namespace load failed for ‘rhdf5’ in dyn.load(file, DLLpath = DLLpath, ...):
#  unable to load shared object '/home/bt392/miniconda3/envs/multiome/lib/R/library/rhdf5/libs/rhdf5.so':
#   libcrypto.so.3: cannot open shared object file: No such file or directory
# Traceback:
#
# 1. library(rhdf5)
# 2. tryCatch({
#  .     attr(package, "LibPath") <- which.lib.loc
#  .     ns <- loadNamespace(package, lib.loc)
#  .     env <- attachNamespace(ns, pos = pos, deps, exclude, include.only)
#  . }, error = function(e) {
#  .     P <- if (!is.null(cc <- conditionCall(e)))
#  .         paste(" in", deparse(cc)[1L])
#  .     else ""
#  .     msg <- gettextf("package or namespace load failed for %s%s:\n %s",
#  .         sQuote(package), P, conditionMessage(e))
#  .     if (logical.return && !quietly)
#  .         message(paste("Error:", msg), domain = NA)
#  .     else stop(msg, call. = FALSE, domain = NA)
#  . })
# 3. tryCatchList(expr, classes, parentenv, handlers)
# 4. tryCatchOne(expr, names, parentenv, handlers[[1L]])
# 5. value[[3L]](cond)
# 6. stop(msg, call. = FALSE, domain = NA)

# %%
library(ArchR)
# Out:
# Error in library(ArchR): there is no package called ‘ArchR’
# Traceback:
#
# 1. library(ArchR)

# %%
library(ArchR)
ArchR::installExtraPackages()

# %%
sessionInfo()
# Out:
# R version 4.1.1 (2021-08-10)
# Platform: x86_64-conda-linux-gnu (64-bit)
# Running under: Scientific Linux 7.9 (Nitrogen)
#
# Matrix products: default
# BLAS/LAPACK: /home/bt392/miniconda3/envs/multiome/lib/libopenblasp-r0.3.18.so
#
# locale:
#  [1] LC_CTYPE=en_GB.UTF-8       LC_NUMERIC=C
#  [3] LC_TIME=en_GB.UTF-8        LC_COLLATE=en_GB.UTF-8
#  [5] LC_MONETARY=en_GB.UTF-8    LC_MESSAGES=en_GB.UTF-8
#  [7] LC_PAPER=en_GB.UTF-8       LC_NAME=C
#  [9] LC_ADDRESS=C               LC_TELEPHONE=C
# [11] LC_MEASUREMENT=en_GB.UTF-8 LC_IDENTIFICATION=C
#
# attached base packages:
# [1] stats     graphics  grDevices utils     datasets  methods   base
#
# other attached packages:
# [1] BiocManager_1.30.16 devtools_2.4.2      usethis_2.1.3
#
# loaded via a namespace (and not attached):
#  [1] pillar_1.6.4      compiler_4.1.1    prettyunits_1.1.1 base64enc_0.1-3
#  [5] remotes_2.4.1     tools_4.1.1       testthat_3.1.0    digest_0.6.28
#  [9] pkgbuild_1.2.0    uuid_1.0-2        pkgload_1.2.3     jsonlite_1.7.2
# [13] evaluate_0.14     memoise_2.0.0     lifecycle_1.0.1   rlang_0.4.12
# [17] IRdisplay_1.0     cli_3.1.0         curl_4.3.2        IRkernel_1.2
# [21] fastmap_1.1.0     repr_1.1.3        withr_2.4.2       desc_1.4.0
# [25] fs_1.5.0          vctrs_0.3.8       rprojroot_2.0.2   glue_1.4.2
# [29] R6_2.5.1          processx_3.5.2    fansi_0.5.0       sessioninfo_1.2.0
# [33] pbdZMQ_0.3-6      purrr_0.3.4       callr_3.7.0       magrittr_2.0.1
# [37] ps_1.6.0          ellipsis_0.3.2    htmltools_0.5.2   utf8_1.2.2
# [41] cachem_1.0.6      crayon_1.4.2

# %%
ip <- as.data.frame(installed.packages()[,c(1,3:4)])
rownames(ip) <- NULL
ip <- ip[is.na(ip$Priority),1:2,drop=FALSE]
print(ip, row.names=FALSE)
# Out:
#                       Package    Version
#                         abind      1.4-5
#                      annotate     1.76.0
#                 AnnotationDbi     1.60.0
#                 AnnotationHub      3.6.0
#                         ArchR      1.0.2
#                      argparse      2.2.1
#                       askpass        1.1
#                    assertthat      0.2.1
#                     backports      1.4.1
#                     base64enc      0.1-3
#                      basilisk     1.9.12
#                basilisk.utils     1.10.0
#                     batchelor     1.14.0
#                      beachmat     2.14.0
#                      beeswarm      0.4.0
#                            BH   1.78.0-0
#                       Biobase     2.58.0
#                 BiocFileCache      2.6.0
#                  BiocGenerics     0.44.0
#                        BiocIO      1.8.0
#                   BiocManager    1.30.19
#                 BiocNeighbors     1.16.0
#                  BiocParallel     1.32.5
#                  BiocSingular     1.14.0
#                   BiocVersion     3.16.0
#                       biomaRt     2.54.0
#                    Biostrings     2.66.0
#                           bit      4.0.5
#                         bit64      4.0.5
#                        bitops      1.0-7
#                          blob      1.2.3
#                       bluster      1.8.0
#                          brew      1.0-8
#                          brio      1.1.3
#                         broom      1.0.2
#                      BSgenome     1.66.1
#  BSgenome.Mmusculus.UCSC.mm10      1.4.3
#                         bslib      0.4.2
#                   BumpyMatrix      1.6.0
#                        cachem      1.0.6
#                         Cairo      1.6-0
#                         callr      3.7.3
#                           car      3.1-1
#                       carData      3.0-5
#                         caret     6.0-93
#                       caTools     1.18.2
#                    cellranger      1.1.0
#                      chromVAR     1.20.2
#                chromVARmotifs      0.2.0
#                      circlize     0.4.15
#                      classInt      0.4-8
#                           cli      3.6.0
#                         clipr      0.8.0
#                         clock      0.6.1
#                          clue     0.3-63
#                          CNEr     1.34.0
#                    colorspace      2.0-3
#                    commonmark      1.8.1
#                ComplexHeatmap     2.14.0
#                       conquer      1.3.1
#                      corrplot       0.92
#                       cowplot      1.1.1
#                         cpp11      0.4.3
#                        crayon      1.5.2
#                   credentials      1.3.2
#                     crosstalk      1.2.0
#                          curl      4.3.3
#                    data.table     1.14.6
#                           DBI      1.1.3
#                        dbplyr      2.3.0
#                  DelayedArray     0.24.0
#            DelayedMatrixStats     1.20.0
#                        deldir      1.0-6
#                      DEoptimR     1.0-11
#                          desc      1.4.2
#                        DESeq2     1.38.0
#                       destiny     3.12.0
#                      devtools      2.4.5
#                       diffobj      0.3.5
#                        digest     0.6.31
#                    dir.expiry      1.6.0
#          DirichletMultinomial     1.40.0
#                    doParallel     1.0.17
#                       downlit      0.4.2
#                         dplyr     1.0.10
#                         dqrng      0.3.0
#                  DropletUtils     1.18.0
#                            DT       0.27
#                         e1071     1.7-12
#                         edgeR     3.40.0
#                      ellipsis      0.3.2
#                      evaluate       0.19
#                 ExperimentHub      2.6.0
#                         fansi      1.0.3
#                        farver      2.1.1
#                       fastmap      1.1.0
#                     fastmatch      1.1-3
#                      filelock      1.0.2
#                    findpython      1.0.7
#                  fitdistrplus      1.1-8
#                           FNN    1.1.3.1
#                   fontawesome      0.4.0
#                       forcats      0.5.2
#                       foreach      1.5.2
#                       formatR       1.13
#                            fs      1.5.2
#                         furrr      0.3.1
#                 futile.logger      1.4.3
#                futile.options      1.0.1
#                        future     1.30.0
#                  future.apply     1.10.0
#                    genefilter     1.80.0
#                   geneplotter     1.76.0
#                      generics      0.1.3
#                  GenomeInfoDb     1.34.1
#              GenomeInfoDbData      1.2.9
#             GenomicAlignments     1.34.0
#                 GenomicRanges     1.50.0
#                          gert      2.0.1
#                    GetoptLong      1.0.5
#                        GGally      2.1.2
#                    ggbeeswarm      0.7.1
#                       ggforce      0.4.1
#                    ggnewscale     0.4.10
#             ggplot.multistats      1.0.0
#                       ggplot2      3.4.0
#                        ggpubr      0.5.0
#                        ggraph      2.1.0
#                       ggrastr      1.0.1
#                       ggrepel      0.9.2
#                      ggridges      0.5.4
#                         ggsci        2.9
#                      ggsignif      0.6.4
#                      ggthemes      4.2.4
#                            gh      1.3.1
#                      gitcreds      0.1.2
#                 GlobalOptions      0.1.2
#                       globals     0.16.2
#                          glue      1.6.2
#                         GO.db     3.16.0
#                       goftest      1.2-3
#                         gower      1.0.1
#                        gplots      3.1.3
#                  graphlayouts      0.8.4
#                     gridExtra        2.3
#                           grr      0.9.5
#                        gtable      0.3.1
#                        gtools      3.9.4
#                       hardhat      1.2.0
#                       harmony      0.1.1
#                         haven      2.5.1
#                     HDF5Array     1.26.0
#                          here      1.0.1
#                        hexbin     1.28.2
#                         highr       0.10
#                           hms      1.1.2
#                     htmltools      0.5.4
#                   htmlwidgets      1.6.1
#                        httpuv      1.6.7
#                          httr      1.4.4
#                      hunspell      3.0.2
#                           ica      1.0-3
#                        igraph      1.3.5
#                           ini      0.3.1
#        interactiveDisplayBase     1.36.0
#                         ipred     0.9-13
#                       IRanges     2.32.0
#                     IRdisplay        1.1
#                      IRkernel      1.3.1
#                         irlba    2.3.5.1
#                       isoband      0.2.7
#                     iterators     1.0.14
#                    JASPAR2020    0.99.10
#                     jquerylib      0.1.4
#                      jsonlite      1.8.4
#                      KEGGREST     1.38.0
#                         knitr       1.41
#                 knn.covertree        1.0
#                      labeling      0.4.2
#                        laeken      0.5.2
#                      lambda.r      1.2.4
#                         later      1.3.0
#                          lava      1.7.1
#                      lazyeval      0.2.2
#                        leiden      0.4.3
#                    leidenbase      0.1.3
#                     lifecycle      1.0.3
#                         limma     3.54.0
#                       listenv      0.9.0
#                          lme4     1.1-31
#                        lmtest     0.9-40
#                        lobstr      1.1.2
#                        locfit    1.5-9.7
#                LoomExperiment     1.16.0
#                          lsei      1.3-0
#                     lubridate      1.9.0
#                        magick      2.7.3
#                      magrittr      2.0.3
#                      maptools      1.1-6
#                  Matrix.utils      0.9.8
#                MatrixGenerics     1.10.0
#                  MatrixModels      0.5-1
#                   matrixStats     0.63.0
#                       memoise      2.0.1
#                       metapod      1.6.0
#                         miloR      1.6.0
#                          mime       0.12
#                        miniUI    0.1.1.1
#                         minqa      1.2.5
#                        mnormt      2.1.1
#                  ModelMetrics    1.2.2.2
#                         MOFA2      1.8.0
#                      monocle3      1.0.0
#                   motifmatchr     1.20.0
#         MouseGastrulationData     1.12.0
#                       munsell      0.5.0
#                         nabor      0.5.0
#                        nloptr      2.0.3
#                        npsurv      0.5-0
#                      numDeriv 2016.8-1.1
#                       openssl      2.1.1
#                      openxlsx    4.2.5.1
#                  org.Mm.eg.db     3.16.0
#                    parallelly     1.33.0
#                     patchwork      1.1.2
#                       pbapply      1.6-0
#                        pbdZMQ      0.3-8
#                      pbkrtest      0.5.1
#                     pbmcapply      1.5.1
#                    pcaMethods     1.90.0
#                      pheatmap     1.0.12
#                        pillar      1.8.1
#                      pkgbuild      1.4.0
#                     pkgconfig      2.0.3
#                       pkgdown      2.0.7
#                       pkgload      1.3.2
#                         plogr      0.2.0
#                        plotly     4.10.1
#                          plyr      1.8.8
#                           png      0.1-8
#                      polyclip     1.10-4
#                       polynom      1.4-1
#                      poweRlaw     0.70.6
#                        pracma      2.4.2
#                        praise      1.0.0
#                        presto      1.0.0
#                   prettyunits      1.1.1
#                     princurve      2.1.6
#                          pROC     1.18.0
#                      processx      3.8.0
#                       prodlim 2019.11.13
#                       profvis      0.3.7
#                      progress      1.2.2
#                     progressr     0.13.0
#                      promises    1.2.0.1
#                         proxy     0.4-27
#                          pryr      0.1.5
#                            ps      1.7.2
#                          pscl      1.5.5
#                         psych      2.2.9
#                         purrr      1.0.1
#                      quantreg       5.94
#                   R.methodsS3      1.8.2
#                          R.oo     1.25.0
#                       R.utils     2.12.2
#                            R6      2.5.1
#                          ragg      1.2.5
#                        ranger     0.14.1
#                          RANN      2.6.1
#                      rappdirs      0.3.3
#                        raster     3.5-21
#                     rcmdcheck      1.4.0
#                  RColorBrewer      1.1-3
#                          Rcpp      1.0.9
#                     RcppAnnoy     0.0.20
#                 RcppArmadillo 0.11.4.2.1
#                     RcppEigen  0.3.3.9.3
#                      RcppHNSW      0.4.1
#                        RcppML      0.3.7
#                  RcppParallel      5.1.6
#                  RcppProgress      0.4.2
#                      RcppRoll      0.3.0
#                      RcppTOML      0.1.7
#                         RCurl   1.98-1.9
#                         readr      2.1.3
#                        readxl      1.4.1
#                       recipes      1.0.4
#                       rematch      1.0.1
#                      rematch2      2.1.2
#                       remotes      2.4.2
#                          repr      1.1.4
#                       reshape      0.8.9
#                      reshape2      1.4.4
#                ResidualMatrix      1.8.0
#                      restfulr     0.0.15
#                    reticulate       1.26
#                         rgeos      0.6-1
#                 rhandsontable      0.3.8
#                         rhdf5     2.42.0
#                  rhdf5filters     1.10.0
#                      Rhdf5lib     1.20.0
#                   RhpcBLASctl 0.21-247.1
#                       Rhtslib      2.0.0
#                           rio     0.5.29
#                         rjson     0.2.21
#                         rlang      1.0.6
#                     rmarkdown       2.19
#                    robustbase     0.95-0
#                          ROCR     1.0-11
#                      roxygen2      7.2.3
#                     rprojroot      2.0.3
#                       rsample      1.1.1
#                     Rsamtools     2.14.0
#                      RSpectra     0.16-1
#                       RSQLite     2.2.20
#                       rstatix      0.7.1
#                    rstudioapi       0.14
#                          rsvd      1.0.5
#                   rtracklayer     1.58.0
#                         Rtsne       0.16
#                     rversions      2.1.2
#                            s2      1.1.4
#                     S4Vectors     0.36.0
#                          sass      0.4.4
#                  ScaledMatrix      1.6.0
#                        scales      1.2.1
#                        scater     1.26.0
#                   scattermore        0.8
#                 scatterplot3d     0.3-42
#                          scds     1.14.0
#                        sceasy      0.0.7
#                         scran     1.26.0
#                   sctransform      0.3.5
#                       scuttle      1.8.0
#                       seqLogo     1.64.0
#                   sessioninfo      1.2.2
#                        Seurat      4.3.0
#                  SeuratObject      4.1.3
#                            sf      1.0-7
#                         shape      1.4.6
#                         shiny      1.7.4
#                   shinythemes      1.2.0
#                        Signac      1.9.0
#                    silicoChIP 0.0.0.9000
#          SingleCellExperiment     1.20.0
#                         sitmo      2.0.2
#                          slam     0.1-50
#                        slider      0.3.0
#                     slingshot      2.6.0
#                      smoother        1.1
#                          snow      0.4-4
#                   sourcetools      0.1.7
#                            sp      1.5-1
#                       SparseM       1.81
#             sparseMatrixStats     1.10.0
#             SpatialExperiment      1.8.0
#                 spatstat.data      3.0-0
#              spatstat.explore      3.0-5
#                 spatstat.geom      3.0-3
#               spatstat.random      3.0-1
#               spatstat.sparse      3.0-0
#                spatstat.utils      3.0-1
#                        spData      2.2.1
#                         spdep      1.2-7
#                      speedglm      0.3-4
#                      spelling        2.2
#                       SQUAREM     2021.1
#                       statmod      1.5.0
#                       stringi     1.7.12
#                       stringr      1.5.0
#          SummarizedExperiment     1.28.0
#                           sys      3.4.1
#                   systemfonts      1.0.4
#                        tensor        1.5
#                         terra     1.5-21
#                      testthat      3.1.6
#                   textshaping      0.3.6
#                     TFBSTools     1.36.0
#                     TFMPvalue      0.0.9
#                        tibble      3.1.8
#                     tidygraph      1.2.3
#                         tidyr      1.2.1
#                    tidyselect      1.2.0
#                    timechange      0.2.0
#                      timeDate   4022.108
#                       tinytex       0.43
#                       tmvnsim      1.0-2
#                      tradeSeq     1.12.0
#               TrajectoryUtils      1.6.0
#                           TTR     0.24.3
#                        tweenr      2.0.2
#                          tzdb      0.3.0
#                         units      0.8-1
#                    urlchecker      1.0.1
#                       usethis      2.1.6
#                          utf8      1.2.2
#                          uuid      1.1-0
#                          uwot     0.1.14
#                           vcd     1.4-10
#                         vctrs      0.5.1
#                           VIM      6.2.2
#                         vipor      0.4.5
#                       viridis      0.6.2
#                   viridisLite      0.4.1
#                         vroom      1.6.0
#                         waldo      0.4.0
#                          warp      0.2.0
#                       whisker      0.4.1
#                         withr      2.5.0
#                            wk      0.7.1
#                          xfun       0.36
#                       xgboost    1.7.4.1
#                           XML  3.99-0.13
#                          xml2      1.3.3
#                         xopen      1.0.0
#                        xtable      1.8-4
#                           xts     0.12.2
#                       XVector     0.38.0
#                          yaml      2.3.6
#                           zip      2.2.2
#                      zlibbioc     1.44.0
#                           zoo     1.8-11

# %%
sessionInfo()
# Out:
# R version 4.2.2 (2022-10-31)
# Platform: x86_64-conda-linux-gnu (64-bit)
# Running under: Rocky Linux 8.10 (Green Obsidian)
#
# Matrix products: default
# BLAS/LAPACK: /rds/project/rds-SDzz0CATGms/users/bt392/miniconda3/envs/env_all/lib/libopenblasp-r0.3.21.so
#
# locale:
#  [1] LC_CTYPE=en_US.UTF-8       LC_NUMERIC=C
#  [3] LC_TIME=en_US.UTF-8        LC_COLLATE=en_US.UTF-8
#  [5] LC_MONETARY=en_US.UTF-8    LC_MESSAGES=en_US.UTF-8
#  [7] LC_PAPER=en_US.UTF-8       LC_NAME=C
#  [9] LC_ADDRESS=C               LC_TELEPHONE=C
# [11] LC_MEASUREMENT=en_US.UTF-8 LC_IDENTIFICATION=C
#
# attached base packages:
# [1] stats     graphics  grDevices utils     datasets  methods   base
#
# loaded via a namespace (and not attached):
#  [1] fansi_1.0.3     crayon_1.5.2    digest_0.6.31   utf8_1.2.2
#  [5] IRdisplay_1.1   repr_1.1.4      lifecycle_1.0.3 jsonlite_1.8.4
#  [9] evaluate_0.19   pillar_1.8.1    rlang_1.0.6     cli_3.6.0
# [13] uuid_1.1-0      vctrs_0.5.1     IRkernel_1.3.1  tools_4.2.2
# [17] glue_1.6.2      fastmap_1.1.0   compiler_4.2.2  base64enc_0.1-3
# [21] pbdZMQ_0.3-8    htmltools_0.5.4
